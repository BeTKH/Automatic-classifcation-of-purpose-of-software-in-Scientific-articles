# %% [markdown]
# # PLoS_methods_bio  split

# %%
import os
import argparse
import time
import random
import shutil

from pathlib import Path
from math import ceil

from somenlp.utils import get_time_marker
from somenlp.feature_engineering import calculate_features_parallel


import os
from os import listdir 
from collections import Counter

import os
from os import listdir 
from collections import Counter


in_path = '/home/beck/Desktop/SoMeNLP/data/PLoS_methods_bio/'
out_path = '/home/beck/Desktop/SoMeNLP/data/PLoS_methods/'

def split_data(in_path, out_path, file_ext =".data.txt", 
               ratio =[60, 20, 20], set_names = ['train', 'devel', 'test']):
    
    in_path = in_path.rstrip('/')
    out_path = out_path.rstrip('/')

    if not os.path.isdir(in_path):
        raise(RuntimeError("Input path does not exist"))
        
    if not os.path.isdir(out_path):
        os.mkdir(out_path)
    
    if sum(ratio) != 100:
        raise(RuntimeError("Input ratio {} does not sum to 100".format(ratio)))
    if len(ratio) != len(set_names):
        raise(RuntimeError("Number of ratios and setnames has to match: {} vs {}".format(ratio, set_names)))

    #print("Loading files")
    single_files = list(Path(in_path).rglob('*{}'.format(file_ext)))
    
    all_files = []
    for entry in single_files:
        
        base_file_name = entry.name.split(file_ext)[0]
        
        base_file_entries = list(Path(in_path).rglob('{}*'.format(base_file_name)))
        
        all_files.append(base_file_entries)
    
    
    
    random.seed()
    random.shuffle(all_files)

    #print("Copying files")
    cut_sum = 0
    prev_cut_idx = 0
    for cut, name in zip(ratio, set_names):
        cut_sum += cut
        cut_idx = ceil(len(all_files) * cut_sum / 100) 
        
        out_folder_name = in_path.rsplit('/')[-1]
        new_output_location = '{}/{}_{}'.format(out_path.rstrip('/'), out_folder_name, name) 
        
        if not os.path.isdir(new_output_location):
            os.makedirs(new_output_location)
            
        for files in all_files[prev_cut_idx:cut_idx]:
            for f in files:
                source_path = str(f)
                target_path = '{}/{}'.format(new_output_location, f.name)
                shutil.copy(source_path, target_path)
        prev_cut_idx = cut_idx
    
    print("Done")
    

def purposeLabel_counter(path):
    
    import os
    from os import listdir 
    from collections import Counter
    
    
    def list_file_names(path, file_ext='.labels.txt'):
    
        file_names_list = []

        for file_name in os.listdir(path):
            if not file_name.endswith(file_ext): continue
            file_names_list.append(file_name) 

        file_names_list.sort()

        return file_names_list
    
    file_name_list = list_file_names(path)
    
    interest_list = ["Analysis", "Modelling", "Stimulation", "DataCollection", "DataPreProcss", 
                 "Simulation", "Visualization", "Programming"]
    
    all_purpose_labels = []
    
    for file_name in file_name_list[:]:
        file_path = path + file_name
        
        with open(file_path, 'r') as f:
            
            list_lines = f.readlines()
            
            #print(list_of_lebs)
            list_of_tokens = ' '.join(list_lines).split()
            
            for tok in list_of_tokens:
                if tok != 'O' and (len(tok.split('-')[1].split('_')) == 3 ):
                    if tok.split('-')[1].split('_')[2] in interest_list:
                        
                        purpose = tok.split('-')[1].split('_')[2]
                        
                        all_purpose_labels.append(purpose)
    
                        
    return  dict(Counter(all_purpose_labels))

def train_test_dev(whole_path, train_path, test_path, dev_path):
    
    _whole = purposeLabel_counter(whole_path)
    _train = purposeLabel_counter(train_path)
    _test  = purposeLabel_counter(test_path)
    _dev   = purposeLabel_counter(dev_path)
    
    
    
    _whole_sorted = dict(sorted(_whole.items()))
    _train_sorted = dict(sorted(_train.items()))
    _test_sorted  = dict(sorted(_test.items()))
    _dev_sorted   = dict(sorted(_dev.items()))
    
    return _whole_sorted, _train_sorted, _test_sorted, _dev_sorted

def __proportion_calculator_with_key(whole_dict, train_dict, test_dict, dev_dict ):
    
    train_purpose_props = []
    for (k,v), (k2,v2) in zip(whole_dict.items(), train_dict.items()):
        if k2 == k: 
            train_percentage = int(v2 / v * 100)
            train_purpose_props.append((train_percentage, k))
            
    dev_purpose_props = []
    for (k,v), (k2,v2) in zip(whole_dict.items(), dev_dict.items()):
        if k2 == k:
            
            dev_percentage = int(v2 / v * 100)
            dev_purpose_props.append((dev_percentage,k))
            
    test_purpose_props = []       
    for (k,v), (k2,v2) in zip(whole_dict.items(), test_dict.items()):
        if k2 == k:
            
            test_percentage = int(v2 / v * 100)
            test_purpose_props.append((test_percentage, k))
            
    return train_purpose_props, dev_purpose_props, test_purpose_props


def __proportion_calculator(whole_dict, train_dict, test_dict, dev_dict ):
    
    train_purpose_props = []
    for (k,v), (k2,v2) in zip(whole_dict.items(), train_dict.items()):
        if k2 == k: 
            train_percentage = int(v2 / v * 100)
            train_purpose_props.append(train_percentage)
            
    dev_purpose_props = []
    for (k,v), (k2,v2) in zip(whole_dict.items(), dev_dict.items()):
        if k2 == k:
            
            dev_percentage = int(v2 / v * 100)
            dev_purpose_props.append(dev_percentage)
            
    test_purpose_props = []       
    for (k,v), (k2,v2) in zip(whole_dict.items(), test_dict.items()):
        if k2 == k:
            
            test_percentage = int(v2 / v * 100)
            test_purpose_props.append(test_percentage)
            
    return train_purpose_props, dev_purpose_props, test_purpose_props



def _within_range(list_):
    
    bool_list = []
    for val in list_:
        if val in range(54,65):
            bool_list.append(True)
        else:
            bool_list.append(False)
            
    return all(bool_list)   # apply & to all and return


def _within_range_pubmed(list_):
    
    bool_list = []
    for val in list_:
        if val in range(50,70):
            bool_list.append(True)
        else:
            bool_list.append(False)
            
            
    withn_range_bool = all(bool_list) # apply & to all and return
    
    # check if all class labels are included , class label stimulation is missing in the PubMed 
    if (len(bool_list) == 7):
        all_classes_included = True
    else:
        all_classes_included = False
        
    result = all_classes_included and withn_range_bool
            
    return result   


def _within_range_dev_test(list_):
    
    bool_list = []
    for val in list_:
        if val in range(15,25):
            bool_list.append(True)
        else:
            bool_list.append(False)
            
    return all(bool_list)   # apply & to all and return


def _is_dev_set_NOT_proportional(whole, dev):
    
    is_not_proportional = False
    
    for (k,v), (k2,v2) in zip(whole.items(), dev.items()):
        if k2 == k: 
            dev_percentage = v2 / v * 100
            
            if dev_percentage < 15: 
                print(f"Dev data split is {round(dev_percentage,2)} below -5%, for purpose {k2} splitting again")
                
                is_not_proportional = True
                return is_not_proportional
                
            elif dev_percentage > 25:
                print(f"Dev data splt is {round(dev_percentage,2)}% over +5 %, for purpose {k2} splitting again")
                
                is_not_proportional = True
                return is_not_proportional
            
            elif (dev_percentage >= 15) and (dev_percentage <= 25):
               
                #print(f"Dev data split is {round(dev_percentage, 2)}% and within  +/- 5%, for purpose {k2}")
                pass
    return is_not_proportional

def _is_train_set_NOT_proportional(whole, train):
    
    is_not_proportional = False
    
    for (k,v), (k2,v2) in zip(whole.items(), train.items()):
        if k2 == k: 
            train_percentage = v2 / v * 100
            
            if train_percentage < 55: 
                
                print(f"Train data split is {round(train_percentage, 2)}% below -5%, for purpose {k2} splitting again")
                
                is_not_proportional = True
                return is_not_proportional
                
            elif train_percentage > 65:
                print(f"Train data split is {round(train_percentage, 2)}% over +5 %, for {k2} purpose splitting again")
                
                is_not_proportional = True
                return is_not_proportional
                
            else:
                #print(f"Train data split is {int(train_percentage)}% and within +/-5 % for purpose {k2}")
                pass 
            
    return is_not_proportional

# %%
#split_data(in_path, out_path)

# plos methods bio   train , test , dev

#path_whole = '/home/beck/Desktop/SoMeNLP/data/PLoS_methods_bio/'
#path_train = "/home/beck/Desktop/SoMeNLP/data/PLoS_methods/PLoS_methods_bio_train/" 
#path_test = "/home/beck/Desktop/SoMeNLP/data/PLoS_methods/PLoS_methods_bio_test/" 
#path_dev = "/home/beck/Desktop/SoMeNLP/data/PLoS_methods/PLoS_methods_bio_devel/"
    
    
#calculate the new distribution 
#whole_dict, train_dict, test_dict, dev_dict = train_test_dev(path_whole, path_train, path_test, path_dev)


# calculate the new proportion
#train_props, dev_props, test_props = __proportion_calculator(whole_dict, train_dict, test_dict, dev_dict)

#split_result = _within_range(train_props)

#i = 0

#while not(_within_range(train_props)):
    
#    print(f'splitting ... loop {i}')
    
#    split_data(in_path, out_path)
    
#    i += 1
    
    
    #calculate the new distribution 
#    whole_dict, train_dict, test_dict, dev_dict = train_test_dev(path_whole, path_train, path_test, path_dev)
    
    
    # calculate the new proportion
#    train_props, dev_props, test_props = __proportion_calculator(whole_dict, train_dict, test_dict, dev_dict)
    
#    split_result = _within_range(train_props)
    
#    print('is the split fair ?')
    
#    if split_result:
        
#        print('split is balanced. stopped splitting')
        
#    else:
        
#        shutil.rmtree(path_train, ignore_errors=False, onerror=None)
#        shutil.rmtree(path_test, ignore_errors=False, onerror=None)
#        shutil.rmtree(path_dev, ignore_errors=False, onerror=None)
        
#        print(f'split is not yet balanced {train_props}.  splitting further ...')
#        print()
        
        
    
    #break

# %%
# plos methods bio   train , test , dev

path_whole = "/home/beck/Desktop/SoMeNLP/data/PLoS_methods_bio/"
path_train = "/home/beck/Desktop/SoMeNLP/data/PLoS_methods/PLoS_methods_bio_train/" 
path_test = "/home/beck/Desktop/SoMeNLP/data/PLoS_methods/PLoS_methods_bio_test/" 
path_dev = "/home/beck/Desktop/SoMeNLP/data/PLoS_methods/PLoS_methods_bio_devel/"
    
    
#calculate the new distribution 
whole_dict, train_dict, test_dict, dev_dict = train_test_dev(path_whole, path_train, path_test, path_dev)


# calculate the new proportion
train_props, dev_props, test_props = __proportion_calculator(whole_dict, train_dict, test_dict, dev_dict)

# %%
print(f'train {train_props}')
print(f'test {test_props}')
print(f'dev {dev_props}')

print()

print(f"train balanced ? {_within_range(train_props)}")
print(f"test  balanced ? {_within_range(test_props)}")
print(f"dev   balanced ? {_within_range(dev_props)}")


# train percentage 60%
print()    
for (k,v), (k2,v2) in zip(whole_dict.items(), train_dict.items()):
    if k2 == k:
        print(f"{k2 :{18}}  {v2}/{v} train {v2/v*100: .2f}% ")
# Out:
# train [58, 58, 62, 58, 54, 62, 59, 57]
# test [20, 20, 21, 26, 29, 8, 23, 19]
# dev [21, 20, 16, 15, 15, 29, 16, 23]
#
# train balanced ? True
# test  balanced ? False
# dev   balanced ? False
#
# Analysis            654/1127 train  58.03%
# DataCollection      114/196 train  58.16%
# DataPreProcss       162/261 train  62.07%
# Modelling           118/203 train  58.13%
# Programming         35/64 train  54.69%
# Simulation          15/24 train  62.50%
# Stimulation         42/71 train  59.15%
# Visualization       51/89 train  57.30%

# %% [markdown]
# # Pubmed_fulltext_bio

# %%
in_path_pubmed = '/home/beck/Desktop/SoMeNLP/data/Pubmed_fulltext_bio/'
out_path_pubmed = '/home/beck/Desktop/SoMeNLP/data/Pubmed_fulltext/'

split_data(in_path_pubmed, out_path_pubmed)
# Out:
# Done

# %%
in_path_pubmed = '/home/beck/Desktop/SoMeNLP/data/Pubmed_fulltext_bio/'
out_path_pubmed = '/home/beck/Desktop/SoMeNLP/data/Pubmed_fulltext/'

split_data(in_path_pubmed, out_path_pubmed)

# pubmed bio   train , test , dev

pubmed_path_whole = '/home/beck/Desktop/SoMeNLP/data/Pubmed_fulltext_bio/'
pubmed_path_train = "/home/beck/Desktop/SoMeNLP/data/Pubmed_fulltext/Pubmed_fulltext_bio_train/" 
pubmed_path_test = "/home/beck/Desktop/SoMeNLP/data/Pubmed_fulltext/Pubmed_fulltext_bio_test/" 
pubmed_path_dev = "/home/beck/Desktop/SoMeNLP/data/Pubmed_fulltext/Pubmed_fulltext_bio_devel/"
    
    
#calculate the distribution of class_labels for pubmed
pubmed_whole_dict, pubmed_train_dict, pubmed_test_dict, pubmed_dev_dict = train_test_dev(pubmed_path_whole, 
                                                                                         pubmed_path_train, 
                                                                                         pubmed_path_test, 
                                                                                         pubmed_path_dev)


# calculate the proportion for each class label (8 - purposes)
pubmed_train_props, pubmed_dev_props, pubmed_test_props = __proportion_calculator(pubmed_whole_dict, 
                                                                                  pubmed_train_dict, 
                                                                                  pubmed_test_dict, 
                                                                                  pubmed_dev_dict)

pubmed_train_split_result_ = _within_range_pubmed(pubmed_train_props)
pubmed_test_split_result_ = _within_range_pubmed(pubmed_test_props)
pubmed_dev_split_result_ = _within_range_pubmed(pubmed_dev_props)

#bool_ = (pubmed_train_split_result_) and (pubmed_test_split_result_) and (pubmed_dev_split_result_)

i = 0

while not(pubmed_train_split_result_):
    
    print(f'splitting ... loop {i}')
    
    split_data(in_path_pubmed, out_path_pubmed)
    
    i += 1
    
    
    #calculate the new distribution 
    pubmed_whole_dict, pubmed_train_dict, pubmed_test_dict, pubmed_dev_dict = train_test_dev(pubmed_path_whole, 
                                                                                             pubmed_path_train, 
                                                                                             pubmed_path_test, 
                                                                                             pubmed_path_dev)
    
    
    # calculate the new proportion
    pubmed_train_props, pubmed_dev_props, pubmed_test_props = __proportion_calculator(pubmed_whole_dict, 
                                                                                      pubmed_train_dict, 
                                                                                      pubmed_test_dict, 
                                                                                      pubmed_dev_dict)
    #print('is the split fair ?')
    pubmed_split_result = _within_range(pubmed_train_props)
    
    
    
    if pubmed_split_result:
        
        print('pubmed split is balanced. stopped splitting')
        
    else:
        
        shutil.rmtree(pubmed_path_train, ignore_errors=False, onerror=None)
        shutil.rmtree(pubmed_path_test, ignore_errors=False, onerror=None)
        shutil.rmtree(pubmed_path_dev, ignore_errors=False, onerror=None)
        
        print(f'pubmed split is not yet balanced {pubmed_train_props}.  splitting further ...')
        print()
        
        
    
    #break
# Out:
# Done
# splitting ... loop 0
# Done
# pubmed split is not yet balanced [93, 78, 91, 91, 100, 100, 85].  splitting further ...
#
# splitting ... loop 1
# Done
# pubmed split is not yet balanced [41, 34, 52, 41, 6, 100, 82].  splitting further ...
#
# splitting ... loop 2
# Done
# pubmed split is not yet balanced [63, 57, 68, 37, 6, 25, 46].  splitting further ...
#
# splitting ... loop 3
# Done
# pubmed split is not yet balanced [45, 50, 39, 54].  splitting further ...
#
# splitting ... loop 4
# Done
# pubmed split is not yet balanced [61, 64, 47, 29, 93, 50, 53].  splitting further ...
#
# splitting ... loop 5
# Done
# pubmed split is not yet balanced [57, 76, 64, 79, 6, 75, 53].  splitting further ...
#
# splitting ... loop 6
# Done
# pubmed split is not yet balanced [51, 68, 52, 41, 6, 25, 53].  splitting further ...
#
# splitting ... loop 7
# Done
# pubmed split is not yet balanced [67, 76, 77, 58, 93, 75, 75].  splitting further ...
#
# splitting ... loop 8
# Done
# pubmed split is not yet balanced [69, 76, 74, 79].  splitting further ...
#
# splitting ... loop 9
# Done
# pubmed split is not yet balanced [55, 72, 60, 37, 87, 50, 75].  splitting further ...
#
# splitting ... loop 10
# Done
# pubmed split is not yet balanced [71, 60, 62, 83, 12, 75, 60].  splitting further ...
#
# splitting ... loop 11
# Done
# pubmed split is not yet balanced [51, 60, 44, 54, 12, 50, 42].  splitting further ...
#
# splitting ... loop 12
# Done
# pubmed split is not yet balanced [64, 78, 70, 83, 100, 75, 71].  splitting further ...
#
# splitting ... loop 13
# Done
# pubmed split is not yet balanced [64, 60, 68, 75, 93, 75, 64].  splitting further ...
#
# splitting ... loop 14
# Done
# pubmed split is not yet balanced [61, 66, 70, 50, 6, 25, 67].  splitting further ...
#
# splitting ... loop 15
# Done
# pubmed split is not yet balanced [62, 56, 68, 75].  splitting further ...
#
# splitting ... loop 16
# Done
# pubmed split is not yet balanced [70, 60, 77, 66, 100, 75, 75].  splitting further ...
#
# splitting ... loop 17
# Done
# pubmed split is not yet balanced [69, 57, 67, 87, 93, 50, 60].  splitting further ...
#
# splitting ... loop 18
# Done
# pubmed split is not yet balanced [59, 52, 62, 62, 100, 75, 50].  splitting further ...
#
# splitting ... loop 19
# Done
# pubmed split is not yet balanced [60, 57, 54, 83, 93, 75, 64].  splitting further ...
#
# splitting ... loop 20
# Done
# pubmed split is not yet balanced [44, 62, 41, 54, 6, 50, 28].  splitting further ...
#
# splitting ... loop 21
# Done
# pubmed split is not yet balanced [67, 78, 67, 75, 93, 50, 39].  splitting further ...
#
# splitting ... loop 22
# Done
# pubmed split is not yet balanced [44, 80, 47, 50, 12, 100, 71].  splitting further ...
#
# splitting ... loop 23
# Done
# pubmed split is not yet balanced [68, 66, 68, 54, 100, 50, 42].  splitting further ...
#
# splitting ... loop 24
# Done
# pubmed split is not yet balanced [73, 96, 90, 79, 6, 100, 89].  splitting further ...
#
# splitting ... loop 25
# Done
# pubmed split is not yet balanced [57, 80, 77, 45, 93, 100, 71].  splitting further ...
#
# splitting ... loop 26
# Done
# pubmed split is not yet balanced [55, 72, 72, 79].  splitting further ...
#
# splitting ... loop 27
# Done
# pubmed split is not yet balanced [58, 62, 52, 41, 93, 75, 71].  splitting further ...
#
# splitting ... loop 28
# Done
# pubmed split is not yet balanced [68, 57, 77, 79, 12, 25, 64].  splitting further ...
#
# splitting ... loop 29
# Done
# pubmed split is not yet balanced [70, 82, 77, 62, 100, 100, 89].  splitting further ...
#
# splitting ... loop 30
# Done
# pubmed split is not yet balanced [67, 72, 51, 58, 100, 75, 67].  splitting further ...
#
# splitting ... loop 31
# Done
# pubmed split is not yet balanced [62, 50, 62, 50, 6, 50, 25].  splitting further ...
#
# splitting ... loop 32
# Done
# pubmed split is not yet balanced [54, 64, 44, 54, 93].  splitting further ...
#
# splitting ... loop 33
# Done
# pubmed split is not yet balanced [77, 90, 81, 91, 100, 75, 85].  splitting further ...
#
# splitting ... loop 34
# Done
# pubmed split is not yet balanced [49, 48, 36, 41, 93, 50, 53].  splitting further ...
#
# splitting ... loop 35
# Done
# pubmed split is not yet balanced [52, 40, 31, 29, 6, 50, 32].  splitting further ...
#
# splitting ... loop 36
# Done
# pubmed split is not yet balanced [70, 60, 70, 91, 6, 25, 50].  splitting further ...
#
# splitting ... loop 37
# Done
# pubmed split is not yet balanced [50, 38, 59, 41, 6, 50, 32].  splitting further ...
#
# splitting ... loop 38
# Done
# pubmed split is not yet balanced [62, 64, 68, 70, 93, 100, 78].  splitting further ...
#
# splitting ... loop 39
# Done
# pubmed split is not yet balanced [47, 70, 48, 45, 93, 25, 53].  splitting further ...
#
# splitting ... loop 40
# Done
# pubmed split is not yet balanced [78, 76, 77, 95, 6, 100, 82].  splitting further ...
#
# splitting ... loop 41
# Done
# pubmed split is not yet balanced [55, 82, 58, 29, 100, 50, 57].  splitting further ...
#
# splitting ... loop 42
# Done
# pubmed split is not yet balanced [50, 62, 40, 25, 87].  splitting further ...
#
# splitting ... loop 43
# Done
# pubmed split is not yet balanced [67, 70, 68, 45, 93, 50, 67].  splitting further ...
#
# splitting ... loop 44
# Done
# pubmed split is not yet balanced [52, 76, 44, 37, 93, 50, 75].  splitting further ...
#
# splitting ... loop 45
# Done
# pubmed split is not yet balanced [58, 90, 82, 79, 6, 75, 64].  splitting further ...
#
# splitting ... loop 46
# Done
# pubmed split is not yet balanced [55, 54, 39, 54, 93, 50, 35].  splitting further ...
#
# splitting ... loop 47
# Done
# pubmed split is not yet balanced [49, 70, 71, 41, 12, 100, 60].  splitting further ...
#
# splitting ... loop 48
# Done
# pubmed split is not yet balanced [60, 72, 60, 50, 93, 100, 89].  splitting further ...
#
# splitting ... loop 49
# Done
# pubmed split is not yet balanced [48, 78, 56, 25, 12, 100, 89].  splitting further ...
#
# splitting ... loop 50
# Done
# pubmed split is not yet balanced [54, 50, 36, 50, 87, 25, 32].  splitting further ...
#
# splitting ... loop 51
# Done
# pubmed split is not yet balanced [65, 40, 70, 87, 6, 75, 64].  splitting further ...
#
# splitting ... loop 52
# Done
# pubmed split is not yet balanced [54, 66, 51, 58, 12, 75, 85].  splitting further ...
#
# splitting ... loop 53
# Done
# pubmed split is not yet balanced [60, 72, 60, 83, 93, 25, 39].  splitting further ...
#
# splitting ... loop 54
# Done
# pubmed split is not yet balanced [52, 46, 43, 12, 87, 25, 39].  splitting further ...
#
# splitting ... loop 55
# Done
# pubmed split is not yet balanced [70, 76, 79, 62, 93, 75, 82].  splitting further ...
#
# splitting ... loop 56
# Done
# pubmed split is not yet balanced [58, 56, 54, 83].  splitting further ...
#
# splitting ... loop 57
# Done
# pubmed split is not yet balanced [66, 56, 75, 75, 93, 50, 57].  splitting further ...
#
# splitting ... loop 58
# Done
# pubmed split is not yet balanced [61, 74, 71, 87, 6, 25, 28].  splitting further ...
#
# splitting ... loop 59
# Done
# pubmed split is not yet balanced [44, 66, 39, 45, 93, 50, 67].  splitting further ...
#
# splitting ... loop 60
# Done
# pubmed split is not yet balanced [54, 57, 67, 58].  splitting further ...
#
# splitting ... loop 61
# Done
# pubmed split is not yet balanced [69, 57, 63, 87, 100, 25, 39].  splitting further ...
#
# splitting ... loop 62
# Done
# pubmed split is not yet balanced [62, 78, 72, 58, 93, 25, 53].  splitting further ...
#
# splitting ... loop 63
# Done
# pubmed split is not yet balanced [63, 42, 68, 79, 12, 50, 53].  splitting further ...
#
# splitting ... loop 64
# Done
# pubmed split is not yet balanced [63, 36, 56, 41, 87, 75, 60].  splitting further ...
#
# splitting ... loop 65
# Done
# pubmed split is not yet balanced [59, 72, 72, 58, 100, 25, 46].  splitting further ...
#
# splitting ... loop 66
# Done
# pubmed split is not yet balanced [61, 32, 48, 66, 12, 50, 39].  splitting further ...
#
# splitting ... loop 67
# Done
# pubmed split is not yet balanced [54, 70, 67, 58, 93, 50, 53].  splitting further ...
#
# splitting ... loop 68
# Done
# pubmed split is not yet balanced [53, 56, 50, 66, 87, 75, 64].  splitting further ...
#
# splitting ... loop 69
# Done
# pubmed split is not yet balanced [69, 72, 62, 75, 12, 25, 60].  splitting further ...
#
# splitting ... loop 70
# Done
# pubmed split is not yet balanced [53, 44, 55, 50, 100, 75, 82].  splitting further ...
#
# splitting ... loop 71
# Done
# pubmed split is not yet balanced [42, 56, 51, 29, 93, 75, 39].  splitting further ...
#
# splitting ... loop 72
# Done
# pubmed split is not yet balanced [57, 66, 60, 54, 87, 75, 67].  splitting further ...
#
# splitting ... loop 73
# Done
# pubmed split is not yet balanced [52, 56, 58, 33, 100, 75, 78].  splitting further ...
#
# splitting ... loop 74
# Done
# pubmed split is not yet balanced [63, 76, 68, 70, 93, 25, 42].  splitting further ...
#
# splitting ... loop 75
# Done
# pubmed split is not yet balanced [59, 40, 63, 87, 6, 100, 67].  splitting further ...
#
# splitting ... loop 76
# Done
# pubmed split is not yet balanced [54, 30, 48, 70, 93, 25, 39].  splitting further ...
#
# splitting ... loop 77
# Done
# pubmed split is not yet balanced [38, 56, 44, 29, 12, 75, 60].  splitting further ...
#
# splitting ... loop 78
# Done
# pubmed split is not yet balanced [66, 30, 60, 58, 12, 100, 67].  splitting further ...
#
# splitting ... loop 79
# Done
# pubmed split is not yet balanced [61, 72, 55, 83, 93, 25, 57].  splitting further ...
#
# splitting ... loop 80
# Done
# pubmed split is not yet balanced [47, 32, 48, 54, 6, 75, 53].  splitting further ...
#
# splitting ... loop 81
# Done
# pubmed split is not yet balanced [46, 38, 43, 33, 93, 75, 50].  splitting further ...
#
# splitting ... loop 82
# Done
# pubmed split is not yet balanced [64, 78, 70, 58, 93, 75, 71].  splitting further ...
#
# splitting ... loop 83
# Done
# pubmed split is not yet balanced [48, 72, 44, 50, 87, 50, 46].  splitting further ...
#
# splitting ... loop 84
# Done
# pubmed split is not yet balanced [51, 57, 50, 41, 93, 75, 50].  splitting further ...
#
# splitting ... loop 85
# Done
# pubmed split is not yet balanced [49, 57, 50, 16, 100, 75, 92].  splitting further ...
#
# splitting ... loop 86
# Done
# pubmed split is not yet balanced [70, 62, 75, 83, 100, 50, 67].  splitting further ...
#
# splitting ... loop 87
# Done
# pubmed split is not yet balanced [52, 68, 67, 79, 6, 100, 60].  splitting further ...
#
# splitting ... loop 88
# Done
# pubmed split is not yet balanced [66, 76, 64, 91, 93, 50, 60].  splitting further ...
#
# splitting ... loop 89
# Done
# pubmed split is not yet balanced [65, 66, 67, 95, 87, 75, 60].  splitting further ...
#
# splitting ... loop 90
# Done
# pubmed split is not yet balanced [64, 78, 71, 91, 12, 100, 67].  splitting further ...
#
# splitting ... loop 91
# Done
# pubmed split is not yet balanced [62, 84, 78, 66, 100, 100, 78].  splitting further ...
#
# splitting ... loop 92
# Done
# pubmed split is not yet balanced [67, 60, 71, 91, 100, 75, 78].  splitting further ...
#
# splitting ... loop 93
# Done
# pubmed split is not yet balanced [61, 36, 67, 66, 6, 25, 39].  splitting further ...
#
# splitting ... loop 94
# Done
# pubmed split is not yet balanced [62, 42, 59, 83, 87, 50, 28].  splitting further ...
#
# splitting ... loop 95
# Done
# pubmed split is not yet balanced [57, 57, 66, 79].  splitting further ...
#
# splitting ... loop 96
# Done
# pubmed split is not yet balanced [53, 56, 71, 62, 12, 75, 78].  splitting further ...
#
# splitting ... loop 97
# Done
# pubmed split is not yet balanced [47, 40, 52, 37, 87, 25, 53].  splitting further ...
#
# splitting ... loop 98
# Done
# pubmed split is not yet balanced [65, 84, 56, 62, 100, 75, 85].  splitting further ...
#
# splitting ... loop 99
# Done
# pubmed split is not yet balanced [65, 50, 66, 75, 6, 50, 46].  splitting further ...
#
# splitting ... loop 100
# Done
# pubmed split is not yet balanced [66, 70, 66, 45, 93, 25, 53].  splitting further ...
#
# splitting ... loop 101
# Done
# pubmed split is not yet balanced [62, 54, 45, 29, 100, 75, 64].  splitting further ...
#
# splitting ... loop 102
# Done
# pubmed split is not yet balanced [64, 64, 52, 41, 100, 100, 78].  splitting further ...
#
# splitting ... loop 103
# Done
# pubmed split is not yet balanced [68, 66, 77, 75, 12, 100, 67].  splitting further ...
#
# splitting ... loop 104
# Done
# pubmed split is not yet balanced [46, 54, 47, 29, 6, 75, 57].  splitting further ...
#
# splitting ... loop 105
# Done
# pubmed split is not yet balanced [63, 82, 68, 75, 6, 75, 53].  splitting further ...
#
# splitting ... loop 106
# Done
# pubmed split is not yet balanced [47, 54, 41, 66, 87, 50, 42].  splitting further ...
#
# splitting ... loop 107
# Done
# pubmed split is not yet balanced [63, 72, 71, 58, 93, 50, 53].  splitting further ...
#
# splitting ... loop 108
# Done
# pubmed split is not yet balanced [72, 48, 60, 91, 100, 75, 50].  splitting further ...
#
# splitting ... loop 109
# Done
# pubmed split is not yet balanced [68, 36, 64, 41, 100, 50, 53].  splitting further ...
#
# splitting ... loop 110
# Done
# pubmed split is not yet balanced [65, 44, 47, 54, 6, 50, 39].  splitting further ...
#
# splitting ... loop 111
# Done
# pubmed split is not yet balanced [70, 66, 75, 75, 93, 75, 82].  splitting further ...
#
# splitting ... loop 112
# Done
# pubmed split is not yet balanced [70, 86, 74, 70, 6, 100, 82].  splitting further ...
#
# splitting ... loop 113
# Done
# pubmed split is not yet balanced [67, 50, 68, 66].  splitting further ...
#
# splitting ... loop 114
# Done
# pubmed split is not yet balanced [70, 56, 62, 33, 100, 75, 78].  splitting further ...
#
# splitting ... loop 115
# Done
# pubmed split is not yet balanced [53, 42, 43, 62, 100, 75, 75].  splitting further ...
#
# splitting ... loop 116
# Done
# pubmed split is not yet balanced [63, 66, 71, 54].  splitting further ...
#
# splitting ... loop 117
# Done
# pubmed split is not yet balanced [66, 54, 54, 87, 93, 50, 57].  splitting further ...
#
# splitting ... loop 118
# Done
# pubmed split is not yet balanced [59, 50, 54, 50, 93, 50, 46].  splitting further ...
#
# splitting ... loop 119
# Done
# pubmed split is not yet balanced [78, 62, 74, 91, 12, 75, 82].  splitting further ...
#
# splitting ... loop 120
# Done
# pubmed split is not yet balanced [69, 72, 63, 62, 93, 50, 75].  splitting further ...
#
# splitting ... loop 121
# Done
# pubmed split is not yet balanced [68, 82, 63, 83, 93, 75, 64].  splitting further ...
#
# splitting ... loop 122
# Done
# pubmed split is not yet balanced [56, 38, 35, 58, 100, 75, 64].  splitting further ...
#
# splitting ... loop 123
# Done
# pubmed split is not yet balanced [73, 62, 79, 87, 100, 75, 71].  splitting further ...
#
# splitting ... loop 124
# Done
# pubmed split is not yet balanced [63, 74, 54, 75].  splitting further ...
#
# splitting ... loop 125
# Done
# pubmed split is not yet balanced [66, 57, 62, 62, 100, 100, 75].  splitting further ...
#
# splitting ... loop 126
# Done
# pubmed split is not yet balanced [66, 57, 71, 79, 12, 100, 71].  splitting further ...
#
# splitting ... loop 127
# Done
# pubmed split is not yet balanced [72, 60, 64, 70, 100, 25, 42].  splitting further ...
#
# splitting ... loop 128
# Done
# pubmed split is not yet balanced [59, 38, 62, 54, 87, 75, 50].  splitting further ...
#
# splitting ... loop 129
# Done
# pubmed split is not yet balanced [67, 52, 59, 79, 6].  splitting further ...
#
# splitting ... loop 130
# Done
# pubmed split is not yet balanced [68, 74, 60, 37, 100, 100, 92].  splitting further ...
#
# splitting ... loop 131
# Done
# pubmed split is not yet balanced [59, 70, 67, 70, 100, 50, 42].  splitting further ...
#
# splitting ... loop 132
# Done
# pubmed split is not yet balanced [43, 56, 54, 45, 6, 75, 64].  splitting further ...
#
# splitting ... loop 133
# Done
# pubmed split is not yet balanced [73, 68, 70, 66, 100, 50, 64].  splitting further ...
#
# splitting ... loop 134
# Done
# pubmed split is not yet balanced [63, 57, 67, 79, 12, 50, 60].  splitting further ...
#
# splitting ... loop 135
# Done
# pubmed split is not yet balanced [55, 56, 45, 62, 12, 75, 50].  splitting further ...
#
# splitting ... loop 136
# Done
# pubmed split is not yet balanced [58, 68, 48, 37, 100, 50, 67].  splitting further ...
#
# splitting ... loop 137
# Done
# pubmed split is not yet balanced [51, 70, 60, 50, 12, 75, 71].  splitting further ...
#
# splitting ... loop 138
# Done
# pubmed split is not yet balanced [57, 48, 56, 83, 87, 25, 53].  splitting further ...
#
# splitting ... loop 139
# Done
# pubmed split is not yet balanced [56, 22, 32, 50, 12, 50, 28].  splitting further ...
#
# splitting ... loop 140
# Done
# pubmed split is not yet balanced [49, 46, 55, 66, 87, 75, 35].  splitting further ...
#
# splitting ... loop 141
# Done
# pubmed split is not yet balanced [67, 70, 68, 37, 100, 75, 57].  splitting further ...
#
# splitting ... loop 142
# Done
# pubmed split is not yet balanced [65, 76, 62, 29, 100, 75, 67].  splitting further ...
#
# splitting ... loop 143
# Done
# pubmed split is not yet balanced [62, 62, 56, 75, 6, 50, 67].  splitting further ...
#
# splitting ... loop 144
# Done
# pubmed split is not yet balanced [64, 46, 60, 45, 87, 75, 50].  splitting further ...
#
# splitting ... loop 145
# Done
# pubmed split is not yet balanced [57, 40, 56, 91, 93, 75, 42].  splitting further ...
#
# splitting ... loop 146
# Done
# pubmed split is not yet balanced [63, 57, 71, 66, 6].  splitting further ...
#
# splitting ... loop 147
# Done
# pubmed split is not yet balanced [50, 66, 77, 41, 87, 25, 60].  splitting further ...
#
# splitting ... loop 148
# Done
# pubmed split is not yet balanced [55, 70, 72, 75].  splitting further ...
#
# splitting ... loop 149
# Done
# pubmed split is not yet balanced [54, 40, 41, 58, 6, 25, 53].  splitting further ...
#
# splitting ... loop 150
# Done
# pubmed split is not yet balanced [67, 62, 81, 70, 12, 75, 92].  splitting further ...
#
# splitting ... loop 151
# Done
# pubmed split is not yet balanced [57, 80, 60, 54, 100, 75, 78].  splitting further ...
#
# splitting ... loop 152
# Done
# pubmed split is not yet balanced [63, 62, 62, 62, 93, 100, 60].  splitting further ...
#
# splitting ... loop 153
# Done
# pubmed split is not yet balanced [73, 78, 75, 79, 93, 75, 78].  splitting further ...
#
# splitting ... loop 154
# Done
# pubmed split is not yet balanced [60, 22, 44, 58, 93, 75, 64].  splitting further ...
#
# splitting ... loop 155
# Done
# pubmed split is not yet balanced [56, 70, 56, 58].  splitting further ...
#
# splitting ... loop 156
# Done
# pubmed split is not yet balanced [71, 66, 82, 70, 100, 100, 75].  splitting further ...
#
# splitting ... loop 157
# Done
# pubmed split is not yet balanced [62, 54, 72, 79, 87, 50, 64].  splitting further ...
#
# splitting ... loop 158
# Done
# pubmed split is not yet balanced [75, 64, 68, 87, 12, 75, 100].  splitting further ...
#
# splitting ... loop 159
# Done
# pubmed split is not yet balanced [48, 80, 55, 33, 100, 75, 57].  splitting further ...
#
# splitting ... loop 160
# Done
# pubmed split is not yet balanced [58, 80, 81, 45, 6, 75, 67].  splitting further ...
#
# splitting ... loop 161
# Done
# pubmed split is not yet balanced [65, 54, 70, 83, 93].  splitting further ...
#
# splitting ... loop 162
# Done
# pubmed split is not yet balanced [50, 56, 56, 50, 93, 25, 32].  splitting further ...
#
# splitting ... loop 163
# Done
# pubmed split is not yet balanced [58, 57, 50, 62, 100, 50, 64].  splitting further ...
#
# splitting ... loop 164
# Done
# pubmed split is not yet balanced [59, 44, 52, 62, 6, 50, 42].  splitting further ...
#
# splitting ... loop 165
# Done
# pubmed split is not yet balanced [73, 74, 75, 58, 12, 75, 64].  splitting further ...
#
# splitting ... loop 166
# Done
# pubmed split is not yet balanced [57, 68, 71, 54, 87, 75, 53].  splitting further ...
#
# splitting ... loop 167
# Done
# pubmed split is not yet balanced [76, 92, 81, 83, 12, 75, 89].  splitting further ...
#
# splitting ... loop 168
# Done
# pubmed split is not yet balanced [74, 62, 63, 70, 100, 50, 42].  splitting further ...
#
# splitting ... loop 169
# Done
# pubmed split is not yet balanced [60, 74, 71, 91, 6, 25, 35].  splitting further ...
#
# splitting ... loop 170
# Done
# pubmed split is not yet balanced [61, 64, 55, 37, 100, 75, 82].  splitting further ...
#
# splitting ... loop 171
# Done
# pubmed split is not yet balanced [52, 48, 62, 75, 93, 50, 60].  splitting further ...
#
# splitting ... loop 172
# Done
# pubmed split is not yet balanced [51, 57, 48, 37, 12, 75, 67].  splitting further ...
#
# splitting ... loop 173
# Done
# pubmed split is not yet balanced [50, 68, 54, 41, 6, 100, 75].  splitting further ...
#
# splitting ... loop 174
# Done
# pubmed split is not yet balanced [56, 30, 43, 45, 93, 25, 32].  splitting further ...
#
# splitting ... loop 175
# Done
# pubmed split is not yet balanced [57, 76, 75, 66].  splitting further ...
#
# splitting ... loop 176
# Done
# pubmed split is not yet balanced [61, 70, 70, 62, 6, 75, 57].  splitting further ...
#
# splitting ... loop 177
# Done
# pubmed split is not yet balanced [43, 52, 56, 45, 12, 50, 57].  splitting further ...
#
# splitting ... loop 178
# Done
# pubmed split is not yet balanced [60, 66, 56, 41, 93, 25, 46].  splitting further ...
#
# splitting ... loop 179
# Done
# pubmed split is not yet balanced [69, 60, 74, 83, 100, 75, 89].  splitting further ...
#
# splitting ... loop 180
# Done
# pubmed split is not yet balanced [61, 68, 75, 83].  splitting further ...
#
# splitting ... loop 181
# Done
# pubmed split is not yet balanced [55, 60, 72, 83, 93, 75, 39].  splitting further ...
#
# splitting ... loop 182
# Done
# pubmed split is not yet balanced [44, 40, 40, 29, 87, 50, 46].  splitting further ...
#
# splitting ... loop 183
# Done
# pubmed split is not yet balanced [67, 84, 71, 87, 100, 75, 60].  splitting further ...
#
# splitting ... loop 184
# Done
# pubmed split is not yet balanced [54, 62, 54, 54, 6, 75, 89].  splitting further ...
#
# splitting ... loop 185
# Done
# pubmed split is not yet balanced [56, 76, 58, 41, 100, 100, 67].  splitting further ...
#
# splitting ... loop 186
# Done
# pubmed split is not yet balanced [62, 62, 43, 58, 93, 50, 71].  splitting further ...
#
# splitting ... loop 187
# Done
# pubmed split is not yet balanced [45, 36, 31, 33, 93].  splitting further ...
#
# splitting ... loop 188
# Done
# pubmed split is not yet balanced [64, 88, 82, 62].  splitting further ...
#
# splitting ... loop 189
# Done
# pubmed split is not yet balanced [66, 56, 72, 45, 93, 50, 64].  splitting further ...
#
# splitting ... loop 190
# Done
# pubmed split is not yet balanced [61, 70, 75, 50, 87, 75, 67].  splitting further ...
#
# splitting ... loop 191
# Done
# pubmed split is not yet balanced [60, 56, 48, 54, 6, 25, 57].  splitting further ...
#
# splitting ... loop 192
# Done
# pubmed split is not yet balanced [53, 76, 64, 16, 93, 50, 75].  splitting further ...
#
# splitting ... loop 193
# Done
# pubmed split is not yet balanced [63, 64, 63, 66].  splitting further ...
#
# splitting ... loop 194
# Done
# pubmed split is not yet balanced [58, 52, 78, 58, 6, 100, 82].  splitting further ...
#
# splitting ... loop 195
# Done
# pubmed split is not yet balanced [69, 40, 68, 62, 93, 50, 64].  splitting further ...
#
# splitting ... loop 196
# Done
# pubmed split is not yet balanced [66, 76, 83, 50, 100, 100, 82].  splitting further ...
#
# splitting ... loop 197
# Done
# pubmed split is not yet balanced [68, 86, 77, 91, 93, 75, 82].  splitting further ...
#
# splitting ... loop 198
# Done
# pubmed split is not yet balanced [65, 74, 60, 62].  splitting further ...
#
# splitting ... loop 199
# Done
# pubmed split is not yet balanced [50, 70, 50, 41].  splitting further ...
#
# splitting ... loop 200
# Done
# pubmed split is not yet balanced [48, 62, 50, 41, 6, 50, 71].  splitting further ...
#
# splitting ... loop 201
# Done
# pubmed split is not yet balanced [64, 62, 62, 58, 100, 75, 85].  splitting further ...
#
# splitting ... loop 202
# Done
# pubmed split is not yet balanced [55, 54, 51, 41, 100, 50, 35].  splitting further ...
#
# splitting ... loop 203
# Done
# pubmed split is not yet balanced [68, 76, 63, 66, 100, 75, 53].  splitting further ...
#
# splitting ... loop 204
# Done
# pubmed split is not yet balanced [55, 78, 50, 62, 12, 50, 60].  splitting further ...
#
# splitting ... loop 205
# Done
# pubmed split is not yet balanced [67, 68, 82, 66, 12, 100, 71].  splitting further ...
#
# splitting ... loop 206
# Done
# pubmed split is not yet balanced [48, 70, 50, 25, 87, 50, 60].  splitting further ...
#
# splitting ... loop 207
# Done
# pubmed split is not yet balanced [58, 57, 66, 37, 6, 100, 89].  splitting further ...
#
# splitting ... loop 208
# Done
# pubmed split is not yet balanced [54, 57, 68, 62, 12, 100, 71].  splitting further ...
#
# splitting ... loop 209
# Done
# pubmed split is not yet balanced [68, 60, 60, 75, 93, 50, 64].  splitting further ...
#
# splitting ... loop 210
# Done
# pubmed split is not yet balanced [64, 38, 40, 66, 93, 25, 50].  splitting further ...
#
# splitting ... loop 211
# Done
# pubmed split is not yet balanced [41, 38, 40, 54].  splitting further ...
#
# splitting ... loop 212
# Done
# pubmed split is not yet balanced [51, 44, 48, 33, 12, 75, 89].  splitting further ...
#
# splitting ... loop 213
# Done
# pubmed split is not yet balanced [51, 52, 48, 29, 93, 100, 75].  splitting further ...
#
# splitting ... loop 214
# Done
# pubmed split is not yet balanced [58, 66, 77, 41, 12, 75, 82].  splitting further ...
#
# splitting ... loop 215
# Done
# pubmed split is not yet balanced [49, 50, 55, 29, 93, 50, 53].  splitting further ...
#
# splitting ... loop 216
# Done
# pubmed split is not yet balanced [69, 78, 64, 58, 100, 75, 64].  splitting further ...
#
# splitting ... loop 217
# Done
# pubmed split is not yet balanced [53, 57, 47, 50, 12, 75, 60].  splitting further ...
#
# splitting ... loop 218
# Done
# pubmed split is not yet balanced [47, 60, 41, 45, 100, 25, 46].  splitting further ...
#
# splitting ... loop 219
# Done
# pubmed split is not yet balanced [49, 34, 50, 70, 93, 50, 60].  splitting further ...
#
# splitting ... loop 220
# Done
# pubmed split is not yet balanced [73, 80, 72, 54, 93, 75, 100].  splitting further ...
#
# splitting ... loop 221
# Done
# pubmed split is not yet balanced [65, 66, 52, 62].  splitting further ...
#
# splitting ... loop 222
# Done
# pubmed split is not yet balanced [53, 34, 36, 45, 6, 50, 53].  splitting further ...
#
# splitting ... loop 223
# Done
# pubmed split is not yet balanced [63, 70, 63, 79, 100, 75, 82].  splitting further ...
#
# splitting ... loop 224
# Done
# pubmed split is not yet balanced [58, 52, 50, 50, 93, 75, 67].  splitting further ...
#
# splitting ... loop 225
# Done
# pubmed split is not yet balanced [71, 86, 86, 79, 12, 75, 75].  splitting further ...
#
# splitting ... loop 226
# Done
# pubmed split is not yet balanced [66, 80, 75, 95, 12, 100, 78].  splitting further ...
#
# splitting ... loop 227
# Done
# pubmed split is not yet balanced [80, 90, 94, 91, 100, 100, 96].  splitting further ...
#
# splitting ... loop 228
# Done
# pubmed split is not yet balanced [55, 50, 50, 29, 93, 75, 67].  splitting further ...
#
# splitting ... loop 229
# Done
# pubmed split is not yet balanced [56, 74, 67, 66, 93, 75, 46].  splitting further ...
#
# splitting ... loop 230
# Done
# pubmed split is not yet balanced [54, 52, 43, 66].  splitting further ...
#
# splitting ... loop 231
# Done
# pubmed split is not yet balanced [68, 34, 52, 58, 93, 25, 42].  splitting further ...
#
# splitting ... loop 232
# Done
# pubmed split is not yet balanced [43, 62, 33, 54, 12, 50, 35].  splitting further ...
#
# splitting ... loop 233
# Done
# pubmed split is not yet balanced [61, 38, 63, 75, 93, 75, 57].  splitting further ...
#
# splitting ... loop 234
# Done
# pubmed split is not yet balanced [48, 54, 44, 58, 100, 100, 53].  splitting further ...
#
# splitting ... loop 235
# Done
# pubmed split is not yet balanced [67, 48, 50, 70, 93, 75, 60].  splitting further ...
#
# splitting ... loop 236
# Done
# pubmed split is not yet balanced [59, 54, 36, 62, 93, 25, 25].  splitting further ...
#
# splitting ... loop 237
# Done
# pubmed split is not yet balanced [66, 80, 70, 87, 100, 100, 71].  splitting further ...
#
# splitting ... loop 238
# Done
# pubmed split is not yet balanced [57, 70, 52, 25, 6, 50, 60].  splitting further ...
#
# splitting ... loop 239
# Done
# pubmed split is not yet balanced [68, 76, 52, 41, 12, 75, 85].  splitting further ...
#
# splitting ... loop 240
# Done
# pubmed split is not yet balanced [73, 57, 70, 83, 93, 25, 60].  splitting further ...
#
# splitting ... loop 241
# Done
# pubmed split is not yet balanced [76, 72, 62, 70, 93, 75, 67].  splitting further ...
#
# splitting ... loop 242
# Done
# pubmed split is not yet balanced [66, 70, 72, 70, 6, 25, 64].  splitting further ...
#
# splitting ... loop 243
# Done
# pubmed split is not yet balanced [61, 57, 64, 87, 93, 75, 78].  splitting further ...
#
# splitting ... loop 244
# Done
# pubmed split is not yet balanced [56, 62, 45, 58, 93, 50, 60].  splitting further ...
#
# splitting ... loop 245
# Done
# pubmed split is not yet balanced [53, 40, 52, 70, 87, 50, 42].  splitting further ...
#
# splitting ... loop 246
# Done
# pubmed split is not yet balanced [73, 78, 62, 66, 100, 75, 71].  splitting further ...
#
# splitting ... loop 247
# Done
# pubmed split is not yet balanced [34, 46, 47, 25, 87, 75, 57].  splitting further ...
#
# splitting ... loop 248
# Done
# pubmed split is not yet balanced [61, 68, 71, 70, 12, 75, 75].  splitting further ...
#
# splitting ... loop 249
# Done
# pubmed split is not yet balanced [52, 56, 47, 54, 6, 50, 67].  splitting further ...
#
# splitting ... loop 250
# Done
# pubmed split is not yet balanced [48, 76, 56, 25, 100, 25, 53].  splitting further ...
#
# splitting ... loop 251
# Done
# pubmed split is not yet balanced [59, 42, 56, 37, 93, 50, 50].  splitting further ...
#
# splitting ... loop 252
# Done
# pubmed split is not yet balanced [66, 57, 74, 91, 12, 50, 67].  splitting further ...
#
# splitting ... loop 253
# Done
# pubmed split is not yet balanced [50, 46, 67, 45, 93, 50, 53].  splitting further ...
#
# splitting ... loop 254
# Done
# pubmed split is not yet balanced [62, 32, 48, 54, 100, 25, 50].  splitting further ...
#
# splitting ... loop 255
# Done
# pubmed split is not yet balanced [36, 50, 36, 50, 6, 50, 35].  splitting further ...
#
# splitting ... loop 256
# Done
# pubmed split is not yet balanced [78, 84, 72, 83, 93].  splitting further ...
#
# splitting ... loop 257
# Done
# pubmed split is not yet balanced [59, 68, 37, 54, 100, 50, 46].  splitting further ...
#
# splitting ... loop 258
# Done
# pubmed split is not yet balanced [60, 64, 47, 58, 12, 50, 46].  splitting further ...
#
# splitting ... loop 259
# Done
# pubmed split is not yet balanced [72, 76, 66, 83, 93, 25, 42].  splitting further ...
#
# splitting ... loop 260
# Done
# pubmed split is not yet balanced [51, 42, 58, 79, 93, 50, 53].  splitting further ...
#
# splitting ... loop 261
# Done
# pubmed split is not yet balanced [62, 57, 68, 83, 12, 75, 42].  splitting further ...
#
# splitting ... loop 262
# Done
# pubmed split is not yet balanced [58, 34, 54, 50, 6, 75, 60].  splitting further ...
#
# splitting ... loop 263
# Done
# pubmed split is not yet balanced [62, 64, 77, 70, 100, 50, 50].  splitting further ...
#
# splitting ... loop 264
# Done
# pubmed split is not yet balanced [54, 36, 56, 75, 87].  splitting further ...
#
# splitting ... loop 265
# Done
# pubmed split is not yet balanced [54, 26, 41, 45, 6, 50, 60].  splitting further ...
#
# splitting ... loop 266
# Done
# pubmed split is not yet balanced [55, 74, 63, 58, 6, 50, 60].  splitting further ...
#
# splitting ... loop 267
# Done
# pubmed split is not yet balanced [62, 57, 66, 41, 6, 75, 60].  splitting further ...
#
# splitting ... loop 268
# Done
# pubmed split is not yet balanced [41, 50, 48, 33, 12, 100, 78].  splitting further ...
#
# splitting ... loop 269
# Done
# pubmed split is not yet balanced [52, 48, 52, 66, 12, 25, 42].  splitting further ...
#
# splitting ... loop 270
# Done
# pubmed split is not yet balanced [50, 68, 71, 58, 93, 50, 75].  splitting further ...
#
# splitting ... loop 271
# Done
# pubmed split is not yet balanced [56, 54, 45, 62, 87, 25, 39].  splitting further ...
#
# splitting ... loop 272
# Done
# pubmed split is not yet balanced [53, 54, 48, 29, 6, 75, 53].  splitting further ...
#
# splitting ... loop 273
# Done
# pubmed split is not yet balanced [65, 60, 47, 66, 87, 50, 75].  splitting further ...
#
# splitting ... loop 274
# Done
# pubmed split is not yet balanced [52, 64, 55, 66, 87, 25, 42].  splitting further ...
#
# splitting ... loop 275
# Done
# pubmed split is not yet balanced [54, 64, 59, 87, 87, 75, 42].  splitting further ...
#
# splitting ... loop 276
# Done
# pubmed split is not yet balanced [56, 48, 66, 50, 100, 75, 57].  splitting further ...
#
# splitting ... loop 277
# Done
# pubmed split is not yet balanced [63, 56, 72, 62, 93, 100, 53].  splitting further ...
#
# splitting ... loop 278
# Done
# pubmed split is not yet balanced [76, 62, 78, 50, 100, 100, 82].  splitting further ...
#
# splitting ... loop 279
# Done
# pubmed split is not yet balanced [62, 54, 72, 62, 100, 75, 67].  splitting further ...
#
# splitting ... loop 280
# Done
# pubmed split is not yet balanced [63, 60, 64, 83, 12, 100, 78].  splitting further ...
#
# splitting ... loop 281
# Done
# pubmed split is not yet balanced [50, 76, 81, 54, 12, 75, 64].  splitting further ...
#
# splitting ... loop 282
# Done
# pubmed split is not yet balanced [54, 76, 77, 54, 93, 100, 71].  splitting further ...
#
# splitting ... loop 283
# Done
# pubmed split is not yet balanced [54, 72, 63, 87, 6, 75, 53].  splitting further ...
#
# splitting ... loop 284
# Done
# pubmed split is not yet balanced [65, 64, 52, 66, 100, 50, 89].  splitting further ...
#
# splitting ... loop 285
# Done
# pubmed split is not yet balanced [49, 64, 52, 29, 93, 75, 57].  splitting further ...
#
# splitting ... loop 286
# Done
# pubmed split is not yet balanced [61, 60, 62, 41, 100, 100, 75].  splitting further ...
#
# splitting ... loop 287
# Done
# pubmed split is not yet balanced [75, 60, 77, 70, 100, 75, 85].  splitting further ...
#
# splitting ... loop 288
# Done
# pubmed split is not yet balanced [70, 72, 77, 79, 87, 50, 57].  splitting further ...
#
# splitting ... loop 289
# Done
# pubmed split is not yet balanced [42, 52, 43, 29, 93, 50, 35].  splitting further ...
#
# splitting ... loop 290
# Done
# pubmed split is not yet balanced [60, 57, 67, 66, 100, 50, 57].  splitting further ...
#
# splitting ... loop 291
# Done
# pubmed split is not yet balanced [59, 60, 51, 66, 100, 100, 71].  splitting further ...
#
# splitting ... loop 292
# Done
# pubmed split is not yet balanced [52, 34, 40, 58, 93, 75, 53].  splitting further ...
#
# splitting ... loop 293
# Done
# pubmed split is not yet balanced [65, 78, 66, 54, 93, 75, 60].  splitting further ...
#
# splitting ... loop 294
# Done
# pubmed split is not yet balanced [44, 54, 37, 20].  splitting further ...
#
# splitting ... loop 295
# Done
# pubmed split is not yet balanced [74, 82, 74, 91, 100, 75, 64].  splitting further ...
#
# splitting ... loop 296
# Done
# pubmed split is not yet balanced [59, 68, 33, 66, 93, 25, 39].  splitting further ...
#
# splitting ... loop 297
# Done
# pubmed split is not yet balanced [47, 44, 35, 37, 100, 50, 50].  splitting further ...
#
# splitting ... loop 298
# Done
# pubmed split is not yet balanced [70, 88, 72, 33, 93, 75, 89].  splitting further ...
#
# splitting ... loop 299
# Done
# pubmed split is not yet balanced [78, 86, 75, 91, 6, 75, 85].  splitting further ...
#
# splitting ... loop 300
# Done
# pubmed split is not yet balanced [47, 26, 37, 33, 87, 75, 57].  splitting further ...
#
# splitting ... loop 301
# Done
# pubmed split is not yet balanced [77, 66, 70, 87, 100, 75, 75].  splitting further ...
#
# splitting ... loop 302
# Done
# pubmed split is not yet balanced [50, 74, 52, 25, 100, 75, 60].  splitting further ...
#
# splitting ... loop 303
# Done
# pubmed split is not yet balanced [55, 72, 50, 33, 100, 50, 60].  splitting further ...
#
# splitting ... loop 304
# Done
# pubmed split is not yet balanced [70, 50, 77, 58, 100, 75, 60].  splitting further ...
#
# splitting ... loop 305
# Done
# pubmed split is not yet balanced [50, 62, 51, 70, 87, 50, 39].  splitting further ...
#
# splitting ... loop 306
# Done
# pubmed split is not yet balanced [59, 64, 55, 37, 100, 75, 78].  splitting further ...
#
# splitting ... loop 307
# Done
# pubmed split is not yet balanced [60, 78, 56, 75, 6, 50, 78].  splitting further ...
#
# splitting ... loop 308
# Done
# pubmed split is not yet balanced [53, 62, 44, 75, 93, 50, 53].  splitting further ...
#
# splitting ... loop 309
# Done
# pubmed split is not yet balanced [49, 72, 50, 29, 6, 100, 85].  splitting further ...
#
# splitting ... loop 310
# Done
# pubmed split is not yet balanced [69, 48, 72, 62, 100, 100, 67].  splitting further ...
#
# splitting ... loop 311
# Done
# pubmed split is not yet balanced [46, 74, 59, 50, 6, 75, 64].  splitting further ...
#
# splitting ... loop 312
# Done
# pubmed split is not yet balanced [58, 66, 62, 37, 93, 75, 78].  splitting further ...
#
# splitting ... loop 313
# Done
# pubmed split is not yet balanced [61, 48, 47, 41, 12, 100, 82].  splitting further ...
#
# splitting ... loop 314
# Done
# pubmed split is not yet balanced [73, 76, 72, 66].  splitting further ...
#
# splitting ... loop 315
# Done
# pubmed split is not yet balanced [64, 66, 44, 45, 93, 75, 78].  splitting further ...
#
# splitting ... loop 316
# Done
# pubmed split is not yet balanced [62, 74, 60, 37, 100, 75, 67].  splitting further ...
#
# splitting ... loop 317
# Done
# pubmed split is not yet balanced [58, 74, 67, 54, 93, 75, 71].  splitting further ...
#
# splitting ... loop 318
# Done
# pubmed split is not yet balanced [63, 38, 54, 79, 93, 50, 32].  splitting further ...
#
# splitting ... loop 319
# Done
# pubmed split is not yet balanced [66, 52, 66, 58, 6, 75, 57].  splitting further ...
#
# splitting ... loop 320
# Done
# pubmed split is not yet balanced [55, 60, 45, 50, 93, 75, 89].  splitting further ...
#
# splitting ... loop 321
# Done
# pubmed split is not yet balanced [70, 80, 72, 70, 6, 100, 85].  splitting further ...
#
# splitting ... loop 322
# Done
# pubmed split is not yet balanced [61, 74, 48, 75, 6, 25, 53].  splitting further ...
#
# splitting ... loop 323
# Done
# pubmed split is not yet balanced [55, 44, 71, 62, 6, 75, 50].  splitting further ...
#
# splitting ... loop 324
# Done
# pubmed split is not yet balanced [62, 60, 58, 41, 6, 75, 71].  splitting further ...
#
# splitting ... loop 325
# Done
# pubmed split is not yet balanced [66, 60, 62, 79, 100, 50, 50].  splitting further ...
#
# splitting ... loop 326
# Done
# pubmed split is not yet balanced [62, 72, 74, 66, 93, 25, 39].  splitting further ...
#
# splitting ... loop 327
# Done
# pubmed split is not yet balanced [47, 50, 37, 41, 87, 50, 21].  splitting further ...
#
# splitting ... loop 328
# Done
# pubmed split is not yet balanced [57, 70, 59, 62, 6, 50, 60].  splitting further ...
#
# splitting ... loop 329
# Done
# pubmed split is not yet balanced [60, 36, 59, 33, 93, 25, 35].  splitting further ...
#
# splitting ... loop 330
# Done
# pubmed split is not yet balanced [63, 64, 81, 54, 93, 100, 85].  splitting further ...
#
# splitting ... loop 331
# Done
# pubmed split is not yet balanced [66, 86, 72, 83, 12, 50, 60].  splitting further ...
#
# splitting ... loop 332
# Done
# pubmed split is not yet balanced [60, 70, 77, 62, 6, 75, 71].  splitting further ...
#
# splitting ... loop 333
# Done
# pubmed split is not yet balanced [60, 78, 59, 62, 12, 100, 82].  splitting further ...
#
# splitting ... loop 334
# Done
# pubmed split is not yet balanced [69, 64, 70, 83, 100, 100, 75].  splitting further ...
#
# splitting ... loop 335
# Done
# pubmed split is not yet balanced [56, 76, 58, 54, 6, 75, 82].  splitting further ...
#
# splitting ... loop 336
# Done
# pubmed split is not yet balanced [45, 70, 55, 41, 6, 75, 50].  splitting further ...
#
# splitting ... loop 337
# Done
# pubmed split is not yet balanced [63, 68, 64, 87, 93, 100, 67].  splitting further ...
#
# splitting ... loop 338
# Done
# pubmed split is not yet balanced [56, 56, 45, 33].  splitting further ...
#
# splitting ... loop 339
# Done
# pubmed split is not yet balanced [65, 80, 72, 70, 87, 75, 67].  splitting further ...
#
# splitting ... loop 340
# Done
# pubmed split is not yet balanced [55, 62, 58, 62, 6, 100, 96].  splitting further ...
#
# splitting ... loop 341
# Done
# pubmed split is not yet balanced [57, 60, 36, 41, 93, 50, 50].  splitting further ...
#
# splitting ... loop 342
# Done
# pubmed split is not yet balanced [60, 70, 68, 66, 100, 75, 64].  splitting further ...
#
# splitting ... loop 343
# Done
# pubmed split is not yet balanced [55, 62, 63, 29, 93, 100, 92].  splitting further ...
#
# splitting ... loop 344
# Done
# pubmed split is not yet balanced [68, 76, 70, 83, 93, 100, 92].  splitting further ...
#
# splitting ... loop 345
# Done
# pubmed split is not yet balanced [67, 68, 66, 83, 100, 75, 89].  splitting further ...
#
# splitting ... loop 346
# Done
# pubmed split is not yet balanced [66, 60, 74, 79, 12, 50, 60].  splitting further ...
#
# splitting ... loop 347
# Done
# pubmed split is not yet balanced [60, 72, 50, 50, 100, 50, 75].  splitting further ...
#
# splitting ... loop 348
# Done
# pubmed split is not yet balanced [65, 72, 50, 16, 100, 50, 60].  splitting further ...
#
# splitting ... loop 349
# Done
# pubmed split is not yet balanced [68, 62, 83, 70, 6, 75, 75].  splitting further ...
#
# splitting ... loop 350
# Done
# pubmed split is not yet balanced [64, 84, 70, 50, 100, 75, 78].  splitting further ...
#
# splitting ... loop 351
# Done
# pubmed split is not yet balanced [67, 57, 75, 50, 87, 50, 71].  splitting further ...
#
# splitting ... loop 352
# Done
# pubmed split is not yet balanced [51, 50, 40, 16, 100, 75, 67].  splitting further ...
#
# splitting ... loop 353
# Done
# pubmed split is not yet balanced [51, 72, 56, 45, 93, 50, 67].  splitting further ...
#
# splitting ... loop 354
# Done
# pubmed split is not yet balanced [49, 76, 52, 62, 87, 25, 42].  splitting further ...
#
# splitting ... loop 355
# Done
# pubmed split is not yet balanced [59, 70, 60, 58, 87, 75, 46].  splitting further ...
#
# splitting ... loop 356
# Done
# pubmed split is not yet balanced [61, 56, 72, 79, 93, 75, 53].  splitting further ...
#
# splitting ... loop 357
# Done
# pubmed split is not yet balanced [71, 82, 82, 62, 12, 75, 75].  splitting further ...
#
# splitting ... loop 358
# Done
# pubmed split is not yet balanced [52, 38, 39, 45, 100, 50, 64].  splitting further ...
#
# splitting ... loop 359
# Done
# pubmed split is not yet balanced [48, 52, 55, 50, 12, 75, 50].  splitting further ...
#
# splitting ... loop 360
# Done
# pubmed split is not yet balanced [47, 44, 63, 58, 100, 100, 64].  splitting further ...
#
# splitting ... loop 361
# Done
# pubmed split is not yet balanced [58, 68, 51, 66, 93, 50, 57].  splitting further ...
#
# splitting ... loop 362
# Done
# pubmed split is not yet balanced [53, 34, 48, 20, 12, 75, 64].  splitting further ...
#
# splitting ... loop 363
# Done
# pubmed split is not yet balanced [58, 78, 66, 66, 93, 100, 89].  splitting further ...
#
# splitting ... loop 364
# Done
# pubmed split is not yet balanced [56, 60, 62, 75, 93].  splitting further ...
#
# splitting ... loop 365
# Done
# pubmed split is not yet balanced [44, 82, 59, 62, 93, 75, 57].  splitting further ...
#
# splitting ... loop 366
# Done
# pubmed split is not yet balanced [68, 60, 72, 83, 6, 100, 75].  splitting further ...
#
# splitting ... loop 367
# Done
# pubmed split is not yet balanced [67, 78, 48, 54, 100, 50, 64].  splitting further ...
#
# splitting ... loop 368
# Done
# pubmed split is not yet balanced [60, 74, 70, 70, 93, 25, 60].  splitting further ...
#
# splitting ... loop 369
# Done
# pubmed split is not yet balanced [61, 64, 71, 50, 100, 50, 46].  splitting further ...
#
# splitting ... loop 370
# Done
# pubmed split is not yet balanced [46, 66, 44, 20, 6, 50, 35].  splitting further ...
#
# splitting ... loop 371
# Done
# pubmed split is not yet balanced [68, 48, 70, 83, 93, 25, 50].  splitting further ...
#
# splitting ... loop 372
# Done
# pubmed split is not yet balanced [57, 40, 44, 58, 87, 75, 60].  splitting further ...
#
# splitting ... loop 373
# Done
# pubmed split is not yet balanced [63, 66, 64, 41, 87, 75, 82].  splitting further ...
#
# splitting ... loop 374
# Done
# pubmed split is not yet balanced [53, 34, 45, 50, 12, 50, 60].  splitting further ...
#
# splitting ... loop 375
# Done
# pubmed split is not yet balanced [49, 64, 40, 45, 100, 100, 78].  splitting further ...
#
# splitting ... loop 376
# Done
# pubmed split is not yet balanced [63, 30, 51, 58, 93, 50, 46].  splitting further ...
#
# splitting ... loop 377
# Done
# pubmed split is not yet balanced [59, 54, 71, 79, 93, 100, 67].  splitting further ...
#
# splitting ... loop 378
# Done
# pubmed split is not yet balanced [59, 48, 58, 58, 93, 75, 71].  splitting further ...
#
# splitting ... loop 379
# Done
# pubmed split is not yet balanced [71, 60, 67, 87, 100, 75, 82].  splitting further ...
#
# splitting ... loop 380
# Done
# pubmed split is not yet balanced [63, 84, 67, 58, 12, 50, 64].  splitting further ...
#
# splitting ... loop 381
# Done
# pubmed split is not yet balanced [53, 70, 50, 33, 93, 50, 64].  splitting further ...
#
# splitting ... loop 382
# Done
# pubmed split is not yet balanced [51, 68, 47, 66, 93, 50, 53].  splitting further ...
#
# splitting ... loop 383
# Done
# pubmed split is not yet balanced [50, 44, 64, 45, 12, 75, 35].  splitting further ...
#
# splitting ... loop 384
# Done
# pubmed split is not yet balanced [60, 78, 59, 70, 93, 75, 67].  splitting further ...
#
# splitting ... loop 385
# Done
# pubmed split is not yet balanced [61, 68, 74, 70, 100, 25, 46].  splitting further ...
#
# splitting ... loop 386
# Done
# pubmed split is not yet balanced [64, 74, 70, 83, 93, 50, 53].  splitting further ...
#
# splitting ... loop 387
# Done
# pubmed split is not yet balanced [50, 50, 29, 33, 100, 75, 57].  splitting further ...
#
# splitting ... loop 388
# Done
# pubmed split is not yet balanced [56, 42, 39, 79, 6, 25, 25].  splitting further ...
#
# splitting ... loop 389
# Done
# pubmed split is not yet balanced [61, 62, 64, 66, 100, 75, 75].  splitting further ...
#
# splitting ... loop 390
# Done
# pubmed split is not yet balanced [58, 56, 71, 66, 6, 25, 42].  splitting further ...
#
# splitting ... loop 391
# Done
# pubmed split is not yet balanced [55, 34, 51, 50, 93, 50, 46].  splitting further ...
#
# splitting ... loop 392
# Done
# pubmed split is not yet balanced [49, 68, 40, 62, 93, 50, 53].  splitting further ...
#
# splitting ... loop 393
# Done
# pubmed split is not yet balanced [60, 54, 55, 45, 12, 100, 89].  splitting further ...
#
# splitting ... loop 394
# Done
# pubmed split is not yet balanced [58, 56, 71, 54].  splitting further ...
#
# splitting ... loop 395
# Done
# pubmed split is not yet balanced [53, 70, 68, 75, 93, 75, 60].  splitting further ...
#
# splitting ... loop 396
# Done
# pubmed split is not yet balanced [57, 56, 55, 33, 93, 50, 67].  splitting further ...
#
# splitting ... loop 397
# Done
# pubmed split is not yet balanced [63, 76, 74, 50, 93, 25, 46].  splitting further ...
#
# splitting ... loop 398
# Done
# pubmed split is not yet balanced [71, 84, 78, 66, 6, 25, 60].  splitting further ...
#
# splitting ... loop 399
# Done
# pubmed split is not yet balanced [53, 56, 37, 29, 93, 75, 67].  splitting further ...
#
# splitting ... loop 400
# Done
# pubmed split is not yet balanced [65, 56, 64, 87, 87].  splitting further ...
#
# splitting ... loop 401
# Done
# pubmed split is not yet balanced [61, 64, 51, 62, 93, 50, 67].  splitting further ...
#
# splitting ... loop 402
# Done
# pubmed split is not yet balanced [54, 76, 63, 62, 93, 50, 53].  splitting further ...
#
# splitting ... loop 403
# Done
# pubmed split is not yet balanced [58, 60, 66, 66, 12, 50, 46].  splitting further ...
#
# splitting ... loop 404
# Done
# pubmed split is not yet balanced [45, 54, 43, 54].  splitting further ...
#
# splitting ... loop 405
# Done
# pubmed split is not yet balanced [55, 68, 47, 50, 12, 75, 64].  splitting further ...
#
# splitting ... loop 406
# Done
# pubmed split is not yet balanced [46, 56, 41, 50, 6, 75, 67].  splitting further ...
#
# splitting ... loop 407
# Done
# pubmed split is not yet balanced [56, 60, 59, 45, 100, 75, 53].  splitting further ...
#
# splitting ... loop 408
# Done
# pubmed split is not yet balanced [60, 32, 63, 62, 87, 50, 57].  splitting further ...
#
# splitting ... loop 409
# Done
# pubmed split is not yet balanced [69, 72, 68, 91, 100, 25, 46].  splitting further ...
#
# splitting ... loop 410
# Done
# pubmed split is not yet balanced [71, 66, 74, 87, 93, 75, 64].  splitting further ...
#
# splitting ... loop 411
# Done
# pubmed split is not yet balanced [59, 54, 64, 70, 87, 25, 42].  splitting further ...
#
# splitting ... loop 412
# Done
# pubmed split is not yet balanced [57, 82, 60, 41, 100, 75, 78].  splitting further ...
#
# splitting ... loop 413
# Done
# pubmed split is not yet balanced [66, 68, 86, 87, 12, 100, 67].  splitting further ...
#
# splitting ... loop 414
# Done
# pubmed split is not yet balanced [72, 52, 64, 75, 87, 50, 39].  splitting further ...
#
# splitting ... loop 415
# Done
# pubmed split is not yet balanced [65, 57, 59, 83, 87, 25, 67].  splitting further ...
#
# splitting ... loop 416
# Done
# pubmed split is not yet balanced [51, 48, 39, 45, 87, 50, 46].  splitting further ...
#
# splitting ... loop 417
# Done
# pubmed split is not yet balanced [55, 40, 63, 58, 87, 75, 50].  splitting further ...
#
# splitting ... loop 418
# Done
# pubmed split is not yet balanced [58, 54, 63, 83, 100, 75, 53].  splitting further ...
#
# splitting ... loop 419
# Done
# pubmed split is not yet balanced [65, 52, 64, 54, 6, 50, 35].  splitting further ...
#
# splitting ... loop 420
# Done
# ...
#
# splitting ... loop 5678
# Done
# pubmed split is not yet balanced [61, 54, 56, 62, 93, 50, 57].  splitting further ...
#
# splitting ... loop 5679
# Done
# pubmed split is not yet balanced [42, 44, 47, 29, 87, 50, 32].  splitting further ...
#
# splitting ... loop 5680
# Done
# pubmed split is not yet balanced [52, 56, 59, 66, 100, 75, 57].  splitting further ...
#
# splitting ... loop 5681
# Done
# pubmed split is not yet balanced [47, 56, 35, 25, 93, 50, 28].  splitting further ...
#
# splitting ... loop 5682
# Done
# pubmed split is not yet balanced [58, 56, 48, 58, 100, 100, 64].  splitting further ...
#
# splitting ... loop 5683
# Done
# pubmed split is not yet balanced [56, 64, 63, 45, 6, 75, 71].  splitting further ...
#
# splitting ... loop 5684
# Done
# pubmed split is not yet balanced [65, 64, 71, 83, 87, 75, 53].  splitting further ...
#
# splitting ... loop 5685
# Done
# pubmed split is not yet balanced [70, 57, 67, 83, 87, 50, 75].  splitting further ...
#
# splitting ... loop 5686
# Done
# pubmed split is not yet balanced [57, 57, 68, 62, 93, 50, 67].  splitting further ...
#
# splitting ... loop 5687
# Done
# pubmed split is not yet balanced [68, 86, 78, 83, 87, 75, 75].  splitting further ...
#
# splitting ... loop 5688
# Done
# pubmed split is not yet balanced [58, 64, 64, 62, 6, 75, 46].  splitting further ...
#
# splitting ... loop 5689
# Done
# pubmed split is not yet balanced [68, 40, 66, 62, 100, 50, 50].  splitting further ...
#
# splitting ... loop 5690
# Done
# pubmed split is not yet balanced [71, 48, 64, 58, 100, 100, 75].  splitting further ...
#
# splitting ... loop 5691
# Done
# pubmed split is not yet balanced [63, 82, 60, 66, 93, 75, 100].  splitting further ...
#
# splitting ... loop 5692
# Done
# pubmed split is not yet balanced [67, 60, 68, 70, 6, 25, 57].  splitting further ...
#
# splitting ... loop 5693
# Done
# pubmed split is not yet balanced [52, 66, 43, 25, 93, 25, 28].  splitting further ...
#
# splitting ... loop 5694
# Done
# pubmed split is not yet balanced [58, 68, 50, 16, 100, 75, 53].  splitting further ...
#
# splitting ... loop 5695
# Done
# pubmed split is not yet balanced [65, 62, 60, 91, 87, 25, 42].  splitting further ...
#
# splitting ... loop 5696
# Done
# pubmed split is not yet balanced [52, 54, 58, 45, 93, 50, 46].  splitting further ...
#
# splitting ... loop 5697
# Done
# pubmed split is not yet balanced [65, 44, 52, 50, 93, 75, 75].  splitting further ...
#
# splitting ... loop 5698
# Done
# pubmed split is not yet balanced [69, 64, 66, 100, 87, 50, 50].  splitting further ...
#
# splitting ... loop 5699
# Done
# pubmed split is not yet balanced [64, 80, 72, 79, 6, 50, 60].  splitting further ...
#
# splitting ... loop 5700
# Done
# pubmed split is not yet balanced [66, 57, 64, 75, 100, 50, 35].  splitting further ...
#
# splitting ... loop 5701
# Done
# pubmed split is not yet balanced [61, 36, 64, 75, 93, 75, 60].  splitting further ...
#
# splitting ... loop 5702
# Done
# pubmed split is not yet balanced [65, 74, 78, 75, 6, 75, 75].  splitting further ...
#
# splitting ... loop 5703
# Done
# pubmed split is not yet balanced [60, 60, 63, 91, 12, 25, 42].  splitting further ...
#
# splitting ... loop 5704
# Done
# pubmed split is not yet balanced [39, 64, 39, 54, 6, 25, 35].  splitting further ...
#
# splitting ... loop 5705
# Done
# pubmed split is not yet balanced [67, 46, 59, 79, 93, 50, 42].  splitting further ...
#
# splitting ... loop 5706
# Done
# pubmed split is not yet balanced [68, 46, 72, 75, 93, 50, 60].  splitting further ...
#
# splitting ... loop 5707
# Done
# pubmed split is not yet balanced [60, 52, 70, 75, 6, 25, 35].  splitting further ...
#
# splitting ... loop 5708
# Done
# pubmed split is not yet balanced [47, 82, 52, 66, 93, 75, 57].  splitting further ...
#
# splitting ... loop 5709
# Done
# pubmed split is not yet balanced [63, 62, 58, 87, 87, 50, 57].  splitting further ...
#
# splitting ... loop 5710
# Done
# pubmed split is not yet balanced [55, 60, 56, 29, 12, 100, 82].  splitting further ...
#
# splitting ... loop 5711
# Done
# pubmed split is not yet balanced [68, 74, 66, 75, 12, 75, 89].  splitting further ...
#
# splitting ... loop 5712
# Done
# pubmed split is not yet balanced [71, 64, 75, 54, 100, 50, 71].  splitting further ...
#
# splitting ... loop 5713
# Done
# pubmed split is not yet balanced [55, 64, 40, 45, 87, 50, 42].  splitting further ...
#
# splitting ... loop 5714
# Done
# pubmed split is not yet balanced [60, 76, 63, 66, 12, 75, 78].  splitting further ...
#
# splitting ... loop 5715
# Done
# pubmed split is not yet balanced [54, 52, 50, 33, 93, 25, 57].  splitting further ...
#
# splitting ... loop 5716
# Done
# pubmed split is not yet balanced [40, 74, 51, 37, 12, 75, 67].  splitting further ...
#
# splitting ... loop 5717
# Done
# pubmed split is not yet balanced [56, 38, 39, 45, 93, 50, 53].  splitting further ...
#
# splitting ... loop 5718
# Done
# pubmed split is not yet balanced [58, 60, 68, 54, 100, 25, 50].  splitting further ...
#
# splitting ... loop 5719
# Done
# pubmed split is not yet balanced [67, 68, 70, 70, 87, 50, 71].  splitting further ...
#
# splitting ... loop 5720
# Done
# pubmed split is not yet balanced [74, 42, 75, 83, 100, 75, 85].  splitting further ...
#
# splitting ... loop 5721
# Done
# pubmed split is not yet balanced [60, 30, 44, 54, 12, 75, 50].  splitting further ...
#
# splitting ... loop 5722
# Done
# pubmed split is not yet balanced [50, 76, 70, 58, 12, 100, 67].  splitting further ...
#
# splitting ... loop 5723
# Done
# pubmed split is not yet balanced [56, 40, 47, 41, 93, 25, 35].  splitting further ...
#
# splitting ... loop 5724
# Done
# pubmed split is not yet balanced [69, 44, 62, 91].  splitting further ...
#
# splitting ... loop 5725
# Done
# pubmed split is not yet balanced [50, 57, 63, 50, 93, 50, 60].  splitting further ...
#
# splitting ... loop 5726
# Done
# pubmed split is not yet balanced [64, 68, 62, 66, 93, 25, 42].  splitting further ...
#
# splitting ... loop 5727
# Done
# pubmed split is not yet balanced [66, 70, 51, 62, 100, 50, 57].  splitting further ...
#
# splitting ... loop 5728
# Done
# pubmed split is not yet balanced [77, 74, 68, 79, 93, 75, 78].  splitting further ...
#
# splitting ... loop 5729
# Done
# pubmed split is not yet balanced [71, 70, 58, 29, 93, 25, 67].  splitting further ...
#
# splitting ... loop 5730
# Done
# pubmed split is not yet balanced [56, 46, 56, 37, 93, 75, 71].  splitting further ...
#
# splitting ... loop 5731
# Done
# pubmed split is not yet balanced [70, 50, 70, 54, 100, 75, 53].  splitting further ...
#
# splitting ... loop 5732
# Done
# pubmed split is not yet balanced [53, 57, 68, 62, 6, 75, 60].  splitting further ...
#
# splitting ... loop 5733
# Done
# pubmed split is not yet balanced [55, 76, 62, 54, 6, 100, 82].  splitting further ...
#
# splitting ... loop 5734
# Done
# pubmed split is not yet balanced [43, 52, 50, 8, 12, 50, 53].  splitting further ...
#
# splitting ... loop 5735
# Done
# pubmed split is not yet balanced [69, 82, 77, 79, 93, 75, 71].  splitting further ...
#
# splitting ... loop 5736
# Done
# pubmed split is not yet balanced [59, 72, 75, 87, 100, 75, 50].  splitting further ...
#
# splitting ... loop 5737
# Done
# pubmed split is not yet balanced [69, 50, 60, 62, 6, 50, 53].  splitting further ...
#
# splitting ... loop 5738
# Done
# pubmed split is not yet balanced [56, 72, 44, 41, 100, 50, 71].  splitting further ...
#
# splitting ... loop 5739
# Done
# pubmed split is not yet balanced [70, 54, 62, 95, 87, 75, 64].  splitting further ...
#
# splitting ... loop 5740
# Done
# pubmed split is not yet balanced [42, 54, 50, 37, 6, 50, 60].  splitting further ...
#
# splitting ... loop 5741
# Done
# pubmed split is not yet balanced [53, 70, 62, 58, 100, 75, 60].  splitting further ...
#
# splitting ... loop 5742
# Done
# pubmed split is not yet balanced [57, 70, 51, 37, 93, 100, 67].  splitting further ...
#
# splitting ... loop 5743
# Done
# pubmed split is not yet balanced [64, 54, 47, 50, 93, 75, 57].  splitting further ...
#
# splitting ... loop 5744
# Done
# pubmed split is not yet balanced [56, 38, 56, 20, 93, 75, 75].  splitting further ...
#
# splitting ... loop 5745
# Done
# pubmed split is not yet balanced [67, 78, 72, 58, 12, 75, 75].  splitting further ...
#
# splitting ... loop 5746
# Done
# pubmed split is not yet balanced [55, 36, 45, 75, 87, 50, 46].  splitting further ...
#
# splitting ... loop 5747
# Done
# pubmed split is not yet balanced [63, 44, 62, 66, 93, 75, 53].  splitting further ...
#
# splitting ... loop 5748
# Done
# pubmed split is not yet balanced [61, 34, 44, 54].  splitting further ...
#
# splitting ... loop 5749
# Done
# pubmed split is not yet balanced [57, 57, 52, 50, 93, 75, 78].  splitting further ...
#
# splitting ... loop 5750
# Done
# pubmed split is not yet balanced [67, 76, 72, 79, 12, 75, 78].  splitting further ...
#
# splitting ... loop 5751
# Done
# pubmed split is not yet balanced [60, 80, 71, 79, 87, 50, 42].  splitting further ...
#
# splitting ... loop 5752
# Done
# pubmed split is not yet balanced [55, 50, 58, 45, 6].  splitting further ...
#
# splitting ... loop 5753
# Done
# pubmed split is not yet balanced [56, 48, 50, 58, 100, 75, 67].  splitting further ...
#
# splitting ... loop 5754
# Done
# pubmed split is not yet balanced [61, 38, 40, 75, 6, 25, 46].  splitting further ...
#
# splitting ... loop 5755
# Done
# pubmed split is not yet balanced [63, 66, 68, 54, 93, 50, 46].  splitting further ...
#
# splitting ... loop 5756
# Done
# pubmed split is not yet balanced [60, 54, 66, 75, 12, 75, 57].  splitting further ...
#
# splitting ... loop 5757
# Done
# pubmed split is not yet balanced [68, 68, 72, 50, 100, 75, 67].  splitting further ...
#
# splitting ... loop 5758
# Done
# pubmed split is not yet balanced [61, 56, 59, 83].  splitting further ...
#
# splitting ... loop 5759
# Done
# pubmed split is not yet balanced [73, 64, 64, 91].  splitting further ...
#
# splitting ... loop 5760
# Done
# pubmed split is not yet balanced [48, 62, 47, 58, 93, 50, 60].  splitting further ...
#
# splitting ... loop 5761
# Done
# pubmed split is not yet balanced [59, 72, 45, 62, 6, 50, 57].  splitting further ...
#
# splitting ... loop 5762
# Done
# pubmed split is not yet balanced [47, 36, 35, 29, 87, 25, 53].  splitting further ...
#
# splitting ... loop 5763
# Done
# pubmed split is not yet balanced [62, 52, 66, 87, 100, 75, 57].  splitting further ...
#
# splitting ... loop 5764
# Done
# pubmed split is not yet balanced [68, 62, 58, 62, 100, 100, 75].  splitting further ...
#
# splitting ... loop 5765
# Done
# pubmed split is not yet balanced [61, 70, 47, 66, 93, 25, 42].  splitting further ...
#
# splitting ... loop 5766
# Done
# pubmed split is not yet balanced [69, 72, 75, 54, 100, 50, 53].  splitting further ...
#
# splitting ... loop 5767
# Done
# pubmed split is not yet balanced [56, 74, 60, 50, 100, 50, 67].  splitting further ...
#
# splitting ... loop 5768
# Done
# pubmed split is not yet balanced [55, 50, 35, 58, 12, 50, 50].  splitting further ...
#
# splitting ... loop 5769
# Done
# pubmed split is not yet balanced [48, 64, 54, 25, 12, 50, 67].  splitting further ...
#
# splitting ... loop 5770
# Done
# pubmed split is not yet balanced [53, 40, 50, 54, 93, 50, 35].  splitting further ...
#
# splitting ... loop 5771
# Done
# pubmed split is not yet balanced [57, 56, 71, 75, 100, 75, 71].  splitting further ...
#
# splitting ... loop 5772
# Done
# pubmed split is not yet balanced [65, 50, 54, 54, 93, 25, 21].  splitting further ...
#
# splitting ... loop 5773
# Done
# pubmed split is not yet balanced [46, 70, 45, 29, 93, 75, 85].  splitting further ...
#
# splitting ... loop 5774
# Done
# pubmed split is not yet balanced [76, 54, 68, 75, 12, 100, 92].  splitting further ...
#
# splitting ... loop 5775
# Done
# pubmed split is not yet balanced [45, 60, 44, 58, 93, 75, 75].  splitting further ...
#
# splitting ... loop 5776
# Done
# pubmed split is not yet balanced [60, 84, 60, 70, 100, 50, 71].  splitting further ...
#
# splitting ... loop 5777
# Done
# pubmed split is not yet balanced [73, 40, 54, 87, 12, 50, 53].  splitting further ...
#
# splitting ... loop 5778
# Done
# pubmed split is not yet balanced [62, 48, 58, 75, 100, 75, 64].  splitting further ...
#
# splitting ... loop 5779
# Done
# pubmed split is not yet balanced [57, 70, 62, 50, 100, 100, 82].  splitting further ...
#
# splitting ... loop 5780
# Done
# pubmed split is not yet balanced [76, 76, 72, 75, 6, 25, 57].  splitting further ...
#
# splitting ... loop 5781
# Done
# pubmed split is not yet balanced [68, 74, 79, 79, 12, 75, 64].  splitting further ...
#
# splitting ... loop 5782
# Done
# pubmed split is not yet balanced [84, 62, 90, 54, 100, 100, 92].  splitting further ...
#
# splitting ... loop 5783
# Done
# pubmed split is not yet balanced [53, 54, 43, 50, 100, 100, 75].  splitting further ...
#
# splitting ... loop 5784
# Done
# pubmed split is not yet balanced [60, 62, 58, 70, 100, 100, 85].  splitting further ...
#
# splitting ... loop 5785
# Done
# pubmed split is not yet balanced [59, 56, 51, 62, 93, 50, 53].  splitting further ...
#
# splitting ... loop 5786
# Done
# pubmed split is not yet balanced [69, 57, 77, 79, 93, 50, 35].  splitting further ...
#
# splitting ... loop 5787
# Done
# pubmed split is not yet balanced [54, 40, 40, 58, 93, 25, 39].  splitting further ...
#
# splitting ... loop 5788
# Done
# pubmed split is not yet balanced [68, 54, 58, 75, 93, 50, 50].  splitting further ...
#
# splitting ... loop 5789
# Done
# pubmed split is not yet balanced [51, 32, 55, 41, 100, 75, 53].  splitting further ...
#
# splitting ... loop 5790
# Done
# pubmed split is not yet balanced [65, 86, 75, 75, 12, 100, 85].  splitting further ...
#
# splitting ... loop 5791
# Done
# pubmed split is not yet balanced [72, 54, 64, 45, 93, 25, 57].  splitting further ...
#
# splitting ... loop 5792
# Done
# pubmed split is not yet balanced [76, 76, 78, 87, 87, 50, 82].  splitting further ...
#
# splitting ... loop 5793
# Done
# pubmed split is not yet balanced [64, 76, 75, 62, 12, 50, 75].  splitting further ...
#
# splitting ... loop 5794
# Done
# pubmed split is not yet balanced [55, 64, 70, 70, 12, 50, 53].  splitting further ...
#
# splitting ... loop 5795
# Done
# pubmed split is not yet balanced [48, 56, 41, 25, 12, 75, 71].  splitting further ...
#
# splitting ... loop 5796
# Done
# pubmed split is not yet balanced [47, 54, 54, 66].  splitting further ...
#
# splitting ... loop 5797
# Done
# pubmed split is not yet balanced [41, 40, 33, 20, 6, 50, 39].  splitting further ...
#
# splitting ... loop 5798
# Done
# pubmed split is not yet balanced [75, 82, 78, 50, 12, 100, 85].  splitting further ...
#
# splitting ... loop 5799
# Done
# pubmed split is not yet balanced [58, 50, 64, 62].  splitting further ...
#
# splitting ... loop 5800
# Done
# pubmed split is not yet balanced [62, 36, 63, 62, 100, 50, 50].  splitting further ...
#
# splitting ... loop 5801
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [55], in <module>
#      35 while not(pubmed_train_split_result_):
#      37     print(f'splitting ... loop {i}')
# ---> 39     split_data(in_path_pubmed, out_path_pubmed)
#      41     i += 1
#      44     #calculate the new distribution
#
# Input In [53], in split_data(in_path, out_path, file_ext, ratio, set_names)
#      47 for entry in single_files:
#      49     base_file_name = entry.name.split(file_ext)[0]
# ---> 51     base_file_entries = list(Path(in_path).rglob('{}*'.format(base_file_name)))
#      53     all_files.append(base_file_entries)
#      55 random.seed()
#
# File /usr/lib/python3.8/pathlib.py:1152, in Path.rglob(self, pattern)
#    1150     raise NotImplementedError("Non-relative patterns are unsupported")
#    1151 selector = _make_selector(("**",) + tuple(pattern_parts), self._flavour)
# -> 1152 for p in selector.select_from(self):
#    1153     yield p
#
# File /usr/lib/python3.8/pathlib.py:587, in _RecursiveWildcardSelector._select_from(self, parent_path, is_dir, exists, scandir)
#     585 successor_select = self.successor._select_from
#     586 for starting_point in self._iterate_directories(parent_path, is_dir, scandir):
# --> 587     for p in successor_select(starting_point, is_dir, exists, scandir):
#     588         if p not in yielded:
#     589             yield p
#
# File /usr/lib/python3.8/pathlib.py:535, in _WildcardSelector._select_from(self, parent_path, is_dir, exists, scandir)
#     533 try:
#     534     with scandir(parent_path) as scandir_it:
# --> 535         entries = list(scandir_it)
#     536     for entry in entries:
#     537         if self.dironly:
#
# KeyboardInterrupt:

# %%
pubmed_path_whole = '/home/beck/Desktop/SoMeNLP/data/Pubmed_fulltext_bio/'
pubmed_path_train = "/home/beck/Desktop/SoMeNLP/data/Pubmed_fulltext/Pubmed_fulltext_bio_train/" 
pubmed_path_test = "/home/beck/Desktop/SoMeNLP/data/Pubmed_fulltext/Pubmed_fulltext_bio_test/" 
pubmed_path_dev = "/home/beck/Desktop/SoMeNLP/data/Pubmed_fulltext/Pubmed_fulltext_bio_devel/"


#calculate the distribution of class_labels for pubmed
pubmed_whole_dict, pubmed_train_dict, pubmed_test_dict, pubmed_dev_dict = train_test_dev(pubmed_path_whole, 
                                                                                         pubmed_path_train, 
                                                                                         pubmed_path_test, 
                                                                                         pubmed_path_dev)


# calculate the proportion for each class label (8 - purposes)
pubmed_train_props, pubmed_dev_props, pubmed_test_props = __proportion_calculator(pubmed_whole_dict, 
                                                                                  pubmed_train_dict, 
                                                                                  pubmed_test_dict, 
                                                                                  pubmed_dev_dict)


print(f'pubmed train {pubmed_train_props}')
print(f'pubmed test {pubmed_test_props}')
print(f'pubmed dev {pubmed_dev_props}')

print()

print(f"pubmed train balanced ? {_within_range(pubmed_train_props)}")
print(f"pubmed test  balanced ? {_within_range(pubmed_test_props)}")
print(f"pubmed dev   balanced ? {_within_range(pubmed_dev_props)}")


# train percentage 60%
print()   
for (k,v), (k2,v2) in zip(pubmed_whole_dict.items(), pubmed_train_dict.items()):
    if k2 == k:
        print(f"{k2 :{18}}  {v2}/{v} train {v2/v*100: .2f}% ")
# Out:
# pubmed train [96, 96, 95, 100, 100, 100, 100]
# pubmed test [60, 56, 68, 62]
# pubmed dev [44, 68, 43, 29, 87, 25, 32]
#
# pubmed train balanced ? False
# pubmed test  balanced ? False
# pubmed dev   balanced ? False
#
# Analysis            298/309 train  96.44%
# DataCollection      48/50 train  96.00%
# DataPreProcss       71/74 train  95.95%
# Modelling           24/24 train  100.00%
# Programming         16/16 train  100.00%
# Simulation          4/4 train  100.00%
# Visualization       28/28 train  100.00%

# %% [markdown]
# # plos_pubmed_combined

# %%
in_path_comb = '/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined_bio/'
out_path_comb = '/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/'

split_data(in_path_comb, out_path_comb)
# Out:
# Done

# %%
in_path_comb = '/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined_bio/'
out_path_comb = '/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/'

split_data(in_path_comb, out_path_comb)

# combined plos pubmed bio   train , test , dev

comb_path_whole = '/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined_bio/'
comb_path_train = "/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/plos_pubmed_combined_bio_train/" 
comb_path_test = "/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/plos_pubmed_combined_bio_test/" 
comb_path_dev = "/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/plos_pubmed_combined_bio_devel/"
    
    
#calculate the distribution of class_labels for cmbined set
comb_whole_dict, comb_train_dict, comb_test_dict, comb_dev_dict = train_test_dev(comb_path_whole, 
                                                                                 comb_path_train, 
                                                                                 comb_path_test, 
                                                                                 comb_path_dev)


# calculate the proportion for each class label (8 - purposes)
comb_train_props, comb_dev_props, comb_test_props = __proportion_calculator(comb_whole_dict, 
                                                                            comb_train_dict, 
                                                                            comb_test_dict, 
                                                                            comb_dev_dict)

comb_train_split_result_ = _within_range_pubmed(comb_train_props)
comb_test_split_result_ = _within_range_pubmed(comb_test_props)
comb_dev_split_result_ = _within_range_pubmed(comb_dev_props)

#bool_ = (pubmed_train_split_result_) and (pubmed_test_split_result_) and (pubmed_dev_split_result_)

i = 0

while not(comb_train_split_result_):
    
    print(f'splitting ... loop {i}')
    
    split_data(in_path_comb, out_path_comb)
    
    i += 1
    
    
    #calculate the distribution of class_labels for cmbined set
    comb_whole_dict, comb_train_dict, comb_test_dict, comb_dev_dict = train_test_dev(comb_path_whole, 
                                                                                 comb_path_train, 
                                                                                 comb_path_test, 
                                                                                 comb_path_dev)


    # calculate the proportion for each class label (8 - purposes)
    comb_train_props, comb_dev_props, comb_test_props = __proportion_calculator(comb_whole_dict, 
                                                                            comb_train_dict, 
                                                                            comb_test_dict, 
                                                                            comb_dev_dict)
    #print('is the split fair ?')
    comb_split_result = _within_range(comb_train_props)
    

    
    
    if comb_split_result:
        
        print('plos_pubmed split is balanced. stopped splitting')
        
    else:
        
        shutil.rmtree(comb_path_train, ignore_errors=False, onerror=None)
        shutil.rmtree(comb_path_test, ignore_errors=False, onerror=None)
        shutil.rmtree(comb_path_dev, ignore_errors=False, onerror=None)
        
        print(f'plos_pubmed split is not yet balanced {comb_train_props}.  splitting further ...')
        print()
        
        
    
    #break
# Out:
# Done
# splitting ... loop 0
# Done
# plos_pubmed split is not yet balanced [79, 87, 84, 82, 75, 85, 88, 85].  splitting further ...
#
# splitting ... loop 1
# Done
# plos_pubmed split is not yet balanced [62, 66, 66, 59, 72, 39, 70, 60].  splitting further ...
#
# splitting ... loop 2
# Done
# plos_pubmed split is not yet balanced [59, 53, 53, 66, 55, 75, 73, 58].  splitting further ...
#
# splitting ... loop 3
# Done
# plos_pubmed split is not yet balanced [53, 54, 56, 48, 53, 75, 53, 65].  splitting further ...
#
# splitting ... loop 4
# Done
# plos_pubmed split is not yet balanced [58, 61, 46, 59, 65, 71, 76, 53].  splitting further ...
#
# splitting ... loop 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [56], in <module>
#      35 while not(comb_train_split_result_):
#      37     print(f'splitting ... loop {i}')
# ---> 39     split_data(in_path_comb, out_path_comb)
#      41     i += 1
#      44     #calculate the distribution of class_labels for cmbined set
#
# Input In [55], in split_data(in_path, out_path, file_ext, ratio, set_names)
#      47 for entry in single_files:
#      49     base_file_name = entry.name.split(file_ext)[0]
# ---> 51     base_file_entries = list(Path(in_path).rglob('{}*'.format(base_file_name)))
#      53     all_files.append(base_file_entries)
#      57 random.seed()
#
# File /usr/lib/python3.8/pathlib.py:1152, in Path.rglob(self, pattern)
#    1150     raise NotImplementedError("Non-relative patterns are unsupported")
#    1151 selector = _make_selector(("**",) + tuple(pattern_parts), self._flavour)
# -> 1152 for p in selector.select_from(self):
#    1153     yield p
#
# File /usr/lib/python3.8/pathlib.py:587, in _RecursiveWildcardSelector._select_from(self, parent_path, is_dir, exists, scandir)
#     585 successor_select = self.successor._select_from
#     586 for starting_point in self._iterate_directories(parent_path, is_dir, scandir):
# --> 587     for p in successor_select(starting_point, is_dir, exists, scandir):
#     588         if p not in yielded:
#     589             yield p
#
# File /usr/lib/python3.8/pathlib.py:535, in _WildcardSelector._select_from(self, parent_path, is_dir, exists, scandir)
#     533 try:
#     534     with scandir(parent_path) as scandir_it:
# --> 535         entries = list(scandir_it)
#     536     for entry in entries:
#     537         if self.dironly:
#
# KeyboardInterrupt:

# %%
comb_path_whole = '/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined_bio/'
comb_path_train = "/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/plos_pubmed_combined_bio_train/" 
comb_path_test = "/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/plos_pubmed_combined_bio_test/" 
comb_path_dev = "/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/plos_pubmed_combined_bio_devel/"
    
    
#calculate the distribution of class_labels for cmbined set
comb_whole_dict, comb_train_dict, comb_test_dict, comb_dev_dict = train_test_dev(comb_path_whole, 
                                                                                 comb_path_train, 
                                                                                 comb_path_test, 
                                                                                 comb_path_dev)


# calculate the proportion for each class label (8 - purposes)
comb_train_props, comb_dev_props, comb_test_props = __proportion_calculator(comb_whole_dict, 
                                                                            comb_train_dict, 
                                                                            comb_test_dict, 
                                                                            comb_dev_dict)

comb_train_split_result_ = _within_range_pubmed(comb_train_props)
comb_test_split_result_ = _within_range_pubmed(comb_test_props)
comb_dev_split_result_ = _within_range_pubmed(comb_dev_props)



print(f'pubmed train {comb_train_props}')
print(f'pubmed test {comb_test_props}')
print(f'pubmed dev {comb_dev_props}')

print()


print(f"pubmed train balanced ? {_within_range(comb_train_props)}")
print(f"pubmed test  balanced ? {_within_range(comb_test_props)}")
print(f"pubmed dev   balanced ? {_within_range(comb_dev_props)}")


# train percentage 60%
print()
for (k,v), (k2,v2) in zip(comb_train_dict.items(), comb_whole_dict.items()):
    if k2 == k:
        print(f"{k2 :{18}}  {v2}/{v} train {v2/v*100: .2f}% ")
# Out:
# pubmed train [56, 56, 57, 59, 81, 57, 73, 59]
# pubmed test [24, 14, 23, 16, 17, 39, 14, 21]
# pubmed dev [18, 28, 19, 24, 1, 3, 12, 18]
#
# pubmed train balanced ? False
# pubmed test  balanced ? False
# pubmed dev   balanced ? False
#
# Analysis            1436/818 train  175.55%
# DataCollection      246/140 train  175.71%
# DataPreProcss       335/192 train  174.48%
# Modelling           227/134 train  169.40%
# Programming         80/65 train  123.08%
# Simulation          28/16 train  175.00%
# Stimulation         71/52 train  136.54%
# Visualization       117/70 train  167.14%

# %%
from math import ceil


rand_ls = []

for i in range(10):
    
    random.seed()
    
    x = random.random()
    
    x_ceil = ceil(x * 100) / 100.0
    
    rand_ls.append(x_ceil)
    
rand_ls
# Out:
# [0.81, 0.51, 0.62, 0.31, 0.56, 0.89, 0.49, 0.9, 0.37, 1.0]
