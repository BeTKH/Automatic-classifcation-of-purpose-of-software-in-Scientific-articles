# %% [markdown]
# # 1. Merging Annotations
#
#
# ##  1.1 PLoS Methods
#
# - merge annotatios of software usage and purpose in PLoS files
# - Write merged annotations to a new folder **SoMeSci/PLoS_methodsClean/**
# - create a DataFRame for merged annotation in PLoS

# %%
import os
from os import listdir
from os.path import isfile, join


# we are interested only on annotations set of:  (software_usage and purpose annotations)

interest_list = ['Application_Usage','ProgrammingEnvironment_Usage',
                 'PlugIn_Usage','OperatingSystem_Usage', 'Purpose_Analysis',
                 'Purpose_Modelling', 'Purpose_Stimulation', 
                 'Purpose_DataCollection', 'Purpose_DataPreProcss', 
                 'Purpose_Simulation', 'Purpose_Visualization', 'Purpose_Programming', 
                 'Application_Creation', 'PlugIn_Creation',
                 'Application_Deposition', 'PlugIn_Deposition', 'SoftwareCoreference_Deposition',
                 'Application_Mention','ProgrammingEnvironment_Mention','OperatingSystem_Mention',
                 'PlugIn_Mention','Version','Developer', 'URL', 'License','Citation', 'Abbreviation', 
                 'AlternativeName', 'Release', 'Extension']

# file path
path = 'SoMeSci/PLoS_methods/'

# gather list of .ann PLoS_methods files ---------------------------------------------
PLOS_filesList = []

# iterating over all files in the dir
for file_name in os.listdir(path):
    
    # if the file is .ann
    if file_name.endswith('.ann'):
        PLOS_filesList.append(file_name)
    else:
        continue

PLOS_filesList.sort() 

print('.ann PLosMethods file count : ', len(PLOS_filesList), '\n')
print('Firts 5 files: ',PLOS_filesList[:5])

# gather list of .ann PLoS_methods files ---------------------------------------------
# Out:
# .ann PLosMethods file count :  480
#
# Firts 5 files:  ['PMC1088287.ann', 'PMC1657052.ann', 'PMC1831734.ann', 'PMC1880851.ann', 'PMC1939732.ann']

# %%
"""

There are different kinds of annotations in the .ann file. 
-----------------------------------------------------------

TYPES OF ANNOTATIONS

T - text bound annotations
R - relations
E - event
A - attribute
M - modification
N - Normalization 
-----------------------------------------------------------

We are interested in "text bound annotations only" that indicate software_usage and software_purpose.

Therefore get a list of all annotations in the .ann file iff:
        
        1. annotations are text bound ( start with T) & 
        2. annotations indicate software_usage or software_purpose
        
the result is then stored in a dictionary 

where,

    key of dict == name of the file 
    Value of dict == list of list of annotation lines in the file
"""

# stores ORIGIAL list of annotations in a file (BEFORE MERGING)
fileAn_dict = {}

# store all annotations in the file ( format: list-of-list)
annotation_filelist = []

# loop over each file 
for indx, file in enumerate(PLOS_filesList[:]):
    
    # path to each file
    file_path = path + file
    
    with open(file_path, "r") as a_file:
        
        # stores annotation line 
        annotation_line = []
        
        
        # check if the annotation is what we want (usage, purpose, starts with T )
        for line in a_file:
            
            # grab the type of annotation
            annotataion = line.split()[1:2][0]
            
            
            if (line.startswith('T') & (annotataion in interest_list)):

                if ( line.split()[2:4] ) not in annotation_line: 
                    
                    #print(line.split()[2:4])
                    
                    annotation_line.append(line.split())
                    #print(indx, file, line.split())

                else:
                    pass
        
        fileAn_dict[file] = annotation_line     
        
#fileAn_dict

print('The size of the mapping dictionary: ', len(fileAn_dict))
print('ALl files included!')
# Out:
# The size of the mapping dictionary:  480
# ALl files included!

# %%
fileAn_dict.get('PMC1657052.ann')
# Out:
# [['T1', 'Application_Usage', '3670', '3681', 'DS', 'modeling'],
#  ['T2', 'Application_Usage', '5677', '5683', 'pCLAMP'],
#  ['T3', 'Application_Usage', '1203', '1211', 'ENSEMBLE'],
#  ['T5', 'Developer', '1224', '1240', 'Sanger', 'Institute'],
#  ['T7', 'Version', '3699', '3702', '1.1'],
#  ['T8', 'Developer', '3704', '3712', 'Accelrys'],
#  ['T9', 'URL', '3714', '3737', 'http://www.accelrys.com'],
#  ['T10', 'Version', '5683', '5684', '9'],
#  ['T11', 'Developer', '5686', '5702', 'Axon', 'Instruments'],
#  ['T4', 'Purpose_Analysis', '1203', '1211', 'ENSEMBLE'],
#  ['T6', 'Purpose_Modelling', '3670', '3681', 'DS', 'modeling'],
#  ['T12', 'Purpose_DataCollection', '5677', '5683', 'pCLAMP']]

# %% [markdown]
# ### Merger Function
#
# Merges usage and purpose annotations into  `Type_Usage:Purpose_PurposeX`.
#
#
# - for example : `Application_Usage:Purpose_Analysis`

# %%
'''

each annotation line has a form of:

     [Tx | Annotation | START | STOP | nameOfSoftware]
     
     example: 'T2', 'Application_Usage', '13536', '13539', 'SAS'

mergeList() merges two lines of annotations if their start is the same

'''

def mergeList(list_1, list_2):
    
    #stores merged annotations
    result_list = []
    
    '''
    
     list_1[2:3] is START number 
     merge two annotations if their start number is the same
    
    '''
    
    for x, y in [(x,y) for x in list_1[2:3] for y in list_2[2:3]]:
        
        
        
        # if the starting positions are the same x=y
        if( x == y):
            
            #print(x)
            
            #get id of the firt annotation 
            result_list.append(list_1[0])
            
            #merge annotations by :
            result_list.append(list_1[1]+':'+list_2[1])
            
            # start number
            result_list.append(list_1[2])
            
            #end number
            result_list.append(list_1[3])
            
            # get name of the software
            software_name_splitted = list_1[4:]
            software_name_joined = ' '.join(software_name_splitted)
            
            result_list.append(software_name_joined)
    
            
        else:
            pass
    return result_list

# %% [markdown]
# #### Merging purpose annotations

# %%
# stores MERGED LIST of annotations in each file
merged_dict = {}

#stores list of list of all annotations
all_annotations_list = []


# for each file in the dict
for key in list(fileAn_dict)[:]:
    
    # stores list of merged annotations
    merged_annotationlist_perfile = []
    
    #print(key)
    """
    compare all annotations to each other and grab those that share the same "start number"
    
    """
    
    lookup_list1 = []
    for ls1 in fileAn_dict.get(key):
            
            
            lookup_list2 = []
            for ls2 in fileAn_dict.get(key):
                
                
                # compare each annotation with another but not to itself
                if (ls1 != ls2) :
                    
                    
                    # merge annotations
                    r = mergeList(ls1,ls2)
                    
                    # if the 
                    if len(r) !=0 :
                        
                        #print(ls1[0],ls2[0], ls1[2:4], ls2[2:4])
                        
                        #print(r)
                        
         
                        if (r[2] not in lookup_list1 ) | (r[3] not in lookup_list1 ):
                            
                            merged_annotationlist_perfile.append(r) 
                            all_annotations_list.append(r)
                            
                            lookup_list2.extend(r[2:4])
                            
                        else:
                            pass
            # save already merged list on the lookup list            
            lookup_list1.extend(lookup_list2)  
            #break
                        
                        
    merged_dict[key] = merged_annotationlist_perfile

# %%
merged_dict.get('PMC1657052.ann')
# Out:
# [['T1', 'Application_Usage:Purpose_Modelling', '3670', '3681', 'DS modeling'],
#  ['T2', 'Application_Usage:Purpose_DataCollection', '5677', '5683', 'pCLAMP'],
#  ['T3', 'Application_Usage:Purpose_Analysis', '1203', '1211', 'ENSEMBLE']]

# %%
for file in list(merged_dict)[:]:
    print('file:', file, '|',merged_dict.get(file), '\n\n')
# Out:
# file: PMC1088287.ann | []
#
#
# file: PMC1657052.ann | [['T1', 'Application_Usage:Purpose_Modelling', '3670', '3681', 'DS modeling'], ['T2', 'Application_Usage:Purpose_DataCollection', '5677', '5683', 'pCLAMP'], ['T3', 'Application_Usage:Purpose_Analysis', '1203', '1211', 'ENSEMBLE']]
#
#
# file: PMC1831734.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '1447', '1450', 'RIU'], ['T2', 'Application_Usage:Purpose_Analysis', '8512', '8517', 'Stata']]
#
#
# file: PMC1880851.ann | []
#
#
# file: PMC1939732.ann | [['T1', 'Application_Usage:Purpose_Modelling', '1984', '1990', 'AsReml'], ['T2', 'ProgrammingEnvironment_Usage:Purpose_Stimulation', '7238', '7244', 'MATLAB'], ['T3', 'Application_Usage:Purpose_Analysis', '7300', '7306', 'AsReml']]
#
#
# file: PMC2002515.ann | [['T1', 'Application_Usage:Purpose_Analysis', '12585', '12588', 'SAS'], ['T2', 'Application_Usage:Purpose_Analysis', '13536', '13539', 'SAS']]
#
#
# file: PMC2134966.ann | [['T1', 'Application_Usage:Purpose_Visualization', '874', '886', 'DS ViewerPro'], ['T2', 'Application_Usage:Purpose_Analysis', '6038', '6044', 'SHARP2'], ['T5', 'Application_Usage:Purpose_Analysis', '5819', '5831', 'ConSurf-HSSP']]
#
#
# file: PMC2214811.ann | []
#
#
# file: PMC2265305.ann | [['T1', 'Application_Usage:Purpose_Analysis', '3540', '3545', 'Stata'], ['T2', 'Application_Usage:Purpose_Modelling', '4256', '4261', 'Stata']]
#
#
# file: PMC2292255.ann | [['T1', 'Application_Usage:Purpose_Analysis', '7560', '7599', 'Statistical Package for Social Sciences']]
#
#
# file: PMC2323303.ann | [['T1', 'Application_Usage:Purpose_Analysis', '8891', '8896', 'Stata'], ['T2', 'Application_Usage:Purpose_Analysis', '8918', '8924', 'ArcGIS']]
#
#
# file: PMC2518622.ann | [['T1', 'Application_Usage:Purpose_Analysis', '6504', '6509', 'Prism']]
#
#
# file: PMC2614476.ann | []
#
#
# file: PMC2644762.ann | [['T1', 'Application_Usage:Purpose_Analysis', '2627', '2632', 'PLINK'], ['T3', 'Application_Usage:Purpose_Analysis', '3504', '3509', 'PLINK'], ['T4', 'Application_Usage:Purpose_Modelling', '3929', '3935', 'Primer'], ['T5', 'Application_Usage:Purpose_DataCollection', '5146', '5163', 'Mutation Surveyor'], ['T6', 'Application_Usage:Purpose_Analysis', '6653', '6658', 'BLAST'], ['T7', 'Application_Usage:Purpose_Analysis', '7396', '7410', 'Genome browser'], ['T8', 'Application_Usage:Purpose_Analysis', '7535', '7543', 'PolyPhen']]
#
#
# file: PMC2661960.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Programming', '3091', '3096', 'Basic']]
#
#
# file: PMC2721656.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4655', '4664', 'CellQuest'], ['T2', 'Application_Usage:Purpose_Analysis', '6087', '6126', 'Statistical Package for Social Sciences'], ['T3', 'Application_Usage:Purpose_Visualization', '6221', '6226', 'Prism']]
#
#
# file: PMC2728840.ann | [['T1', 'Application_Usage:Purpose_Analysis', '5500', '5504', 'SPSS']]
#
#
# file: PMC2730576.ann | [['T1', 'Application_Usage:Purpose_Analysis', '5733', '5737', 'SPSS'], ['T2', 'Application_Usage:Purpose_Analysis', '5845', '5848', 'JMP']]
#
#
# file: PMC2731885.ann | [['T1', 'Application_Usage:Purpose_Modelling', '1983', '1992', 'Structure'], ['T2', 'Application_Usage:Purpose_Modelling', '2006', '2014', 'ADMIXMAP']]
#
#
# file: PMC2740825.ann | [['T1', 'Application_Usage:Purpose_Analysis', '13186', '13196', 'Statistica']]
#
#
# file: PMC2777312.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4798', '4802', 'SPSS']]
#
#
# file: PMC2878316.ann | []
#
#
# file: PMC2943469.ann | []
#
#
# file: PMC2952602.ann | [['T1', 'Application_Usage:Purpose_Analysis', '5987', '6005', 'iQ5 Optical system']]
#
#
# file: PMC2953514.ann | [['T1', 'Application_Usage:Purpose_Analysis', '16701', '16706', 'Mplus'], ['T2', 'OperatingSystem_Usage:Purpose_Analysis', '16715', '16722', 'Windows'], ['T3', 'PlugIn_Usage:Purpose_DataPreProcss', '17121', '17131', 'AmeliaView'], ['T4', 'Application_Usage:Purpose_Modelling', '20089', '20094', 'MPlus']]
#
#
# file: PMC2970551.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4247', '4252', 'Stata']]
#
#
# file: PMC2987837.ann | [['T1', 'Application_Usage:Purpose_DataPreProcss', '2640', '2644', 'Mach'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '7057', '7061', 'Mach'], ['T4', 'Application_Usage:Purpose_Analysis', '10094', '10099', 'GRIMP'], ['T5', 'Application_Usage:Purpose_Analysis', '10359', '10364', 'METAL'], ['T6', 'Application_Usage:Purpose_Analysis', '11451', '11466', 'SPSS Statistics'], ['T7', 'Application_Usage:Purpose_Analysis', '11425', '11430', 'PLINK'], ['T8', 'Application_Usage:Purpose_Analysis', '11603', '11608', 'METAL'], ['T9', 'Application_Usage:Purpose_Analysis', '12213', '12218', 'PLINK'], ['T10', 'Application_Usage:Purpose_Analysis', '12237', '12252', 'SPSS Statistics'], ['T11', 'Application_Usage:Purpose_Analysis', '12641', '12646', 'PLINK'], ['T12', 'Application_Usage:Purpose_Analysis', '12846', '12851', 'METAL'], ['T15', 'Application_Usage:Purpose_Analysis', '6387', '6397', 'BeadStudio'], ['T22', 'Application_Usage:Purpose_Analysis', '10053', '10061', 'Mach2QTL']]
#
#
# file: PMC3004789.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4470', '4473', 'JMP'], ['T2', 'Application_Usage:Purpose_Analysis', '4475', '4478', 'JMP']]
#
#
# file: PMC3022523.ann | []
#
#
# file: PMC3027618.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Stimulation', '4769', '4775', 'MatLab']]
#
#
# file: PMC3029269.ann | [['T1', 'Application_Usage:Purpose_Analysis', '10705', '10713', 'Statview']]
#
#
# file: PMC3050879.ann | []
#
#
# file: PMC3055867.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Simulation', '4901', '4907', 'MATLAB'], ['T2', 'Application_Usage:Purpose_Stimulation', '5955', '5962', 'E-prime'], ['T3', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '6455', '6461', 'MATLAB'], ['T4', 'Application_Usage:Purpose_Analysis', '6366', '6396', 'statistical parametric mapping'], ['T5', 'Application_Usage:Purpose_Modelling', '11295', '11298', 'SPM'], ['T7', 'Application_Usage:Purpose_Analysis', '6398', '6401', 'SPM']]
#
#
# file: PMC3071806.ann | [['T1', 'Application_Usage:Purpose_Analysis', '3110', '3119', 'Photoshop'], ['T2', 'ProgrammingEnvironment_Usage:Purpose_Modelling', '5614', '5620', 'MATLAB'], ['T3', 'ProgrammingEnvironment_Usage:Purpose_Modelling', '5752', '5758', 'MATLAB'], ['T4', 'PlugIn_Usage:Purpose_Modelling', '5727', '5748', 'Curve Fitting Toolbox']]
#
#
# file: PMC3077394.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '6933', '6939', 'ImageJ'], ['T2', 'Application_Usage:Purpose_Analysis', '11012', '11017', 'Prism'], ['T3', 'OperatingSystem_Usage:Purpose_Analysis', '11026', '11031', 'MacOS']]
#
#
# file: PMC3078911.ann | []
#
#
# file: PMC3084698.ann | [['T1', 'Application_Usage:Purpose_Visualization', '93', '98', 'Flash'], ['T2', 'ProgrammingEnvironment_Usage:Purpose_Programming', '126', '138', 'Actionscript'], ['T4', 'Application_Usage:Purpose_Analysis', '2755', '2762', 'MacVide'], ['T5', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '3828', '3834', 'Matlab']]
#
#
# file: PMC3089627.ann | []
#
#
# file: PMC3098255.ann | []
#
#
# file: PMC3111463.ann | [['T1', 'Application_Usage:Purpose_Analysis', '3035', '3038', 'SAS']]
#
#
# file: PMC3120774.ann | [['T1', 'Application_Usage:Purpose_Analysis', '8074', '8079', 'STATA'], ['T8', 'Application_Usage:Purpose_Analysis', '8122', '8127', 'Stata']]
#
#
# file: PMC3127803.ann | []
#
#
# file: PMC3144942.ann | [['T1', 'Application_Usage:Purpose_Analysis', '5488', '5500', 'BrainVoyager']]
#
#
# file: PMC3148213.ann | []
#
#
# file: PMC3156136.ann | [['T1', 'Application_Usage:Purpose_Analysis', '9414', '9421', 'Image J'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '10008', '10013', 'Excel'], ['T3', 'Application_Usage:Purpose_Analysis', '10723', '10727', 'SPSS'], ['T4', 'OperatingSystem_Usage:Purpose_Analysis', '10737', '10744', 'Windows']]
#
#
# file: PMC3167846.ann | []
#
#
# file: PMC3173408.ann | [['T1', 'Application_Usage:Purpose_Analysis', '6071', '6076', 'Stata']]
#
#
# file: PMC3173492.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Programming', '2242', '2248', 'Python'], ['T2', 'PlugIn_Usage:Purpose_DataPreProcss', '2255', '2259', 'NLTK'], ['T16', 'Application_Usage:Purpose_DataCollection', '1615', '1660', 'Entrez Utilities Entrez Programming Utilities'], ['T6', 'Application_Usage:Purpose_DataPreProcss', '4479', '4493', 'Yahoo-BOSS API'], ['T8', 'Application_Usage:Purpose_DataPreProcss', '4813', '4823', 'Yahoo-BOSS']]
#
#
# file: PMC3176775.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '1221', '1227', 'Matlab']]
#
#
# file: PMC3177840.ann | [['T1', 'Application_Usage:Purpose_Visualization', '2948', '2959', 'LSM imaging'], ['T2', 'Application_Usage:Purpose_DataCollection', '6965', '6972', 'Openlab'], ['T3', 'Application_Usage:Purpose_Analysis', '9824', '9834', 'Chromeleon']]
#
#
# file: PMC3184170.ann | [['T1', 'Application_Usage:Purpose_Analysis', '7316', '7324', 'Videomot'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '10101', '10107', 'ImageJ'], ['T3', 'Application_Usage:Purpose_Analysis', '10156', '10161', 'Prism'], ['T4', 'Application_Usage:Purpose_Analysis', '12723', '12734', 'Patchmaster'], ['T5', 'Application_Usage:Purpose_DataPreProcss', '17120', '17133', 'Spectrum Mill'], ['T7', 'Application_Usage:Purpose_DataPreProcss', '20367', '20380', 'Spectrum Mill'], ['T8', 'Application_Usage:Purpose_Analysis', '20872', '20885', 'Spectrum Mill']]
#
#
# file: PMC3187751.ann | []
#
#
# file: PMC3197517.ann | []
#
#
# file: PMC3210121.ann | []
#
#
# file: PMC3258258.ann | []
#
#
# file: PMC3280282.ann | []
#
#
# file: PMC3282691.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4398', '4441', 'Statistical Package for the Social Sciences']]
#
#
# file: PMC3283723.ann | [['T1', 'Application_Usage:Purpose_Analysis', '1987', '1995', 'SeqScape'], ['T2', 'Application_Usage:Purpose_Analysis', '2240', '2248', 'Arlequin'], ['T3', 'Application_Usage:Purpose_Analysis', '2381', '2391', 'STATISTICA'], ['T4', 'Application_Usage:Purpose_Analysis', '2562', '2572', 'STATISTICA'], ['T5', 'Application_Usage:Purpose_Analysis', '3539', '3546', 'Network'], ['T6', 'Application_Usage:Purpose_Analysis', '3580', '3586', 'mtPhyl']]
#
#
# file: PMC3292581.ann | [['T1', 'Application_Usage:Purpose_DataPreProcss', '9197', '9203', 'ImageJ'], ['T2', 'Application_Usage:Purpose_Analysis', '9352', '9357', 'Prism'], ['T3', 'OperatingSystem_Usage:Purpose_Analysis', '9366', '9373', 'Windows']]
#
#
# file: PMC3293852.ann | [['T1', 'PlugIn_Usage:Purpose_Stimulation', '693', '701', 'STRAIGHT'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '1907', '1912', 'Praat'], ['T3', 'Application_Usage:Purpose_DataPreProcss', '2779', '2784', 'Praat'], ['T4', 'Application_Usage:Purpose_DataPreProcss', '2975', '2980', 'Praat']]
#
#
# file: PMC3293908.ann | []
#
#
# file: PMC3303470.ann | [['T1', 'Application_Usage:Purpose_DataPreProcss', '1801', '1806', 'CALIB'], ['T2', 'Application_Usage:Purpose_DataCollection', '3178', '3184', 'Mimics'], ['T4', 'Application_Usage:Purpose_DataCollection', '3714', '3721', 'Strand7'], ['T7', 'Application_Usage:Purpose_Visualization', '3794', '3801', 'Strand7']]
#
#
# file: PMC3305323.ann | []
#
#
# file: PMC3314648.ann | [['T1', 'Application_Usage:Purpose_Analysis', '5005', '5012', 'OpenEpi'], ['T2', 'Application_Usage:Purpose_Analysis', '5094', '5097', 'SAS']]
#
#
# file: PMC3338667.ann | [['T1', 'Application_Usage:Purpose_Analysis', '3588', '3598', 'PyroTagger'], ['T3', 'Application_Usage:Purpose_Analysis', '4676', '4682', 'blastn'], ['T4', 'Application_Usage:Purpose_Modelling', '5084', '5090', 'blastn'], ['T5', 'Application_Usage:Purpose_Modelling', '5466', '5475', 'EstimateS'], ['T6', 'Application_Usage:Purpose_Analysis', '6385', '6391', 'blastn'], ['T7', 'ProgrammingEnvironment_Usage:Purpose_DataPreProcss', '6776', '6780', 'Perl'], ['T8', 'Application_Usage:Purpose_Analysis', '6823', '6828', 'PCORD'], ['T9', 'Application_Usage:Purpose_DataPreProcss', '10152', '10166', 'RDP Classifier'], ['T10', 'Application_Usage:Purpose_DataPreProcss', '10313', '10321', 'Geneious'], ['T11', 'Application_Usage:Purpose_DataPreProcss', '10567', '10579', 'Bellerpheron'], ['T12', 'Application_Usage:Purpose_Analysis', '10755', '10761', 'MUSCLE'], ['T13', 'Application_Usage:Purpose_Analysis', '10769', '10777', 'Geneious'], ['T14', 'Application_Usage:Purpose_DataPreProcss', '11206', '11212', 'blastn'], ['T15', 'Application_Usage:Purpose_DataPreProcss', '11474', '11480', 'Blastn'], ['T16', 'Application_Usage:Purpose_DataPreProcss', '11754', '11758', 'MEGA'], ['T17', 'Application_Usage:Purpose_Analysis', '11801', '11806', 'DNAsp'], ['T18', 'Application_Usage:Purpose_Modelling', '12467', '12471', 'MEGA'], ['T19', 'Application_Usage:Purpose_Analysis', '14605', '14611', 'Blastn'], ['T2', 'Application_Usage:Purpose_Analysis', '3673', '3679', 'blastn']]
#
#
# file: PMC3341400.ann | [['T1', 'PlugIn_Usage:Purpose_Modelling', '5808', '5813', 'QUEST'], ['T2', 'PlugIn_Usage:Purpose_Modelling', '5826', '5847', 'Psychophysics Toolbox']]
#
#
# file: PMC3342258.ann | [['T1', 'Application_Usage:Purpose_Analysis', '3234', '3241', 'ImpaxEE']]
#
#
# file: PMC3355143.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '2067', '2070', 'SAS'], ['T2', 'Application_Usage:Purpose_Analysis', '9928', '9931', 'SAS'], ['T4', 'Application_Usage:Purpose_DataCollection', '2080', '2083', 'SAS']]
#
#
# file: PMC3355173.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '2059', '2069', 'Ethovision']]
#
#
# file: PMC3366939.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Stimulation', '1374', '1380', 'MATLAB'], ['T2', 'Application_Usage:Purpose_Stimulation', '2480', '2487', 'E-prime'], ['T3', 'PlugIn_Usage:Purpose_Stimulation', '1346', '1370', 'image processing toolbox'], ['T5', 'Application_Usage:Purpose_Stimulation', '2498', '2505', 'E-prime']]
#
#
# file: PMC3393741.ann | [['T1', 'Application_Usage:Purpose_Analysis', '7247', '7252', 'STATA']]
#
#
# file: PMC3394799.ann | [['T1', 'Application_Usage:Purpose_Analysis', '6680', '6689', 'Haploview'], ['T2', 'Application_Usage:Purpose_DataCollection', '8206', '8212', 'Access'], ['T3', 'Application_Usage:Purpose_Analysis', '8242', '8285', 'Statistical Package for the Social Sciences'], ['T4', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '8322', '8323', 'R']]
#
#
# file: PMC3397979.ann | [['T1', 'Application_Usage:Purpose_Analysis', '7429', '7432', 'SPM'], ['T2', 'PlugIn_Usage:Purpose_Modelling', '9372', '9379', 'Marsbar'], ['T3', 'Application_Usage:Purpose_DataPreProcss', '12489', '12492', 'SPM'], ['T4', 'Application_Usage:Purpose_DataPreProcss', '12462', '12471', 'Pickatlas']]
#
#
# file: PMC3402403.ann | [['T1', 'Application_Usage:Purpose_Analysis', '7960', '7963', 'SAS'], ['T2', 'Application_Usage:Purpose_DataCollection', '7860', '7868', 'Epi Info'], ['T3', 'Application_Usage:Purpose_DataCollection', '8409', '8415', 'MAXQDA'], ['T4', 'Application_Usage:Purpose_DataCollection', '8603', '8609', 'MAXQDA']]
#
#
# file: PMC3406004.ann | [['T1', 'Application_Usage:Purpose_Simulation', '5748', '5753', 'ADAPT'], ['T2', 'ProgrammingEnvironment_Usage:Purpose_Simulation', '5776', '5782', 'MATLAB']]
#
#
# file: PMC3407080.ann | []
#
#
# file: PMC3411727.ann | [['T1', 'Application_Usage:Purpose_Stimulation', '2707', '2713', 'Med-PC'], ['T2', 'Application_Usage:Purpose_DataCollection', '11717', '11723', 'Med-PC'], ['T3', 'Application_Usage:Purpose_DataCollection', '12952', '12957', 'Excel'], ['T4', 'Application_Usage:Purpose_DataCollection', '12870', '12875', 'MedPC'], ['T5', 'Application_Usage:Purpose_Visualization', '12990', '12995', 'Prism'], ['T6', 'Application_Usage:Purpose_Visualization', '12983', '12988', 'Excel'], ['T7', 'Application_Usage:Purpose_Visualization', '13034', '13045', 'Illustrator'], ['T8', 'Application_Usage:Purpose_Modelling', '13149', '13164', 'SPSS Statistics'], ['T12', 'Application_Usage:Purpose_DataCollection', '12969', '12975', 'Office']]
#
#
# file: PMC3418282.ann | []
#
#
# file: PMC3420877.ann | [['T1', 'Application_Usage:Purpose_Analysis', '2272', '2277', 'Prism'], ['T2', 'Application_Usage:Purpose_Analysis', '8843', '8850', 'Image J'], ['T3', 'Application_Usage:Purpose_Analysis', '9821', '9827', 'Instat']]
#
#
# file: PMC3420898.ann | [['T1', 'Application_Usage:Purpose_Stimulation', '4520', '4529', 'Cyberball'], ['T3', 'Application_Usage:Purpose_Analysis', '7482', '7485', 'SPM'], ['T4', 'Application_Usage:Purpose_DataPreProcss', '7893', '7896', 'SPM'], ['T5', 'Application_Usage:Purpose_Analysis', '8767', '8770', 'SPM'], ['T6', 'Application_Usage:Purpose_Analysis', '8920', '8923', 'SPM'], ['T7', 'Application_Usage:Purpose_Stimulation', '3459', '3468', 'Cyberball']]
#
#
# file: PMC3425502.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '9308', '9318', 'Chromeleon']]
#
#
# file: PMC3431302.ann | [['T1', 'Application_Usage:Purpose_Visualization', '8666', '8672', 'Crimap'], ['T2', 'Application_Usage:Purpose_Analysis', '8901', '8912', 'QTL Express'], ['T7', 'Application_Usage:Purpose_Analysis', '8939', '8944', 'qxpak'], ['T9', 'PlugIn_Usage:Purpose_Analysis', '8960', '8965', 'R/Qtl']]
#
#
# file: PMC3432100.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '2066', '2073', 'Digipro'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '8543', '8554', 'Scion image'], ['T3', 'Application_Usage:Purpose_Analysis', '10269', '10273', 'SPSS']]
#
#
# file: PMC3439430.ann | []
#
#
# file: PMC3459919.ann | [['T1', 'Application_Usage:Purpose_DataPreProcss', '874', '879', 'PLINK'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '1112', '1116', 'MACH'], ['T3', 'Application_Usage:Purpose_Analysis', '1735', '1740', 'PLINK'], ['T4', 'Application_Usage:Purpose_Modelling', '1274', '1282', 'Birdseye']]
#
#
# file: PMC3460928.ann | [['T1', 'Application_Usage:Purpose_Analysis', '5100', '5108', 'Aninhado'], ['T2', 'Application_Usage:Purpose_Analysis', '5490', '5498', 'netcarto'], ['T3', 'Application_Usage:Purpose_Analysis', '5508', '5513', 'Pajek'], ['T4', 'Application_Usage:Purpose_Analysis', '7174', '7182', 'netcarto'], ['T5', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '8899', '8900', 'R'], ['T9', 'PlugIn_Usage:Purpose_Analysis', '8901', '8910', 'bipartite']]
#
#
# file: PMC3466236.ann | [['T1', 'Application_Usage:Purpose_Analysis', '10207', '10219', 'BrainVoyager'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '12121', '12137', 'Tailarach Daemon']]
#
#
# file: PMC3485250.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4327', '4337', 'GENEMAPPER'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '4431', '4438', 'BIOEDIT'], ['T3', 'Application_Usage:Purpose_Analysis', '4515', '4523', 'ARLEQUIN'], ['T4', 'Application_Usage:Purpose_Programming', '4782', '4787', 'PHASE'], ['T5', 'Application_Usage:Purpose_Analysis', '4965', '4975', 'SPLITSTREE'], ['T6', 'Application_Usage:Purpose_Programming', '5060', '5070', 'Datamonkey'], ['T7', 'Application_Usage:Purpose_DataPreProcss', '5484', '5493', 'MODELTEST'], ['T8', 'Application_Usage:Purpose_Analysis', '5556', '5561', 'PhyML'], ['T9', 'Application_Usage:Purpose_Analysis', '5751', '5758', 'MRBAYES'], ['T10', 'Application_Usage:Purpose_Visualization', '6151', '6155', 'PAUP'], ['T11', 'Application_Usage:Purpose_Visualization', '6213', '6220', 'NETWORK'], ['T12', 'Application_Usage:Purpose_Analysis', '6550', '6558', 'ARLEQUIN'], ['T13', 'Application_Usage:Purpose_Analysis', '6614', '6621', 'GENEPOP'], ['T14', 'Application_Usage:Purpose_Analysis', '6817', '6824', 'GENEPOP'], ['T15', 'Application_Usage:Purpose_Analysis', '6884', '6888', 'MEGA'], ['T16', 'Application_Usage:Purpose_DataPreProcss', '7167', '7175', 'ARLEQUIN'], ['T17', 'Application_Usage:Purpose_Analysis', '7206', '7214', 'ARLEQUIN'], ['T18', 'Application_Usage:Purpose_Modelling', '7691', '7696', 'BEAST'], ['T19', 'Application_Usage:Purpose_Analysis', '8765', '8774', 'MODELTEST'], ['T20', 'Application_Usage:Purpose_Analysis', '9461', '9467', 'TRACER'], ['T21', 'Application_Usage:Purpose_Modelling', '9482', '9487', 'BEAST'], ['T22', 'Application_Usage:Purpose_Analysis', '9793', '9800', 'GENEPOP'], ['T23', 'Application_Usage:Purpose_Analysis', '9714', '9722', 'ARLEQUIN'], ['T24', 'Application_Usage:Purpose_Analysis', '9957', '9962', 'FSTAT'], ['T25', 'Application_Usage:Purpose_Analysis', '10097', '10102', 'FSTAT'], ['T26', 'Application_Usage:Purpose_Modelling', '10197', '10203', 'FREENA'], ['T27', 'Application_Usage:Purpose_DataPreProcss', '10244', '10257', 'MICRO-CHECKER'], ['T29', 'Application_Usage:Purpose_Modelling', '10369', '10378', 'STRUCTURE'], ['T30', 'Application_Usage:Purpose_Analysis', '10656', '10662', 'CLUMPP'], ['T31', 'Application_Usage:Purpose_Analysis', '10733', '10741', 'GENELAND'], ['T32', 'Application_Usage:Purpose_Visualization', '11201', '11209', 'DISTRUCT'], ['T33', 'Application_Usage:Purpose_DataPreProcss', '11341', '11349', 'ARLEQUIN'], ['T34', 'Application_Usage:Purpose_Analysis', '11587', '11595', 'ARLEQUIN'], ['T35', 'Application_Usage:Purpose_Analysis', '11600', '11607', 'SPAGeDI'], ['T36', 'Application_Usage:Purpose_Modelling', '12169', '12177', 'LAGRANGE'], ['T37', 'Application_Usage:Purpose_Analysis', '12542', '12547', 'BEAST'], ['T38', 'Application_Usage:Purpose_Modelling', '13144', '13150', 'DIYABC'], ['T41', 'Application_Usage:Purpose_Analysis', '10359', '10366', 'GENEPOP'], ['T42', 'Application_Usage:Purpose_Modelling', '11150', '11159', 'STRUCTURE'], ['T43', 'Application_Usage:Purpose_Analysis', '11164', '11172', 'GENELAND'], ['T44', 'Application_Usage:Purpose_Analysis', '11641', '11644', 'VIP'], ['T39', 'Application_Usage:Purpose_Analysis', '9546', '9555', 'Bioportal']]
#
#
# file: PMC3485322.ann | [['T1', 'Application_Usage:Purpose_Visualization', '6862', '6871', 'Cytoscape'], ['T2', 'Application_Usage:Purpose_Visualization', '7171', '7180', 'Cytoscape']]
#
#
# file: PMC3485355.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '6623', '6630', 'OOIBase']]
#
#
# file: PMC3494716.ann | [['T1', 'Application_Usage:Purpose_DataPreProcss', '8223', '8230', 'BioEdit'], ['T2', 'Application_Usage:Purpose_Analysis', '8127', '8143', 'Sequence Scanner'], ['T3', 'Application_Usage:Purpose_Analysis', '9543', '9551', 'Arlequin'], ['T4', 'Application_Usage:Purpose_Visualization', '9668', '9672', 'SPSS'], ['T5', 'Application_Usage:Purpose_Visualization', '9775', '9782', 'Network'], ['T6', 'Application_Usage:Purpose_Visualization', '10063', '10069', 'Surfer'], ['T7', 'Application_Usage:Purpose_Modelling', '9399', '9407', 'ArlequÃ\xadn']]
#
#
# file: PMC3498108.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Programming', '4999', '5005', 'MATLAB'], ['T2', 'Application_Usage:Purpose_Analysis', '4886', '4916', 'Statistical Parametric Mapping'], ['T3', 'Application_Usage:Purpose_Modelling', '8835', '8838', 'SPM'], ['T4', 'PlugIn_Usage:Purpose_Modelling', '8847', '8860', 'Anatomy atlas'], ['T5', 'Application_Usage:Purpose_Analysis', '4917', '4920', 'SPM']]
#
#
# file: PMC3509097.ann | [['T1', 'Application_Usage:Purpose_DataPreProcss', '703', '707', 'MEGA'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '804', '808', 'MEGA']]
#
#
# file: PMC3509157.ann | [['T2', 'Application_Usage:Purpose_Visualization', '4713', '4720', 'ProtÃ©gÃ©'], ['T3', 'Application_Usage:Purpose_Analysis', '5178', '5185', 'OntoFox'], ['T4', 'Application_Usage:Purpose_Visualization', '5251', '5258', 'ProtÃ©gÃ©']]
#
#
# file: PMC3514170.ann | [['T1', 'Application_Usage:Purpose_Analysis', '3213', '3216', 'JMP']]
#
#
# file: PMC3515570.ann | []
#
#
# file: PMC3515589.ann | [['T1', 'Application_Usage:Purpose_DataPreProcss', '6897', '6918', 'Brain Vision Analyzer'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '7632', '7654', 'FMRIB Software Library'], ['T3', 'Application_Usage:Purpose_DataPreProcss', '8187', '8190', 'FSL'], ['T4', 'Application_Usage:Purpose_DataPreProcss', '8103', '8106', 'FSL'], ['T5', 'Application_Usage:Purpose_Analysis', '12573', '12576', 'FSL'], ['T6', 'Application_Usage:Purpose_DataPreProcss', '13271', '13274', 'FSL'], ['T10', 'Application_Usage:Purpose_DataPreProcss', '7695', '7698', 'FSL']]
#
#
# file: PMC3515609.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '7964', '7969', 'Chart'], ['T2', 'Application_Usage:Purpose_Analysis', '10835', '10840', 'STATA'], ['T3', 'Application_Usage:Purpose_Stimulation', '9975', '9981', 'CANTAB'], ['T7', 'Application_Usage:Purpose_Analysis', '2769', '2820', 'Cambridge Neuropsychological Test Automated Battery']]
#
#
# file: PMC3520913.ann | []
#
#
# file: PMC3528761.ann | [['T1', 'Application_Usage:Purpose_Modelling', '26', '40', 'Skeeter Buster'], ['T5', 'Application_Usage:Purpose_Simulation', '3068', '3082', 'Skeeter Buster'], ['T6', 'Application_Usage:Purpose_Modelling', '179', '185', 'CIMSiM']]
#
#
# file: PMC3530491.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '7282', '7303', 'Brain Vision Recorder'], ['T2', 'Application_Usage:Purpose_Analysis', '9494', '9500', 'EEGlab']]
#
#
# file: PMC3532431.ann | [['T1', 'Application_Usage:Purpose_Modelling', '7480', '7490', 'STATISTICA']]
#
#
# file: PMC3536769.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '3852', '3858', 'MATLAB'], ['T2', 'Application_Usage:Purpose_Analysis', '7828', '7832', 'tnet'], ['T3', 'Application_Usage:Purpose_Analysis', '21252', '21256', 'tnet'], ['T4', 'Application_Usage:Purpose_Analysis', '1944', '1948', 'tnet']]
#
#
# file: PMC3536813.ann | [['T1', 'PlugIn_Usage:Purpose_Analysis', '5741', '5745', 'BVQX'], ['T2', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '5757', '5763', 'MATLAB'], ['T3', 'Application_Usage:Purpose_Analysis', '5671', '5683', 'BrainVoyager']]
#
#
# file: PMC3544705.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '9121', '9131', 'Videotrack'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '16837', '16846', 'Photoshop'], ['T3', 'Application_Usage:Purpose_Analysis', '18524', '18530', 'pClamp'], ['T4', 'Application_Usage:Purpose_Analysis', '19615', '19621', 'pClamp'], ['T5', 'Application_Usage:Purpose_Analysis', '19629', '19637', 'Igor pro'], ['T6', 'Application_Usage:Purpose_DataCollection', '19856', '19863', 'Visilog'], ['T7', 'Application_Usage:Purpose_Analysis', '20407', '20414', 'Visilog'], ['T8', 'Application_Usage:Purpose_Analysis', '9809', '9819', 'VideoTrack'], ['T9', 'Application_Usage:Purpose_Analysis', '10652', '10662', 'VideoTrack']]
#
#
# file: PMC3544906.ann | []
#
#
# file: PMC3549981.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4427', '4438', 'WinEpiscope'], ['T2', 'Application_Usage:Purpose_Analysis', '16167', '16171', 'NCSS']]
#
#
# file: PMC3554644.ann | [['T1', 'Application_Usage:Purpose_Analysis', '2095', '2122', 'Comprehensive Meta-Analysis']]
#
#
# file: PMC3555879.ann | [['T1', 'Application_Usage:Purpose_Analysis', '5503', '5507', 'SPSS']]
#
#
# file: PMC3561353.ann | [['T1', 'Application_Usage:Purpose_Analysis', '7585', '7595', 'GeneMapper'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '7679', '7682', 'FAP'], ['T3', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '14763', '14764', 'R'], ['T4', 'PlugIn_Usage:Purpose_Modelling', '15016', '15020', 'lme4'], ['T5', 'PlugIn_Usage:Purpose_Analysis', '15106', '15109', 'car'], ['T6', 'PlugIn_Usage:Purpose_Modelling', '15192', '15200', 'MCMCglmm'], ['T7', 'PlugIn_Usage:Purpose_Analysis', '15293', '15297', 'lme4']]
#
#
# file: PMC3566204.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '4482', '4487', 'BLAST'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '4654', '4658', 'MEGA'], ['T3', 'Application_Usage:Purpose_Analysis', '5196', '5206', 'genemapper'], ['T4', 'Application_Usage:Purpose_DataCollection', '5875', '5879', 'MEGA'], ['T5', 'Application_Usage:Purpose_DataPreProcss', '5844', '5853', 'Clustal W'], ['T6', 'Application_Usage:Purpose_DataPreProcss', '6005', '6009', 'MEGA'], ['T7', 'Application_Usage:Purpose_DataPreProcss', '6090', '6094', 'MEGA'], ['T8', 'Application_Usage:Purpose_DataPreProcss', '6229', '6234', 'DnaSP'], ['T9', 'Application_Usage:Purpose_Analysis', '6998', '7003', 'PAUP*'], ['T10', 'Application_Usage:Purpose_Visualization', '7365', '7372', 'Network'], ['T11', 'Application_Usage:Purpose_Modelling', '7535', '7542', 'MrBayes'], ['T12', 'Application_Usage:Purpose_Modelling', '7735', '7744', 'Modeltest'], ['T13', 'Application_Usage:Purpose_DataCollection', '8448', '8460', 'Google Earth'], ['T14', 'Application_Usage:Purpose_Analysis', '8735', '8743', 'Arlequin'], ['T15', 'Application_Usage:Purpose_Analysis', '8889', '8894', 'IBDWS'], ['T16', 'Application_Usage:Purpose_Analysis', '9256', '9264', 'Arlequin'], ['T17', 'Application_Usage:Purpose_Analysis', '9834', '9842', 'Arlequin'], ['T18', 'Application_Usage:Purpose_Modelling', '10312', '10317', 'beast'], ['T19', 'Application_Usage:Purpose_Modelling', '10842', '10851', 'Modeltest'], ['T20', 'Application_Usage:Purpose_Analysis', '11454', '11460', 'Tracer'], ['T21', 'Application_Usage:Purpose_DataPreProcss', '11579', '11590', 'LogCombiner'], ['T22', 'Application_Usage:Purpose_Visualization', '11676', '11689', 'TreeAnnotator'], ['T23', 'Application_Usage:Purpose_Visualization', '11707', '11715', 'Fig Tree'], ['T24', 'Application_Usage:Purpose_DataCollection', '11759', '11764', 'EXCEL'], ['T25', 'Application_Usage:Purpose_Analysis', '11844', '11852', 'Arlequin'], ['T26', 'Application_Usage:Purpose_Analysis', '11998', '12005', 'GenePop'], ['T27', 'Application_Usage:Purpose_Analysis', '12136', '12141', 'Fstat'], ['T28', 'Application_Usage:Purpose_Analysis', '12267', '12277', 'Bottleneck'], ['T29', 'Application_Usage:Purpose_Analysis', '12590', '12600', 'Bottleneck'], ['T30', 'Application_Usage:Purpose_Analysis', '12704', '12712', 'Arlequin'], ['T31', 'Application_Usage:Purpose_Analysis', '12772', '12781', 'Structure'], ['T32', 'Application_Usage:Purpose_Analysis', '13407', '13415', 'Geneland'], ['T33', 'Application_Usage:Purpose_Modelling', '14089', '14096', 'migrate'], ['T75', 'Application_Usage:Purpose_DataPreProcss', '11822', '11829', 'convert']]
#
#
# file: PMC3579796.ann | [['T1', 'Application_Usage:Purpose_Analysis', '20222', '20230', 'Statview']]
#
#
# file: PMC3587422.ann | [['T1', 'Application_Usage:Purpose_Analysis', '5480', '5484', 'PASW'], ['T2', 'OperatingSystem_Usage:Purpose_Analysis', '5490', '5497', 'Windows']]
#
#
# file: PMC3589395.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4158', '4172', 'Review Manager']]
#
#
# file: PMC3594295.ann | [['T1', 'Application_Usage:Purpose_Analysis', '6676', '6680', 'SPSS']]
#
#
# file: PMC3602039.ann | []
#
#
# file: PMC3603876.ann | [['T1', 'Application_Usage:Purpose_DataPreProcss', '3272', '3281', 'Dataquest'], ['T2', 'Application_Usage:Purpose_Modelling', '7764', '7770', 'Primer'], ['T3', 'Application_Usage:Purpose_Analysis', '8104', '8110', 'GeNorm'], ['T4', 'Application_Usage:Purpose_Analysis', '8659', '8665', 'GeNorm']]
#
#
# file: PMC3614510.ann | []
#
#
# file: PMC3615101.ann | []
#
#
# file: PMC3621674.ann | [['T1', 'Application_Usage:Purpose_DataPreProcss', '4921', '4929', 'ATLAS.ti'], ['T2', 'Application_Usage:Purpose_Analysis', '5507', '5511', 'SPSS'], ['T3', 'Application_Usage:Purpose_DataCollection', '5429', '5435', 'Access']]
#
#
# file: PMC3629137.ann | [['T1', 'Application_Usage:Purpose_Analysis', '5605', '5609', 'SPSS']]
#
#
# file: PMC3629193.ann | [['T1', 'Application_Usage:Purpose_Analysis', '12306', '12321', 'PASW Statistics']]
#
#
# file: PMC3633849.ann | [['T1', 'Application_Usage:Purpose_Analysis', '7719', '7724', 'Stata']]
#
#
# file: PMC3641137.ann | [['T1', 'Application_Usage:Purpose_Analysis', '7810', '7815', 'Stata']]
#
#
# file: PMC3643955.ann | [['T1', 'Application_Usage:Purpose_Analysis', '6883', '6891', 'JWatcher'], ['T2', 'Application_Usage:Purpose_Analysis', '9232', '9236', 'SPSS'], ['T3', 'Application_Usage:Purpose_DataCollection', '8455', '8462', 'Digilab']]
#
#
# file: PMC3655978.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '6750', '6756', 'Matlab'], ['T2', 'Application_Usage:Purpose_Analysis', '6737', '6745', 'ScopeWin']]
#
#
# file: PMC3660501.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '8934', '8953', 'Stereo investigator'], ['T2', 'Application_Usage:Purpose_Analysis', '10263', '10268', 'excel']]
#
#
# file: PMC3664640.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '4535', '4557', 'MassHunter Acquisition'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '4751', '4782', 'MassHunter Qualitative Analysis'], ['T3', 'Application_Usage:Purpose_Analysis', '5854', '5880', 'Mass Profiler Professional'], ['T4', 'Application_Usage:Purpose_Analysis', '6532', '6558', 'Mass Profiler Professional'], ['T5', 'Application_Usage:Purpose_Analysis', '7365', '7370', 'Prism']]
#
#
# file: PMC3669023.ann | [['T1', 'Application_Usage:Purpose_Analysis', '9988', '9991', 'SAS']]
#
#
# file: PMC3673943.ann | []
#
#
# file: PMC3679178.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_DataPreProcss', '453', '459', 'Matlab'], ['T2', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '941', '947', 'Matlab']]
#
#
# file: PMC3683044.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '3811', '3821', 'GPS Sample'], ['T2', 'OperatingSystem_Usage:Purpose_DataCollection', '3826', '3840', 'Windows Mobile'], ['T3', 'Application_Usage:Purpose_Analysis', '7768', '7773', 'STATA']]
#
#
# file: PMC3699512.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '3885', '3891', 'ArcGIS'], ['T2', 'Application_Usage:Purpose_DataCollection', '6369', '6375', 'ArcMap'], ['T3', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '8999', '9000', 'R']]
#
#
# file: PMC3699520.ann | [['T1', 'Application_Usage:Purpose_Analysis', '5589', '5592', 'SAS']]
#
#
# file: PMC3701628.ann | [['T1', 'Application_Usage:Purpose_Analysis', '583', '590', 'G*Power'], ['T3', 'Application_Usage:Purpose_DataCollection', '1765', '1782', 'Experiment Center'], ['T4', 'Application_Usage:Purpose_DataCollection', '1788', '1795', 'iView X'], ['T5', 'Application_Usage:Purpose_Stimulation', '9502', '9508', 'BeGaze']]
#
#
# file: PMC3709901.ann | [['T1', 'Application_Usage:Purpose_Analysis', '1895', '1898', 'SAS']]
#
#
# file: PMC3712955.ann | [['T1', 'Application_Usage:Purpose_Analysis', '1674', '1679', 'BLAST'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '1772', '1780', 'ClustalW'], ['T3', 'Application_Usage:Purpose_Modelling', '1858', '1863', 'SMART'], ['T4', 'Application_Usage:Purpose_Modelling', '1902', '1909', 'SignalP'], ['T5', 'Application_Usage:Purpose_DataPreProcss', '2057', '2063', 'Muscle'], ['T6', 'Application_Usage:Purpose_Visualization', '2171', '2176', 'PhyML'], ['T7', 'Application_Usage:Purpose_Modelling', '2405', '2413', 'I-TASSER'], ['T8', 'Application_Usage:Purpose_Analysis', '3973', '4016', 'Statistical Package for the Social Sciences'], ['T9', 'Application_Usage:Purpose_Analysis', '9529', '9535', 'MASCOT'], ['T10', 'Application_Usage:Purpose_Stimulation', '10053', '10064', 'GlobalWorks'], ['T21', 'Application_Usage:Purpose_Analysis', '4027', '4031', 'SPSS']]
#
#
# file: PMC3723741.ann | [['T1', 'Application_Usage:Purpose_Analysis', '9005', '9010', 'Stata']]
#
#
# file: PMC3728110.ann | [['T1', 'Application_Usage:Purpose_Analysis', '6022', '6025', 'SAS'], ['T2', 'Application_Usage:Purpose_Analysis', '6092', '6097', 'Stata']]
#
#
# file: PMC3738546.ann | [['T1', 'Application_Usage:Purpose_Stimulation', '1439', '1446', 'E-Prime']]
#
#
# file: PMC3747168.ann | []
#
#
# file: PMC3757022.ann | []
#
#
# file: PMC3760870.ann | []
#
#
# file: PMC3790745.ann | [['T1', 'Application_Usage:Purpose_Analysis', '5747', '5753', 'MAXQDA']]
#
#
# file: PMC3792883.ann | [['T1', 'Application_Usage:Purpose_Analysis', '7670', '7675', 'Gower'], ['T2', 'Application_Usage:Purpose_Analysis', '8717', '8726', 'Bootstrap'], ['T3', 'Application_Usage:Purpose_Analysis', '8938', '8942', 'SPSS'], ['T6', 'Application_Usage:Purpose_Analysis', '8767', '8776', 'Bootstrap']]
#
#
# file: PMC3798718.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '6153', '6154', 'R'], ['T2', 'PlugIn_Usage:Purpose_Analysis', '6126', '6137', 'sensitivity']]
#
#
# file: PMC3804575.ann | [['T1', 'Application_Usage:Purpose_Visualization', '3441', '3446', 'PRISM'], ['T4', 'Application_Usage:Purpose_Analysis', '3823', '3828', 'Excel']]
#
#
# file: PMC3804580.ann | []
#
#
# file: PMC3818257.ann | [['T1', 'Application_Usage:Purpose_Analysis', '7125', '7137', 'BrainVoyager'], ['T2', 'Application_Usage:Purpose_Analysis', '8681', '8694', 'Brain Voyager']]
#
#
# file: PMC3827111.ann | [['T3', 'Application_Usage:Purpose_Programming', '2291', '2298', 'dcm4che'], ['T6', 'PlugIn_Usage:Purpose_Programming', '2413', '2421', 'dcm4chee'], ['T7', 'Application_Usage:Purpose_Programming', '2475', '2481', 'OsiriX'], ['T13', 'Application_Usage:Purpose_Programming', '3643', '3649', 'OsiriX'], ['T18', 'ProgrammingEnvironment_Usage:Purpose_Programming', '3958', '3969', 'Objective-C'], ['T19', 'ProgrammingEnvironment_Usage:Purpose_Programming', '4005', '4006', 'C'], ['T20', 'ProgrammingEnvironment_Usage:Purpose_Programming', '4007', '4010', 'C++'], ['T21', 'ProgrammingEnvironment_Usage:Purpose_Programming', '4011', '4022', 'Objective-C'], ['T22', 'PlugIn_Usage:Purpose_Programming', '2399', '2407', 'dcm4chee']]
#
#
# file: PMC3840028.ann | []
#
#
# file: PMC3885438.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '6170', '6171', 'R']]
#
#
# file: PMC3885597.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4960', '4964', 'ENVI'], ['T2', 'Application_Usage:Purpose_Analysis', '6227', '6259', 'geo-spatial modeling environment'], ['T3', 'Application_Usage:Purpose_Analysis', '6303', '6312', 'Fragstats'], ['T4', 'Application_Usage:Purpose_Modelling', '8255', '8260', 'STATA'], ['T5', 'Application_Usage:Purpose_Analysis', '10601', '10607', 'ArcGIS'], ['T15', 'PlugIn_Usage:Purpose_Analysis', '10608', '10626', 'Spatial Statistics']]
#
#
# file: PMC3893159.ann | [['T1', 'Application_Usage:Purpose_DataPreProcss', '3798', '3806', 'Igor Pro']]
#
#
# file: PMC3896435.ann | [['T1', 'Application_Usage:Purpose_Stimulation', '948', '960', 'Presentation'], ['T2', 'Application_Usage:Purpose_DataCollection', '2260', '2272', 'Presentation'], ['T3', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '3614', '3620', 'MATLAB'], ['T4', 'Application_Usage:Purpose_Analysis', '3671', '3686', 'SPSS Statistics'], ['T5', 'Application_Usage:Purpose_Analysis', '5100', '5112', 'BrainVoyager'], ['T6', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '5198', '5204', 'MATLAB'], ['T7', 'Application_Usage:Purpose_Analysis', '5210', '5225', 'SPSS Statistics'], ['T12', 'Application_Usage:Purpose_Analysis', '3688', '3703', 'PASW Statistics']]
#
#
# file: PMC3900730.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4780', '4785', 'STATA'], ['T2', 'Application_Usage:Purpose_Modelling', '4835', '4840', 'MLwiN']]
#
#
# file: PMC3919787.ann | [['T2', 'Application_Usage:Purpose_Analysis', '6837', '6841', 'SPSS'], ['T3', 'OperatingSystem_Usage:Purpose_Analysis', '6855', '6862', 'Windows']]
#
#
# file: PMC3925163.ann | [['T1', 'Application_Usage:Purpose_Analysis', '2872', '2875', 'SPM'], ['T2', 'PlugIn_Usage:Purpose_DataCollection', '3292', '3363', 'Diffeomorphic Anatomical Registration Through Exponentiated Lie Algebra'], ['T3', 'Application_Usage:Purpose_Analysis', '3917', '3920', 'SPM'], ['T4', 'Application_Usage:Purpose_DataPreProcss', '4433', '4437', 'REST'], ['T5', 'PlugIn_Usage:Purpose_DataPreProcss', '4398', '4406', 'AlphaSim']]
#
#
# file: PMC3938425.ann | []
#
#
# file: PMC3944928.ann | [['T1', 'Application_Usage:Purpose_Visualization', '808', '814', 'ArcGIS'], ['T2', 'Application_Usage:Purpose_Visualization', '836', '847', 'Photofiltre'], ['T3', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '1438', '1439', 'R'], ['T4', 'Application_Usage:Purpose_Modelling', '4177', '4186', 'EstimateS'], ['T5', 'ProgrammingEnvironment_Usage:Purpose_Modelling', '5398', '5399', 'R'], ['T6', 'PlugIn_Usage:Purpose_Modelling', '5408', '5412', 'lme4']]
#
#
# file: PMC3948886.ann | [['T1', 'Application_Usage:Purpose_DataPreProcss', '4572', '4575', 'SPM'], ['T2', 'Application_Usage:Purpose_Modelling', '9883', '9886', 'SPM'], ['T3', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '10709', '10715', 'Matlab']]
#
#
# file: PMC3954587.ann | [['T1', 'Application_Usage:Purpose_Stimulation', '243', '267', 'EASY RA1 Easy Randomizer'], ['T2', 'Application_Usage:Purpose_Visualization', '1459', '1469', 'PowerPoint'], ['T3', 'Application_Usage:Purpose_Visualization', '2160', '2170', 'PowerPoint'], ['T4', 'Application_Usage:Purpose_DataPreProcss', '8541', '8546', 'Excel'], ['T5', 'Application_Usage:Purpose_Analysis', '8590', '8593', 'SAS']]
#
#
# file: PMC3954845.ann | [['T1', 'Application_Usage:Purpose_Analysis', '8921', '8924', 'SPM'], ['T2', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '9023', '9029', 'MATLAB'], ['T3', 'PlugIn_Usage:Purpose_DataPreProcss', '9192', '9200', 'Fieldmap'], ['T4', 'Application_Usage:Purpose_DataPreProcss', '9226', '9229', 'SPM']]
#
#
# file: PMC3960144.ann | []
#
#
# file: PMC3961335.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Programming', '644', '650', 'Matlab'], ['T2', 'PlugIn_Usage:Purpose_Programming', '670', '682', 'Psychtoolbox'], ['T4', 'ProgrammingEnvironment_Usage:Purpose_Modelling', '3024', '3030', 'Matlab']]
#
#
# file: PMC3966771.ann | [['T1', 'Application_Usage:Purpose_Analysis', '6586', '6591', 'Stata']]
#
#
# file: PMC3968121.ann | [['T1', 'Application_Usage:Purpose_Analysis', '9278', '9286', 'Actiware'], ['T2', 'Application_Usage:Purpose_Analysis', '11167', '11170', 'SAS'], ['T3', 'Application_Usage:Purpose_Analysis', '12837', '12840', 'SAS']]
#
#
# file: PMC3974736.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '4934', '4940', 'Access'], ['T2', 'Application_Usage:Purpose_DataCollection', '4947', '4954', 'EpiInfo'], ['T3', 'Application_Usage:Purpose_Analysis', '4988', '4992', 'SPSS'], ['T4', 'OperatingSystem_Usage:Purpose_Analysis', '5014', '5021', 'Windows'], ['T5', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '5076', '5077', 'R'], ['T7', 'Application_Usage:Purpose_Analysis', '4994', '5009', 'SPSS Statistics']]
#
#
# file: PMC3974756.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4314', '4352', 'Statistical Package for Social Science'], ['T2', 'Application_Usage:Purpose_Analysis', '4410', '4413', 'SAS'], ['T3', 'OperatingSystem_Usage:Purpose_Analysis', '4440', '4447', 'Windows'], ['T15', 'Application_Usage:Purpose_Analysis', '4425', '4428', 'SAS']]
#
#
# file: PMC3976311.ann | [['T1', 'Application_Usage:Purpose_Analysis', '8752', '8791', 'Statistical Package for Social Sciences'], ['T2', 'OperatingSystem_Usage:Purpose_Analysis', '8803', '8810', 'Windows']]
#
#
# file: PMC3977835.ann | [['T1', 'Application_Usage:Purpose_Modelling', '1367', '1373', 'Maxent'], ['T2', 'Application_Usage:Purpose_Modelling', '4547', '4580', "Hawth's analysis tools for ArcGis"], ['T3', 'PlugIn_Usage:Purpose_Modelling', '5364', '5379', 'Spatial Analyst'], ['T4', 'Application_Usage:Purpose_Modelling', '5381', '5387', 'ArcGis'], ['T5', 'PlugIn_Usage:Purpose_Modelling', '5519', '5534', 'Spatial Analyst']]
#
#
# file: PMC3986106.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '4354', '4362', 'Epi Info'], ['T2', 'Application_Usage:Purpose_Analysis', '4486', '4491', 'Stata']]
#
#
# file: PMC3995918.ann | [['T1', 'Application_Usage:Purpose_Analysis', '3803', '3808', 'STATA']]
#
#
# file: PMC4006795.ann | [['T1', 'Application_Usage:Purpose_Analysis', '7587', '7592', 'Stata'], ['T2', 'Application_Usage:Purpose_Analysis', '9184', '9189', 'Stata']]
#
#
# file: PMC4028183.ann | [['T1', 'Application_Usage:Purpose_Analysis', '14143', '14148', 'Stata']]
#
#
# file: PMC4028276.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '8422', '8431', 'EyeVision'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '8258', '8267', 'EyeVision'], ['T3', 'Application_Usage:Purpose_Analysis', '13406', '13410', 'SPSS']]
#
#
# file: PMC4047120.ann | [['T1', 'PlugIn_Usage:Purpose_Analysis', '1619', '1628', 'DTV.II SR'], ['T2', 'Application_Usage:Purpose_Analysis', '2197', '2205', 'Virtuoso'], ['T3', 'Application_Usage:Purpose_Analysis', '9305', '9311', 'Primer'], ['T4', 'Application_Usage:Purpose_DataPreProcss', '11872', '11881', 'MetaMorph'], ['T5', 'Application_Usage:Purpose_Analysis', '13971', '14014', 'Statistical Package for the Social Sciences'], ['T11', 'Application_Usage:Purpose_Analysis', '14016', '14020', 'SPSS'], ['T14', 'Application_Usage:Purpose_Analysis', '1772', '1780', 'Volume 1']]
#
#
# file: PMC4057118.ann | [['T1', 'Application_Usage:Purpose_DataPreProcss', '8072', '8077', 'Nvivo']]
#
#
# file: PMC4070976.ann | []
#
#
# file: PMC4079667.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Modelling', '15200', '15201', 'R'], ['T2', 'PlugIn_Usage:Purpose_Modelling', '15211', '15216', 'Mixer'], ['T3', 'ProgrammingEnvironment_Usage:Purpose_Modelling', '15645', '15651', 'Matlab'], ['T4', 'PlugIn_Usage:Purpose_Modelling', '15653', '15679', 'Brain Connectivity Toolbox'], ['T5', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '16726', '16727', 'R'], ['T6', 'ProgrammingEnvironment_Usage:Purpose_Modelling', '16785', '16786', 'R'], ['T11', 'PlugIn_Usage:Purpose_Analysis', '16704', '16721', 'adjustedRandIndex'], ['T14', 'PlugIn_Usage:Purpose_Modelling', '16797', '16801', 'lmer']]
#
#
# file: PMC4079709.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Modelling', '53', '60', 'NetLogo']]
#
#
# file: PMC4081795.ann | [['T1', 'Application_Usage:Purpose_Programming', '2250', '2260', 'Visual C++'], ['T2', 'ProgrammingEnvironment_Usage:Purpose_DataPreProcss', '4072', '4078', 'Matlab'], ['T3', 'Application_Usage:Purpose_Analysis', '10976', '10991', 'SPSS Statistics']]
#
#
# file: PMC4084914.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4044', '4051', 'EpiInfo'], ['T2', 'Application_Usage:Purpose_Analysis', '4062', '4067', 'Stata']]
#
#
# file: PMC4091876.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '4554', '4555', 'R'], ['T2', 'PlugIn_Usage:Purpose_Analysis', '4543', '4546', 'car'], ['T3', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '7093', '7094', 'R']]
#
#
# file: PMC4110050.ann | [['T1', 'Application_Usage:Purpose_Analysis', '2921', '2925', 'SPSS']]
#
#
# file: PMC4111290.ann | [['T1', 'Application_Usage:Purpose_DataPreProcss', '3223', '3231', 'Goldwave'], ['T2', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '6045', '6051', 'Matlab'], ['T3', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '6734', '6740', 'Matlab'], ['T4', 'ProgrammingEnvironment_Usage:Purpose_Programming', '8566', '8572', 'Matlab'], ['T5', 'ProgrammingEnvironment_Usage:Purpose_Modelling', '12821', '12827', 'Matlab'], ['T6', 'ProgrammingEnvironment_Usage:Purpose_Modelling', '18464', '18470', 'Matlab'], ['T7', 'PlugIn_Usage:Purpose_Modelling', '18441', '18460', 'Statistical Toolbox']]
# file: PMC4113310.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '2994', '3001', 'Endnote'], ['T2', 'Application_Usage:Purpose_DataCollection', '3005', '3010', 'Sente']]
#
#
# file: PMC4121144.ann | []
#
#
# file: PMC4125212.ann | [['T1', 'Application_Usage:Purpose_Modelling', '5970', '5992', 'MassARRAY Assay Design'], ['T2', 'Application_Usage:Purpose_DataCollection', '6497', '6512', 'MassARRAY Typer'], ['T3', 'Application_Usage:Purpose_Analysis', '6838', '6845', 'GENEPOP'], ['T4', 'Application_Usage:Purpose_Simulation', '6913', '6918', 'CLUMP'], ['T5', 'Application_Usage:Purpose_Analysis', '7230', '7269', 'Statistical Package for Social Sciences'], ['T6', 'OperatingSystem_Usage:Purpose_Analysis', '7288', '7295', 'windows'], ['T7', 'Application_Usage:Purpose_Analysis', '7409', '7412', '2LD'], ['T8', 'Application_Usage:Purpose_Modelling', '7462', '7474', 'GENECOUNTING'], ['T9', 'Application_Usage:Purpose_Analysis', '8205', '8208', 'PGA'], ['T11', 'Application_Usage:Purpose_DataCollection', '4914', '4923', 'Haploview']]
#
#
# file: PMC4126730.ann | []
#
#
# file: PMC4153588.ann | [['T1', 'Application_Usage:Purpose_Visualization', '9581', '9593', 'Presentation'], ['T2', 'Application_Usage:Purpose_Analysis', '14855', '14869', 'WFU-pick atlas'], ['T3', 'Application_Usage:Purpose_Analysis', '15695', '15698', 'SPM'], ['T4', 'Application_Usage:Purpose_Modelling', '16754', '16757', 'SPM'], ['T5', 'PlugIn_Usage:Purpose_DataCollection', '17545', '17552', 'MarsBar'], ['T6', 'Application_Usage:Purpose_Analysis', '17948', '17951', 'SPM']]
#
#
# file: PMC4153678.ann | []
#
#
# ...
#
#
# file: PMC5965841.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '5947', '5953', 'Matlab'], ['T2', 'Application_Usage:Purpose_Modelling', '6462', '6501', 'Statistical Package for Social Sciences']]
#
#
# file: PMC5973846.ann | [['T1', 'Application_Usage:Purpose_Analysis', '3630', '3633', 'SAS']]
#
#
# file: PMC5976182.ann | [['T1', 'Application_Usage:Purpose_Analysis', '3715', '3720', 'Stata']]
#
#
# file: PMC5983414.ann | []
#
#
# file: PMC5988334.ann | [['T2', 'Application_Usage:Purpose_Modelling', '327', '337', 'RabiesEcon'], ['T3', 'Application_Usage:Purpose_DataCollection', '598', '608', 'RabiesEcon'], ['T5', 'Application_Usage:Purpose_Analysis', '1731', '1741', 'RabiesEcon']]
#
#
# file: PMC5995370.ann | []
#
#
# file: PMC6016926.ann | [['T1', 'Application_Usage:Purpose_Analysis', '6805', '6809', 'SPSS']]
#
#
# file: PMC6028105.ann | []
#
#
# file: PMC6033422.ann | [['T1', 'Application_Usage:Purpose_Analysis', '5125', '5128', 'SAS']]
#
#
# file: PMC6042701.ann | [['T1', 'Application_Usage:Purpose_Programming', '7778', '7786', 'Inquisit'], ['T2', 'Application_Usage:Purpose_Modelling', '7907', '7915', 'Inquisit'], ['T3', 'Application_Usage:Purpose_DataPreProcss', '25365', '25370', 'Stata'], ['T4', 'Application_Usage:Purpose_Analysis', '25586', '25591', 'Stata'], ['T5', 'Application_Usage:Purpose_Visualization', '26260', '26265', 'Stata']]
#
#
# file: PMC6054378.ann | []
#
#
# file: PMC6059445.ann | [['T1', 'Application_Usage:Purpose_Analysis', '2506', '2510', 'SPSS'], ['T2', 'Application_Usage:Purpose_Analysis', '2496', '2501', 'Stata'], ['T3', 'Application_Usage:Purpose_Modelling', '2807', '2812', 'Stata']]
#
#
# file: PMC6061979.ann | [['T1', 'Application_Usage:Purpose_Simulation', '8813', '8819', 'NEURON'], ['T2', 'Application_Usage:Purpose_Simulation', '8931', '8937', 'NEURON']]
#
#
# file: PMC6062014.ann | [['T1', 'Application_Usage:Purpose_Analysis', '7555', '7559', 'JASP']]
#
#
# file: PMC6063436.ann | [['T1', 'Application_Usage:Purpose_Analysis', '2796', '2800', 'PAST'], ['T2', 'Application_Usage:Purpose_Analysis', '4225', '4229', 'PAST']]
#
#
# file: PMC6066197.ann | []
#
#
# file: PMC6084954.ann | [['T1', 'Application_Usage:Purpose_Analysis', '6104', '6119', 'SPSS Statistics']]
#
#
# file: PMC6086460.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4141', '4146', 'Stata']]
#
#
# file: PMC6093656.ann | [['T1', 'Application_Usage:Purpose_Analysis', '3599', '3604', 'STATA']]
#
#
# file: PMC6097700.ann | [['T1', 'Application_Usage:Purpose_DataPreProcss', '1522', '1527', 'GREAT'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '1809', '1814', 'GREAT'], ['T3', 'Application_Usage:Purpose_DataPreProcss', '2219', '2224', 'GREAT'], ['T4', 'Application_Usage:Purpose_Analysis', '2370', '2375', 'GREAT'], ['T5', 'Application_Usage:Purpose_Analysis', '2576', '2581', 'GREAT'], ['T6', 'Application_Usage:Purpose_DataPreProcss', '3113', '3120', 'BioMart'], ['T7', 'Application_Usage:Purpose_Analysis', '6044', '6049', 'MAGMA'], ['T9', 'Application_Usage:Purpose_Analysis', '7216', '7221', 'MAGMA'], ['T12', 'Application_Usage:Purpose_Visualization', '7572', '7577', 'MAGMA'], ['T13', 'Application_Usage:Purpose_DataPreProcss', '9948', '9955', 'BioMart'], ['T16', 'Application_Usage:Purpose_DataPreProcss', '3088', '3095', 'Ensembl']]
#
#
# file: PMC6104922.ann | []
#
#
# file: PMC6110470.ann | [['T1', 'PlugIn_Usage:Purpose_DataPreProcss', '2136', '2144', 'cutadapt'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '2154', '2160', 'sickle'], ['T3', 'Application_Usage:Purpose_DataPreProcss', '2167', '2171', 'GATK'], ['T4', 'Application_Usage:Purpose_DataPreProcss', '2419', '2427', 'SAMtools'], ['T5', 'Application_Usage:Purpose_DataPreProcss', '2563', '2569', 'Picard'], ['T6', 'Application_Usage:Purpose_DataPreProcss', '2730', '2734', 'GATK'], ['T7', 'Application_Usage:Purpose_Analysis', '2883', '2887', 'GATK'], ['T8', 'Application_Usage:Purpose_Analysis', '2970', '2974', 'GATK'], ['T9', 'Application_Usage:Purpose_Analysis', '3911', '3920', 'PLINK/SEQ'], ['T10', 'Application_Usage:Purpose_Analysis', '4084', '4089', 'PLINK'], ['T11', 'Application_Usage:Purpose_Analysis', '4146', '4151', 'PLINK'], ['T12', 'Application_Usage:Purpose_DataPreProcss', '5207', '5215', 'BCFtools'], ['T13', 'Application_Usage:Purpose_DataPreProcss', '5312', '5320', 'BCFtools'], ['T14', 'Application_Usage:Purpose_DataPreProcss', '5376', '5383', 'ANNOVAR'], ['T18', 'Application_Usage:Purpose_Analysis', '7228', '7233', 'PLINK'], ['T19', 'Application_Usage:Purpose_Analysis', '7617', '7623', 'CNVmap'], ['T20', 'Application_Usage:Purpose_Analysis', '9558', '9584', 'Ingenuity Pathway Analyser'], ['T21', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '10227', '10228', 'R'], ['T22', 'PlugIn_Usage:Purpose_Analysis', '10229', '10240', 'GeneOverlap'], ['T23', 'Application_Usage:Purpose_DataPreProcss', '2336', '2343', 'BWA-MEM'], ['T28', 'Application_Usage:Purpose_Analysis', '6542', '6546', 'XHMM'], ['T29', 'Application_Usage:Purpose_DataPreProcss', '6748', '6756', 'bedtools'], ['T31', 'Application_Usage:Purpose_DataPreProcss', '6987', '6991', 'XHMM'], ['T32', 'Application_Usage:Purpose_DataPreProcss', '7024', '7028', 'XHMM']]
#
#
# file: PMC6112653.ann | [['T1', 'Application_Usage:Purpose_Analysis', '1086', '1097', 'Soscisurvey'], ['T2', 'Application_Usage:Purpose_DataCollection', '6215', '6226', 'Soscisurvey'], ['T3', 'PlugIn_Usage:Purpose_DataPreProcss', '10581', '10585', 'mice'], ['T4', 'ProgrammingEnvironment_Usage:Purpose_DataPreProcss', '10602', '10603', 'R']]
#
#
# file: PMC6122792.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Modelling', '5838', '5839', 'R'], ['T3', 'PlugIn_Usage:Purpose_Modelling', '5848', '5855', 'bnlearn']]
#
#
# file: PMC6136735.ann | [['T1', 'Application_Usage:Purpose_Analysis', '3485', '3507', 'Microsoft Office Excel'], ['T2', 'Application_Usage:Purpose_Analysis', '3517', '3522', 'Stata'], ['T10', 'Application_Usage:Purpose_Analysis', '3533', '3538', 'Stata']]
#
#
# file: PMC6147404.ann | []
#
#
# file: PMC6147453.ann | [['T1', 'Application_Usage:Purpose_Analysis', '3458', '3462', 'SPSS']]
#
#
# file: PMC6147600.ann | [['T1', 'Application_Usage:Purpose_DataPreProcss', '3554', '3557', 'SPM'], ['T2', 'PlugIn_Usage:Purpose_DataPreProcss', '4156', '4163', 'Nilearn'], ['T3', 'ProgrammingEnvironment_Usage:Purpose_Programming', '4178', '4184', 'Python'], ['T4', 'Application_Usage:Purpose_Analysis', '6468', '6475', 'Mricron'], ['T5', 'Application_Usage:Purpose_Analysis', '6479', '6486', 'FSLView'], ['T6', 'PlugIn_Usage:Purpose_Analysis', '8882', '8894', 'Scikit-learn'], ['T7', 'PlugIn_Usage:Purpose_Visualization', '9870', '9882', 'Scikit-learn'], ['T10', 'Application_Usage:Purpose_Analysis', '6682', '6692', 'NeuroSynth'], ['T11', 'Application_Usage:Purpose_Analysis', '6729', '6739', 'NeuroSynth'], ['T12', 'Application_Usage:Purpose_DataCollection', '8523', '8533', 'NeuroSynth'], ['T13', 'Application_Usage:Purpose_DataCollection', '8582', '8592', 'NeuroSynth'], ['T14', 'Application_Usage:Purpose_DataCollection', '10182', '10192', 'NeuroSynth'], ['T15', 'Application_Usage:Purpose_Analysis', '11332', '11342', 'NeuroSynth']]
#
#
# file: PMC6152971.ann | [['T2', 'Application_Usage:Purpose_Analysis', '12940', '12943', 'SAS']]
#
#
# file: PMC6157871.ann | [['T1', 'Application_Usage:Purpose_Analysis', '3580', '3586', 'ImageJ'], ['T2', 'PlugIn_Usage:Purpose_Analysis', '3588', '3592', 'Fiji']]
#
#
# file: PMC6169876.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Programming', '2347', '2359', 'Visual Basic'], ['T2', 'Application_Usage:Purpose_Analysis', '3582', '3591', 'Photoshop'], ['T3', 'Application_Usage:Purpose_Analysis', '3640', '3650', 'Pixelmator'], ['T4', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '6624', '6625', 'R'], ['T5', 'PlugIn_Usage:Purpose_Analysis', '6647', '6651', 'lme4']]
#
#
# file: PMC6173405.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '5475', '5476', 'R'], ['T2', 'PlugIn_Usage:Purpose_Analysis', '5486', '5500', 'quantregForest']]
#
#
# file: PMC6181388.ann | []
#
#
# file: PMC6185835.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '1729', '1741', 'Experimetrix'], ['T2', 'Application_Usage:Purpose_Stimulation', '5323', '5330', 'E-Prime'], ['T3', 'Application_Usage:Purpose_DataCollection', '8313', '8334', 'Brain Vision Analyzer']]
#
#
# file: PMC6188870.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Modelling', '8889', '8890', 'R'], ['T2', 'ProgrammingEnvironment_Usage:Purpose_Modelling', '9442', '9443', 'R']]
#
#
# file: PMC6214541.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4474', '4489', 'SPSS statistics'], ['T2', 'OperatingSystem_Usage:Purpose_Analysis', '4494', '4501', 'windows']]
#
#
# file: PMC6218194.ann | [['T1', 'Application_Usage:Purpose_Analysis', '3233', '3239', 'ArcGIS']]
#
#
# file: PMC6224090.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4861', '4900', 'Statistical package for Social Sciences']]
#
#
# file: PMC6235347.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '10120', '10128', 'Promasys'], ['T2', 'ProgrammingEnvironment_Usage:Purpose_Visualization', '10502', '10503', 'R'], ['T3', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '10732', '10733', 'R'], ['T4', 'PlugIn_Usage:Purpose_Analysis', '10772', '10777', 'dplyr'], ['T5', 'PlugIn_Usage:Purpose_Analysis', '10790', '10795', 'psych'], ['T6', 'PlugIn_Usage:Purpose_Analysis', '10808', '10813', 'tidyr']]
#
#
# file: PMC6239323.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '4660', '4666', 'MATLAB'], ['T2', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '5100', '5106', 'MATLAB'], ['T3', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '6092', '6098', 'MATLAB'], ['T4', 'Application_Usage:Purpose_Analysis', '6243', '6248', 'Excel'], ['T5', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '4668', '4674', 'MATLAB'], ['T8', 'Application_Usage:Purpose_Analysis', '6260', '6265', 'Excel']]
#
#
# file: PMC6258130.ann | []
#
#
# file: PMC6261107.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4365', '4369', 'SPSS']]
#
#
# file: PMC6269088.ann | [['T1', 'PlugIn_Usage:Purpose_Analysis', '7195', '7205', 'TensorFlow'], ['T2', 'PlugIn_Usage:Purpose_Analysis', '8199', '8210', 'PyRadiomics'], ['T3', 'PlugIn_Usage:Purpose_Analysis', '8346', '8349', 'irr'], ['T4', 'PlugIn_Usage:Purpose_Analysis', '8592', '8597', 'mRMRe'], ['T5', 'PlugIn_Usage:Purpose_Analysis', '10225', '10233', 'survcomp'], ['T6', 'Application_Usage:Purpose_Analysis', '11985', '11989', 'GSEA'], ['T7', 'Application_Usage:Purpose_Analysis', '12253', '12257', 'GSEA'], ['T8', 'PlugIn_Usage:Purpose_Analysis', '9064', '9069', 'caret']]
#
#
# file: PMC6283531.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4164', '4168', 'SPSS']]
#
#
# file: PMC6291126.ann | [['T1', 'Application_Usage:Purpose_Analysis', '6505', '6510', 'STATA']]
#
#
# file: PMC6301656.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '5157', '5162', 'Excel'], ['T2', 'Application_Usage:Purpose_Analysis', '6985', '6990', 'Stata']]
#
#
# file: PMC6307725.ann | []
#
#
# file: PMC6312286.ann | [['T1', 'Application_Usage:Purpose_Analysis', '4231', '4236', 'Stata'], ['T13', 'Application_Usage:Purpose_Analysis', '4253', '4258', 'Stata']]
#
#
# file: PMC6312331.ann | [['T1', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '3173', '3174', 'R'], ['T2', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '5017', '5018', 'R']]
#
#
# file: PMC6314571.ann | []
#
#
# file: PMC6319765.ann | [['T1', 'Application_Usage:Purpose_Analysis', '7083', '7103', 'Sperm Class Analyzer'], ['T2', 'Application_Usage:Purpose_Analysis', '11079', '11089', 'Statistica'], ['T3', 'Application_Usage:Purpose_Analysis', '11313', '11323', 'Statistica'], ['T4', 'Application_Usage:Purpose_Analysis', '13563', '13573', 'Statistica']]
#
#
# file: PMC6328161.ann | [['T1', 'Application_Usage:Purpose_DataCollection', '5048', '5055', 'epidata'], ['T2', 'Application_Usage:Purpose_Analysis', '5093', '5097', 'SPSS']]
#
#
# file: PMC6333370.ann | [['T1', 'Application_Usage:Purpose_Analysis', '3425', '3468', 'Statistical Program for the Social Sciences']]
#
#
# file: PMC6334909.ann | [['T1', 'Application_Usage:Purpose_Analysis', '9293', '9298', 'Prism']]
#
#
# file: PMC6338373.ann | [['T1', 'Application_Usage:Purpose_Analysis', '7854', '7864', 'Statistica'], ['T2', 'OperatingSystem_Usage:Purpose_Analysis', '7874', '7881', 'Windows']]
#
#
# file: PMC6343886.ann | [['T1', 'Application_Usage:Purpose_Analysis', '8295', '8309', 'NQuery Advisor'], ['T2', 'Application_Usage:Purpose_Analysis', '8370', '8375', 'STATA']]
#
#
# file: PMC6345421.ann | [['T1', 'Application_Usage:Purpose_Analysis', '8101', '8108', 'GenCall'], ['T2', 'Application_Usage:Purpose_Analysis', '8704', '8709', 'PLINK'], ['T3', 'Application_Usage:Purpose_Analysis', '8895', '8903', 'SMARTPCA'], ['T4', 'Application_Usage:Purpose_DataPreProcss', '11296', '11304', 'SHAPEITv'], ['T5', 'Application_Usage:Purpose_DataPreProcss', '11342', '11348', 'IMPUTE'], ['T6', 'Application_Usage:Purpose_Analysis', '12007', '12014', 'SNPTEST'], ['T7', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '14506', '14507', 'R'], ['T8', 'PlugIn_Usage:Purpose_Analysis', '14479', '14482', 'rms'], ['T9', 'Application_Usage:Purpose_Analysis', '14586', '14592', 'Quanto'], ['T10', 'Application_Usage:Purpose_Analysis', '14691', '14698', 'SNPTEST'], ['T11', 'ProgrammingEnvironment_Usage:Purpose_Simulation', '15118', '15119', 'R'], ['T12', 'Application_Usage:Purpose_Simulation', '15186', '15193', 'DISSECT'], ['T13', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '15872', '15873', 'R'], ['T14', 'PlugIn_Usage:Purpose_Analysis', '15882', '15885', 'GTX'], ['T15', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '16327', '16328', 'R'], ['T16', 'PlugIn_Usage:Purpose_Analysis', '16319', '16326', 'ordinal'], ['T17', 'Application_Usage:Purpose_Analysis', '18495', '18500', 'PLINK'], ['T18', 'Application_Usage:Purpose_Analysis', '18790', '18797', 'SNPTEST'], ['T19', 'Application_Usage:Purpose_Analysis', '19114', '19121', 'SNPTEST'], ['T20', 'Application_Usage:Purpose_Analysis', '21200', '21209', 'METACARPA'], ['T21', 'Application_Usage:Purpose_Analysis', '21279', '21284', 'METAL'], ['T22', 'Application_Usage:Purpose_Analysis', '21366', '21371', 'METAL'], ['T28', 'Application_Usage:Purpose_DataPreProcss', '9592', '9596', 'KING'], ['T30', 'Application_Usage:Purpose_Analysis', '10187', '10191', 'KING'], ['T35', 'Application_Usage:Purpose_Analysis', '12183', '12191', 'BOLT-LMM'], ['T54', 'Application_Usage:Purpose_DataPreProcss', '4548', '4578', 'Haplotype Reference Consortium'], ['T56', 'Application_Usage:Purpose_DataPreProcss', '6147', '6150', 'HRC']]
#
#
# file: PMC6347236.ann | [['T1', 'Application_Usage:Purpose_Analysis', '10140', '10145', 'Stata']]
#
#
# file: PMC6353544.ann | [['T1', 'Application_Usage:Purpose_Analysis', '6517', '6524', 'G*Power'], ['T2', 'Application_Usage:Purpose_DataCollection', '8352', '8358', 'Enketo'], ['T4', 'Application_Usage:Purpose_DataCollection', '8487', '8493', 'Enketo'], ['T5', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '11462', '11463', 'R']]
#
#
# file: PMC6358157.ann | [['T1', 'Application_Usage:Purpose_Analysis', '12922', '12925', 'SAS']]

# %% [markdown]
# ### `PLoS` : writing merged annotation  Into a Data Frame

# %%
import pandas as pd

df_PLOS = pd.DataFrame(columns=['code', 'annotation','start','stop','software'], data=all_annotations_list)
#df_PLOS

# %%
len(all_annotations_list)
# Out:
# 1455

# %% [markdown]
# ### Save the df_PLOS image

# %%
# get head and tail of the df
PLOS_head = df_PLOS.head(10)
PLOS_tail = df_PLOS.tail(10)


import dataframe_image as dfi


PLOS_head = PLOS_head.style.background_gradient()
dfi.export(PLOS_head,"PLOS_head_.png")

PLOS_tail = PLOS_tail.style.background_gradient()
dfi.export(PLOS_tail,"PLOS_tail_.png")

df_PLOS.to_csv(r'PLOS_.csv', index = False)
# Out:
# C:\Users\Beck\projectDir\venv\lib\site-packages\dataframe_image\_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'

# %% [markdown]
# ## 1.2. PubMed Full Text

# %%
import os
from os import listdir
from os.path import isfile, join


interest_list = ['Application_Usage','ProgrammingEnvironment_Usage','PlugIn_Usage','OperatingSystem_Usage', 'Purpose_Analysis','Purpose_Modelling', 'Purpose_Stimulation', 
                 'Purpose_DataCollection', 'Purpose_DataPreProcss', 'Purpose_Simulation', 'Purpose_Visualization', 
                 'Purpose_Programming', 'Application_Creation', 'PlugIn_Creation',
                 'Application_Deposition', 'PlugIn_Deposition', 'SoftwareCoreference_Deposition',
                 'Application_Mention','ProgrammingEnvironment_Mention','OperatingSystem_Mention','PlugIn_Mention',
                 'Version','Developer', 'URL', 'License','Citation', 'Abbreviation', 'AlternativeName', 'Release', 'Extension']


#  1. get a list of PubMed file names---------------------------------------------------------------------

mypath = "SoMeSci/Pubmed_fulltext/"

Pubmed_filesList = []
  
# iterating over all files in the dir
for file_name in os.listdir(mypath):
    
    # if the file is .ann
    if file_name.endswith('.ann'):
        Pubmed_filesList.append(file_name)
    else:
        continue

Pubmed_filesList.sort() 

#print('First 5 files: ',Pubmed_filesList[:5])


# 2. get file name and list of annotations into a dict-------------------------------------------------------


# stores ORIGIAL list of annotations in a file (BEFORE MERGING)
fileAn_dict2 = {}

# store all annotations in the file ( format: list-of-list)
annotation_filelist2 = []

# loop over each file 
for indx, file in enumerate(Pubmed_filesList[:]):
    
    # path to each file
    file_path = mypath + file
    
    with open(file_path, "r") as a_file:
        
        # stores annotation line 
        annotation_line2 = []
        
        
        # check if the annotation is what we want (usage, purpose, starts with T )
        for line in a_file:
            
            # grab the type of annotation
            annotataion = line.split()[1:2][0]
            
            if (line.startswith('T') & (annotataion in interest_list)):

                if ( line.split()[2:4] ) not in annotation_line2: 
                    
                    annotation_line2.append(line.split())
                    #print(indx, file, line.split())

                else:
                    pass
        
        fileAn_dict2[file] = annotation_line2     
        
# 3. Merge annotations -----------------------------------------------------------------------


#store all merged annotations with a file name 
# stores MERGED LIST of annotations in each file
merged_dict2 = {}

#stores list of list of all annotations
all_annotations_list2 = []


# for each file in the dict
for key in list(fileAn_dict2):
    
    # stores list of merged annotations
    merged_annotationlist_perfile2 = []
    #print(key)
    """
    compare all annotations to each other and grab those that share the same "start number"
    
    """
    
    lookup_list1 = []
    for ls1 in fileAn_dict2.get(key):
            
            
            lookup_list2 = []
            for ls2 in fileAn_dict2.get(key):
                
                
                # compare each annotation with another but not to itself
                if (ls1 != ls2) :
                    
                    
                    # merge annotations
                    r = mergeList(ls1,ls2)
                    
                    
                    
                    # if the 
                    if len(r) !=0 :
                        #print(ls1[0],ls2[0], ls1[2:4], ls2[2:4])
         
                        if (r[2] not in lookup_list1 ) | (r[3] not in lookup_list1 ):
                            
                            merged_annotationlist_perfile2.append(r) 
                            all_annotations_list2.append(r)
                            
                            
                            lookup_list2.extend(r[2:4])
                            
                        else:
                            pass
            # save already merged list on the lookup list            
            lookup_list1.extend(lookup_list2)  
            #break
                        
                        
    merged_dict2[key] = merged_annotationlist_perfile2

# %%
for file in list(merged_dict2)[:]:
    print('file name:', file, '|  ',merged_dict2.get(file), '\n\n')
# Out:
# file name: PMC1240430.ann |   []
#
#
# file name: PMC2790482.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '15525', '15534', 'SigmaStat'], ['T3', 'OperatingSystem_Usage:Purpose_Analysis', '15544', '15551', 'Windows'], ['T5', 'Application_Usage:Purpose_DataCollection', '23622', '23636', 'Image-Pro Plus'], ['T7', 'OperatingSystem_Usage:Purpose_DataCollection', '23645', '23652', 'Windows'], ['T10', 'Application_Usage:Purpose_DataCollection', '23735', '23744', 'Scope-Pro'], ['T11', 'OperatingSystem_Usage:Purpose_DataCollection', '23753', '23760', 'Windows'], ['T14', 'Application_Usage:Purpose_DataPreProcss', '24827', '24830', 'IPP'], ['T15', 'Application_Usage:Purpose_Visualization', '24913', '24922', 'Photoshop'], ['T20', 'Application_Usage:Purpose_DataPreProcss', '25136', '25139', 'IPP'], ['T21', 'Application_Usage:Purpose_DataPreProcss', '25842', '25854', 'Office Excel'], ['T25', 'Application_Usage:Purpose_Visualization', '25983', '25992', 'SigmaPlot'], ['T27', 'OperatingSystem_Usage:Purpose_Visualization', '26001', '26008', 'Windows'], ['T29', 'Application_Usage:Purpose_Analysis', '26915', '26924', 'Photoshop'], ['T30', 'Application_Usage:Purpose_Analysis', '26968', '26971', 'IPP'], ['T31', 'Application_Usage:Purpose_Analysis', '27608', '27616', 'Satistix'], ['T33', 'OperatingSystem_Usage:Purpose_Analysis', '27627', '27634', 'Windows']]
#
#
# file name: PMC2936424.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '14072', '14077', 'Stata']]
#
#
# file name: PMC3071738.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '17952', '17959', 'Image J']]
#
#
# file name: PMC3106454.ann |   []
#
#
# file name: PMC3120364.ann |   [['T1', 'Application_Usage:Purpose_DataCollection', '2209', '2221', 'CrystalClear'], ['T3', 'Application_Usage:Purpose_DataPreProcss', '2257', '2269', 'CrystalClear'], ['T4', 'Application_Usage:Purpose_DataPreProcss', '2287', '2299', 'CrystalClear'], ['T5', 'Application_Usage:Purpose_Analysis', '2337', '2343', 'SHELXS'], ['T8', 'Application_Usage:Purpose_Analysis', '2404', '2410', 'SHELXL'], ['T11', 'Application_Usage:Purpose_Visualization', '2454', '2459', 'ORTEP'], ['T13', 'OperatingSystem_Usage:Purpose_Visualization', '2466', '2473', 'Windows'], ['T15', 'Application_Usage:Purpose_DataPreProcss', '2497', '2503', 'PLATON'], ['T17', 'Application_Usage:Purpose_DataPreProcss', '2571', '2577', 'SHELXL']]
#
#
# file name: PMC3167763.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '10144', '10159', 'SPSS statistics']]
#
#
# file name: PMC3187606.ann |   []
#
#
# file name: PMC3224237.ann |   []
#
#
# file name: PMC3245656.ann |   []
#
#
# file name: PMC3289918.ann |   [['T1', 'ProgrammingEnvironment_Usage:Purpose_Programming', '230', '233', 'C++'], ['T2', 'ProgrammingEnvironment_Usage:Purpose_Programming', '238', '244', 'OpenCL'], ['T6', 'ProgrammingEnvironment_Usage:Purpose_Programming', '1700', '1703', 'C++'], ['T9', 'PlugIn_Usage:Purpose_Analysis', '3203', '3209', 'glmnet'], ['T11', 'ProgrammingEnvironment_Usage:Purpose_Programming', '3708', '3709', 'R'], ['T12', 'PlugIn_Usage:Purpose_Analysis', '3723', '3729', 'glmnet'], ['T13', 'ProgrammingEnvironment_Usage:Purpose_Programming', '3777', '3780', 'C++'], ['T14', 'PlugIn_Usage:Purpose_Analysis', '3879', '3885', 'glmnet'], ['T15', 'Application_Usage:Purpose_Analysis', '3890', '3899', 'gpu-lasso'], ['T16', 'Application_Usage:Purpose_Analysis', '3907', '3916', 'gpu-lasso'], ['T18', 'ProgrammingEnvironment_Usage:Purpose_Programming', '5986', '5989', 'C++']]
#
#
# file name: PMC3320279.ann |   []
#
#
# file name: PMC3437120.ann |   []
#
#
# file name: PMC3512794.ann |   []
#
#
# file name: PMC3561110.ann |   []
#
#
# file name: PMC3568080.ann |   [['T1', 'Application_Usage:Purpose_DataCollection', '7995', '8004', 'ImagePro+'], ['T4', 'Application_Usage:Purpose_Analysis', '8920', '8924', 'MyIQ'], ['T7', 'Application_Usage:Purpose_Analysis', '12327', '12336', 'FlexArray'], ['T10', 'Application_Usage:Purpose_Analysis', '12453', '12479', 'Ingenuity Pathway Analysis'], ['T12', 'Application_Usage:Purpose_Analysis', '12551', '12556', 'STATA']]
#
#
# file name: PMC3623473.ann |   [['T1', 'Application_Usage:Purpose_DataCollection', '4131', '4138', 'Datacam'], ['T2', 'Application_Usage:Purpose_Visualization', '8976', '8983', 'Datacam'], ['T3', 'Application_Usage:Purpose_DataCollection', '9586', '9593', 'Datacam'], ['T4', 'Application_Usage:Purpose_Analysis', '10355', '10359', 'SPSS'], ['T5', 'Application_Usage:Purpose_Analysis', '10364', '10369', 'Excel'], ['T7', 'OperatingSystem_Usage:Purpose_Analysis', '10397', '10400', 'Mac']]
#
#
# file name: PMC3639350.ann |   []
#
#
# file name: PMC3705362.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '5321', '5329', 'ConoMass'], ['T2', 'Application_Usage:Purpose_Analysis', '5600', '5608', 'ConoMass']]
#
#
# file name: PMC3721944.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '6938', '6942', 'SPSS'], ['T2', 'OperatingSystem_Usage:Purpose_Analysis', '6947', '6954', 'Windows']]
#
#
# file name: PMC3747095.ann |   []
#
#
# file name: PMC3781520.ann |   []
#
#
# file name: PMC3794969.ann |   [['T2', 'Application_Usage:Purpose_Analysis', '9079', '9095', 'Luminex 100 â„¢ IS'], ['T3', 'Application_Usage:Purpose_Analysis', '10089', '10093', 'SPSS'], ['T5', 'OperatingSystem_Usage:Purpose_Analysis', '10103', '10110', 'Windows']]
#
#
# file name: PMC4072059.ann |   [['T1', 'ProgrammingEnvironment_Usage:Purpose_DataCollection', '11170', '11177', 'Fortran'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '12877', '12880', 'FSL'], ['T5', 'PlugIn_Usage:Purpose_DataPreProcss', '13068', '13073', 'FLIRT'], ['T7', 'Application_Usage:Purpose_Modelling', '13333', '13336', 'FSL'], ['T9', 'PlugIn_Usage:Purpose_DataCollection', '14343', '14348', 'FLIRT'], ['T11', 'Application_Usage:Purpose_DataCollection', '14376', '14379', 'FSL'], ['T13', 'Application_Usage:Purpose_Modelling', '14745', '14748', 'FSL'], ['T14', 'Application_Usage:Purpose_Analysis', '15537', '15540', 'FSL']]
#
#
# file name: PMC4090832.ann |   []
#
#
# file name: PMC4093161.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '11656', '11663', 'Minitab']]
#
#
# file name: PMC4100254.ann |   []
#
#
# file name: PMC4122196.ann |   []
#
#
# file name: PMC4175729.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '8821', '8825', 'SPSS']]
#
#
# file name: PMC4183953.ann |   [['T1', 'ProgrammingEnvironment_Usage:Purpose_DataCollection', '21779', '21785', 'Matlab'], ['T3', 'Application_Usage:Purpose_DataCollection', '21802', '21808', 'Cogent'], ['T5', 'Application_Usage:Purpose_DataPreProcss', '23394', '23398', 'AFNI'], ['T7', 'Application_Usage:Purpose_Analysis', '24328', '24332', 'AFNI'], ['T8', 'PlugIn_Usage:Purpose_Modelling', '25509', '25521', '3dDeconvolve'], ['T9', 'PlugIn_Usage:Purpose_DataCollection', '26621', '26630', '3dmaskave'], ['T10', 'Application_Usage:Purpose_DataCollection', '26614', '26618', 'AFNI'], ['T11', 'Application_Usage:Purpose_Analysis', '27985', '27989', 'SPSS'], ['T14', 'Application_Usage:Purpose_Analysis', '29178', '29182', 'AFNI'], ['T15', 'PlugIn_Usage:Purpose_DataCollection', '29734', '29743', '3dmaskave'], ['T16', 'PlugIn_Usage:Purpose_Analysis', '29789', '29798', '3dDetrend'], ['T17', 'Application_Usage:Purpose_Analysis', '30051', '30055', 'AFNI'], ['T18', 'PlugIn_Usage:Purpose_Analysis', '30056', '30061', 'waver'], ['T19', 'Application_Usage:Purpose_DataCollection', '31095', '31099', 'AFNI'], ['T20', 'Application_Usage:Purpose_DataPreProcss', '31188', '31216', 'Advanced Normalization Tools'], ['T22', 'Application_Usage:Purpose_Analysis', '31805', '31809', 'AFNI'], ['T23', 'PlugIn_Usage:Purpose_Analysis', '31812', '31822', '3dttest+ +'], ['T24', 'PlugIn_Usage:Purpose_DataCollection', '32431', '32441', '3dttest+ +'], ['T25', 'PlugIn_Usage:Purpose_Analysis', '32555', '32562', '3dFWHMx'], ['T26', 'PlugIn_Usage:Purpose_Analysis', '32577', '32587', '3dClustsim']]
#
#
# file name: PMC4213368.ann |   []
#
#
# file name: PMC4255417.ann |   []
#
#
# file name: PMC4461773.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '12732', '12736', 'SPSS'], ['T2', 'OperatingSystem_Usage:Purpose_Analysis', '12761', '12768', 'Windows']]
#
#
# file name: PMC4468325.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '16731', '16739', 'CompuSyn'], ['T2', 'Application_Usage:Purpose_Analysis', '27306', '27311', 'Prism'], ['T4', 'Application_Usage:Purpose_Analysis', '27487', '27495', 'CompuSin'], ['T6', 'Application_Usage:Purpose_Analysis', '28066', '28075', 'CellQuest'], ['T7', 'Application_Usage:Purpose_Analysis', '28833', '28842', 'CellQuest'], ['T8', 'Application_Usage:Purpose_Analysis', '29646', '29655', 'CellQuest'], ['T9', 'Application_Usage:Purpose_Analysis', '29511', '29520', 'CellQuest'], ['T10', 'Application_Usage:Purpose_Analysis', '30270', '30279', 'CellQuest'], ['T11', 'OperatingSystem_Usage:Purpose_Analysis', '30439', '30452', 'Linux Red Hat'], ['T12', 'Application_Usage:Purpose_Analysis', '30485', '30498', 'Autodock Vina'], ['T16', 'Application_Usage:Purpose_Analysis', '30508', '30517', 'InsightII'], ['T17', 'Application_Usage:Purpose_DataPreProcss', '30858', '30862', 'Vina'], ['T18', 'Application_Usage:Purpose_Modelling', '31064', '31073', 'InsightII'], ['T19', 'Application_Usage:Purpose_Visualization', '31397', '31402', 'PyMOL'], ['T21', 'Application_Usage:Purpose_Modelling', '31500', '31509', 'InsightII'], ['T23', 'Application_Usage:Purpose_Analysis', '34594', '34606', 'Quantity One']]
#
#
# file name: PMC4470332.ann |   [['T1', 'Application_Usage:Purpose_DataPreProcss', '19784', '19793', 'Novoalign'], ['T2', 'Application_Usage:Purpose_Analysis', '19886', '19909', 'Genome Analysis Toolkit'], ['T5', 'Application_Usage:Purpose_DataPreProcss', '19984', '19988', 'GATK'], ['T7', 'Application_Usage:Purpose_DataPreProcss', '20559', '20562', 'VAX'], ['T9', 'Application_Usage:Purpose_Analysis', '20628', '20636', 'Polyphen'], ['T10', 'Application_Usage:Purpose_Analysis', '20643', '20647', 'Sift'], ['T11', 'Application_Usage:Purpose_Analysis', '20654', '20660', 'Condel'], ['T12', 'Application_Usage:Purpose_Analysis', '20671', '20675', 'CADD'], ['T17', 'Application_Usage:Purpose_Analysis', '21129', '21137', 'Geneious'], ['T21', 'Application_Usage:Purpose_DataCollection', '27854', '27860', 'ImageJ'], ['T23', 'Application_Usage:Purpose_Analysis', '28674', '28680', 'ImageJ'], ['T25', 'Application_Usage:Purpose_Analysis', '29165', '29170', 'Prism'], ['T28', 'Application_Usage:Purpose_Analysis', '30989', '30995', 'ImageJ']]
#
#
# file name: PMC4484448.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '1206', '1213', 'FunRich'], ['T2', 'Application_Usage:Purpose_Analysis', '7169', '7176', 'FunRich'], ['T3', 'PlugIn_Usage:Purpose_Analysis', '15628', '15634', 'ClueGO'], ['T4', 'Application_Usage:Purpose_Analysis', '15635', '15644', 'cytoscape'], ['T5', 'PlugIn_Usage:Purpose_Analysis', '16315', '16323', 'Reactome'], ['T6', 'Application_Usage:Purpose_Analysis', '16334', '16343', 'Cytoscape'], ['T7', 'Application_Usage:Purpose_DataPreProcss', '30360', '30368', 'Bioworks'], ['T10', 'Application_Usage:Purpose_Analysis', '30867', '30873', 'MASCOT'], ['T13', 'PlugIn_Usage:Purpose_Analysis', '33808', '33814', 'ClueGO'], ['T16', 'Application_Usage:Purpose_Analysis', '33830', '33839', 'Cytoscape'], ['T19', 'Application_Usage:Purpose_Analysis', '34059', '34066', 'FunRich'], ['T20', 'Application_Usage:Purpose_Visualization', '34275', '34284', 'Cytoscape'], ['T22', 'PlugIn_Usage:Purpose_Visualization', '34448', '34460', 'clusterMaker'], ['T24', 'PlugIn_Usage:Purpose_Analysis', '34471', '34476', 'BiNGO'], ['T26', 'Application_Usage:Purpose_Analysis', '34484', '34493', 'cytoscape'], ['T27', 'Application_Usage:Purpose_Analysis', '38174', '38179', 'Prism'], ['T30', 'Application_Usage:Purpose_Analysis', '38206', '38218', 'Office Excel']]
#
#
# file name: PMC4502071.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '11198', '11203', 'STATA']]
#
#
# file name: PMC4623726.ann |   [['T1', 'Application_Usage:Purpose_DataCollection', '11040', '11045', 'Excel']]
#
#
# file name: PMC4643858.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '19653', '19661', 'Atlas.ti']]
#
#
# file name: PMC4662706.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '7650', '7693', 'Statistical Package for the Social Sciences']]
#
#
# file name: PMC4718728.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '11688', '11714', 'Ingenuity Pathway Analysis'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '45733', '45747', 'Genomics Suite'], ['T5', 'Application_Usage:Purpose_Analysis', '45988', '45994', 'Partek'], ['T6', 'Application_Usage:Purpose_Analysis', '13150', '13159', 'Ingenuity'], ['T7', 'Application_Usage:Purpose_Analysis', '13263', '13272', 'Ingenuity'], ['T8', 'Application_Usage:Purpose_Analysis', '49518', '49523', 'Prism'], ['T11', 'OperatingSystem_Usage:Purpose_Analysis', '49540', '49548', 'Mac OS X']]
#
#
# file name: PMC4737043.ann |   []
#
#
# file name: PMC4996584.ann |   []
#
#
# file name: PMC5006964.ann |   []
#
#
# file name: PMC5168472.ann |   []
#
#
# file name: PMC5230193.ann |   []
#
#
# file name: PMC5253549.ann |   [['T1', 'Application_Usage:Purpose_Modelling', '11383', '11388', 'MLWin'], ['T3', 'Application_Usage:Purpose_Modelling', '11446', '11451', 'MLwiN'], ['T6', 'Application_Usage:Purpose_Analysis', '11761', '11766', 'MLwiN']]
#
#
# file name: PMC5273844.ann |   []
#
#
# file name: PMC5332665.ann |   []
#
#
# file name: PMC5351064.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '7607', '7624', 'Open Meta-Analyst'], ['T4', 'ProgrammingEnvironment_Usage:Purpose_Programming', '9123', '9124', 'R'], ['T6', 'Application_Usage:Purpose_Analysis', '9146', '9163', 'Open Meta-Analyst']]
#
#
# file name: PMC5365064.ann |   []
#
#
# file name: PMC5446749.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '8856', '8862', 'IMARIS'], ['T4', 'Application_Usage:Purpose_DataCollection', '10311', '10322', 'Axio Vision'], ['T7', 'Application_Usage:Purpose_Analysis', '10401', '10407', 'ImageJ'], ['T9', 'Application_Usage:Purpose_Analysis', '10874', '10882', 'GraphPad']]
#
#
# file name: PMC5478624.ann |   [['T5', 'OperatingSystem_Usage:Purpose_DataCollection', '7244', '7251', 'Windows']]
#
#
# file name: PMC5579545.ann |   []
#
#
# file name: PMC5593182.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '9848', '9862', 'PASW Statistic']]
#
#
# file name: PMC5690316.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '1311', '1317', 'ImageJ'], ['T8', 'Application_Usage:Purpose_DataPreProcss', '10420', '10426', 'ImageJ'], ['T9', 'Application_Usage:Purpose_Analysis', '10677', '10683', 'ImageJ'], ['T10', 'Application_Usage:Purpose_Simulation', '11235', '11241', 'ImageJ'], ['T14', 'Application_Usage:Purpose_DataPreProcss', '11410', '11417', 'Ki67 Vv'], ['T15', 'Application_Usage:Purpose_Programming', '12324', '12330', 'ImageJ'], ['T17', 'Application_Usage:Purpose_Analysis', '13615', '13626', 'Immunoratio'], ['T18', 'Application_Usage:Purpose_DataCollection', '14591', '14602', 'Immunoratio'], ['T19', 'Application_Usage:Purpose_DataPreProcss', '16102', '16108', 'ImageJ'], ['T21', 'Application_Usage:Purpose_DataCollection', '16235', '16246', 'Immunoratio'], ['T22', 'Application_Usage:Purpose_Analysis', '16375', '16386', 'Immunoratio'], ['T23', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '17101', '17102', 'R'], ['T27', 'Application_Usage:Purpose_DataCollection', '17395', '17406', 'Immunoratio'], ['T28', 'PlugIn_Usage:Purpose_Analysis', '17431', '17435', 'ROCR'], ['T30', 'PlugIn_Usage:Purpose_Visualization', '17570', '17577', 'FigureJ'], ['T32', 'Application_Usage:Purpose_Analysis', '19160', '19171', 'Immunoratio'], ['T33', 'Application_Usage:Purpose_Visualization', '19805', '19816', 'Immunoratio'], ['T34', 'Application_Usage:Purpose_Visualization', '20692', '20703', 'Immunoratio'], ['T35', 'Application_Usage:Purpose_Visualization', '20786', '20797', 'Immunoratio']]
#
#
# file name: PMC5869224.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '6326', '6351', 'Santa Cruz genome browser']]
#
#
# file name: PMC5902404.ann |   []
#
#
# file name: PMC5904046.ann |   []
#
#
# file name: PMC5939909.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '7770', '7776', 'RevMan'], ['T3', 'Application_Usage:Purpose_Analysis', '7807', '7812', 'Stata']]
#
#
# file name: PMC5941044.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '8761', '8764', 'SAS'], ['T2', 'Application_Usage:Purpose_Analysis', '8766', '8769', 'SAS'], ['T5', 'Application_Usage:Purpose_Analysis', '8951', '8954', 'SAS']]
#
#
# file name: PMC5968553.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '11381', '11393', 'Quantity One'], ['T2', 'Application_Usage:Purpose_Analysis', '12296', '12300', 'SPSS'], ['T5', 'Application_Usage:Purpose_Analysis', '12374', '12379', 'Prism'], ['T9', 'Application_Usage:Purpose_Analysis', '15239', '15245', 'TANRIC']]
#
#
# file name: PMC5991323.ann |   []
#
#
# file name: PMC6017189.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '8311', '8315', 'PASS'], ['T2', 'Application_Usage:Purpose_Analysis', '11996', '12041', 'Prediction of Activity Spectra for Substances'], ['T5', 'Application_Usage:Purpose_Simulation', '12453', '12456', 'MOE'], ['T7', 'Application_Usage:Purpose_DataCollection', '12574', '12577', 'MOE'], ['T8', 'Application_Usage:Purpose_Visualization', '12788', '12791', 'MOE'], ['T9', 'Application_Usage:Purpose_Visualization', '12796', '12803', 'Chimera'], ['T11', 'PlugIn_Usage:Purpose_Analysis', '13005', '13012', 'CPPTRAJ'], ['T12', 'Application_Usage:Purpose_Analysis', '13023', '13033', 'AMBERTOOLS'], ['T15', 'Application_Usage:Purpose_DataPreProcss', '23153', '23158', 'SAINT'], ['T16', 'Application_Usage:Purpose_DataPreProcss', '23163', '23169', 'SADABS'], ['T18', 'Application_Usage:Purpose_Analysis', '23298', '23305', 'SHELXTL'], ['T20', 'Application_Usage:Purpose_Visualization', '23700', '23705', 'ORTEP']]
#
#
# file name: PMC6190357.ann |   []
#
#
# file name: PMC6372264.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '9763', '9770', 'Biomart'], ['T2', 'Application_Usage:Purpose_DataCollection', '10204', '10211', 'BioMart'], ['T3', 'Application_Usage:Purpose_DataPreProcss', '12284', '12292', 'ClustalW'], ['T4', 'Application_Usage:Purpose_DataPreProcss', '12297', '12305', 'Geneious'], ['T8', 'Application_Usage:Purpose_Modelling', '12796', '12804', 'Geneious'], ['T10', 'Application_Usage:Purpose_Visualization', '12816', '12823', 'MrBayes'], ['T12', 'Application_Usage:Purpose_Analysis', '13007', '13014', 'MrBayes'], ['T13', 'Application_Usage:Purpose_Analysis', '14030', '14034', 'MEGA'], ['T15', 'Application_Usage:Purpose_Analysis', '14430', '14434', 'MEGA'], ['T17', 'Application_Usage:Purpose_Analysis', '15301', '15311', 'Datamonkey'], ['T18', 'Application_Usage:Purpose_Analysis', '15327', '15332', 'HyPhy'], ['T20', 'Application_Usage:Purpose_Analysis', '15613', '15621', 'Geneious'], ['T21', 'Application_Usage:Purpose_DataCollection', '15685', '15695', 'Datamonkey'], ['T22', 'Application_Usage:Purpose_Analysis', '20176', '20181', 'BLAST'], ['T23', 'Application_Usage:Purpose_DataPreProcss', '20749', '20757', 'ClustalW'], ['T24', 'Application_Usage:Purpose_DataCollection', '28599', '28609', 'Datamonkey'], ['T25', 'Application_Usage:Purpose_Analysis', '28635', '28640', 'HyPhy'], ['T26', 'Application_Usage:Purpose_Analysis', '36545', '36550', 'BLAST']]
#
#
# file name: PMC6411919.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '9676', '9685', 'CIBERSORT'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '28578', '28582', 'STAR'], ['T4', 'Application_Usage:Purpose_DataCollection', '28681', '28688', 'Subread'], ['T6', 'Application_Usage:Purpose_DataCollection', '28752', '28760', 'Sailfish'], ['T8', 'Application_Usage:Purpose_Analysis', '29015', '29020', 'RSeQC'], ['T11', 'Application_Usage:Purpose_Visualization', '34964', '34975', 'Bioanalyzer'], ['T13', 'Application_Usage:Purpose_Analysis', '35324', '35327', 'RTA'], ['T15', 'Application_Usage:Purpose_DataPreProcss', '35423', '35429', 'CASAVA'], ['T17', 'Application_Usage:Purpose_DataPreProcss', '35501', '35505', 'STAR'], ['T19', 'Application_Usage:Purpose_DataPreProcss', '35648', '35652', 'STAR'], ['T20', 'PlugIn_Usage:Purpose_Analysis', '35802', '35808', 'DESeq2'], ['T21', 'Application_Usage:Purpose_Analysis', '35870', '35882', 'Gene Cluster'], ['T23', 'Application_Usage:Purpose_Visualization', '35917', '35925', 'Treeview'], ['T25', 'Application_Usage:Purpose_Analysis', '36297', '36308', 'Genepix Pro'], ['T27', 'PlugIn_Usage:Purpose_Analysis', '37037', '37042', 'EdgeR'], ['T29', 'Application_Usage:Purpose_Analysis', '37393', '37400', 'ToppFun'], ['T31', 'Application_Usage:Purpose_Analysis', '37515', '37524', 'CIBERSORT'], ['T32', 'Application_Usage:Purpose_Analysis', '37962', '37980', 'immunoSEQ Analyzer'], ['T34', 'Application_Usage:Purpose_Analysis', '38117', '38122', 'PIVOT'], ['T38', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '38332', '38333', 'R'], ['T39', 'PlugIn_Usage:Purpose_Analysis', '38315', '38320', 'Rtsne'], ['T40', 'Application_Usage:Purpose_Analysis', '38381', '38386', 'PIVOT'], ['T41', 'Application_Usage:Purpose_Analysis', '38398', '38405', 'Cluster'], ['T44', 'Application_Usage:Purpose_Visualization', '38438', '38446', 'TreeView'], ['T46', 'Application_Usage:Purpose_Visualization', '38544', '38549', 'Prism'], ['T48', 'Application_Usage:Purpose_Analysis', '38582', '38588', 'FlowJo']]
#
#
# file name: PMC6487331.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '14722', '14727', 'Prism'], ['T4', 'OperatingSystem_Usage:Purpose_Analysis', '14736', '14743', 'windows']]
#
#
# file name: PMC6498765.ann |   []
#
#
# file name: PMC6541987.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '9834', '9842', 'Cytobank'], ['T3', 'Application_Usage:Purpose_Analysis', '12123', '12129', 'ImageJ'], ['T4', 'PlugIn_Usage:Purpose_Analysis', '12151', '12155', 'Fiji'], ['T5', 'Application_Usage:Purpose_Analysis', '13612', '13624', 'Rotor-Gene Q'], ['T6', 'Application_Usage:Purpose_Analysis', '15600', '15612', 'Quantity One'], ['T8', 'Application_Usage:Purpose_Analysis', '16056', '16061', 'Prism'], ['T11', 'Application_Usage:Purpose_Analysis', '19185', '19192', 'TopSpin'], ['T14', 'Application_Usage:Purpose_Analysis', '19471', '19475', 'AMIX'], ['T16', 'Application_Usage:Purpose_Analysis', '19615', '19632', 'Chenomx NMR Suite'], ['T19', 'Application_Usage:Purpose_Modelling', '19957', '19964', 'Chenomx'], ['T20', 'Application_Usage:Purpose_Analysis', '20752', '20759', 'SIMCA-P'], ['T21', 'Application_Usage:Purpose_Analysis', '20321', '20328', 'TopSpin'], ['T25', 'Application_Usage:Purpose_Analysis', '27954', '27961', 'Chenomx']]
#
#
# file name: PMC6627141.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '12007', '12010', 'Iox'], ['T4', 'Application_Usage:Purpose_Analysis', '14851', '14860', 'Image Lab'], ['T6', 'Application_Usage:Purpose_Analysis', '15372', '15382', 'Kubios HRV'], ['T8', 'Application_Usage:Purpose_DataPreProcss', '15427', '15433', 'Kubios'], ['T9', 'Application_Usage:Purpose_DataCollection', '15813', '15816', 'Iox'], ['T12', 'Application_Usage:Purpose_Analysis', '15974', '15979', 'Prism']]
#
#
# file name: PMC6651979.ann |   []
#
#
# file name: PMC6664586.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '15758', '15763', 'Prism'], ['T5', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '15904', '15905', 'R']]
#
#
# file name: PMC6719071.ann |   [['T1', 'ProgrammingEnvironment_Usage:Purpose_DataPreProcss', '9330', '9334', 'Perl'], ['T2', 'Application_Usage:Purpose_DataPreProcss', '9509', '9515', 'TopHat'], ['T5', 'Application_Usage:Purpose_Analysis', '9527', '9532', 'HTSeq'], ['T7', 'PlugIn_Usage:Purpose_Analysis', '9872', '9877', 'DESeq'], ['T8', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '9881', '9882', 'R'], ['T10', 'PlugIn_Usage:Purpose_Analysis', '10366', '10371', 'GOseq'], ['T12', 'Application_Usage:Purpose_Analysis', '10394', '10399', 'KOBAS'], ['T18', 'Application_Usage:Purpose_DataCollection', '12005', '12009', 'FIMO'], ['T20', 'Application_Usage:Purpose_DataPreProcss', '13516', '13522', 'skewer'], ['T22', 'Application_Usage:Purpose_DataPreProcss', '13615', '13618', 'BWA'], ['T24', 'Application_Usage:Purpose_Analysis', '13719', '13723', 'MACS']]
#
#
# file name: PMC6721559.ann |   []
#
#
# file name: PMC6737803.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '955', '959', 'SPSS'], ['T3', 'Application_Usage:Purpose_Analysis', '7293', '7308', 'SPSS Statistics'], ['T4', 'OperatingSystem_Usage:Purpose_Analysis', '7313', '7320', 'Windows']]
#
#
# file name: PMC6769648.ann |   []
#
#
# file name: PMC6773754.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '19210', '19216', 'Qbase+'], ['T3', 'Application_Usage:Purpose_Analysis', '21229', '21242', 'ImageQuant TL'], ['T6', 'Application_Usage:Purpose_DataPreProcss', '22793', '22799', 'ImageJ'], ['T10', 'Application_Usage:Purpose_Analysis', '22931', '22943', 'NIS-Elements'], ['T12', 'Application_Usage:Purpose_DataPreProcss', '23275', '23287', 'NIS-Elements'], ['T13', 'Application_Usage:Purpose_Analysis', '23515', '23520', 'prism']]
#
#
# file name: PMC6910861.ann |   [['T1', 'Application_Usage:Purpose_Modelling', '5418', '5426', 'microRNA'], ['T3', 'Application_Usage:Purpose_Modelling', '5471', '5481', 'TargetScan'], ['T5', 'Application_Usage:Purpose_Modelling', '5515', '5520', 'miRDB'], ['T7', 'Application_Usage:Purpose_Analysis', '5577', '5582', 'Venny'], ['T10', 'Application_Usage:Purpose_Analysis', '5665', '5676', 'PPI Network'], ['T12', 'PlugIn_Usage:Purpose_Analysis', '5769', '5774', 'MCODE'], ['T14', 'Application_Usage:Purpose_DataCollection', '6125', '6129', 'Xena'], ['T17', 'Application_Usage:Purpose_Analysis', '6245', '6249', 'Xena'], ['T18', 'Application_Usage:Purpose_Analysis', '10649', '10658', 'Image lab'], ['T21', 'Application_Usage:Purpose_Analysis', '11807', '11813', 'ModFit'], ['T24', 'Application_Usage:Purpose_Analysis', '11932', '11936', 'SPSS'], ['T27', 'Application_Usage:Purpose_Modelling', '12647', '12657', 'TargetScan'], ['T28', 'Application_Usage:Purpose_Modelling', '12662', '12667', 'miRDB'], ['T29', 'Application_Usage:Purpose_Modelling', '12637', '12645', 'microRNA'], ['T30', 'PlugIn_Usage:Purpose_Analysis', '13012', '13017', 'MCODE'], ['T31', 'Application_Usage:Purpose_Analysis', '14543', '14554', 'PPI Network']]
#
#
# file name: PMC6944514.ann |   []
#
#
# file name: PMC7057420.ann |   []
#
#
# file name: PMC7072535.ann |   [['T1', 'Application_Usage:Purpose_DataPreProcss', '7317', '7326', 'J-Express'], ['T4', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '7420', '7421', 'R'], ['T7', 'PlugIn_Usage:Purpose_Analysis', '7446', '7458', 'BioConductor'], ['T10', 'Application_Usage:Purpose_Analysis', '7558', '7562', 'GSEA'], ['T13', 'Application_Usage:Purpose_Analysis', '8685', '8692', 'Cluster'], ['T15', 'Application_Usage:Purpose_Analysis', '8701', '8709', 'TreeView'], ['T16', 'Application_Usage:Purpose_Analysis', '8835', '8861', 'Large Average Submatricies'], ['T19', 'Application_Usage:Purpose_Analysis', '12378', '12392', 'Image-Pro Plus'], ['T22', 'Application_Usage:Purpose_Analysis', '13226', '13229', 'SAS'], ['T24', 'Application_Usage:Purpose_Modelling', '13567', '13570', 'LAS'], ['T25', 'Application_Usage:Purpose_Analysis', '16735', '16738', 'LAS']]
#
#
# file name: PMC7098419.ann |   [['T1', 'OperatingSystem_Usage:Purpose_DataCollection', '8503', '8510', 'Windows'], ['T3', 'Application_Usage:Purpose_DataCollection', '8775', '8783', 'Imagelab'], ['T5', 'Application_Usage:Purpose_DataPreProcss', '8997', '9012', 'SPSS Statistics']]
#
#
# file name: PMC7118005.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '12525', '12529', 'SPSS']]
#
#
# file name: PMC7143136.ann |   []
#
#
# file name: PMC7150319.ann |   []
#
#
# file name: PMC7177638.ann |   [['T1', 'Application_Usage:Purpose_Simulation', '17593', '17599', 'Alogps'], ['T4', 'Application_Usage:Purpose_Analysis', '29820', '29825', 'iTeva'], ['T6', 'Application_Usage:Purpose_DataPreProcss', '39422', '39430', 'MultiPak']]
#
#
# file name: PMC7251557.ann |   []
#
#
# file name: PMC7258648.ann |   []
#
#
# file name: PMC7298014.ann |   [['T6', 'Application_Usage:Purpose_DataCollection', '14849', '14854', 'LAS X'], ['T7', 'Application_Usage:Purpose_DataPreProcss', '15155', '15160', 'LAS X'], ['T8', 'Application_Usage:Purpose_DataPreProcss', '15296', '15302', 'Imaris'], ['T11', 'Application_Usage:Purpose_Visualization', '15342', '15348', 'Imaris'], ['T12', 'PlugIn_Usage:Purpose_Visualization', '15478', '15482', 'Fiji'], ['T14', 'Application_Usage:Purpose_Visualization', '15509', '15518', 'Photoshop'], ['T18', 'Application_Usage:Purpose_Visualization', '15536', '15545', 'Quicktime'], ['T22', 'Application_Usage:Purpose_Analysis', '15868', '15877', 'Photoshop'], ['T26', 'Application_Usage:Purpose_Analysis', '15894', '15905', 'Illustrator'], ['T29', 'PlugIn_Usage:Purpose_Analysis', '16370', '16374', 'Fiji'], ['T30', 'Application_Usage:Purpose_Visualization', '17144', '17149', 'Prism'], ['T33', 'Application_Usage:Purpose_Visualization', '17196', '17207', 'Illustrator'], ['T1', 'Application_Usage:Purpose_Simulation', '1866', '1869', 'CFD'], ['T4', 'Application_Usage:Purpose_Modelling', '2031', '2034', 'CAD']]
#
#
# file name: PMC7305855.ann |   []
#
#
# file name: PMC7331121.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '7974', '7978', 'SPSS'], ['T3', 'Application_Usage:Purpose_Visualization', '8534', '8539', 'Prism']]
#
#
# file name: PMC7471053.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '5894', '5921', 'Statistical Analysis System'], ['T2', 'OperatingSystem_Usage:Purpose_Analysis', '5926', '5933', 'Windows']]
#
#
# file name: PMC7474915.ann |   []
#
#
# file name: PMC7504728.ann |   []
#
#
# file name: PMC7519650.ann |   [['T1', 'Application_Usage:Purpose_Analysis', '10254', '10260', 'SnpEff'], ['T3', 'Application_Usage:Purpose_DataCollection', '32729', '32735', 'REDCap'], ['T6', 'Application_Usage:Purpose_DataPreProcss', '34534', '34544', 'bcl2fastq2'], ['T9', 'Application_Usage:Purpose_DataCollection', '34686', '34692', 'Picard'], ['T10', 'Application_Usage:Purpose_DataPreProcss', '34719', '34723', 'GATK'], ['T11', 'Application_Usage:Purpose_Analysis', '34761', '34767', 'Picard'], ['T12', 'Application_Usage:Purpose_Analysis', '35083', '35089', 'MuTect'], ['T14', 'Application_Usage:Purpose_Analysis', '35199', '35206', 'VarScan'], ['T17', 'Application_Usage:Purpose_Modelling', '35238', '35246', 'samtools'], ['T19', 'Application_Usage:Purpose_DataPreProcss', '35299', '35305', 'SnpEff'], ['T21', 'Application_Usage:Purpose_Modelling', '35383', '35389', 'SnpEff'], ['T22', 'Application_Usage:Purpose_Analysis', '35703', '35713', 'Polysolver'], ['T24', 'Application_Usage:Purpose_DataPreProcss', '35831', '35837', 'MuPeXI'], ['T26', 'Application_Usage:Purpose_DataPreProcss', '36074', '36083', 'NetMHCpan'], ['T28', 'Application_Usage:Purpose_DataPreProcss', '36406', '36418', 'GenomeStudio'], ['T31', 'ProgrammingEnvironment_Usage:Purpose_DataPreProcss', '36534', '36535', 'R'], ['T32', 'PlugIn_Usage:Purpose_DataPreProcss', '36544', '36549', 'ASCAT'], ['T34', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '37334', '37335', 'R'], ['T35', 'PlugIn_Usage:Purpose_Analysis', '37345', '37362', 'SomaticSignatures'], ['T37', 'PlugIn_Usage:Purpose_Analysis', '37372', '37390', 'MutationalPatterns'], ['T39', 'Application_Usage:Purpose_DataPreProcss', '38475', '38481', 'SnpEff'], ['T40', 'Application_Usage:Purpose_Analysis', '39268', '39277', 'MSIsensor'], ['T42', 'Application_Usage:Purpose_Analysis', '39420', '39428', 'Polyphen'], ['T45', 'Application_Usage:Purpose_Analysis', '39439', '39455', 'MutationAssessor'], ['T47', 'Application_Usage:Purpose_Analysis', '39540', '39548', 'PolyPhen'], ['T49', 'Application_Usage:Purpose_Analysis', '39554', '39570', 'MutationAssessor'], ['T50', 'Application_Usage:Purpose_Analysis', '39766', '39772', 'MuTect'], ['T52', 'Application_Usage:Purpose_Analysis', '34801', '34807', 'MuTect'], ['T54', 'Application_Usage:Purpose_Analysis', '40160', '40173', 'bam-readcount'], ['T55', 'Application_Usage:Purpose_Analysis', '40916', '40922', 'Salmon'], ['T57', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '41049', '41050', 'R'], ['T58', 'PlugIn_Usage:Purpose_Analysis', '41061', '41069', 'tximport'], ['T60', 'PlugIn_Usage:Purpose_Analysis', '41079', '41084', 'edgeR'], ['T62', 'ProgrammingEnvironment_Usage:Purpose_Modelling', '41261', '41262', 'R'], ['T63', 'PlugIn_Usage:Purpose_Modelling', '41269', '41283', 'consensus MIBC'], ['T65', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '41616', '41617', 'R'], ['T66', 'PlugIn_Usage:Purpose_Analysis', '41626', '41629', 'RTN'], ['T68', 'Application_Usage:Purpose_Analysis', '42240', '42245', 'xCell'], ['T69', 'PlugIn_Usage:Purpose_DataPreProcss', '43082', '43087', 'ChAMP'], ['T70', 'ProgrammingEnvironment_Usage:Purpose_DataPreProcss', '43088', '43089', 'R'], ['T72', 'Application_Usage:Purpose_Analysis', '46935', '46945', 'Visiopharm'], ['T74', 'Application_Usage:Purpose_DataPreProcss', '47120', '47130', 'Visiopharm'], ['T75', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '49366', '49367', 'R'], ['T76', 'PlugIn_Usage:Purpose_Analysis', '49377', '49386', 'survminer'], ['T77', 'PlugIn_Usage:Purpose_Analysis', '49391', '49399', 'survival'], ['T7', 'Application_Usage:Purpose_DataPreProcss', '34549', '34560', 'Trim Galore']]
#
#
# file name: PMC7548573.ann |   []
#
#
# file name: PMC7576861.ann |   [['T1', 'Application_Usage:Purpose_DataPreProcss', '9337', '9367', 'Draeger EIT Data Analysis Tool'], ['T3', 'Application_Usage:Purpose_Analysis', '11679', '11683', 'SPSS']]
#
#
# file name: PMC7598519.ann |   [['T1', 'ProgrammingEnvironment_Usage:Purpose_Analysis', '12455', '12456', 'R'], ['T3', 'PlugIn_Usage:Purpose_Analysis', '12485', '12501', 'OptimalCutpoints'], ['T4', 'Application_Usage:Purpose_Modelling', '11761', '11766', 'Blast'], ['T7', 'Application_Usage:Purpose_Modelling', '11814', '11820', 'Primer']]
#
#
# file name: PMC7641733.ann |   [['T1', 'Application_Usage:Purpose_DataPreProcss', '11418', '11429', 'Trimmomatic'], ['T3', 'Application_Usage:Purpose_DataCollection', '11569', '11575', 'Bowtie']]

# %%
print('size of merged annotatioon list: ', len(all_annotations_list2), '\n')

print('merged annotation list overview:')
all_annotations_list2[:1]
# Out:
# size of merged annotatioon list:  392
#
# merged annotation list overview:
# [['T1', 'Application_Usage:Purpose_Analysis', '15525', '15534', 'SigmaStat']]

# %% [markdown]
# ### `PubMed` : writing merged annotation  Into a Data Frame

# %%
len(all_annotations_list2)
# Out:
# 392

# %%
import pandas as pd

PubMed = pd.DataFrame(columns=['code', 'annotation','start','stop','software'], data=all_annotations_list2)
PubMed
# Out:
#     code                                    annotation  start   stop  \
# 0     T1            Application_Usage:Purpose_Analysis  15525  15534
# 1     T3        OperatingSystem_Usage:Purpose_Analysis  15544  15551
# 2     T5      Application_Usage:Purpose_DataCollection  23622  23636
# 3     T7  OperatingSystem_Usage:Purpose_DataCollection  23645  23652
# 4    T10      Application_Usage:Purpose_DataCollection  23735  23744
# ..   ...                                           ...    ...    ...
# 387   T3                 PlugIn_Usage:Purpose_Analysis  12485  12501
# 388   T4           Application_Usage:Purpose_Modelling  11761  11766
# 389   T7           Application_Usage:Purpose_Modelling  11814  11820
# 390   T1       Application_Usage:Purpose_DataPreProcss  11418  11429
# 391   T3      Application_Usage:Purpose_DataCollection  11569  11575
#
#              software
# 0           SigmaStat
# 1             Windows
# 2      Image-Pro Plus
# 3             Windows
# 4           Scope-Pro
# ..                ...
# 387  OptimalCutpoints
# 388             Blast
# 389            Primer
# 390       Trimmomatic
# 391            Bowtie
#
# [392 rows x 5 columns]

# %% [markdown]
# ### Save the df image

# %%
import dataframe_image as dfi

PubMed_head = PubMed.head(10)
PubMed_tail = PubMed.tail(10)

# save image of head
PubMed_head = PubMed_head.style.background_gradient()
dfi.export(PubMed_head,"PubMed_head_.png")

# save image of tail
PubMed_tail = PubMed_tail.style.background_gradient()
dfi.export(PubMed_tail,"PubMed_tail_.png")


PubMed.to_csv(r'PubMed_.csv', index = False)
# Out:
# C:\Users\Beck\projectDir\venv\lib\site-packages\dataframe_image\_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'

# %% [markdown]
# ## 1.3. Merging PLOS and PubMed DataFrames

# %%
df_PLOS
# Out:
#      code                                     annotation  start   stop  \
# 0      T1            Application_Usage:Purpose_Modelling   3670   3681
# 1      T2       Application_Usage:Purpose_DataCollection   5677   5683
# 2      T3             Application_Usage:Purpose_Analysis   1203   1211
# 3      T1       Application_Usage:Purpose_DataCollection   1447   1450
# 4      T2             Application_Usage:Purpose_Analysis   8512   8517
# ...   ...                                            ...    ...    ...
# 1450   T1             Application_Usage:Purpose_Analysis   6517   6524
# 1451   T2       Application_Usage:Purpose_DataCollection   8352   8358
# 1452   T4       Application_Usage:Purpose_DataCollection   8487   8493
# 1453   T5  ProgrammingEnvironment_Usage:Purpose_Analysis  11462  11463
# 1454   T1             Application_Usage:Purpose_Analysis  12922  12925
#
#          software
# 0     DS modeling
# 1          pCLAMP
# 2        ENSEMBLE
# 3             RIU
# 4           Stata
# ...           ...
# 1450      G*Power
# 1451       Enketo
# 1452       Enketo
# 1453            R
# 1454          SAS
#
# [1455 rows x 5 columns]

# %%
PubMed
# Out:
#     code                                    annotation  start   stop  \
# 0     T1            Application_Usage:Purpose_Analysis  15525  15534
# 1     T3        OperatingSystem_Usage:Purpose_Analysis  15544  15551
# 2     T5      Application_Usage:Purpose_DataCollection  23622  23636
# 3     T7  OperatingSystem_Usage:Purpose_DataCollection  23645  23652
# 4    T10      Application_Usage:Purpose_DataCollection  23735  23744
# ..   ...                                           ...    ...    ...
# 387   T3                 PlugIn_Usage:Purpose_Analysis  12485  12501
# 388   T4           Application_Usage:Purpose_Modelling  11761  11766
# 389   T7           Application_Usage:Purpose_Modelling  11814  11820
# 390   T1       Application_Usage:Purpose_DataPreProcss  11418  11429
# 391   T3      Application_Usage:Purpose_DataCollection  11569  11575
#
#              software
# 0           SigmaStat
# 1             Windows
# 2      Image-Pro Plus
# 3             Windows
# 4           Scope-Pro
# ..                ...
# 387  OptimalCutpoints
# 388             Blast
# 389            Primer
# 390       Trimmomatic
# 391            Bowtie
#
# [392 rows x 5 columns]

# %%
# merge the two dfs

frames = [df_PLOS,PubMed]
PubMed_PLoS = pd.concat(frames)

# reset index
PubMed_PLoS = PubMed_PLoS.reset_index(drop=True)


# EXPORT RESULTS


# save image of head and tail
PubMed_PLoS_head = PubMed_PLoS.head(10)
PubMed_PLoS_tail = PubMed_PLoS.tail(10)


PubMed_PLoS_head = PubMed_PLoS_head.style.background_gradient()
dfi.export(PubMed_tail,"PubMed_PLoS_head_.png")

PubMed_PLoS_tail = PubMed_PLoS_tail.style.background_gradient()
dfi.export(PubMed_PLoS_tail,"PubMed_PLoS_tail_.png")

# save to csv
PubMed_PLoS.to_csv(r'PubMed_PLoS_.csv', index = False)
# Out:
# C:\Users\Beck\projectDir\venv\lib\site-packages\dataframe_image\_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'

# %%
PubMed_PLoS
# Out:
#      code                                annotation  start   stop  \
# 0      T1       Application_Usage:Purpose_Modelling   3670   3681
# 1      T2  Application_Usage:Purpose_DataCollection   5677   5683
# 2      T3        Application_Usage:Purpose_Analysis   1203   1211
# 3      T1  Application_Usage:Purpose_DataCollection   1447   1450
# 4      T2        Application_Usage:Purpose_Analysis   8512   8517
# ...   ...                                       ...    ...    ...
# 1842   T3             PlugIn_Usage:Purpose_Analysis  12485  12501
# 1843   T4       Application_Usage:Purpose_Modelling  11761  11766
# 1844   T7       Application_Usage:Purpose_Modelling  11814  11820
# 1845   T1   Application_Usage:Purpose_DataPreProcss  11418  11429
# 1846   T3  Application_Usage:Purpose_DataCollection  11569  11575
#
#               software
# 0          DS modeling
# 1               pCLAMP
# 2             ENSEMBLE
# 3                  RIU
# 4                Stata
# ...                ...
# 1842  OptimalCutpoints
# 1843             Blast
# 1844            Primer
# 1845       Trimmomatic
# 1846            Bowtie
#
# [1847 rows x 5 columns]

# %% [markdown]
# # 2. Analysis of Annotations
#
#
# A deeper look into the annotated data.
#
# ### Steps:
#
# ## 2.1 Pre-processing
#
# - Co-Ref resolution of software entities : Handling software names that refer to the same software entity
# - Format `PubMed_PLoS` dataframe in `NTP` format ... NameTypePurpose format.
#
# ## 2.2 Analysis annotations
#
# #### 2.1. from the software perspective:
#
# - How much software does appear only for a single purpose?
# - What type combinations appear for software?
#
# #### 2.2. from the type perspective:
#
# - How many different software is there per type?
# - Does any type just have few software? etc.

# %% [markdown]
# ### Co-ref resolution of software names

# %%
def softName_link(*keys):
    
    
    list_SWLink = {}
    
    with open('artifacts.json') as f:
        
        # d is list of dictionaries for each software
        d = json.load(f)
        
        for i in range(len(d)):
            
            a_subset = {key: d[i][key] for key in keys_to_extract}
             
            swNam = a_subset["mention"]
            swLnk = a_subset["link"] 
        
            list_SWLink[swNam] = swLnk
        
    return list_SWLink

# %%
import json
keys_to_extract = ["mention", "link"]

list_SWLink = softName_link(keys_to_extract)
list_SWLink
# Out:
# {'2LD': 'https://gaow.github.io/genetic-analysis-software/1/2ld',
#  '3C Primer Design': 'http://www.pristionchus.org/3CPrimerDesign',
#  '3dBandpass': 'https://afni.nimh.nih.gov/pub/dist/doc/program_help/3dBandpass.html',
#  '3dClustsim': 'https://afni.nimh.nih.gov/pub/dist/doc/program_help/3dClustSim.html',
#  '3dDeconvolve': 'https://afni.nimh.nih.gov/pub/dist/doc/program_help/3dDeconvolve.html',
#  '3dDespike': 'https://afni.nimh.nih.gov/pub/dist/doc/program_help/3dDespike.html',
#  '3dDetrend': 'https://afni.nimh.nih.gov/pub/dist/doc/program_help/3dDetrend.html',
#  '3dFDR': 'https://afni.nimh.nih.gov/pub/dist/doc/program_help/3dFDR.html',
#  '3dFWHMx': 'https://afni.nimh.nih.gov/pub/dist/doc/program_help/3dFWHMx.html',
#  '3dmaskave': 'https://afni.nimh.nih.gov/pub/dist/doc/program_help/3dmaskave.html',
#  '3dttest+ +': 'https://afni.nimh.nih.gov/pub/dist/doc/program_help/3dttest++.html',
#  '3PD': 'http://www.pristionchus.org/3CPrimerDesign',
#  '4Cin': 'https://github.com/batxes/4Cin',
#  'Access': 'https://www.wikidata.org/wiki/Q80689',
#  'AccuTyping': 'http://www2.umdnj.edu/lilabweb/publications/AccuTyping.html',
#  'ACME': 'https://github.com/krm15/ACME',
#  'AcqKnowledge': 'https://www.biopac.com/product/acqknowledge-software',
#  'Acrobat': 'https://www.wikidata.org/wiki/Q207902',
#  'ActiLife': 'https://actigraphcorp.com/support/software/actilife',
#  'Actionscript': 'https://www.wikidata.org/wiki/Q234657',
#  'Actiware': 'http://www.actigraphy.respironics.com/solutions/actiware',
#  'ADAPT': 'https://bmsr.usc.edu/software/adapt',
#  'adjustedRandIndex': 'https://cran.r-project.org/package=mclust',
#  'ADMIXMAP': 'http://homepages.ed.ac.uk/pmckeigu/software/admixmap',
#  'Advanced Model': 'https://www.ibm.com/products/spss-advanced-statistics',
#  'Advanced Normalization Tools': 'https://github.com/ANTsX/ANTs',
#  'AFNI': 'https://www.wikidata.org/wiki/Q4751099',
#  'aLFQ': 'https://cran.r-project.org/package=aLFQ',
#  'AlignerBoost': 'https://github.com/Grice-Lab/AlignerBoost',
#  'Alogps': 'http://www.vcclab.org/lab/alogps',
#  'AlphaSim': 'ALPHASIM_01',
#  'Altmetric': 'https://www.altmetric.com/products/free-tools/bookmarklet',
#  'AMBERTOOLS': 'https://ambermd.org/AmberTools.php',
#  'AmeliaView': 'https://cran.r-project.org/package=Amelia',
#  'AMIX': 'https://www.bruker.com/en/services/training/magnetic-resonance/nmr-trainings/germany-switzerland/amix-software.html',
#  'AMOS': 'https://www.ibm.com/products/structural-equation-modeling-sem',
#  'Analysis of Moment Structures': 'https://www.ibm.com/products/structural-equation-modeling-sem',
#  'Analyst': 'https://sciex.com/products/software/analyst-software',
#  'Anatomy atlas': 'https://www.fz-juelich.de/inm/inm-1/DE/Forschung/_docs/SPMAnatomyToolbox/SPMAnatomyToolbox_node.html',
#  'ANDES': 'https://sourceforge.net/projects/andestools',
#  'ANFI': 'https://www.wikidata.org/wiki/Q4751099',
#  'Aninhado': 'https://www.guimaraes.bio.br/soft.html',
#  'ANNOVAR': 'https://www.wikidata.org/wiki/Q85738947',
#  'ArcGis': 'https://www.wikidata.org/wiki/Q513297',
#  'ArcGIS': 'https://www.wikidata.org/wiki/Q513297',
#  'ArcMap': 'https://www.wikidata.org/wiki/Q4784993',
#  'ArcView': 'https://www.wikidata.org/wiki/Q631011',
#  'Arlequin': 'https://www.wikidata.org/wiki/Q4792191',
#  'ARLEQUIN': 'https://www.wikidata.org/wiki/Q4792191',
#  'Arlequín': 'https://www.wikidata.org/wiki/Q4792191',
#  'ART': 'https://www.nitrc.org/projects/artifact_detect',
#  'Artemis': 'https://github.com/sanger-pathogens/Artemis',
#  'articulatory synthesizer': 'https://www.fon.hum.uva.nl/praat/manual/Articulatory_synthesis.html',
#  'Artifact Rejection Toolbox': 'https://www.nitrc.org/projects/artifact_detect',
#  'ASCAT': 'http://www.ifi.uio.no/bioinf/Projects/ASCAT',
#  'ASPASIA': 'https://www.york.ac.uk/computational-immunology/software/aspasia',
#  'AsReml': 'https://www.wikidata.org/wiki/Q4654344',
#  'ATLAS.ti': 'https://www.wikidata.org/wiki/Q3628244',
#  'Atlas.ti': 'https://www.wikidata.org/wiki/Q3628244',
#  'Attivio': 'https://www.attivio.com',
#  'AUTO': 'http://indy.cs.concordia.ca/auto',
#  'Autodock Vina': 'http://vina.scripps.edu',
#  'Axio Vision': 'http://www.zeiss.com/microscopy/int/products/microscope-software/axiovision',
#  'bam-readcount': 'https://github.com/genome/bam-readcount',
#  'Bamgineer': 'http://github.com/pughlab/bamgineer',
#  'Basic': 'https://www.wikidata.org/wiki/Q42979',
#  'Basic Local Alignment Search Tool': 'https://www.wikidata.org/wiki/Q286820',
#  'Bayesian Evolutionary Analysis by Sampling Trees': 'https://beast.community',
#  'BCFtools': 'https://github.com/samtools/bcftools',
#  'bcl2fastq2': 'https://github.com/brwnj/bcl2fastq',
#  'BD FACSDiva': 'https://www.bdbiosciences.com/en-us/instruments/research-instruments/research-software/flow-cytometry-acquisition/facsdiva-software',
#  'BeadStudio': 'https://www.illumina.com/Documents/products/datasheets/datasheet_beadstudio.pdf',
#  'BEAGLE': 'https://faculty.washington.edu/browning/beagle/beagle.html',
#  'BEAST': 'https://beast.community',
#  'beast': 'https://beast.community',
#  'bedtools': 'https://github.com/arq5x/bedtools2',
#  'BEDTools': 'https://github.com/arq5x/bedtools2',
#  'BeGaze': 'https://gazeintelligence.com/smi-software-download',
#  'Behavior Annotator': 'https://github.com/pdollar/toolbox/blob/master/videos/behaviorAnnotator.m',
#  'Bellerpheron': 'http://comp-bio.anu.edu.au/bellerophon/bellerophon.pl',
#  'BeWith': 'https://www.ncbi.nlm.nih.gov/CBBresearch/Przytycka/index.cgi#bewith',
#  'BiNGO': 'https://www.psb.ugent.be/cbd/papers/BiNGO/Home.html',
#  'Bioanalyzer': 'https://www.agilent.com/en/product/automated-electrophoresis/bioanalyzer-systems',
#  'BioConductor': 'https://bioconductor.org',
#  'Bioconductor': 'https://bioconductor.org',
#  'BioEdit': 'https://www.nucleics.com/DNA_sequencing_support/Trace_viewer_reviews/BioEdit',
#  'BIOEDIT': 'https://www.nucleics.com/DNA_sequencing_support/Trace_viewer_reviews/BioEdit',
#  'biographer': 'http://code.google.com/p/biographer',
#  'BioMart': 'https://www.wikidata.org/wiki/Q28444600',
#  'Biomart': 'https://www.wikidata.org/wiki/Q28444600',
#  'BioNetGen': 'https://github.com/RuleWorld/bionetgen',
#  'Bioplex Manager': 'https://www.bio-rad.com/en-us/product/bio-plex-manager-software-standard-edition',
#  'Bioportal': 'http://www.bioportal.uio.no',
#  'BioPython': 'https://www.wikidata.org/wiki/Q4118434',
#  'Biopython': 'https://www.wikidata.org/wiki/Q4118434',
#  'BioTools': 'https://bruker-daltonics-biotools.software.informer.com/3.0',
#  'Biotrace': 'https://www.mindmedia.com/downloads',
#  'Bioworks': 'http://tools.thermofisher.com/content/sfs/manuals/Man-XCALI-97194-BioWorks-331-SP1-User-ManXCALI97194-B-EN.pdf',
#  'bipartite': 'https://cran.r-project.org/package=bipartite',
#  'Birdseye': 'https://www.broadinstitute.org/birdsuite',
#  'BisoGenet': 'http://apps.cytoscape.org/apps/bisogenet',
#  'Bitbucket': 'https://www.wikidata.org/wiki/Q2493781',
#  'BLASR': 'https://github.com/PacificBiosciences/blasr',
#  'BLAST': 'https://www.wikidata.org/wiki/Q286820',
#  'blast': 'https://www.wikidata.org/wiki/Q286820',
#  'Blast': 'https://www.wikidata.org/wiki/Q286820',
#  'blastn': 'https://www.wikidata.org/wiki/Q286820',
#  'Blastn': 'https://www.wikidata.org/wiki/Q286820',
#  'BLASTp': 'https://www.wikidata.org/wiki/Q286820',
#  'Blastp': 'https://www.wikidata.org/wiki/Q286820',
#  'bnlearn': 'https://cran.r-project.org/package=bnlearn',
#  'BOLT-LMM': 'https://alkesgroup.broadinstitute.org/BOLT-LMM',
#  'boot': 'https://cran.r-project.org/package=boot',
#  'BootES': 'https://cran.r-project.org/package=bootES',
#  'Bootstrap': 'https://www.pbarrett.net/Bootstrap/Bootstrap.html',
#  'BOTTLENECK': 'http://www1.montpellier.inra.fr/CBGP/software/Bottleneck/bottleneck.html',
#  'Bottleneck': 'http://www1.montpellier.inra.fr/CBGP/software/Bottleneck/bottleneck.html',
#  'Bowtie': 'http://bowtie-bio.sourceforge.net/bowtie2',
#  'Brain Connectivity Toolbox': 'https://sites.google.com/site/bctnet',
#  'Brain Vision Analyzer': 'https://www.brainproducts.com/downloads.php?kid=9',
#  'Brain Vision Recorder': 'https://www.brainproducts.com/downloads.php?kid=2',
#  'Brain Voyager': 'https://www.wikidata.org/wiki/Q41793788',
#  'Brainsight': 'https://www.rogue-research.com/tms/brainsight-tms',
#  'BrainStorm': 'https://www.wikidata.org/wiki/Q64816680',
#  'BrainVoyager': 'https://www.wikidata.org/wiki/Q41793788',
#  'BVQX': 'http://www.brainvoyager.com/products/brainvoyagerqx.html',
#  'BWA': 'https://github.com/lh3/bwa',
#  'BWA-MEM': 'https://github.com/lh3/bwa',
#  'C': 'https://www.wikidata.org/wiki/Q15777',
#  'C#': 'https://www.wikidata.org/wiki/Q2370',
#  'C++': 'https://www.wikidata.org/wiki/Q2407',
#  'C2': 'https://eprint.ncl.ac.uk/6053',
#  'CAD': 'https://www.solidworks.com/product/solidworks-3d-cad',
#  'CADD': 'https://cadd.gs.washington.edu',
#  'CALIB': 'http://calib.org/calib',
#  'Calib': 'http://calib.org/calib',
#  'Cambridge Neuropsychological Test Automated Battery': 'https://www.wikidata.org/wiki/Q5025484',
#  'Cancer, Heart And Soft Tissue Environment': 'https://github.com/Chaste/Chaste',
#  'CANTAB': 'https://www.wikidata.org/wiki/Q5025484',
#  'CapR': 'https://sites.google.com/site/fukunagatsu/software/capr',
#  'car': 'https://cran.r-project.org/package=car',
#  'caret': 'https://cran.r-project.org/package=caret',
#  'CASAVA': 'http://support.illumina.com/sequencing/sequencing_software/casava.html',
#  'CBFA': 'http://www.optflux.org/cbfa',
#  'CCS': 'https://www.hcup-us.ahrq.gov/toolssoftware/ccs/ccs.jsp',
#  'CeleST': 'http://celest.mbb.rutgers.edu',
#  'CellProfiler': 'https://github.com/CellProfiler',
#  'CellQuest': 'CELLQUEST_01',
#  'cellSens Dimension': 'https://www.olympus-lifescience.com/software/cellsens',
#  'cellXpress': 'http://www.cellxpress.org',
#  'Cervus': 'http://www.fieldgenetics.com/pages/aboutCervus_Overview.jsp',
#  'CFD': 'https://www.ansys.com/products/fluids',
#  'CGBayesNets': 'http://www.cgbayesnets.com',
#  'ChAMP': 'https://bioconductor.org/packages/ChAMP',
#  'Chart': 'CHART_01',
#  'Chaste': 'https://github.com/Chaste/Chaste',
#  'Chemistry Development Kit': 'https://www.wikidata.org/wiki/Q2383032',
#  'Chenomx': 'https://www.chenomx.com',
#  'Chenomx NMR Suite': 'https://www.chenomx.com',
#  'Chimera': 'http://www.cgl.ucsf.edu/chimera',
#  'Chrome': 'https://www.wikidata.org/wiki/Q777',
#  'Chromeleon': 'https://www.thermofisher.com/order/catalog/product/CHROMELEON7#/CHROMELEON7',
#  'CIBERSORT': 'https://cibersort.stanford.edu',
#  'CIMSiM': 'CIMSIM_01',
#  'clam': 'https://cran.r-project.org/package=clam',
#  'CLC Genomic Workbench': 'https://www.wikidata.org/wiki/Q29876897',
#  'Clinical Classifications Software': 'https://www.hcup-us.ahrq.gov/toolssoftware/ccs/ccs.jsp',
#  'CloVR': 'http://clovr.org',
#  'CloVR-ITS': 'https://doi.org/10.1186%2F2049-2618-1-6',
#  'ClueGO': 'https://apps.cytoscape.org/apps/cluego',
#  'CLUMP': 'https://gaow.github.io/genetic-analysis-software/c/clump',
#  'CLUMPP': 'https://rosenberglab.stanford.edu/clumpp.html',
#  'Clustal': 'https://www.wikidata.org/wiki/Q866737',
#  'Clustal W': 'https://www.wikidata.org/wiki/Q866737',
#  'ClustalW': 'https://www.wikidata.org/wiki/Q866737',
#  'Cluster': 'http://bonsai.hgc.jp/~mdehoon/software/cluster',
#  'clusterMaker': 'https://apps.cytoscape.org/apps/clustermaker',
#  'cnvHap': 'http://www.imperial.ac.uk/people/l.coin',
#  'CNVkit': 'https://github.com/etal/cnvkit',
#  'CNVmap': 'https://doi.org/10.25386/genetics.10266425',
#  'COANCESTRY': 'https://www.zsl.org/science/software/coancestry',
#  'COBRAme': 'https://github.com/sbrg/cobrame',
#  'COBRApy': 'https://github.com/opencobra/cobrapy',
#  'Coffalyser.NET': 'https://www.mrcholland.com/technology/software/coffalyser-net',
#  'Cogent': 'http://www.vislab.ucl.ac.uk/cogent.php',
#  'Cogent 2000': 'http://www.vislab.ucl.ac.uk/cogent_2000.php',
#  'COLONY': 'https://www.zsl.org/science/software/colony',
#  'Combined Annotation Dependent Depletion': 'https://cadd.gs.washington.edu',
#  'Complex samples': 'https://www.ibm.com/products/spss-complex-samples',
#  'Complex Samples': 'https://www.ibm.com/products/spss-complex-samples',
#  'Comprehensive Meta-Analysis': 'https://www.meta-analysis.com',
#  'CompuSin': 'https://www.combosyn.com',
#  'CompuSyn': 'https://www.combosyn.com',
#  'Condel': 'http://bg.upf.edu/condel',
#  'CoNIFER': 'http://conifer.sourceforge.net',
#  'CONN': 'http://www.nitrc.org/projects/conn',
#  'conn': 'http://www.nitrc.org/projects/conn',
#  'ConoMass': 'http://www.conoserver.org',
#  'ConQuest': 'https://www.wikidata.org/wiki/Q5013404',
#  'consensus MIBC': 'https://github.com/cit-bioinfo/consensusMIBC',
#  'Constraint-based Flux Analysis': 'http://www.optflux.org/cbfa',
#  'ConSurf-HSSP': 'http://consurf-hssp.tau.ac.il',
#  'convert': 'http://hpc.ilri.cgiar.org/beca/bioinfo/convert.html',
#  'Copy Number Inference from Exome Reads': 'http://conifer.sourceforge.net',
#  'coXpress': 'http://coxpress.sf.net',
#  'CoXpress': 'http://coxpress.sf.net',
#  'CPPTRAJ': 'https://github.com/Amber-MD/cpptraj',
#  'CRAN': 'https://www.wikidata.org/wiki/Q2086703',
#  'Crimap': 'http://teacher.bmc.uu.se/CRIMAP/Crimap/wwwversn.html',
#  'CrystalClear': 'https://www.rigaku.com/downloads/software/crystalclear',
#  'CSPRO': 'https://www.wikidata.org/wiki/Q5014227',
#  'CT-Expo': 'http://www.mh-hannover.de/kliniken/radiologie/str_04.html',
#  'Ctrax': 'http://ctrax.sourceforge.net',
#  'CubeX': 'http://www.oege.org/software/cubex',
#  'Cufflinks': 'https://github.com/cole-trapnell-lab/cufflinks',
#  'Curve Fitting Toolbox': 'https://mathworks.com/products/curvefitting.html',
#  'cutadapt': 'https://github.com/marcelm/cutadapt',
#  'CVODE': 'https://github.com/ufz/cvode',
#  'Cyberball': 'http://www3.psych.purdue.edu/~willia55/Announce/cyberball.htm',
#  'Cytobank': 'http://www.cytobank.org',
#  'Cytoscape': 'https://www.wikidata.org/wiki/Q3699942',
#  'cytoscape': 'https://www.wikidata.org/wiki/Q3699942',
#  'DARTEL': 'https://neurometrika.org/node/34',
#  'Database for Annotation, Visualization and Integrated Discovery': 'http://david.abcc.ncifcrf.gov',
#  'Datacam': 'DATACAM_01',
#  'Datamonkey': 'https://github.com/veg/datamonkey-js',
#  'Dataquest': 'https://www.datasci.com/products/software/dataquest-art',
#  'DAVID': 'http://david.abcc.ncifcrf.gov',
#  'DCE@urLAB': 'http://www.die.upm.es/im/archives/DCEurLAB',
#  'dcGOR': 'https://cran.r-project.org/package=dcGOR',
#  'dcm4che': 'https://www.dcm4che.org',
#  'dcm4chee': 'https://github.com/dcm4che/dcm4chee-arc-light/',
#  'Debian': 'https://www.wikidata.org/wiki/Q7715973',
#  'DELLY': 'http://www.korbel.embl.de/software.html',
#  'DelPhi': 'http://compbio.clemson.edu/DelPhi.php',
#  'DESeq': 'https://bioconductor.org/packages/DESeq',
#  'DESeq2': 'https://bioconductor.org/packages/DESeq2',
#  'Diffeomorphic Anatomical Registration Through Exponentiated Lie Algebra': 'https://neurometrika.org/node/34',
#  'diffeomorphic anatomical registration through the exponentiated Lie algebra': 'https://neurometrika.org/node/34',
#  'Digilab': 'https://www.motic.com/As_microscope_software_a/product_236.html',
#  'Digipro': 'DIGIPRO_01',
#  'dismo': 'https://cran.r-project.org/package=dismo',
#  'DISSECT': 'http://www.dissect.ed.ac.uk',
#  'DISTRUCT': 'https://rosenberglab.stanford.edu/distruct.html',
#  'DIVA-GIS': 'https://www.wikidata.org/wiki/Q1153889',
#  'DIYABC': 'http://www1.montpellier.inra.fr/CBGP/diyabc',
#  'Django': 'https://www.wikidata.org/wiki/Q842014',
#  'dlnm': 'https://cran.r-project.org/package=dlnm',
#  'DNAsp': 'http://www.ub.edu/dnasp',
#  'DnaSP': 'http://www.ub.edu/dnasp',
#  'DOGS': 'http://doi.org/10.1371/journal.pcbi.1002380',
#  'dplyr': 'https://www.wikidata.org/wiki/Q104854189',
#  'Draeger EIT Data Analysis Tool': 'DRAEGER_EIT_DATA_ANALYSIS_TOOL_01',
#  'DriverNet': 'https://bioconductor.org/packages/DriverNet',
#  'DS modeling': 'https://www.wikidata.org/wiki/Q5281973',
#  'DS ViewerPro': 'http://www.accelrys.com/dstudio/ds_viewer',
#  'DTIFit': 'https://users.fmrib.ox.ac.uk/~behrens/fdt_docs/fdt_dtifit.html',
#  'DTV.II SR': 'http://www.ut-radiology.umin.jp/people/masutani/dTV/dTV_frame-e.htm',
#  'dual regression': 'https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/DualRegression',
#  'E-prime': 'https://pstnet.com/products/e-prime',
#  'E-Prime': 'https://pstnet.com/products/e-prime',
#  'EASY RA1 Easy Randomizer': 'EASY_RA1_EASY_RANDOMIZER_01',
#  'edge': 'https://www.bioconductor.org/packages/edge',
#  'edgeR': 'https://bioconductor.org/packages/edgeR',
#  'EdgeR': 'https://bioconductor.org/packages/edgeR',
#  'EEGLAB': 'https://github.com/sccn/eeglab',
#  'EEGLab': 'https://github.com/sccn/eeglab',
#  'EEGlab': 'https://github.com/sccn/eeglab',
#  'eMatchSite': 'http://www.brylinski.org/ematchsite',
#  'ENCORE': 'https://github.com/encore-similarity/encore',
#  'Endnote': 'https://www.wikidata.org/wiki/Q1340244',
#  'Enketo': 'https://enketo.org',
#  'ENMtools': 'https://github.com/danlwarren/ENMTools',
#  'Ensembl': 'http://www.ensembl.org',
#  'ENSEMBLE': 'http://www.ensembl.org',
#  'Ensembler': 'https://github.com/choderalab/ensembler',
#  'Entrez Utilities Entrez Programming Utilities': 'http://eutils.ncbi.nlm.nih.gov',
#  'ENVI': 'https://www.l3harrisgeospatial.com/Software-Technology/ENVI',
#  'Epi': 'https://cran.r-project.org/package=Epi',
#  'Epi Info': 'https://www.wikidata.org/wiki/Q2601695',
#  'EPI INFO': 'https://www.wikidata.org/wiki/Q2601695',
#  'EPI info': 'https://www.wikidata.org/wiki/Q2601695',
#  'EPI Info': 'https://www.wikidata.org/wiki/Q2601695',
#  'Epi-Info': 'https://www.wikidata.org/wiki/Q2601695',
#  'epidata': 'https://www.wikidata.org/wiki/Q5382673',
#  'EpiData': 'https://www.wikidata.org/wiki/Q5382673',
#  'Epidata': 'https://www.wikidata.org/wiki/Q5382673',
#  'EpiData Analysis': 'https://www.wikidata.org/wiki/Q5382673',
#  'EpiGRAPH': 'http://epigraph.mpi-inf.mpg.de',
#  'EpiInfo': 'https://www.wikidata.org/wiki/Q2601695',
#  'EpiR': 'https://cran.r-project.org/package=epiR',
#  'EpiTools': 'https://cran.r-project.org/package=epitools',
#  'EQ-5D calculator': 'http://www.euroqol.org/eq-5d-products/eq-5d-5l.html',
#  'eRM': 'https://cran.r-project.org/package=eRm',
#  'ESPRIT-Forest': 'https://www.acsu.buffalo.edu/~yijunsun/lab/ESPRIT-Forest.html',
#  'EstimateS': 'http://www.purl.oclc.org/estimates',
#  'Ethovision': 'https://www.noldus.com/ethovision-xt',
#  'EthoVision': 'https://www.noldus.com/ethovision-xt',
#  'EventIDE': 'http://www.okazolab.com',
#  'Excel': 'https://www.wikidata.org/wiki/Q11272',
#  'EXCEL': 'https://www.wikidata.org/wiki/Q11272',
#  'excel': 'https://www.wikidata.org/wiki/Q11272',
#  'Experiment Builder': 'https://www.sr-research.com/experiment-builder',
#  'Experiment Center': 'EXPERIMENT_CENTER_01',
#  'Experimetrix': 'https://www.experimetrix.com',
#  'Expression Analysis Systematic Explorer': 'http://david.niaid.nih.gov/david/ease.htm',
#  'EyeLink API': 'EYELINK_API_01',
#  'EyeLink Data Viewer': 'https://www.sr-research.com/data-viewer',
#  'Eyelink Toolbox': 'http://psychtoolbox.org/docs/EyelinkToolbox',
#  'EyeVision': 'EYEVISION_01',
#  'FACSuite': 'https://www.bdbiosciences.com/en-us/instruments/research-instruments/research-software/flow-cytometry-acquisition/facsuite-software',
#  'FamSeq': 'http://sourceforge.net/projects/famseq',
#  'FAP': 'http://www.aqua.stir.ac.uk/rep-gen/Downloads.html',
#  'FastQC': 'https://www.wikidata.org/wiki/Q67141781',
#  'FDT': 'https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FDT',
#  'FGENESB': 'http://www.softberry.com/berry.phtml',
#  'Fieldmap': 'https://www.fil.ion.ucl.ac.uk/spm/toolbox/fieldmap',
#  'Fig Tree': 'https://github.com/rambaut/figtree',
#  'FigureJ': 'http://www.figurej.org',
#  'Fiji': 'https://www.wikidata.org/wiki/Q5425748',
#  'FIMO': 'http://meme.sdsc.edu',
#  'FIMTrack': 'http://fim.uni-muenster.de',
#  'Fire Weather Indices Calculator': 'https://github.com/Insubric/fire-calculator',
#  'Firefox': 'https://www.wikidata.org/wiki/Q698',
#  'FixErrors': 'http://ctrax.sourceforge.net/fixerrors.html',
#  'Flash': 'https://www.wikidata.org/wiki/Q165658',
#  'Flex Analysis': 'https://www.bruker.com/en/products-and-solutions/mass-spectrometry/maldi-tof/autoflex-max.html',
#  'FlexArray': 'http://www.gqinnovationcenter.com/services/bioinformatics/flexarray',
#  'FLIRT': 'https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FLIRT',
#  'FlowJo': 'https://www.wikidata.org/wiki/Q5462055',
#  'FMRIB Software Library': 'https://www.wikidata.org/wiki/Q3737246',
#  "FMRIB's Automated Segmentation Tool": 'https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FAST',
#  "FMRIB's ICA-based X-noiseifier": 'https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FIX',
#  'FMRIB’s Diffusion Toolbox': 'https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FDT',
#  'FMRIB’s Integrated Registration and Segmentation Tool': 'https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FIRST',
#  'fmsb': 'https://cran.r-project.org/package=fmsb',
#  'FNIRT': 'https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FNIRT',
#  'Fortran': 'https://www.wikidata.org/wiki/Q83303',
#  'FragIt': 'http://www.github.com/FragIt',
#  'Fragstats': 'http://www.umass.edu/landeco/research/fragstats/fragstats.html',
#  'FREENA': 'https://www1.montpellier.inra.fr/CBGP/software/FreeNA',
#  'FreeSurfer': 'https://www.wikidata.org/wiki/Q2363545',
#  'FSL': 'https://www.wikidata.org/wiki/Q3737246',
#  'FSL-VBM': 'https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FSLVBM',
#  'FSLView': 'https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FslView',
#  'FSTAT': 'https://www.wikidata.org/wiki/Q5427149',
#  'Fstat': 'https://www.wikidata.org/wiki/Q5427149',
#  'FunciSNP': 'https://bioconductor.org/packages/FunciSNP',
#  'Functional Annotation Tool': 'https://david.ncifcrf.gov/content.jsp?file=functional_annotation.html',
#  'Functional Identification of SNPs': 'https://bioconductor.org/packages/FunciSNP',
#  'FunRich': 'http://www.funrich.org',
#  'G*Power': 'https://www.wikidata.org/wiki/Q18411871',
#  'g++': 'https://www.wikidata.org/wiki/Q178940',
#  'GAMESS': 'https://www.msg.chem.iastate.edu/gamess',
#  'Gannet': 'https://www.gabamrs.com',
#  'GARLI': 'http://www.bio.utexas.edu/faculty/antisense/garli/Garli.html',
#  'GATK': 'https://www.wikidata.org/wiki/Q28974859',
#  'gcc': 'https://www.wikidata.org/wiki/Q178940',
#  'GDAL': 'https://www.wikidata.org/wiki/Q580605',
#  'gdata': 'https://cran.r-project.org/package=gdata',
#  'GEMINI': 'https://github.com/arq5x/gemini',
#  'GenAlEx': 'https://biology-assets.anu.edu.au/GenAlEx',
#  'GenCall': 'https://www.illumina.com/Documents/products/technotes/technote_gencall_data_analysis_software.pdf',
#  'Gene Cluster': 'http://bonsai.hgc.jp/~mdehoon/software/cluster',
#  'GENECOUNTING': 'http://www.iop.kcl.ac.uk/IoP/Departments/PsychMed/GEpiBSt/software.stm',
#  'Geneious': 'https://www.wikidata.org/wiki/Q5531616',
#  'GENELAND': 'https://www.wikidata.org/wiki/Q47519550',
#  'Geneland': 'https://www.wikidata.org/wiki/Q47519550',
#  'GENEMAPPER': 'http://doi.org/10.1186/gb-2006-7-4-r29',
#  'genemapper': 'http://doi.org/10.1186/gb-2006-7-4-r29',
#  'GeneMapper': 'http://doi.org/10.1186/gb-2006-7-4-r29',
#  'GeneOverlap': 'https://bioconductor.org/packages/GeneOverlap',
#  'GenePix': 'https://www.moleculardevices.com/products/additional-products/genepix-microarray-systems-scanners',
#  'Genepix Pro': 'https://www.moleculardevices.com/products/additional-products/genepix-microarray-systems-scanners',
#  'GENEPOP': 'https://kimura.univ-montp2.fr/%7Erousset/Genepop.htm',
#  'GenePop': 'https://kimura.univ-montp2.fr/%7Erousset/Genepop.htm',
#  'Genescan': 'https://tools.thermofisher.com/content/sfs/brochures/cms_039770.pdf',
#  'Genevestigator': 'https://www.wikidata.org/wiki/Q30178153',
#  'Genome Analysis Toolkit': 'https://gatk.broadinstitute.org',
#  'Genome browser': 'https://www.wikidata.org/wiki/Q5533486',
#  'Genome Variation Server': 'https://gvs.gs.washington.edu/GVS150',
#  'GenomePop': 'http://webs.uvigo.es/acraaj/GenomePop.htm',
#  'GenomeStudio': 'https://www.illumina.com/techniques/microarrays/array-data-analysis-experimental-design/genomestudio.html',
#  'Genomics Suite': 'https://www.partek.com/partek-genomics-suite',
#  'GeNorm': 'https://genorm.cmgg.be',
#  'geo-spatial modeling environment': 'http://www.spatialecology.com/gme',
#  'geographic information system': 'https://www.wikidata.org/wiki/Q5535060',
#  'get_totals': 'http://www0.cs.ucl.ac.uk/staff/g.ridgway/vbm/get_totals.m',
#  'ggplot2': 'https://www.wikidata.org/wiki/Q326489',
#  'ggsashimi': 'https://github.com/guigolab/ggsashimi',
#  'GINI': 'http://sailing.cs.cmu.edu/Drosophila_ISH_images',
#  'GIS': 'https://www.wikidata.org/wiki/Q5535060',
#  'GitHub': 'https://www.wikidata.org/wiki/Q364',
#  'github': 'https://www.wikidata.org/wiki/Q364',
#  'glmnet': 'https://cran.r-project.org/package=glmnet',
#  'Globalpark': 'GLOBALPARK_01',
#  'GlobalWorks': 'http://olisweb.com/olisweb_old/Olis-Software.html',
#  'GLPK': 'https://www.wikidata.org/wiki/Q838189',
#  'GNU R': 'https://www.wikidata.org/wiki/Q206904',
#  'Goldwave': 'https://www.wikidata.org/wiki/Q576474',
#  'GoldWave': 'https://www.wikidata.org/wiki/Q576474',
#  'Google Cloud': 'https://www.wikidata.org/wiki/Q17054505',
#  'Google Earth': 'https://www.wikidata.org/wiki/Q42274',
#  'GOseq': 'http://bioinf.wehi.edu.au/software/goseq',
#  'Gower': 'https://www.pbarrett.net/Gower/Gower.html',
#  'gplots': 'https://cran.r-project.org/package=gplots',
#  'GPS Sample': 'https://sites.google.com/a/wolkon.com/gps-sample',
#  'gpu-lasso': 'https://doi.org/10.1093/bioinformatics/bts015',
#  'GRAB': 'http://familygenomics.systemsbiology.net/grab',
#  'GraphPad': 'https://www.wikidata.org/wiki/Q1355082',
#  'GREAT': 'http://bejerano.stanford.edu/great',
#  'GRIMP': 'https://doi.org/10.1093/bioinformatics/btp497',
#  'GSEA': 'https://www.gsea-msigdb.org/gsea/index.jsp',
#  'GSEA-P': 'https://www.gsea-msigdb.org/gsea/index.jsp',
#  'gtools': 'https://cran.r-project.org/package=gtools',
#  'GTX': 'https://cran.r-project.org/src/contrib/Archive/gtx',
#  'H2O R interface': 'https://cran.r-project.org/package=h2o',
#  'h2oEnsemble': 'https://github.com/h2oai/h2o-3/tree/master/h2o-r/ensemble',
#  'Habit 2000': 'HABIT_2000_01',
#  'Haplotype Reference Consortium': 'http://www.haplotype-reference-consortium.org',
#  'Haploview': 'https://www.wikidata.org/wiki/Q5652128',
#  "Hawth's analysis tools for ArcGis": 'http://www.spatialecology.com/htools',
#  'HDDM': 'https://github.com/hddm-devs/hddm',
#  'HGF': 'HGF_01',
#  'hgu95av2': 'https://bioconductor.org/packages/hgu95av2',
#  'Hi-Corrector': 'http://zhoulab.usc.edu/Hi-Corrector',
#  'HMMER': 'http://hmmer.janelia.org',
#  'HRC': 'http://www.haplotype-reference-consortium.org',
#  'HTML': 'https://www.wikidata.org/wiki/Q8811',
#  'HTSeq': 'https://github.com/htseq/htseq',
#  'hu6800': 'https://bioconductor.org/packages/hu6800.db',
#  'HVS Image': 'http://hvsimage.com',
#  'HyPhy': 'https://www.hyphy.org',
#  'I-TASSER': 'https://www.wikidata.org/wiki/Q17029600',
#  'IBDWS': 'https://sourceforge.net/projects/ibdws',
#  'ICC toolbox': 'http://brainmap.co.uk',
#  'ice': 'https://ideas.repec.org/c/boc/bocode/s446602.html',
#  'ICE': 'https://ideas.repec.org/c/boc/bocode/s446602.html',
#  'iDataFax': 'https://rome.phri.ca/files/idatafax',
#  'IDEPI': 'https://github.com/veg/idepi',
#  'IDL': 'https://www.ittvis.com/idl',
#  'IDL Virtual Machine': 'https://www.ittvis.com/idlvm',
#  'iDREM': 'https://github.com/phoenixding/idrem',
#  'iGenomes': 'https://support.illumina.com/sequencing/sequencing_software/igenome.html',
#  'Igor pro': 'https://www.wikidata.org/wiki/Q13574543',
#  'Igor Pro': 'https://www.wikidata.org/wiki/Q13574543',
#  'IHC Profiler': 'https://sourceforge.net/projects/ihcprofiler',
#  'IHC profiler': 'https://sourceforge.net/projects/ihcprofiler',
#  'illuminaio': 'https://bioconductor.org/packages/illuminaio',
#  'Illustrator': 'https://www.wikidata.org/wiki/Q215016',
#  'Image Acquisition Toolbox': 'https://mathworks.com/products/image-acquisition.html',
#  'Image J': 'https://www.wikidata.org/wiki/Q1659584',
#  'Image Lab': 'https://www.bio-rad.com/en-de/product/image-lab-software?ID=KRE6P5E8Z',
#  'Image lab': 'https://www.bio-rad.com/en-de/product/image-lab-software?ID=KRE6P5E8Z',
#  'image processing toolbox': 'https://mathworks.com/products/image.html',
#  'Image Processing Toolbox': 'https://mathworks.com/products/image.html',
#  'Image-J': 'https://www.wikidata.org/wiki/Q1659584',
#  'Image-Pro Plus': 'https://www.mediacy.com/imageproplus',
#  'ImageJ': 'https://www.wikidata.org/wiki/Q1659584',
#  'Imagelab': 'IMAGELAB_01',
#  'ImaGene': 'https://www.biodiscovery.com/imagene',
#  'ImagePro+': 'https://www.mediacy.com/imageproplus',
#  'ImageQuant TL': 'https://www.cytivalifesciences.com/imagingsoftware',
#  'iMap': 'https://perso.unifr.ch/roberto.caldara/index.php?page=3',
#  'Imaris': 'https://imaris.oxinst.com',
#  'IMARIS': 'https://imaris.oxinst.com',
#  'Immunoratio': 'http://jvsmicroscope.uta.fi/immunoratio',
#  'immunoSEQ Analyzer': 'https://www.adaptivebiotech.com/immunoseq',
#  'ImpaxEE': 'https://www.wikidata.org/wiki/Q4692169',
#  'IMPUTE': 'https://mathgen.stats.ox.ac.uk/impute/impute_v2.html',
#  'Ingenuity': 'https://digitalinsights.qiagen.com/products-overview/discovery-insights-portfolio/analysis-and-visualization/qiagen-ipa',
#  'Ingenuity Pathway Analyser': 'https://digitalinsights.qiagen.com/products-overview/discovery-insights-portfolio/analysis-and-visualization/qiagen-ipa',
#  'Ingenuity Pathway Analysis': 'https://digitalinsights.qiagen.com/products-overview/discovery-insights-portfolio/analysis-and-visualization/qiagen-ipa',
#  'Inquisit': 'https://www.millisecond.com',
#  'InsightII': 'https://www.3ds.com/products-services/biovia/products/data-science/biovia-insight',
#  'Instat': 'https://www.wikidata.org/wiki/Q5597064',
#  'InStat': 'https://www.wikidata.org/wiki/Q5597064',
#  'interactive DREM': 'https://github.com/phoenixding/idrem',
#  'Internet Explorer': 'https://www.wikidata.org/wiki/Q1575',
#  'InterPro': 'https://www.wikidata.org/wiki/Q3047275',
#  'Inxight': 'http://www.inxightfedsys.com/pdfs/LinguistX_FinalWeb.pdf',
#  'Iox': 'https://www.emka.fr/product/iox2-software',
#  'IPA': 'https://digitalinsights.qiagen.com/products-overview/discovery-insights-portfolio/analysis-and-visualization/qiagen-ipa',
#  'IPP': 'https://www.mediacy.com/imageproplus',
#  'iQ5 Optical system': 'https://www.bio-rad.com/en-de/sku/1709753-iq5-optical-system-software',
#  'irr': 'https://cran.r-project.org/package=irr',
#  'ISC-toolbox': 'https://www.nitrc.org/projects/isc-toolbox',
#  'iTeva': 'https://tools.thermofisher.com/content/sfs/brochures/D01575~.pdf',
#  'IVICT': 'http://www.babyvoc.org/IVICT.html',
#  'iView X': 'IVIEW_X_01',
#  'J-Express': 'https://jexpress.bioinfo.no/site',
#  'JAGS': 'https://www.wikidata.org/wiki/Q6316598',
#  'JASP': 'https://www.wikidata.org/wiki/Q26229866',
#  'Java': 'https://www.wikidata.org/wiki/Q251',
#  'JAVA': 'https://www.wikidata.org/wiki/Q251',
#  'Java Advanced Imaging': 'https://www.wikidata.org/wiki/Q1129895',
#  'Java JRE': 'https://www.wikidata.org/wiki/Q1504505',
#  'Java Runtime Environment': 'https://www.wikidata.org/wiki/Q1504505',
#  'Java Virtual Machine': 'https://www.wikidata.org/wiki/Q193321',
#  'JavaScript': 'https://www.wikidata.org/wiki/Q2005',
#  'Javascript': 'https://www.wikidata.org/wiki/Q2005',
#  'JDK': 'https://www.wikidata.org/wiki/Q741303',
#  'JMP': 'https://www.wikidata.org/wiki/Q1161680',
#  'joblib': 'https://github.com/joblib/joblib',
#  'jQuery': 'https://www.wikidata.org/wiki/Q230036',
#  'JWatcher': 'https://www.jwatcher.ucla.edu',
#  'Ki67 Vv': 'https://github.com/gilbertbigras/Ki67',
#  'KING': 'https://people.virginia.edu/~wc9c/KING',
#  'KOBAS': 'http://kobas.cbi.pku.edu.cn',
#  'Kubios': 'https://www.kubios.com',
#  'Kubios HRV': 'https://www.kubios.com',
#  'LabVIEW': 'https://www.wikidata.org/wiki/Q746261',
#  'LAGRANGE': 'https://code.google.com/archive/p/lagrange',
#  'LAILAPS-QSM': 'https://bitbucket.org/ipk_bit_team/bioescorte-suggestion',
#  'LAMINA': 'http://sourceforge.net/projects/lamina',
#  'LAN toolbox': 'http://neurocics.udd.cl/LANtoolbox.html',
#  'Land Cover Classification System': 'https://www.wikidata.org/wiki/Q1797907',
#  'Large Average Submatricies': 'https://genome.unc.edu/las',
#  'LAS': 'https://genome.unc.edu/las',
#  'LAS AF': 'https://www.leica-microsystems.com/products/microscope-software/p/leica-application-suite',
#  'LAS X': 'https://www.leica-microsystems.com/products/microscope-software/p/leica-las-x-ls',
#  'LatentGold': 'https://www.statisticalinnovations.com/latent-gold',
#  'lattice': 'https://cran.r-project.org/package=lattice',
#  'LCR-eXXXplorer': 'http://repeat.biol.ucy.ac.cy/lcr-exxxplorer',
#  'Learning Embeddings Atlas Propagation': 'https://doi.org/10.1016/j.neuroimage.2009.09.069',
#  'Ledalab': 'http://www.ledalab.de',
#  'Leica Application Suite Advanced Fluorescence': 'https://www.leica-microsystems.com/products/microscope-software/p/leica-application-suite',
#  'LI-toolbox': 'https://www.medizin.uni-tuebingen.de/das-klinikum/einrichtungen/kliniken/kinderklinik/kinderheilkunde-iii/forschung-iii/software',
#  'Librosa': 'https://github.com/librosa/librosa',
#  'LiDAR Analyst': 'https://www.textronsystems.com/products/lidar-analyst',
#  'Linux': 'https://www.wikidata.org/wiki/Q388',
#  'linux': 'https://www.wikidata.org/wiki/Q388',
#  'Linux Red Hat': 'https://www.wikidata.org/wiki/Q220182',
#  'LISREL': 'https://www.wikidata.org/wiki/Q3376999',
#  'lme4': 'https://cran.r-project.org/package=lme4',
#  'lmer': 'https://cran.r-project.org/package=lme4',
#  'LogCombiner': 'https://beast.community/logcombiner',
#  'LSM imaging': 'LSM_IMAGING_01',
#  'ltm': 'https://cran.r-project.org/package=ltm',
#  'Luminex 100 ™ IS': 'https://www.luminexcorp.com/luminex-100200',
#  'M-Track': 'https://github.com/scimemia/M-Track',
#  'Mac': 'https://www.wikidata.org/wiki/Q14116',
#  'Mac OS': 'https://www.wikidata.org/wiki/Q14116',
#  'Mac OS X': 'https://www.wikidata.org/wiki/Q14116',
#  'Mach': 'http://csg.sph.umich.edu/abecasis/mach',
#  'MACH': 'http://csg.sph.umich.edu/abecasis/mach',
#  'Mach2QTL': 'https://www.nitrc.org/projects/mach2qtl',
#  'Macintosh': 'https://www.wikidata.org/wiki/Q14116',
#  'MacOS': 'https://www.wikidata.org/wiki/Q14116',
#  'MacOS X': 'https://www.wikidata.org/wiki/Q14116',
#  'MacOSX': 'https://www.wikidata.org/wiki/Q14116',
#  'MACS': 'http://liulab.dfci.harvard.edu/MACS',
#  'MacVide': 'http://www.macvide.com/Macvide_FlashVideo_Converter',
#  'MAFCO': 'https://github.com/lumiratos/mafco',
#  'MAGERI': 'https://github.com/mikessh/mageri',
#  'MAGMA': 'http://ctg.cncr.nl/software/magma',
#  'MAGPIE': 'https://github.com/christbald/magpie',
#  'map2stan': 'https://github.com/rmcelreath/rethinking/blob/master/R/map2stan.r',
#  'MapIcosahedron': 'https://afni.nimh.nih.gov/pub/dist/doc/program_help/MapIcosahedron.html',
#  'MapInfo Professional': 'https://www.wikidata.org/wiki/Q64189',
#  'MapWin': 'http://www.thomaskoenig.ch/index.php/software/mapwin',
#  'Mapwin': 'http://www.thomaskoenig.ch/index.php/software/mapwin',
#  'MarsBar': 'http://marsbar.sourceforge.net',
#  'Marsbar': 'http://marsbar.sourceforge.net',
#  'MASCOT': 'https://www.wikidata.org/wiki/Q1726452',
#  'Mass Profiler Professional': 'https://www.agilent.com/en/product/software-informatics/mass-spectrometry-software/data-analysis/mass-profiler-professional-software',
#  'MassARRAY Assay Design': 'https://agenabio.com/products/massarray-system',
#  'MassARRAY Typer': 'https://agenabio.com/products/massarray-system',
#  'MassHunter Acquisition': 'https://www.agilent.com/en/product/software-informatics/mass-spectrometry-software/data-acquisition/acquisition-for-lc-ms',
#  'MassHunter Qualitative Analysis': 'https://www.agilent.com/en/product/software-informatics/mass-spectrometry-software/data-analysis/qualitative-analysis',
#  'MatCont': 'https://sourceforge.net/projects/matcont',
#  'Matlab': 'https://www.wikidata.org/wiki/Q169478',
#  'MATLAB': 'https://www.wikidata.org/wiki/Q169478',
#  'MatLab': 'https://www.wikidata.org/wiki/Q169478',
#  'MATLB': 'https://www.wikidata.org/wiki/Q169478',
#  'Matplotlib': 'https://www.wikidata.org/wiki/Q2985668',
#  'matplotlib': 'https://www.wikidata.org/wiki/Q2985668',
#  'MatrixConverter': 'https://github.com/gburleigh/MatrixConverter',
#  'Maxent': 'https://www.wikidata.org/wiki/Q1913760',
#  'MaxEnt': 'https://www.wikidata.org/wiki/Q1913760',
#  'MAXQDA': 'https://www.wikidata.org/wiki/Q1258962',
#  'MaxQDA': 'https://www.wikidata.org/wiki/Q1258962',
#  'MCMCglmm': 'https://cran.r-project.org/package=MCMCglmm',
#  'MCODE': 'http://apps.cytoscape.org/apps/mcode',
#  'MDAnalysis': 'http://mdanalysis.googlecode.com',
#  'MDAnalysis molecular analysis toolkit': 'http://mdanalysis.googlecode.com',
#  'Mechanical Turk': 'https://www.wikidata.org/wiki/Q733115',
#  'Mechanochemical Dynamics of Active Networks': 'http://www.medyan.org',
#  'Med-PC': 'https://www.med-associates.com/med-pc-v/',
#  'MedPC': 'https://www.med-associates.com/med-pc-v/',
#  'MEDYAN': 'http://www.medyan.org',
#  'MEGA': 'https://www.wikidata.org/wiki/Q6715328',
#  'MELODIC': 'https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/MELODIC',
#  'MERLIN': 'http://www.sph.umich.edu/csg/abecasis/Merlin',
#  'Metabomatching': 'https://github.com/rrueedi/metabomatching',
#  'METACARPA': 'https://github.com/hmgu-itg/metacarpa',
#  'METAL': 'http://csg.sph.umich.edu/abecasis/metal',
#  'MetaMorph': 'https://www.moleculardevices.com/products/cellular-imaging-systems/acquisition-and-analysis-software/metamorph-microscopy',
#  'Metamorph': 'https://www.moleculardevices.com/products/cellular-imaging-systems/acquisition-and-analysis-software/metamorph-microscopy',
#  'metareg': 'https://ideas.repec.org/c/boc/bocode/s446201.html',
#  'MetaSel': 'http://www4a.biotec.or.th/GI/tools/metasel',
#  'mgcv': 'https://cran.r-project.org/package=mgcv',
#  'mice': 'https://cran.r-project.org/package=mice',
#  'Mice': 'https://cran.r-project.org/package=mice',
#  'MICRO-CHECKER': 'http://www.nrp.ac.uk/nrp-strategic-alliances/elsa/software/microchecker/',
#  'MICROCHECKER': 'http://www.nrp.ac.uk/nrp-strategic-alliances/elsa/software/microchecker/',
#  'microRNA': 'http://www.microrna.org',
#  'Microscopy Image Browser': 'http://mib.helsinki.fi',
#  'Microsoft Office Excel': 'https://www.wikidata.org/wiki/Q11272',
#  'MicroSyn': 'http://fcsb.njau.edu.cn/microsyn',
#  'migrate': 'https://peterbeerli.com/migrate-html5',
#  'MIiSR': 'http://www.phagocytes.ca/miisr',
#  'Mimics': 'https://www.wikidata.org/wiki/Q6862245',
#  'Mindboggle': 'http://www.binarybottle.com/mindboggle.html',
#  'MinGW-w64': 'https://www.wikidata.org/wiki/Q595758',
#  'Minitab': 'https://www.wikidata.org/wiki/Q1471909',
#  'miRDB': 'http://mirdb.org',
#  'Mirdeep2': 'https://github.com/rajewsky-lab/mirdeep2',
#  'mitml': 'https://cran.r-project.org/package=mitml',
#  'Mixer': 'https://cran.r-project.org/src/contrib/Archive/mixer',
#  'MLRELATE': 'https://www.montana.edu/kalinowski/software/ml-relate',
#  'MLwiN': 'https://www.wikidata.org/wiki/Q6716702',
#  'MLWiN': 'https://www.wikidata.org/wiki/Q6716702',
#  'MLWin': 'https://www.wikidata.org/wiki/Q6716702',
#  'MODELTEST': 'https://github.com/ddarriba/modeltest',
#  'Modeltest': 'https://github.com/ddarriba/modeltest',
#  'ModFit': 'http://www.vsh.com/products/mflt',
#  'MOE': 'https://www.wikidata.org/wiki/Q28447694',
#  'Molecular Interactions in Super Resolution': 'http://phagocytes.ca/miisr',
#  'Molecular Interactions in Super-Resolution': 'http://phagocytes.ca/miisr',
#  'MORGAN': 'https://sites.stat.washington.edu/thompson/Genepi/MORGAN/Morgan.shtml',
#  'MorphoLibJ': 'https://github.com/ijpb/MorphoLibJ',
#  'Mothur': 'https://www.wikidata.org/wiki/Q25099639',
#  'mothur': 'https://www.wikidata.org/wiki/Q25099639',
#  'Mplus': 'https://www.statmodel.com',
#  'MPlus': 'https://www.statmodel.com',
#  'MRBAYES': 'https://www.wikidata.org/wiki/Q10920783',
#  'MrBayes': 'https://www.wikidata.org/wiki/Q10920783',
#  'Mricron': 'https://www.nitrc.org/projects/mricron',
#  'mRMRe': 'https://cran.r-project.org/package=mRMRe',
#  'mrsFAST': 'http://sfu-compbio.github.io/mrsfast',
#  'MSACompro': 'http://sysbio.rnet.missouri.edu/multicom_toolbox',
#  'MSAProbs': 'http://msaprobs.sourceforge.net',
#  'MSIsensor': 'https://github.com/ding-lab/msisensor',
#  'MSM-All': 'https://github.com/Washington-University/HCPpipelines/tree/master/MSMAll',
#  'MSOffice': 'https://www.wikidata.org/wiki/Q11255',
#  'MSstats': 'https://bioconductor.org/packages/MSstats',
#  'mtPhyl': 'https://sites.google.com/site/mtphyl',
#  'MultiPak': 'https://www.phi.com/surface-analysis-equipment/system-software/multipak-data-reduction-software.html',
#  'MultiTypeTree': 'https://tgvaughan.github.io/MultiTypeTree',
#  'Multivariate Exploratory Linear Optimized Decomposition into Independent Components': 'https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/MELODIC',
#  'MuPeXI': 'http://www.cbs.dtu.dk/services/MuPeXI',
#  'MUSCLE': 'https://www.wikidata.org/wiki/Q6719088',
#  'Muscle': 'https://www.wikidata.org/wiki/Q6719088',
#  'Mutation Surveyor': 'https://softgenetics.com/mutationSurveyor.php',
#  'MutationalPatterns': 'http://bioconductor.org/packages/MutationalPatterns',
#  'MutationAssessor': 'http://mutationassessor.org',
#  'MuTect': 'https://software.broadinstitute.org/cancer/cga/mutect',
#  'MyIQ': 'https://www.bio-rad.com/en-de/product/myiq2-two-color-real-time-pcr-detection-system',
#  'MySQL': 'https://www.wikidata.org/wiki/Q850',
#  'NCSS': 'https://www.wikidata.org/wiki/Q17042611',
#  'NemaFootPrinter': 'http://bio.ifom-firc.it/NTFootPrinter',
#  'NET': 'https://www.microsoft.com/download/details.aspx?id=21',
#  'netcarto': 'https://amaral.northwestern.edu/resources/software/netcarto',
#  'Netcdf': 'https://www.wikidata.org/wiki/Q67197176',
#  'NetLogo': 'https://www.wikidata.org/wiki/Q672307',
#  'NetMHCpan': 'http://www.cbs.dtu.dk/services/NetMHCpan',
#  'Network': 'https://www.fluxus-engineering.com/sharenet.htm',
#  'NETWORK': 'https://www.fluxus-engineering.com/sharenet.htm',
#  'NeuroDebian': 'https://neuro.debian.net',
#  'NeuroExplorer': 'http://www.neuroexplorer.com',
#  'neurofeedback toolbox': 'http://doi.org/10.1371/journal.pone.0091620',
#  'NeuroMap': 'https://sites.google.com/site/neuromapsoftware',
#  'NEURON': 'https://www.wikidata.org/wiki/Q7002467',
#  'NeuroQuant': 'https://www.cortechs.ai/products/neuroquant',
#  'NeuroSynth': 'https://www.wikidata.org/wiki/Q23992212',
#  'Newbler': 'https://www.wikidata.org/wiki/Q7016954',
#  'Newborn Size Application': 'http://intergrowth21.ndog.ox.ac.uk',
#  'NFTsim': 'https://github.com/BrainDynamicsUSYD/nftsim',
#  'Nilearn': 'https://pypi.org/project/nilearn',
#  'NIRS_SPM': 'https://www.nitrc.org/projects/nirs_spm',
#  'NIS': 'https://www.microscope.healthcare.nikon.com/products/software/nis-elements',
#  'NIS-Elements': 'https://www.microscope.healthcare.nikon.com/products/software/nis-elements',
#  'NLME': 'https://cran.r-project.org/package=nlme',
#  'nlme': 'https://cran.r-project.org/package=nlme',
#  'NLTK': 'https://www.wikidata.org/wiki/Q1635410',
#  'Novoalign': 'http://www.novocraft.com/products/novoalign',
#  'NovoSNP': 'http://novosnp.bioinf.be',
#  'NQuery Advisor': 'https://www.wikidata.org/wiki/Q55641191',
#  'NumPy': 'https://www.wikidata.org/wiki/Q197520',
#  'Nvivo': 'https://www.wikidata.org/wiki/Q6955723',
#  'NVivo': 'https://www.wikidata.org/wiki/Q6955723',
#  'Objective-C': 'https://www.wikidata.org/wiki/Q188531',
#  'Office': 'https://www.wikidata.org/wiki/Q11255',
#  'Office Excel': 'https://www.wikidata.org/wiki/Q11272',
#  'OHM': 'http://bioinfo.unice.fr/ohm',
#  'Oligo Calc': 'http://biotools.nubic.northwestern.edu/OligoCalc.html',
#  'OntoFox': 'http://ontofox.hegroup.org',
#  'OOIBase': 'OOIBASE_01',
#  'Open Data Kit': 'https://www.wikidata.org/wiki/Q56291130',
#  'Open Meta-Analyst': 'https://github.com/bwallace/OpenMeta-analyst-',
#  'Open sorter': 'https://www.tdt.com/component/opensorter',
#  'OpenCL': 'https://www.wikidata.org/wiki/Q681360',
#  'OpenCV': 'https://www.wikidata.org/wiki/Q165277',
#  'OpenEpi': 'https://www.wikidata.org/wiki/Q7095785',
#  'Openlab': 'https://www.wikidata.org/wiki/Q7096535',
#  'openMEEG': 'http://openmeeg.github.io',
#  'OpenSim': 'https://www.wikidata.org/wiki/Q2038919',
#  'OpenSUSE': 'https://www.wikidata.org/wiki/Q16691',
#  'OptFlux': 'http://www.optflux.org',
#  'Optflux': 'http://www.optflux.org',
#  'OptimalCutpoints': 'https://cran.r-project.org/package=OptimalCutpoints',
#  'ordinal': 'https://cran.r-project.org/package=ordinal',
#  'OriginLab': 'https://www.wikidata.org/wiki/Q1307239',
#  'OriginPro': 'https://www.wikidata.org/wiki/Q1307239',
#  'ORTEP': 'https://www.chem.gla.ac.uk/~louis/software/ortep',
#  'OS-X': 'https://www.wikidata.org/wiki/Q14116',
#  'OsiriX': 'https://www.wikidata.org/wiki/Q1301762',
#  'OSX': 'https://www.wikidata.org/wiki/Q14116',
#  'PABAK-OS calculator': 'http://www.singlecaseresearch.org/calculators/pabak-os',
#  'Pajek': 'https://www.wikidata.org/wiki/Q96075529',
#  'Partek': 'https://www.partek.com/partek-genomics-suite',
#  'PASS': 'http://www.ibmh.msk.su/PASS',
#  'PAST': 'https://palaeo-electronica.org/2001_1/past/issue1_01.htm',
#  'PASW': 'https://www.wikidata.org/wiki/Q181596',
#  'PASW Statistic': 'https://www.wikidata.org/wiki/Q181596',
#  'PASW Statistics': 'https://www.wikidata.org/wiki/Q181596',
#  'Patch Analyst': 'http://flash.lakeheadu.ca/~rrempel/ecology',
#  'Patchmaster': 'https://www.heka.com/downloads/downloads_main.html#down_patchmaster',
#  'Pathomx': 'http://pathomx.org',
#  'PathVisio': 'https://www.wikidata.org/wiki/Q16975296',
#  'PathVisioRPC': 'https://github.com/PathVisio/PathVisioRPC',
#  'PAUP': 'https://www.wikidata.org/wiki/Q7118292',
#  'PAUP*': 'https://www.wikidata.org/wiki/Q7118292',
#  'PBAP': 'https://faculty.washington.edu/wijsman/software.shtml',
#  'pClamp': 'https://moleculardevices.com/products/axon-patch-clamp-system/acquisition-and-analysis-software/pclamp-software-suite',
#  'pCLAMP': 'https://moleculardevices.com/products/axon-patch-clamp-system/acquisition-and-analysis-software/pclamp-software-suite',
#  'PCORD': 'https://www.wildblueberrymedia.net/pcord',
#  'Peakscanner': 'https://www.thermofisher.com/order/catalog/product/4381867#/4381867',
#  'Pedigree-Based Analysis Pipeline': 'https://faculty.washington.edu/wijsman/software.shtml',
#  'PEDSTATS': 'http://csg.sph.umich.edu/abecasis/Pedstats',
#  'PennCNV': 'http://penncnv.openbioinformatics.org/en/latest',
#  'Pep2Path': 'http://pep2path.sourceforge.net',
#  'PEPIS': 'http://bioinfo.noble.org/PolyGenic_QTL',
#  'Perl': 'https://www.wikidata.org/wiki/Q42478',
#  'PERL': 'https://www.wikidata.org/wiki/Q42478',
#  'PGA': 'https://dceg.cancer.gov/tools/design/pga',
#  'PHASE': 'http://stephenslab.uchicago.edu/phase/download.html',
#  'PhosphOrtholog': 'http://www.phosphortholog.com',
#  'Photofiltre': 'https://www.wikidata.org/wiki/Q1235617',
#  'Photoshop': 'https://www.wikidata.org/wiki/Q129793',
#  'PhyloBot': 'https://github.com/vhsvhs/phylobot-django',
#  'PhyloGibbs': 'https://www.imsc.res.in/~rsidd/phylogibbs',
#  'PhyloGibbs-MP': 'https://www.imsc.res.in/~rsidd/phylogibbs-mp',
#  'PhylopythiaS': 'https://phylopythias.bifo.helmholtz-hzi.de',
#  'PhyML': 'http://www.atgc-montpellier.fr/phyml',
#  'PhysiCell': 'https://github.com/MathCancer/PhysiCell',
#  'Picard': 'https://github.com/broadinstitute/picard',
#  'Pickatlas': 'https://www.nitrc.org/projects/wfu_pickatlas',
#  'Pipeline for estimating EPIStatic genetic effects': 'http://bioinfo.noble.org/PolyGenic_QTL',
#  'PIVOT': 'https://kim.bio.upenn.edu/software/pivot.shtml',
#  'Pixelmator': 'https://www.wikidata.org/wiki/Q735748',
#  'PLATON': 'https://www.platonsoft.nl/platon',
#  'PLINK': 'https://www.wikidata.org/wiki/Q18359288',
#  'Plink': 'https://www.wikidata.org/wiki/Q18359288',
#  'PLINK/SEQ': 'https://atgu.mgh.harvard.edu/plinkseq',
#  'plotrix': 'https://cran.r-project.org/package=plotrix',
#  'Podbat': 'http://www.bionut.ki.se/users/pesv/podbat',
#  'PolyPhen': 'http://genetics.bwh.harvard.edu/pph2',
#  'Polyphen': 'http://genetics.bwh.harvard.edu/pph2',
#  'PolyPhred': 'https://droog.gs.washington.edu/polyphred',
#  'Polysolver': 'https://software.broadinstitute.org/cancer/cga/polysolver',
#  'Pong': 'https://www.wikidata.org/wiki/Q216293',
#  'PoreWalker': 'http://www.ebi.ac.uk/thornton-srv/software/PoreWalker',
#  'Portable System for the Analysis of Metabolic Models': 'https://pypi.org/project/psamm',
#  'PowerPoint': 'https://www.wikidata.org/wiki/Q11266',
#  'PPI Network': 'https://www.theppinetwork.com',
#  'Praat': 'https://www.wikidata.org/wiki/Q378530',
#  'PRAAT': 'https://www.wikidata.org/wiki/Q378530',
#  'Prediction of Activity Spectra for Substances': 'http://www.ibmh.msk.su/PASS',
#  'Presentation': 'https://www.neurobs.com/menu_presentation/menu_features/features_overview',
#  'PRIMER': 'https://www.wikidata.org/wiki/Q11239942',
#  'Primer': 'https://www.wikidata.org/wiki/Q11239942',
#  'Primer-BLAST': 'https://www.ncbi.nlm.nih.gov/tools/primer-blast',
#  'Primer3 Input': 'https://www.wikidata.org/wiki/Q11239942',
#  'principal component analysis spike sorter': 'https://www.tdt.com/docs/synapse/gizmos/pca-spike-sorting',
#  'Prism': 'https://www.wikidata.org/wiki/Q1355082',
#  'PRISM': 'https://www.wikidata.org/wiki/Q1355082',
#  'prism': 'https://www.wikidata.org/wiki/Q1355082',
#  'pROC': 'https://cran.r-project.org/package=pROC',
#  'PROCESS': 'https://www.processmacro.org',
#  'ProctorU': 'https://www.proctoru.com',
#  'ProDy': 'http://prody.csb.pitt.edu',
#  'Prokaryotic Genomes Automatic Annotation Pipeline': 'https://github.com/ncbi/pgap',
#  'Promasys': 'https://www.pharmacompass.com/pdf/party/content/omnicomm-systems-inc-party-content-1496916964.pdf',
#  'ProteoLens': 'http://bio.informatics.iupui.edu/proteolens',
#  'ProteomeWeaver': 'https://www.bio-rad.com/webroot/web/pdf/lsr/literature/Bulletin_5400.pdf',
#  'Protégé': 'https://www.wikidata.org/wiki/Q2066865',
#  'PRTools': 'http://prtools.tudelft.nl',
#  'PSAMM': 'https://pypi.org/project/psamm',
#  'PSICIC': 'https://scholar.princeton.edu/gitailab/psicic',
#  'pSSAlib': 'https://sbalzarini-lab.org/?q=downloads/stochastic_chemical_net',
#  'psych': 'https://cran.r-project.org/package=psych',
#  'Psychophysics Toolbox': 'https://www.wikidata.org/wiki/Q18215965',
#  'Psychophysics toolbox': 'https://www.wikidata.org/wiki/Q18215965',
#  'PsychoPy': 'https://www.wikidata.org/wiki/Q7256288',
#  'Psychopy': 'https://www.wikidata.org/wiki/Q7256288',
#  'Psychtoolbox': 'https://www.wikidata.org/wiki/Q18215965',
#  'punafcc': 'https://ideas.repec.org/c/boc/bocode/s457354.html',
#  'Pycdf': 'https://pypi.org/project/pycdf',
#  'Pycluster': 'https://anaconda.org/bioconda/pycluster',
#  'PyMOL': 'https://www.wikidata.org/wiki/Q1373457',
#  'PyMS': 'http://code.google.com/p/pyms',
#  'PyMVPA': 'https://github.com/PyMVPA/PyMVPA',
#  'PyPhi': 'https://github.com/wmayner/pyphi',
#  'PyPi': 'https://github.com/wmayner/pyphi',
#  'PyRadiomics': 'https://pypi.org/project/pyradiomics',
#  'PyroTagger': 'http://pyrotagger.jgi-psf.org',
#  'Python': 'https://www.wikidata.org/wiki/Q28865',
#  'Q-LAB': 'https://www.wikidata.org/wiki/Q7265483',
#  'qBase': 'https://www.qbaseplus.com',
#  'Qbase+': 'https://www.qbaseplus.com',
#  'QGIS': 'https://www.wikidata.org/wiki/Q1329181',
#  'Qt': 'https://www.wikidata.org/wiki/Q201904',
#  'QTL Express': 'http://qtlcap.ed.ac.uk',
#  'Quantity One': 'https://www.bio-rad.com/en-de/product/quantity-one-1-d-analysis-software',
#  'Quanto': 'https://hydra.usc.edu/gxe',
#  'quantregForest': 'https://cran.r-project.org/package=quantregForest',
#  'Quarc': 'https://www.quanser.com/products/quarc-real-time-control-software',
#  'Querying and visualizing Chromatin Interaction Networks': 'https://github.com/UcarLab/QuIN',
#  'QUEST': 'http://psychtoolbox.org/docs/Quest',
#  'Questionpro': 'https://www.questionpro.de',
#  'QuickPALM': 'https://code.google.com/archive/p/quickpalm',
#  'Quicktime': 'https://www.wikidata.org/wiki/Q1243769',
#  'QuIN': 'https://github.com/UcarLab/QuIN',
#  'qxpak': 'https://www.icrea.cat/Web/OtherSectionViewer.aspx?key=485&titol=Software:Qxpak',
#  'R': 'https://www.wikidata.org/wiki/Q206904',
#  'R Studio': 'https://www.wikidata.org/wiki/Q24451405',
#  'R-Scan': 'https://www.oculus.de/produkte/topographie/keratograph-5m/keratograph-5m',
#  'R/Qtl': 'https://cran.r-project.org/package=qtl',
#  'R2WinBUGS': 'https://cran.r-project.org/package=R2WinBUGS',
#  'RabiesEcon': 'https://doi.org/10.1371/journal.pntd.0006490.s001',
#  'RankProdIt': 'http://strep-microarray.sbs.surrey.ac.uk/RankProducts',
#  'Rapid Annotation using Subsystem Technology': 'https://rast.nmpdr.org',
#  'raster': 'https://cran.r-project.org/package=raster',
#  'Rcpp': 'https://cran.r-project.org/package=Rcpp',
#  'RDP Classifier': 'http://rdp.cme.msu.edu',
#  'Reactome': 'https://apps.cytoscape.org/apps/reactomefis',
#  'READ': 'https://bitbucket.org/tguenther/read',
#  'REALCOM-IMPUTE': 'http://www.bristol.ac.uk/cmm/software/realcom',
#  'REDCap': 'https://www.wikidata.org/wiki/Q7305527',
#  'Redirector': 'https://github.com//bionomicron/Redirector.git',
#  'Refworks': 'https://www.wikidata.org/wiki/Q7307076',
#  'REGRESSIONv2.m': 'https://doi.org/10.1086/590395',
#  'Relationship Estimation from Ancient DNA': 'https://bitbucket.org/tguenther/read',
#  'ReMIT': 'http://doi.org/10.1371/journal.pone.0078786',
#  'REMIT': 'http://doi.org/10.1371/journal.pone.0078786',
#  'ReMIT Client': 'http://doi.org/10.1371/journal.pone.0078786',
#  'ReMITclient': 'http://doi.org/10.1371/journal.pone.0078786',
#  'Remote Proctor Now': 'https://remoteproctor.com',
#  'Reportlab': 'https://www.wikidata.org/wiki/Q7314104',
#  'REST': 'http://www.restfmri.net/forum/REST_V1.8',
#  'Review Manager': 'https://training.cochrane.org/online-learning/core-software-cochrane-reviews/revman',
#  'Revman': 'https://www.wikidata.org/wiki/Q106381184',
#  'RevMan': 'https://www.wikidata.org/wiki/Q106381184',
#  'rgdal': 'https://cran.r-project.org/package=rgdal',
#  'RHEL': 'https://www.wikidata.org/wiki/Q215273',
#  'Rhtslib': 'https://bioconductor.org/packages/Rhtslib',
#  'rioja': 'https://cran.r-project.org/package=rioja',
#  'RIU': 'http://www.mtifwb.com',
#  'rjags': 'https://cran.r-project.org/package=rjags',
#  'rms': 'https://cran.r-project.org/package=rms',
#  'RNA-SeQC': 'http://www.broadinstitute.org/rna-seqc',
#  'RNA-Skim': 'http://www.csbio.unc.edu/rs',
#  'ROCR': 'https://cran.r-project.org/package=ROCR',
#  'Rotor-Gene Q': 'https://www.qiagen.com/us/products/discovery-and-translational-research/epigenetics/dna-methylation/methylation-specific-pcr/rotor-gene-q',
#  'rpart': 'https://cran.r-project.org/package=rpart',
#  'RSeQC': 'http://rseqc.sourceforge.net',
#  'Rstan': 'https://cran.r-project.org/package=rstan',
#  'RT2 Profiler PCR Array Data analysis': 'https://dataanalysis.qiagen.com/pcr/documents/RT2ProfilerDataAnalysisHandbook.pdf',
#  'RTA': 'https://jp.support.illumina.com/sequencing/sequencing_software/real-time_analysis_rta.html',
#  'RTN': 'https://www.bioconductor.org/packages/RTN',
#  'Rtsne': 'https://cran.r-project.org/package=Rtsne',
#  'Ruby on Rails': 'https://www.wikidata.org/wiki/Q190478',
#  'RuleBender': 'http://visualizlab.org/rulebender',
#  'RUMM': 'http://www.rummlab.com.au',
#  'runmlwin': 'http://www.bristol.ac.uk/cmm/software/runmlwin',
#  'SADABS': 'SADABS_01',
#  'Safari': 'https://www.wikidata.org/wiki/Q35773',
#  'Sailfish': 'https://github.com/kingsfordgroup/sailfish',
#  'SAINT': 'SAINT_01',
#  'Salmon': 'https://github.com/COMBINE-lab/Salmon',
#  'SAMSCo': 'https://doi.org/10.1016/j.neuroimage.2010.12.012',
#  'samtools': 'https://www.wikidata.org/wiki/Q7388648',
#  'Samtools': 'https://www.wikidata.org/wiki/Q7388648',
#  'SAMtools': 'https://www.wikidata.org/wiki/Q7388648',
#  'Santa Cruz genome browser': 'https://www.wikidata.org/wiki/Q7864116',
#  'SAS': 'https://www.wikidata.org/wiki/Q2003932',
#  'SAS Enterprise Guide': 'https://www.wikidata.org/wiki/Q2003932',
#  'SAS Lab Pro': 'https://www.wikidata.org/wiki/Q2003932',
#  'Satistix': 'https://www.statistix.com',
#  'Scan': 'https://compumedicsneuroscan.com/tag/scan',
#  'Scikit-learn': 'https://www.wikidata.org/wiki/Q1026367',
#  'scikit-learn': 'https://www.wikidata.org/wiki/Q1026367',
#  'Scion image': 'https://www.wikidata.org/wiki/Q25931876',
#  'SciPy': 'https://www.wikidata.org/wiki/Q197492',
#  'Scope-Pro': 'http://www.adept.net.au/software/mediacy/ImagePro/scopePro.shtml',
#  'ScopeWin': 'https://www.tedia.eu/products/sw-scopewin.html',
#  'SCOTTI': 'https://github.com/Taming-the-BEAST/SCOTTI-Tutorial',
#  'scPipe': 'https://bioconductor.org/packages/scPipe',
#  'SDMtoolbox': 'http://www.sdmtoolbox.org',
#  'Seattle Seq': 'https://snp.gs.washington.edu/SeattleSeqAnnotation',
#  'sensitivity': 'https://cran.r-project.org/package=sensitivity',
#  'Sente': 'https://www.wikidata.org/wiki/Q3478650',
#  'SeqScape': 'https://www.thermofisher.com/order/catalog/product/4474978',
#  'Sequence Scanner': 'https://www.labtools.us/sequence-scanner',
#  'SHAPEITv': 'https://mathgen.stats.ox.ac.uk/genetics_software/shapeit/shapeit.html',
#  'SHARP2': 'http://www.bioinformatics.sussex.ac.uk/SHARP2',
#  'SHELXL': 'https://www.wikidata.org/wiki/Q51715613',
#  'SHELXS': 'https://www.wikidata.org/wiki/Q51715613',
#  'SHELXTL': 'https://www.wikidata.org/wiki/Q51715613',
#  'sickle': 'https://github.com/najoshi/sickle',
#  'Sift': 'https://sift.bii.a-star.edu.sg',
#  'Sightlines DxCG Risk Solutions': 'https://www.verisk.com/archived/2011/verisk-health-s-dxcg-risk-solutions-technology-ready-to-support-industry-adoption-of-icd-10-cm',
#  'Sigma plot': 'https://www.wikidata.org/wiki/Q4049465',
#  'SigmaPlot': 'https://www.wikidata.org/wiki/Q4049465',
#  'Sigmaplot': 'https://www.wikidata.org/wiki/Q4049465',
#  'SigmaStat': 'https://www.wikidata.org/wiki/Q7512231',
#  'SignalP': 'http://www.cbs.dtu.dk/services/SignalP',
#  'SILVA SINA': 'https://www.arb-silva.de/aligner',
#  'SIMCA-P': 'https://www.sartorius.com/en/products/process-analytical-technology/data-analytics-software/mvda-software/simca',
#  'Skeeter Buster': 'http://legrosmathi.eu/skeeterbuster',
#  'skewer': 'https://sourceforge.net/projects/skewer',
#  'Skyline': 'https://www.wikidata.org/wiki/Q48989793',
#  'SLINK': 'https://www.jurgott.org/linkage/SLINK.htm',
#  'sLORETA': 'https://www.mindmedia.com/losungen/qeeg/sloreta',
#  'SMART': 'http://smart.emblheidelberg.de',
#  'SMARTPCA': 'https://github.com/DReichLab/EIG',
#  'SMRT analysis': 'https://www.pacb.com/products-and-services/analytical-software/smrt-analysis',
#  'SNAP': 'SNAP_01',
#  'SNPdetector': 'http://lpg.nci.nih.gov',
#  'SnpEff': 'https://www.wikidata.org/wiki/Q30593150',
#  'SNPTEST': 'https://mathgen.stats.ox.ac.uk/genetics_software/snptest/snptest.html',
#  'SOCPROG': 'http://whitelab.biology.dal.ca/SOCPROG/social.htm',
#  'Software Package for Statistical Analysis': 'https://www.wikidata.org/wiki/Q181596',
#  'SomaticSignatures': 'https://bioconductor.org/packages/SomaticSignatures',
#  'Soscisurvey': 'https://www.wikidata.org/wiki/Q101554882',
#  'sourceR': 'https://cran.r-project.org/package=sourceR',
#  'SPAGeDI': 'https://github.com/reedacartwright/spagedi',
#  'Spatial Analyst': 'https://desktop.arcgis.com/en/arcobjects/latest/net/webframe.htm#PerformingAnalysisWithSpatialAnalyst.htm',
#  'Spatial Statistics': 'https://pro.arcgis.com/en/pro-app/latest/tool-reference/spatial-statistics/an-overview-of-the-spatial-statistics-toolbox.htm',
#  'Spectrum Mill': 'https://proteomics.broadinstitute.org',
#  'Sperm Class Analyzer': 'https://www.micropticsl.com/products/sperm-class-analyzer-casa-system',
#  'SPIKE-dist': 'http://wwwold.fi.isc.cnr.it/users/thomas.kreuz/sourcecode.html',
#  'SPLITSTREE': 'https://www.wikidata.org/wiki/Q258956',
#  'SPM': 'https://www.wikidata.org/wiki/Q41566485',
#  'SPM anatomy toolbox': 'https://www.fz-juelich.de/inm/inm-1/DE/Forschung/_docs/SPMAnatomyToolbox/SPMAnatomyToolbox_node.html',
#  'SPSS': 'https://www.wikidata.org/wiki/Q181596',
#  'SPSS Amos': 'https://www.ibm.com/products/structural-equation-modeling-sem',
#  'SPSS AMOS': 'https://www.ibm.com/products/structural-equation-modeling-sem',
#  'SPSS Dimensions': 'https://www.wikidata.org/wiki/Q181596',
#  'SPSS Statistics': 'https://www.wikidata.org/wiki/Q181596',
#  'SPSS statistics': 'https://www.wikidata.org/wiki/Q181596',
#  'SQL': 'https://www.wikidata.org/wiki/Q47607',
#  'SSPACE-LongRead': 'http://www.baseclear.com/bioinformatics-tools',
#  'Stan': 'https://www.wikidata.org/wiki/Q17085079',
#  'STAR': 'http://code.google.com/p/rna-star',
#  'STATA': 'https://www.wikidata.org/wiki/Q1204300',
#  'Stata': 'https://www.wikidata.org/wiki/Q1204300',
#  'stata': 'https://www.wikidata.org/wiki/Q1204300',
#  'STATISTICA': 'https://www.wikidata.org/wiki/Q1788435',
#  'Statistica': 'https://www.wikidata.org/wiki/Q1788435',
#  'statistical analyses software': 'https://www.wikidata.org/wiki/Q2003932',
#  'Statistical Analysis of Minimum cost path based Structural Connectivity': 'https://doi.org/10.1016/j.neuroimage.2010.12.012',
#  'Statistical Analysis System': 'https://www.wikidata.org/wiki/Q2003932',
#  'Statistical Analysis Systems': 'https://www.wikidata.org/wiki/Q2003932',
#  'Statistical Package for Social Science': 'https://www.wikidata.org/wiki/Q181596',
#  'statistical package for social science': 'https://www.wikidata.org/wiki/Q181596',
#  'Statistical Package for Social Sciences': 'https://www.wikidata.org/wiki/Q181596',
#  'Statistical package for Social Sciences': 'https://www.wikidata.org/wiki/Q181596',
#  'statistical package for social sciences': 'https://www.wikidata.org/wiki/Q181596',
#  'Statistical Package for the Social Science': 'https://www.wikidata.org/wiki/Q181596',
#  'Statistical Package for the Social Sciences': 'https://www.wikidata.org/wiki/Q181596',
#  'statistical parametric mapping': 'https://www.wikidata.org/wiki/Q41566485',
#  'Statistical Parametric Mapping': 'https://www.wikidata.org/wiki/Q41566485',
#  'Statistical Product and Service Solutions': 'https://www.wikidata.org/wiki/Q181596',
#  'Statistical Program for the Social Sciences': 'https://www.wikidata.org/wiki/Q181596',
#  'Statistical Toolbox': 'https://mathworks.com/products/statistics.html',
#  'statistics toolbox': 'https://mathworks.com/products/statistics.html',
#  'Statview': 'https://www.wikidata.org/wiki/Q7602967',
#  'STATVIEW': 'https://www.wikidata.org/wiki/Q7602967',
#  'StatView': 'https://www.wikidata.org/wiki/Q7602967',
#  'Stella': 'https://stella-emu.github.io',
#  'Stereo investigator': 'https://www.mbfbioscience.com/stereo-investigator',
#  'STRAIGHT': 'http://www.wakayama-u.ac.jp/~kawahara/STRAIGHTdemo',
#  'Strand7': 'https://www.wikidata.org/wiki/Q7394802',
#  'Strawberry': 'https://github.com/ruolin/strawberry',
#  'Structure': 'https://web.stanford.edu/group/pritchardlab/structure.html',
#  'STRUCTURE': 'https://web.stanford.edu/group/pritchardlab/structure.html',
#  'Subread': 'http://subread.sourceforge.net',
#  ...}

# %% [markdown]
# ### Finding All  software With the Same link in a Python Dictionary

# %%
sw_nameVarations = {}

# store all software name variations as value and link as a key ( link is unique)

  
for key, value in list_SWLink.items():
    if value not in sw_nameVarations:
        sw_nameVarations[value] = [key]
    else:
        sw_nameVarations[value].append(key)

# %%
# example result for Matlab

for lnk in list(sw_nameVarations):
    
    if lnk == "https://www.wikidata.org/wiki/Q169478":
        print(sw_nameVarations.get(lnk)," resolves to ->",lnk)
    #break
# Out:
# ['Matlab', 'MATLAB', 'MatLab', 'MATLB']  resolves to -> https://www.wikidata.org/wiki/Q169478

# %% [markdown]
# ### Assign a single name for variation of software names

# %%
list_swNTP = []

for index, row in PubMed_PLoS.iterrows():
    
    softwareName = row['software']
    
    
     # resolve software names that refer to the same entity
    
    '''
    find the name of the software in the variations list
    and replace it with the first variation among the list
    '''
    
    for lnk in list(sw_nameVarations):
        if softwareName in sw_nameVarations.get(lnk):
            softwareName = sw_nameVarations.get(lnk)[0]
            
    softwareType_Purpose = row['annotation']
    
    swType = softwareType_Purpose.split(':')[0].split('_')[0]
    swPurp = softwareType_Purpose.split(':')[1].split('_')[1]
    
    
    lst_ = []
    
    lst_.append(softwareName)
    lst_.append(swType)
    lst_.append(swPurp)
    
    list_swNTP.append(lst_)
    
    print(f"{softwareName:{55}}| {swType:{22}}| {swPurp:{14}}")
    
    #break
# Out:
# DS modeling                                            | Application           | Modelling
# pClamp                                                 | Application           | DataCollection
# Ensembl                                                | Application           | Analysis
# RIU                                                    | Application           | DataCollection
# STATA                                                  | Application           | Analysis
# AsReml                                                 | Application           | Modelling
# Matlab                                                 | ProgrammingEnvironment| Stimulation
# AsReml                                                 | Application           | Analysis
# SAS                                                    | Application           | Analysis
# SAS                                                    | Application           | Analysis
# DS ViewerPro                                           | Application           | Visualization
# SHARP2                                                 | Application           | Analysis
# ConSurf-HSSP                                           | Application           | Analysis
# STATA                                                  | Application           | Analysis
# STATA                                                  | Application           | Modelling
# PASW                                                   | Application           | Analysis
# STATA                                                  | Application           | Analysis
# ArcGis                                                 | Application           | Analysis
# GraphPad                                               | Application           | Analysis
# PLINK                                                  | Application           | Analysis
# PLINK                                                  | Application           | Analysis
# PRIMER                                                 | Application           | Modelling
# Mutation Surveyor                                      | Application           | DataCollection
# Basic Local Alignment Search Tool                      | Application           | Analysis
# Genome browser                                         | Application           | Analysis
# PolyPhen                                               | Application           | Analysis
# Basic                                                  | ProgrammingEnvironment| Programming
# CellQuest                                              | Application           | Analysis
# PASW                                                   | Application           | Analysis
# GraphPad                                               | Application           | Visualization
# PASW                                                   | Application           | Analysis
# PASW                                                   | Application           | Analysis
# JMP                                                    | Application           | Analysis
# Structure                                              | Application           | Modelling
# ADMIXMAP                                               | Application           | Modelling
# STATISTICA                                             | Application           | Analysis
# PASW                                                   | Application           | Analysis
# iQ5 Optical system                                     | Application           | Analysis
# Mplus                                                  | Application           | Analysis
# Win                                                    | OperatingSystem       | Analysis
# AmeliaView                                             | PlugIn                | DataPreProcss
# Mplus                                                  | Application           | Modelling
# STATA                                                  | Application           | Analysis
# Mach                                                   | Application           | DataPreProcss
# Mach                                                   | Application           | DataPreProcss
# GRIMP                                                  | Application           | Analysis
# METAL                                                  | Application           | Analysis
# PASW                                                   | Application           | Analysis
# PLINK                                                  | Application           | Analysis
# METAL                                                  | Application           | Analysis
# PLINK                                                  | Application           | Analysis
# PASW                                                   | Application           | Analysis
# PLINK                                                  | Application           | Analysis
# METAL                                                  | Application           | Analysis
# BeadStudio                                             | Application           | Analysis
# Mach2QTL                                               | Application           | Analysis
# JMP                                                    | Application           | Analysis
# JMP                                                    | Application           | Analysis
# Matlab                                                 | ProgrammingEnvironment| Stimulation
# Statview                                               | Application           | Analysis
# Matlab                                                 | ProgrammingEnvironment| Simulation
# E-prime                                                | Application           | Stimulation
# Matlab                                                 | ProgrammingEnvironment| Analysis
# SPM                                                    | Application           | Analysis
# SPM                                                    | Application           | Modelling
# SPM                                                    | Application           | Analysis
# Photoshop                                              | Application           | Analysis
# Matlab                                                 | ProgrammingEnvironment| Modelling
# Matlab                                                 | ProgrammingEnvironment| Modelling
# Curve Fitting Toolbox                                  | PlugIn                | Modelling
# Image J                                                | Application           | DataCollection
# GraphPad                                               | Application           | Analysis
# Mac                                                    | OperatingSystem       | Analysis
# Flash                                                  | Application           | Visualization
# Actionscript                                           | ProgrammingEnvironment| Programming
# MacVide                                                | Application           | Analysis
# Matlab                                                 | ProgrammingEnvironment| Analysis
# SAS                                                    | Application           | Analysis
# STATA                                                  | Application           | Analysis
# STATA                                                  | Application           | Analysis
# Brain Voyager                                          | Application           | Analysis
# Image J                                                | Application           | Analysis
# Excel                                                  | Application           | DataPreProcss
# PASW                                                   | Application           | Analysis
# Win                                                    | OperatingSystem       | Analysis
# STATA                                                  | Application           | Analysis
# Python                                                 | ProgrammingEnvironment| Programming
# NLTK                                                   | PlugIn                | DataPreProcss
# Entrez Utilities Entrez Programming Utilities          | Application           | DataCollection
# Yahoo-BOSS                                             | Application           | DataPreProcss
# Yahoo-BOSS                                             | Application           | DataPreProcss
# Matlab                                                 | ProgrammingEnvironment| Analysis
# LSM imaging                                            | Application           | Visualization
# Openlab                                                | Application           | DataCollection
# Chromeleon                                             | Application           | Analysis
# Videomot                                               | Application           | Analysis
# Image J                                                | Application           | DataPreProcss
# GraphPad                                               | Application           | Analysis
# Patchmaster                                            | Application           | Analysis
# Spectrum Mill                                          | Application           | DataPreProcss
# Spectrum Mill                                          | Application           | DataPreProcss
# Spectrum Mill                                          | Application           | Analysis
# PASW                                                   | Application           | Analysis
# SeqScape                                               | Application           | Analysis
# Arlequin                                               | Application           | Analysis
# STATISTICA                                             | Application           | Analysis
# STATISTICA                                             | Application           | Analysis
# Network                                                | Application           | Analysis
# mtPhyl                                                 | Application           | Analysis
# Image J                                                | Application           | DataPreProcss
# GraphPad                                               | Application           | Analysis
# Win                                                    | OperatingSystem       | Analysis
# STRAIGHT                                               | PlugIn                | Stimulation
# Praat                                                  | Application           | DataPreProcss
# Praat                                                  | Application           | DataPreProcss
# Praat                                                  | Application           | DataPreProcss
# CALIB                                                  | Application           | DataPreProcss
# Mimics                                                 | Application           | DataCollection
# Strand7                                                | Application           | DataCollection
# Strand7                                                | Application           | Visualization
# OpenEpi                                                | Application           | Analysis
# SAS                                                    | Application           | Analysis
# PyroTagger                                             | Application           | Analysis
# Basic Local Alignment Search Tool                      | Application           | Analysis
# Basic Local Alignment Search Tool                      | Application           | Modelling
# EstimateS                                              | Application           | Modelling
# Basic Local Alignment Search Tool                      | Application           | Analysis
# Perl                                                   | ProgrammingEnvironment| DataPreProcss
# PCORD                                                  | Application           | Analysis
# RDP Classifier                                         | Application           | DataPreProcss
# Geneious                                               | Application           | DataPreProcss
# Bellerpheron                                           | Application           | DataPreProcss
# MUSCLE                                                 | Application           | Analysis
# Geneious                                               | Application           | Analysis
# Basic Local Alignment Search Tool                      | Application           | DataPreProcss
# Basic Local Alignment Search Tool                      | Application           | DataPreProcss
# MEGA                                                   | Application           | DataPreProcss
# DNAsp                                                  | Application           | Analysis
# MEGA                                                   | Application           | Modelling
# Basic Local Alignment Search Tool                      | Application           | Analysis
# Basic Local Alignment Search Tool                      | Application           | Analysis
# QUEST                                                  | PlugIn                | Modelling
# Psychophysics Toolbox                                  | PlugIn                | Modelling
# ImpaxEE                                                | Application           | Analysis
# SAS                                                    | Application           | DataCollection
# SAS                                                    | Application           | Analysis
# SAS                                                    | Application           | DataCollection
# Ethovision                                             | Application           | DataCollection
# Matlab                                                 | ProgrammingEnvironment| Stimulation
# E-prime                                                | Application           | Stimulation
# image processing toolbox                               | PlugIn                | Stimulation
# E-prime                                                | Application           | Stimulation
# STATA                                                  | Application           | Analysis
# Haploview                                              | Application           | Analysis
# Access                                                 | Application           | DataCollection
# PASW                                                   | Application           | Analysis
# GNU R                                                  | ProgrammingEnvironment| Analysis
# SPM                                                    | Application           | Analysis
# MarsBar                                                | PlugIn                | Modelling
# SPM                                                    | Application           | DataPreProcss
# Pickatlas                                              | Application           | DataPreProcss
# SAS                                                    | Application           | Analysis
# Epi Info                                               | Application           | DataCollection
# MAXQDA                                                 | Application           | DataCollection
# MAXQDA                                                 | Application           | DataCollection
# ADAPT                                                  | Application           | Simulation
# Matlab                                                 | ProgrammingEnvironment| Simulation
# Med-PC                                                 | Application           | Stimulation
# Med-PC                                                 | Application           | DataCollection
# Excel                                                  | Application           | DataCollection
# Med-PC                                                 | Application           | DataCollection
# GraphPad                                               | Application           | Visualization
# Excel                                                  | Application           | Visualization
# Illustrator                                            | Application           | Visualization
# PASW                                                   | Application           | Modelling
# MSOffice                                               | Application           | DataCollection
# GraphPad                                               | Application           | Analysis
# Image J                                                | Application           | Analysis
# Instat                                                 | Application           | Analysis
# Cyberball                                              | Application           | Stimulation
# SPM                                                    | Application           | Analysis
# SPM                                                    | Application           | DataPreProcss
# SPM                                                    | Application           | Analysis
# SPM                                                    | Application           | Analysis
# Cyberball                                              | Application           | Stimulation
# Chromeleon                                             | Application           | DataCollection
# Crimap                                                 | Application           | Visualization
# QTL Express                                            | Application           | Analysis
# qxpak                                                  | Application           | Analysis
# R/Qtl                                                  | PlugIn                | Analysis
# Digipro                                                | Application           | DataCollection
# Scion image                                            | Application           | DataPreProcss
# PASW                                                   | Application           | Analysis
# PLINK                                                  | Application           | DataPreProcss
# Mach                                                   | Application           | DataPreProcss
# PLINK                                                  | Application           | Analysis
# Birdseye                                               | Application           | Modelling
# Aninhado                                               | Application           | Analysis
# netcarto                                               | Application           | Analysis
# Pajek                                                  | Application           | Analysis
# netcarto                                               | Application           | Analysis
# GNU R                                                  | ProgrammingEnvironment| Analysis
# bipartite                                              | PlugIn                | Analysis
# Brain Voyager                                          | Application           | Analysis
# Tailarach Daemon                                       | Application           | DataPreProcss
# GENEMAPPER                                             | Application           | Analysis
# BioEdit                                                | Application           | DataPreProcss
# Arlequin                                               | Application           | Analysis
# PHASE                                                  | Application           | Programming
# SPLITSTREE                                             | Application           | Analysis
# Datamonkey                                             | Application           | Programming
# MODELTEST                                              | Application           | DataPreProcss
# PhyML                                                  | Application           | Analysis
# MRBAYES                                                | Application           | Analysis
# PAUP                                                   | Application           | Visualization
# Network                                                | Application           | Visualization
# Arlequin                                               | Application           | Analysis
# GENEPOP                                                | Application           | Analysis
# GENEPOP                                                | Application           | Analysis
# MEGA                                                   | Application           | Analysis
# Arlequin                                               | Application           | DataPreProcss
# Arlequin                                               | Application           | Analysis
# Bayesian Evolutionary Analysis by Sampling Trees       | Application           | Modelling
# MODELTEST                                              | Application           | Analysis
# TRACER                                                 | Application           | Analysis
# Bayesian Evolutionary Analysis by Sampling Trees       | Application           | Modelling
# GENEPOP                                                | Application           | Analysis
# Arlequin                                               | Application           | Analysis
# FSTAT                                                  | Application           | Analysis
# FSTAT                                                  | Application           | Analysis
# FREENA                                                 | Application           | Modelling
# MICRO-CHECKER                                          | Application           | DataPreProcss
# Structure                                              | Application           | Modelling
# CLUMPP                                                 | Application           | Analysis
# GENELAND                                               | Application           | Analysis
# DISTRUCT                                               | Application           | Visualization
# Arlequin                                               | Application           | DataPreProcss
# Arlequin                                               | Application           | Analysis
# SPAGeDI                                                | Application           | Analysis
# LAGRANGE                                               | Application           | Modelling
# Bayesian Evolutionary Analysis by Sampling Trees       | Application           | Analysis
# DIYABC                                                 | Application           | Modelling
# GENEPOP                                                | Application           | Analysis
# Structure                                              | Application           | Modelling
# GENELAND                                               | Application           | Analysis
# VIP                                                    | Application           | Analysis
# Bioportal                                              | Application           | Analysis
# Cytoscape                                              | Application           | Visualization
# Cytoscape                                              | Application           | Visualization
# OOIBase                                                | Application           | DataCollection
# BioEdit                                                | Application           | DataPreProcss
# Sequence Scanner                                       | Application           | Analysis
# Arlequin                                               | Application           | Analysis
# PASW                                                   | Application           | Visualization
# Network                                                | Application           | Visualization
# Surfer                                                 | Application           | Visualization
# ArlequÃ­n                                              | Application           | Modelling
# Matlab                                                 | ProgrammingEnvironment| Programming
# SPM                                                    | Application           | Analysis
# SPM                                                    | Application           | Modelling
# Anatomy atlas                                          | PlugIn                | Modelling
# SPM                                                    | Application           | Analysis
# MEGA                                                   | Application           | DataPreProcss
# MEGA                                                   | Application           | DataPreProcss
# ProtÃ©gÃ©                                              | Application           | Visualization
# OntoFox                                                | Application           | Analysis
# ProtÃ©gÃ©                                              | Application           | Visualization
# JMP                                                    | Application           | Analysis
# Brain Vision Analyzer                                  | Application           | DataPreProcss
# FMRIB Software Library                                 | Application           | DataPreProcss
# FMRIB Software Library                                 | Application           | DataPreProcss
# FMRIB Software Library                                 | Application           | DataPreProcss
# FMRIB Software Library                                 | Application           | Analysis
# FMRIB Software Library                                 | Application           | DataPreProcss
# FMRIB Software Library                                 | Application           | DataPreProcss
# Chart                                                  | Application           | DataCollection
# STATA                                                  | Application           | Analysis
# Cambridge Neuropsychological Test Automated Battery    | Application           | Stimulation
# Cambridge Neuropsychological Test Automated Battery    | Application           | Analysis
# Skeeter Buster                                         | Application           | Modelling
# Skeeter Buster                                         | Application           | Simulation
# CIMSiM                                                 | Application           | Modelling
# Brain Vision Recorder                                  | Application           | DataCollection
# EEGLAB                                                 | Application           | Analysis
# STATISTICA                                             | Application           | Modelling
# Matlab                                                 | ProgrammingEnvironment| Analysis
# tnet                                                   | Application           | Analysis
# tnet                                                   | Application           | Analysis
# tnet                                                   | Application           | Analysis
# BVQX                                                   | PlugIn                | Analysis
# Matlab                                                 | ProgrammingEnvironment| Analysis
# Brain Voyager                                          | Application           | Analysis
# Videotrack                                             | Application           | DataCollection
# Photoshop                                              | Application           | DataPreProcss
# pClamp                                                 | Application           | Analysis
# pClamp                                                 | Application           | Analysis
# Igor pro                                               | Application           | Analysis
# Visilog                                                | Application           | DataCollection
# Visilog                                                | Application           | Analysis
# Videotrack                                             | Application           | Analysis
# Videotrack                                             | Application           | Analysis
# WinEpiscope                                            | Application           | Analysis
# NCSS                                                   | Application           | Analysis
# Comprehensive Meta-Analysis                            | Application           | Analysis
# PASW                                                   | Application           | Analysis
# GENEMAPPER                                             | Application           | Analysis
# FAP                                                    | Application           | DataPreProcss
# GNU R                                                  | ProgrammingEnvironment| Analysis
# lme4                                                   | PlugIn                | Modelling
# car                                                    | PlugIn                | Analysis
# MCMCglmm                                               | PlugIn                | Modelling
# lme4                                                   | PlugIn                | Analysis
# Basic Local Alignment Search Tool                      | Application           | DataCollection
# MEGA                                                   | Application           | DataPreProcss
# GENEMAPPER                                             | Application           | Analysis
# MEGA                                                   | Application           | DataCollection
# Clustal                                                | Application           | DataPreProcss
# MEGA                                                   | Application           | DataPreProcss
# MEGA                                                   | Application           | DataPreProcss
# DNAsp                                                  | Application           | DataPreProcss
# PAUP                                                   | Application           | Analysis
# Network                                                | Application           | Visualization
# MRBAYES                                                | Application           | Modelling
# MODELTEST                                              | Application           | Modelling
# Google Earth                                           | Application           | DataCollection
# Arlequin                                               | Application           | Analysis
# IBDWS                                                  | Application           | Analysis
# Arlequin                                               | Application           | Analysis
# Arlequin                                               | Application           | Analysis
# Bayesian Evolutionary Analysis by Sampling Trees       | Application           | Modelling
# MODELTEST                                              | Application           | Modelling
# TRACER                                                 | Application           | Analysis
# LogCombiner                                            | Application           | DataPreProcss
# TreeAnnotator                                          | Application           | Visualization
# Fig Tree                                               | Application           | Visualization
# Excel                                                  | Application           | DataCollection
# Arlequin                                               | Application           | Analysis
# GENEPOP                                                | Application           | Analysis
# FSTAT                                                  | Application           | Analysis
# BOTTLENECK                                             | Application           | Analysis
# BOTTLENECK                                             | Application           | Analysis
# Arlequin                                               | Application           | Analysis
# Structure                                              | Application           | Analysis
# GENELAND                                               | Application           | Analysis
# migrate                                                | Application           | Modelling
# convert                                                | Application           | DataPreProcss
# Statview                                               | Application           | Analysis
# PASW                                                   | Application           | Analysis
# Win                                                    | OperatingSystem       | Analysis
# Review Manager                                         | Application           | Analysis
# PASW                                                   | Application           | Analysis
# Dataquest                                              | Application           | DataPreProcss
# PRIMER                                                 | Application           | Modelling
# GeNorm                                                 | Application           | Analysis
# GeNorm                                                 | Application           | Analysis
# ATLAS.ti                                               | Application           | DataPreProcss
# PASW                                                   | Application           | Analysis
# Access                                                 | Application           | DataCollection
# PASW                                                   | Application           | Analysis
# PASW                                                   | Application           | Analysis
# STATA                                                  | Application           | Analysis
# STATA                                                  | Application           | Analysis
# JWatcher                                               | Application           | Analysis
# PASW                                                   | Application           | Analysis
# Digilab                                                | Application           | DataCollection
# Matlab                                                 | ProgrammingEnvironment| Analysis
# ScopeWin                                               | Application           | Analysis
# Stereo investigator                                    | Application           | DataCollection
# Excel                                                  | Application           | Analysis
# MassHunter Acquisition                                 | Application           | DataCollection
# MassHunter Qualitative Analysis                        | Application           | DataPreProcss
# Mass Profiler Professional                             | Application           | Analysis
# Mass Profiler Professional                             | Application           | Analysis
# GraphPad                                               | Application           | Analysis
# SAS                                                    | Application           | Analysis
# Matlab                                                 | ProgrammingEnvironment| DataPreProcss
# Matlab                                                 | ProgrammingEnvironment| Analysis
# GPS Sample                                             | Application           | DataCollection
# Windows Mobile                                         | OperatingSystem       | DataCollection
# STATA                                                  | Application           | Analysis
# ArcGis                                                 | Application           | DataCollection
# ArcMap                                                 | Application           | DataCollection
# GNU R                                                  | ProgrammingEnvironment| Analysis
# SAS                                                    | Application           | Analysis
# G*Power                                                | Application           | Analysis
# Experiment Center                                      | Application           | DataCollection
# iView X                                                | Application           | DataCollection
# BeGaze                                                 | Application           | Stimulation
# SAS                                                    | Application           | Analysis
# Basic Local Alignment Search Tool                      | Application           | Analysis
# Clustal                                                | Application           | DataPreProcss
# SMART                                                  | Application           | Modelling
# SignalP                                                | Application           | Modelling
# MUSCLE                                                 | Application           | DataPreProcss
# PhyML                                                  | Application           | Visualization
# I-TASSER                                               | Application           | Modelling
# PASW                                                   | Application           | Analysis
# MASCOT                                                 | Application           | Analysis
# GlobalWorks                                            | Application           | Stimulation
# PASW                                                   | Application           | Analysis
# STATA                                                  | Application           | Analysis
# SAS                                                    | Application           | Analysis
# STATA                                                  | Application           | Analysis
# E-prime                                                | Application           | Stimulation
# MAXQDA                                                 | Application           | Analysis
# Gower                                                  | Application           | Analysis
# Bootstrap                                              | Application           | Analysis
# PASW                                                   | Application           | Analysis
# Bootstrap                                              | Application           | Analysis
# GNU R                                                  | ProgrammingEnvironment| Analysis
# sensitivity                                            | PlugIn                | Analysis
# GraphPad                                               | Application           | Visualization
# Excel                                                  | Application           | Analysis
# Brain Voyager                                          | Application           | Analysis
# Brain Voyager                                          | Application           | Analysis
# dcm4che                                                | Application           | Programming
# dcm4chee                                               | PlugIn                | Programming
# OsiriX                                                 | Application           | Programming
# OsiriX                                                 | Application           | Programming
# Objective-C                                            | ProgrammingEnvironment| Programming
# C                                                      | ProgrammingEnvironment| Programming
# C++                                                    | ProgrammingEnvironment| Programming
# Objective-C                                            | ProgrammingEnvironment| Programming
# dcm4chee                                               | PlugIn                | Programming
# GNU R                                                  | ProgrammingEnvironment| Analysis
# ENVI                                                   | Application           | Analysis
# geo-spatial modeling environment                       | Application           | Analysis
# Fragstats                                              | Application           | Analysis
# STATA                                                  | Application           | Modelling
# ArcGis                                                 | Application           | Analysis
# Spatial Statistics                                     | PlugIn                | Analysis
# Igor pro                                               | Application           | DataPreProcss
# Presentation                                           | Application           | Stimulation
# Presentation                                           | Application           | DataCollection
# Matlab                                                 | ProgrammingEnvironment| Analysis
# PASW                                                   | Application           | Analysis
# Brain Voyager                                          | Application           | Analysis
# Matlab                                                 | ProgrammingEnvironment| Analysis
# PASW                                                   | Application           | Analysis
# PASW                                                   | Application           | Analysis
# STATA                                                  | Application           | Analysis
# MLwiN                                                  | Application           | Modelling
# PASW                                                   | Application           | Analysis
# Win                                                    | OperatingSystem       | Analysis
# SPM                                                    | Application           | Analysis
# DARTEL                                                 | PlugIn                | DataCollection
# SPM                                                    | Application           | Analysis
# REST                                                   | Application           | DataPreProcss
# AlphaSim                                               | PlugIn                | DataPreProcss
# ArcGis                                                 | Application           | Visualization
# Photofiltre                                            | Application           | Visualization
# GNU R                                                  | ProgrammingEnvironment| Analysis
# EstimateS                                              | Application           | Modelling
# GNU R                                                  | ProgrammingEnvironment| Modelling
# lme4                                                   | PlugIn                | Modelling
# SPM                                                    | Application           | DataPreProcss
# SPM                                                    | Application           | Modelling
# Matlab                                                 | ProgrammingEnvironment| Analysis
# EASY RA1 Easy Randomizer                               | Application           | Stimulation
# PowerPoint                                             | Application           | Visualization
# PowerPoint                                             | Application           | Visualization
# Excel                                                  | Application           | DataPreProcss
# SAS                                                    | Application           | Analysis
# SPM                                                    | Application           | Analysis
# Matlab                                                 | ProgrammingEnvironment| Analysis
# Fieldmap                                               | PlugIn                | DataPreProcss
# SPM                                                    | Application           | DataPreProcss
# Matlab                                                 | ProgrammingEnvironment| Programming
# Psychophysics Toolbox                                  | PlugIn                | Programming
# Matlab                                                 | ProgrammingEnvironment| Modelling
# STATA                                                  | Application           | Analysis
# Actiware                                               | Application           | Analysis
# SAS                                                    | Application           | Analysis
# SAS                                                    | Application           | Analysis
# Access                                                 | Application           | DataCollection
# Epi Info                                               | Application           | DataCollection
# PASW                                                   | Application           | Analysis
# Win                                                    | OperatingSystem       | Analysis
# GNU R                                                  | ProgrammingEnvironment| Analysis
# PASW                                                   | Application           | Analysis
# PASW                                                   | Application           | Analysis
# SAS                                                    | Application           | Analysis
# Win                                                    | OperatingSystem       | Analysis
# SAS                                                    | Application           | Analysis
# PASW                                                   | Application           | Analysis
# Win                                                    | OperatingSystem       | Analysis
# Maxent                                                 | Application           | Modelling
# Hawth's analysis tools for ArcGis                      | Application           | Modelling
# Spatial Analyst                                        | PlugIn                | Modelling
# ArcGis                                                 | Application           | Modelling
# Spatial Analyst                                        | PlugIn                | Modelling
# Epi Info                                               | Application           | DataCollection
# STATA                                                  | Application           | Analysis
# STATA                                                  | Application           | Analysis
# STATA                                                  | Application           | Analysis
# STATA                                                  | Application           | Analysis
# STATA                                                  | Application           | Analysis
# EyeVision                                              | Application           | DataCollection
# EyeVision                                              | Application           | DataPreProcss
# PASW                                                   | Application           | Analysis
# ...
# STAR                                                   | Application           | DataPreProcss
# DESeq2                                                 | PlugIn                | Analysis
# Cluster                                                | Application           | Analysis
# Treeview                                               | Application           | Visualization
# GenePix                                                | Application           | Analysis
# edgeR                                                  | PlugIn                | Analysis
# ToppFun                                                | Application           | Analysis
# CIBERSORT                                              | Application           | Analysis
# immunoSEQ Analyzer                                     | Application           | Analysis
# PIVOT                                                  | Application           | Analysis
# GNU R                                                  | ProgrammingEnvironment| Analysis
# Rtsne                                                  | PlugIn                | Analysis
# PIVOT                                                  | Application           | Analysis
# Cluster                                                | Application           | Analysis
# Treeview                                               | Application           | Visualization
# GraphPad                                               | Application           | Visualization
# FlowJo                                                 | Application           | Analysis
# GraphPad                                               | Application           | Analysis
# Win                                                    | OperatingSystem       | Analysis
# Cytobank                                               | Application           | Analysis
# Image J                                                | Application           | Analysis
# Fiji                                                   | PlugIn                | Analysis
# Rotor-Gene Q                                           | Application           | Analysis
# Quantity One                                           | Application           | Analysis
# GraphPad                                               | Application           | Analysis
# TopSpin                                                | Application           | Analysis
# AMIX                                                   | Application           | Analysis
# Chenomx                                                | Application           | Analysis
# Chenomx                                                | Application           | Modelling
# SIMCA-P                                                | Application           | Analysis
# TopSpin                                                | Application           | Analysis
# Chenomx                                                | Application           | Analysis
# Iox                                                    | Application           | Analysis
# Image Lab                                              | Application           | Analysis
# Kubios                                                 | Application           | Analysis
# Kubios                                                 | Application           | DataPreProcss
# Iox                                                    | Application           | DataCollection
# GraphPad                                               | Application           | Analysis
# GraphPad                                               | Application           | Analysis
# GNU R                                                  | ProgrammingEnvironment| Analysis
# Perl                                                   | ProgrammingEnvironment| DataPreProcss
# Tophat                                                 | Application           | DataPreProcss
# HTSeq                                                  | Application           | Analysis
# DESeq                                                  | PlugIn                | Analysis
# GNU R                                                  | ProgrammingEnvironment| Analysis
# GOseq                                                  | PlugIn                | Analysis
# KOBAS                                                  | Application           | Analysis
# FIMO                                                   | Application           | DataCollection
# skewer                                                 | Application           | DataPreProcss
# BWA                                                    | Application           | DataPreProcss
# MACS                                                   | Application           | Analysis
# PASW                                                   | Application           | Analysis
# PASW                                                   | Application           | Analysis
# Win                                                    | OperatingSystem       | Analysis
# qBase                                                  | Application           | Analysis
# ImageQuant TL                                          | Application           | Analysis
# Image J                                                | Application           | DataPreProcss
# NIS                                                    | Application           | Analysis
# NIS                                                    | Application           | DataPreProcss
# GraphPad                                               | Application           | Analysis
# microRNA                                               | Application           | Modelling
# TargetScan                                             | Application           | Modelling
# miRDB                                                  | Application           | Modelling
# Venny                                                  | Application           | Analysis
# PPI Network                                            | Application           | Analysis
# MCODE                                                  | PlugIn                | Analysis
# Xena                                                   | Application           | DataCollection
# Xena                                                   | Application           | Analysis
# Image Lab                                              | Application           | Analysis
# ModFit                                                 | Application           | Analysis
# PASW                                                   | Application           | Analysis
# TargetScan                                             | Application           | Modelling
# miRDB                                                  | Application           | Modelling
# microRNA                                               | Application           | Modelling
# MCODE                                                  | PlugIn                | Analysis
# PPI Network                                            | Application           | Analysis
# J-Express                                              | Application           | DataPreProcss
# GNU R                                                  | ProgrammingEnvironment| Analysis
# BioConductor                                           | PlugIn                | Analysis
# GSEA                                                   | Application           | Analysis
# Cluster                                                | Application           | Analysis
# Treeview                                               | Application           | Analysis
# Large Average Submatricies                             | Application           | Analysis
# Image-Pro Plus                                         | Application           | Analysis
# SAS                                                    | Application           | Analysis
# Large Average Submatricies                             | Application           | Modelling
# Large Average Submatricies                             | Application           | Analysis
# Win                                                    | OperatingSystem       | DataCollection
# Imagelab                                               | Application           | DataCollection
# PASW                                                   | Application           | DataPreProcss
# PASW                                                   | Application           | Analysis
# Alogps                                                 | Application           | Simulation
# iTeva                                                  | Application           | Analysis
# MultiPak                                               | Application           | DataPreProcss
# LAS X                                                  | Application           | DataCollection
# LAS X                                                  | Application           | DataPreProcss
# Imaris                                                 | Application           | DataPreProcss
# Imaris                                                 | Application           | Visualization
# Fiji                                                   | PlugIn                | Visualization
# Photoshop                                              | Application           | Visualization
# Quicktime                                              | Application           | Visualization
# Photoshop                                              | Application           | Analysis
# Illustrator                                            | Application           | Analysis
# Fiji                                                   | PlugIn                | Analysis
# GraphPad                                               | Application           | Visualization
# Illustrator                                            | Application           | Visualization
# CFD                                                    | Application           | Simulation
# CAD                                                    | Application           | Modelling
# PASW                                                   | Application           | Analysis
# GraphPad                                               | Application           | Visualization
# SAS                                                    | Application           | Analysis
# Win                                                    | OperatingSystem       | Analysis
# SnpEff                                                 | Application           | Analysis
# REDCap                                                 | Application           | DataCollection
# bcl2fastq2                                             | Application           | DataPreProcss
# Picard                                                 | Application           | DataCollection
# GATK                                                   | Application           | DataPreProcss
# Picard                                                 | Application           | Analysis
# MuTect                                                 | Application           | Analysis
# VarScan                                                | Application           | Analysis
# samtools                                               | Application           | Modelling
# SnpEff                                                 | Application           | DataPreProcss
# SnpEff                                                 | Application           | Modelling
# Polysolver                                             | Application           | Analysis
# MuPeXI                                                 | Application           | DataPreProcss
# NetMHCpan                                              | Application           | DataPreProcss
# GenomeStudio                                           | Application           | DataPreProcss
# GNU R                                                  | ProgrammingEnvironment| DataPreProcss
# ASCAT                                                  | PlugIn                | DataPreProcss
# GNU R                                                  | ProgrammingEnvironment| Analysis
# SomaticSignatures                                      | PlugIn                | Analysis
# MutationalPatterns                                     | PlugIn                | Analysis
# SnpEff                                                 | Application           | DataPreProcss
# MSIsensor                                              | Application           | Analysis
# PolyPhen                                               | Application           | Analysis
# MutationAssessor                                       | Application           | Analysis
# PolyPhen                                               | Application           | Analysis
# MutationAssessor                                       | Application           | Analysis
# MuTect                                                 | Application           | Analysis
# MuTect                                                 | Application           | Analysis
# bam-readcount                                          | Application           | Analysis
# Salmon                                                 | Application           | Analysis
# GNU R                                                  | ProgrammingEnvironment| Analysis
# tximport                                               | PlugIn                | Analysis
# edgeR                                                  | PlugIn                | Analysis
# GNU R                                                  | ProgrammingEnvironment| Modelling
# consensus MIBC                                         | PlugIn                | Modelling
# GNU R                                                  | ProgrammingEnvironment| Analysis
# RTN                                                    | PlugIn                | Analysis
# xCell                                                  | Application           | Analysis
# ChAMP                                                  | PlugIn                | DataPreProcss
# GNU R                                                  | ProgrammingEnvironment| DataPreProcss
# Visiopharm                                             | Application           | Analysis
# Visiopharm                                             | Application           | DataPreProcss
# GNU R                                                  | ProgrammingEnvironment| Analysis
# survminer                                              | PlugIn                | Analysis
# Survival                                               | PlugIn                | Analysis
# Trim Galore                                            | Application           | DataPreProcss
# Draeger EIT Data Analysis Tool                         | Application           | DataPreProcss
# PASW                                                   | Application           | Analysis
# GNU R                                                  | ProgrammingEnvironment| Analysis
# OptimalCutpoints                                       | PlugIn                | Analysis
# Basic Local Alignment Search Tool                      | Application           | Modelling
# PRIMER                                                 | Application           | Modelling
# Trimmomatic                                            | Application           | DataPreProcss
# Bowtie                                                 | Application           | DataCollection

# %% [markdown]
# ### `PubMed_PLoS` Dataframe to  `NTP`  format  for Analysis
#
# `NTP` format is `Name`, `Type`, `Purpose` format

# %%
#PubMed_PLoS

# %%
import pandas as pd

PubMedPLoS_swNTP = pd.DataFrame(columns=['Sw_Name', 'Type','Purpose'], data=list_swNTP)


PubMedPLoS_swNTP.reset_index

PubMedPLoS_swNTP
# Out:
#                                 Sw_Name         Type         Purpose
# 0                           DS modeling  Application       Modelling
# 1                                pClamp  Application  DataCollection
# 2                               Ensembl  Application        Analysis
# 3                                   RIU  Application  DataCollection
# 4                                 STATA  Application        Analysis
# ...                                 ...          ...             ...
# 1842                   OptimalCutpoints       PlugIn        Analysis
# 1843  Basic Local Alignment Search Tool  Application       Modelling
# 1844                             PRIMER  Application       Modelling
# 1845                        Trimmomatic  Application   DataPreProcss
# 1846                             Bowtie  Application  DataCollection
#
# [1847 rows x 3 columns]

# %% [markdown]
# # 2.1. Software perspective:
#
# - How much software does appear only for a single purpose?
# - What type combinations appear for software?

# %% [markdown]
# ## Analysis #1: Software  `Name`
#
# ### Top software by Mention Count

# %%
PubMedPLoS_swN = PubMedPLoS_swNTP.groupby(['Sw_Name']).size().reset_index(name='Count')

PubMedPLoS_swN_dsc = PubMedPLoS_swN.sort_values(by=['Count'], ascending=False)

PubMedPLoS_swN_dsc
# Out:
#            Sw_Name  Count
# 380           PASW    129
# 211          GNU R     91
# 477          STATA     76
# 326         Matlab     68
# 459            SAS     52
# ..             ...    ...
# 262        ImpaxEE      1
# 259       Imagelab      1
# 258  ImageQuant TL      1
# 252          IVICT      1
# 656          xCell      1
#
# [657 rows x 2 columns]

# %%
Top20_Sw = PubMedPLoS_swN_dsc.head(20)

Top20_Sw = Top20_Sw.set_index('Sw_Name')
Top20_Sw
# Out:
#                                    Count
# Sw_Name
# PASW                                 129
# GNU R                                 91
# STATA                                 76
# Matlab                                68
# SAS                                   52
# SPM                                   40
# Win                                   39
# GraphPad                              35
# Excel                                 26
# Image J                               24
# FMRIB Software Library                21
# Basic Local Alignment Search Tool     19
# AFNI                                  18
# MEGA                                  17
# PLINK                                 16
# Arlequin                              14
# STATISTICA                            13
# FreeSurfer                            10
# Ingenuity                             10
# Python                                10

# %%
import matplotlib.pyplot as plt

# plot style
plt.style.use("seaborn-deep")

fig, ax = plt.subplots(figsize=(10, 5))

Top20_Sw_ind = Top20_Sw['Count'].index
Top20_Sw_val = Top20_Sw['Count'].values

ax.barh(Top20_Sw_ind,Top20_Sw_val, align='center')

# labels
ax.set_title("Top software mentions")
ax.set_xlabel("Count")

ax.invert_yaxis()
plt.grid(color='grey', linestyle='-.', linewidth=0.1)
plt.show()

fig.tight_layout()
fig.savefig("Ananlysis_output_pngs/1.Top software mentions.png", dpi = 130)

# %% [markdown]
# ### Analysis #2: Software `Purpose`

# %%
SwP = PubMedPLoS_swNTP.groupby(['Purpose']).size().reset_index(name='Count')

SwP_dsc = SwP.sort_values(by=['Count','Purpose'], ascending=False)

SwP_dsc = SwP_dsc.set_index("Purpose")

SwP_dsc
# Out:
#                 Count
# Purpose
# Analysis         1035
# DataPreProcss     246
# DataCollection    174
# Modelling         172
# Visualization      99
# Programming        56
# Stimulation        43
# Simulation         22

# %%
# visualize the shre of resources pie-chart

import matplotlib.pyplot as plt

# plot style
plt.style.use("seaborn-deep")
fig, ax = plt.subplots(figsize=(10, 5), subplot_kw=dict(aspect="equal"))

# Data to plot
label = SwP_dsc['Count'].index
valu_ = SwP_dsc['Count'].values

explode = (0.1, 0.1, 0.1,0.1,0.2,0.25,0.275, 0.3)  # explode 1st slice


plt.pie(valu_,explode=explode,autopct='%1.1f%%', shadow=True, startangle=55)

# annotate
plt.legend(label, loc="best")

ax.set_title("Software Usage Purpose ")
plt.axis('equal')

fig.tight_layout()
fig.savefig("Ananlysis_output_pngs/2.Software Usage Purpose pie.png", dpi = 130)
plt.show()

# %%
import matplotlib.pyplot as plt

# plot style
plt.style.use("seaborn-deep")

fig, ax = plt.subplots(figsize=(10, 5))



val_ = SwP_dsc['Count'].values
ind_ = SwP_dsc['Count'].index


ax.bar(ind_,val_, align='center')

# labels
ax.set_title("Software Purposes")
ax.set_xlabel("Software Purpose")
ax.set_ylabel("Mention count")

ax.set_xticklabels(ind_, rotation=15)

#ax.invert_yaxis()
plt.grid(color='grey', linestyle='-.', linewidth=0.3)
plt.show()

fig.tight_layout()
fig.savefig("Ananlysis_output_pngs/3.Software Purposes.png", dpi = 130)
# Out:
# C:\Users\Beck\AppData\Local\Temp\ipykernel_10056\1292477950.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ind_, rotation=15)

# %% [markdown]
# ### Analysis #3: Software Type
#
# ### What type combinations appear for software?

# %%
SwT = PubMedPLoS_swNTP.groupby(['Type']).size().reset_index(name='Count')
SwT_dsc = SwT.sort_values(by=['Count','Type'], ascending=False)

SwT_dsc = SwT_dsc.set_index('Type')
SwT_dsc
# Out:
#                         Count
# Type
# Application              1390
# PlugIn                    221
# ProgrammingEnvironment    188
# OperatingSystem            48

# %%
# visualize the shre of resources pie-chart

import matplotlib.pyplot as plt

# plot style
plt.style.use("seaborn-deep")
fig, ax = plt.subplots(figsize=(10, 5), subplot_kw=dict(aspect="equal"))

# Data to plot
label = SwT_dsc['Count'].index
x = SwT_dsc['Count'].values

explode = (0.1, 0.1, 0.1,0.1)  # explode 1st slice


plt.pie(x,explode=explode,autopct='%1.1f%%', shadow=True, startangle=55)

# annotate
plt.legend(label, loc="best")

ax.set_title("Software Types")
plt.axis('equal')

fig.tight_layout()
fig.savefig("Ananlysis_output_pngs/4.Software Types pie.png", dpi = 130)

plt.show()

# %% [markdown]
# ####  How many different software is there per type?
# ####  Does any type just have few software? etc.

# %% [markdown]
# ### Analysis #4: Software `Type, Purpose`
#
#
# ### software type in each purpose of usage

# %%
import matplotlib.pyplot as plt

# plot style
plt.style.use("seaborn-deep")

fig, ax = plt.subplots(figsize=(10, 5))



val_swt = SwT_dsc['Count'].values
ind_swt = SwT_dsc['Count'].index


ax.barh(ind_swt,val_swt, align='center')

# labels
ax.set_title("Types of Software")
ax.set_xlabel("Software Type counts")


ax.invert_yaxis()
plt.grid(color='grey', linestyle='-.', linewidth=0.3)
plt.show()

fig.tight_layout()
fig.savefig("Ananlysis_output_pngs/5.Software Types bar.png", dpi = 130)

# %%
SwTP = PubMedPLoS_swNTP.groupby(['Type','Purpose']).size().reset_index(name='CountTP')

#SwTP_dsc = SwTP.sort_values(by=['Count','Type', 'Purpose'], ascending=False)

SwTP_dsc = SwTP.sort_values(by=['Purpose','Type'], ascending=True)


Analysis_ = SwTP_dsc[SwTP_dsc["Purpose"] == "Analysis"]
DataColl_ = SwTP_dsc[SwTP_dsc["Purpose"] == "DataCollection"]

PreProcs_ = SwTP_dsc[SwTP_dsc["Purpose"] == "DataPreProcss"]
Modellin_ = SwTP_dsc[SwTP_dsc["Purpose"] == "Modelling"]
Programm_ = SwTP_dsc[SwTP_dsc["Purpose"] == "Programming"]
Simulatn_ = SwTP_dsc[SwTP_dsc["Purpose"] == "Simulation"]
STimulan_ = SwTP_dsc[SwTP_dsc["Purpose"] == "Stimulation"]
VIzualan_ = SwTP_dsc[SwTP_dsc["Purpose"] == "Visualization"]


'''

The data farmes have different shapes

Add 0 conts for consistency

'''


preprocc_row = {'Type':'OperatingSystem', 'Purpose':'DataPreProcss', 'CountTP':0}
PreProcs_ = PreProcs_.append(preprocc_row, ignore_index=True)
PreProcs_ = PreProcs_.sort_values(by=['Type'], ascending=True)
PreProcs_ = PreProcs_.set_index("Type")




Modellin_row = {'Type':'OperatingSystem', 'Purpose':'Modelling', 'CountTP':0}
Modellin_ = Modellin_.append(Modellin_row, ignore_index=True)
Modellin_ = Modellin_.sort_values(by=['Type'], ascending=True)
Modellin_ = Modellin_.set_index("Type")

Programm_row = {'Type':'OperatingSystem', 'Purpose':'Programming', 'CountTP':0}
Programm_ = Programm_.append(Programm_row, ignore_index=True)
Programm_ = Programm_.sort_values(by=['Type'], ascending=True)
Programm_ = Programm_.set_index("Type")


Simulatn_row = {'Type':'OperatingSystem', 'Purpose':'Simulation', 'CountTP':0}
Simulatn_ = Simulatn_.append(Simulatn_row, ignore_index=True)
Simulatn_ = Simulatn_.sort_values(by=['Type'], ascending=True)
Simulatn_ = Simulatn_.set_index("Type")


STimulan_ = STimulan_.set_index("Type")
VIzualan_ = VIzualan_.set_index("Type")
DataColl_ = DataColl_.set_index("Type")
Analysis_ = Analysis_.set_index("Type")
# Out:
# C:\Users\Beck\AppData\Local\Temp\ipykernel_10056\490506669.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   PreProcs_ = PreProcs_.append(preprocc_row, ignore_index=True)
# C:\Users\Beck\AppData\Local\Temp\ipykernel_10056\490506669.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Modellin_ = Modellin_.append(Modellin_row, ignore_index=True)
# C:\Users\Beck\AppData\Local\Temp\ipykernel_10056\490506669.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Programm_ = Programm_.append(Programm_row, ignore_index=True)
# C:\Users\Beck\AppData\Local\Temp\ipykernel_10056\490506669.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Simulatn_ = Simulatn_.append(Simulatn_row, ignore_index=True)

# %%
import matplotlib.pyplot as plt

# plot style
plt.style.use("seaborn-deep")
#plt.style.use('ggplot')

fig, ax = plt.subplots(figsize=(10, 5))

# plot analysis

A_ind= Analysis_['CountTP'].index
A_Val= Analysis_['CountTP'].values
ax.barh(A_ind,A_Val, align='center', label="Analysis" )

# Plot DC

DC_ind = DataColl_['CountTP'].index
DC_val = DataColl_['CountTP'].values

ax.barh(DC_ind, DC_val,left= A_Val, label="Data-Collection" )


# Plot Viz

pp_ind = PreProcs_['CountTP'].index
pp_val = PreProcs_['CountTP'].values

ax.barh(pp_ind, pp_val,left= A_Val+DC_val, label="Pre-processing" )


# Plot Viz

Viz_ind = VIzualan_['CountTP'].index
VIz_val = VIzualan_['CountTP'].values

ax.barh(Viz_ind, VIz_val,left= A_Val+DC_val+pp_val, label="Vizualization" )


# plot modelling

Modellin_ind = Modellin_['CountTP'].index
Modellin_val = Modellin_['CountTP'].values

ax.barh(Modellin_ind, Modellin_val,left= A_Val+DC_val+pp_val+VIz_val, label="Modelling" )


# plot programming

Programm_ind = Programm_['CountTP'].index
Programm_val = Programm_['CountTP'].values

ax.barh(Programm_ind, Programm_val,left= A_Val+DC_val+pp_val+VIz_val+Modellin_val, label="Programmng" )


# plot simulation

Simulatn_ind = Simulatn_['CountTP'].index
Simulatn_val = Simulatn_['CountTP'].values

ax.barh(Programm_ind, Programm_val,left= A_Val+DC_val+pp_val+VIz_val+Modellin_val+Programm_val, label="Simulation" )



# plot stimulation

STimulan_ind = STimulan_['CountTP'].index
STimulan_val = STimulan_['CountTP'].values

ax.barh(Programm_ind, Programm_val,left= A_Val+DC_val+pp_val+VIz_val+Modellin_val+Programm_val+STimulan_val, label="STimulation" )

ax.invert_yaxis()

ax.set_title("Types of Software and Purpose")
ax.set_xlabel("Software Type-purpose counts")

ax.legend()
plt.grid(color='grey', linestyle='-.', linewidth=0.3)
plt.show()

fig.tight_layout()
fig.savefig("Ananlysis_output_pngs/6.Types of Software and Purpose stacked bar.png", dpi = 130)

# %% [markdown]
# ### Analysis #5: Software `Name Purpose`
#
# ### - How much software does appear only for a single purpose?

# %%
SwNP = PubMedPLoS_swNTP.groupby(['Sw_Name','Purpose']).size().reset_index(name='Count')



SwNP_dsc = SwNP.sort_values(by=['Count','Purpose','Sw_Name'], ascending=False)


"""

count all instances for all software with :

software with only single purpose 
software with two purpose 

...

software with 8 purpose 



"""
SwNP_dsc.head(10)
# Out:
#       Sw_Name    Purpose  Count
# 522      PASW   Analysis    120
# 659     STATA   Analysis     67
# 278     GNU R   Analysis     56
# 632       SAS   Analysis     46
# 768       Win   Analysis     32
# 448    Matlab   Analysis     31
# 314  GraphPad   Analysis     28
# 655       SPM   Analysis     24
# 280     GNU R  Modelling     14
# 336   Image J   Analysis     13

# %%
'''

we want to get all possible purposes a software is used for 

subset only software name and purpose 

'''

# example for Matlab 

swnp = SwNP_dsc[['Sw_Name', 'Purpose']]
swnp[swnp['Sw_Name'] == 'Matlab']
# Out:
#     Sw_Name         Purpose
# 448  Matlab        Analysis
# 454  Matlab     Stimulation
# 451  Matlab       Modelling
# 452  Matlab     Programming
# 450  Matlab   DataPreProcss
# 449  Matlab  DataCollection
# 453  Matlab      Simulation

# %%
sbs = swnp.groupby(["Sw_Name", "Purpose"])[["Sw_Name"]].count()

# %%
sbs
# Out:
#                             Sw_Name
# Sw_Name      Purpose
# 2LD          Analysis             1
# 3dBandpass   DataPreProcss        1
# 3dClustsim   Analysis             1
# 3dDeconvolve Modelling            1
# 3dDespike    DataPreProcss        1
# ...                             ...
# tnet         Analysis             1
# tximport     Analysis             1
# vcftools     Analysis             1
# waver        Analysis             1
# xCell        Analysis             1
#
# [878 rows x 1 columns]

# %%
# list of tuple ('softwareName', 'Purpose')

liT = list(sbs['Sw_Name'].index)
liT
# Out:
# [('2LD', 'Analysis'),
#  ('3dBandpass', 'DataPreProcss'),
#  ('3dClustsim', 'Analysis'),
#  ('3dDeconvolve', 'Modelling'),
#  ('3dDespike', 'DataPreProcss'),
#  ('3dDetrend', 'Analysis'),
#  ('3dFDR', 'DataPreProcss'),
#  ('3dFDR', 'Modelling'),
#  ('3dFWHMx', 'Analysis'),
#  ('3dmaskave', 'DataCollection'),
#  ('3dttest+ +', 'Analysis'),
#  ('3dttest+ +', 'DataCollection'),
#  ('ADAPT', 'Simulation'),
#  ('ADMIXMAP', 'Modelling'),
#  ('AFNI', 'Analysis'),
#  ('AFNI', 'DataCollection'),
#  ('AFNI', 'DataPreProcss'),
#  ('AFNI', 'Modelling'),
#  ('AMBERTOOLS', 'Analysis'),
#  ('AMIX', 'Analysis'),
#  ('AMOS', 'Analysis'),
#  ('ANNOVAR', 'DataPreProcss'),
#  ('ART', 'Analysis'),
#  ('ART', 'Modelling'),
#  ('ASCAT', 'DataPreProcss'),
#  ('ATLAS.ti', 'Analysis'),
#  ('ATLAS.ti', 'DataPreProcss'),
#  ('Access', 'DataCollection'),
#  ('Acrobat', 'DataCollection'),
#  ('ActiLife', 'DataPreProcss'),
#  ('Actionscript', 'Programming'),
#  ('Actiware', 'Analysis'),
#  ('Advanced Normalization Tools', 'DataPreProcss'),
#  ('Alogps', 'Simulation'),
#  ('AlphaSim', 'DataPreProcss'),
#  ('Altmetric', 'DataCollection'),
#  ('AmeliaView', 'DataPreProcss'),
#  ('Analyst', 'Analysis'),
#  ('Anatomy atlas', 'Analysis'),
#  ('Anatomy atlas', 'Modelling'),
#  ('Aninhado', 'Analysis'),
#  ('ArcGis', 'Analysis'),
#  ('ArcGis', 'DataCollection'),
#  ('ArcGis', 'Modelling'),
#  ('ArcGis', 'Visualization'),
#  ('ArcMap', 'DataCollection'),
#  ('ArcView', 'DataCollection'),
#  ('ArcView', 'Visualization'),
#  ('Arlequin', 'Analysis'),
#  ('Arlequin', 'DataPreProcss'),
#  ('ArlequÃ\xadn', 'Modelling'),
#  ('Artemis', 'DataPreProcss'),
#  ('AsReml', 'Analysis'),
#  ('AsReml', 'Modelling'),
#  ('Autodock Vina', 'Analysis'),
#  ('Autodock Vina', 'DataPreProcss'),
#  ('Axio Vision', 'DataCollection'),
#  ('BCFtools', 'DataPreProcss'),
#  ('BD FACSDiva', 'Analysis'),
#  ('BEAGLE', 'Analysis'),
#  ('BEAGLE', 'Modelling'),
#  ('BOLT-LMM', 'Analysis'),
#  ('BOTTLENECK', 'Analysis'),
#  ('BVQX', 'Analysis'),
#  ('BWA', 'DataPreProcss'),
#  ('Basic', 'Programming'),
#  ('Basic Local Alignment Search Tool', 'Analysis'),
#  ('Basic Local Alignment Search Tool', 'DataCollection'),
#  ('Basic Local Alignment Search Tool', 'DataPreProcss'),
#  ('Basic Local Alignment Search Tool', 'Modelling'),
#  ('Bayesian Evolutionary Analysis by Sampling Trees', 'Analysis'),
#  ('Bayesian Evolutionary Analysis by Sampling Trees', 'Modelling'),
#  ('BeGaze', 'Stimulation'),
#  ('BeadStudio', 'Analysis'),
#  ('Bellerpheron', 'DataPreProcss'),
#  ('BiNGO', 'Analysis'),
#  ('BioConductor', 'Analysis'),
#  ('BioEdit', 'DataPreProcss'),
#  ('BioMart', 'Analysis'),
#  ('BioMart', 'DataCollection'),
#  ('BioMart', 'DataPreProcss'),
#  ('BioNetGen', 'Analysis'),
#  ('BioNetGen', 'Modelling'),
#  ('BioNetGen', 'Simulation'),
#  ('BioTools', 'Visualization'),
#  ('Bioanalyzer', 'Visualization'),
#  ('Bioplex Manager', 'Analysis'),
#  ('Bioplex Manager', 'DataCollection'),
#  ('Bioportal', 'Analysis'),
#  ('Biotrace', 'DataCollection'),
#  ('Bioworks', 'DataPreProcss'),
#  ('Birdseye', 'Modelling'),
#  ('BisoGenet', 'Visualization'),
#  ('BootES', 'Analysis'),
#  ('Bootstrap', 'Analysis'),
#  ('Bowtie', 'DataCollection'),
#  ('Brain Connectivity Toolbox', 'Modelling'),
#  ('Brain Vision Analyzer', 'DataCollection'),
#  ('Brain Vision Analyzer', 'DataPreProcss'),
#  ('Brain Vision Recorder', 'DataCollection'),
#  ('Brain Voyager', 'Analysis'),
#  ('BrainStorm', 'Modelling'),
#  ('Brainsight', 'Analysis'),
#  ('C', 'Programming'),
#  ('C#', 'Programming'),
#  ('C++', 'Programming'),
#  ('C2', 'Visualization'),
#  ('CAD', 'Modelling'),
#  ('CADD', 'Analysis'),
#  ('CALIB', 'DataPreProcss'),
#  ('CASAVA', 'DataPreProcss'),
#  ('CCS', 'Analysis'),
#  ('CCS', 'Programming'),
#  ('CFD', 'Simulation'),
#  ('CIBERSORT', 'Analysis'),
#  ('CIMSiM', 'Modelling'),
#  ('CLC Genomic Workbench', 'Analysis'),
#  ('CLUMP', 'Simulation'),
#  ('CLUMPP', 'Analysis'),
#  ('CNVmap', 'Analysis'),
#  ('COANCESTRY', 'Analysis'),
#  ('COLONY', 'Analysis'),
#  ('CONN', 'Analysis'),
#  ('CPPTRAJ', 'Analysis'),
#  ('CSPRO', 'DataCollection'),
#  ('CT-Expo', 'Stimulation'),
#  ('CVODE', 'Analysis'),
#  ('Cambridge Neuropsychological Test Automated Battery', 'Analysis'),
#  ('Cambridge Neuropsychological Test Automated Battery', 'Stimulation'),
#  ('CellQuest', 'Analysis'),
#  ('Cervus', 'Analysis'),
#  ('ChAMP', 'DataPreProcss'),
#  ('Chart', 'DataCollection'),
#  ('Chenomx', 'Analysis'),
#  ('Chenomx', 'Modelling'),
#  ('Chimera', 'Visualization'),
#  ('Chromeleon', 'Analysis'),
#  ('Chromeleon', 'DataCollection'),
#  ('ClueGO', 'Analysis'),
#  ('Clustal', 'DataPreProcss'),
#  ('Cluster', 'Analysis'),
#  ('CoNIFER', 'DataCollection'),
#  ('Coffalyser.NET', 'Analysis'),
#  ('Cogent', 'DataCollection'),
#  ('Comprehensive Meta-Analysis', 'Analysis'),
#  ('CompuSin', 'Analysis'),
#  ('ConSurf-HSSP', 'Analysis'),
#  ('Condel', 'Analysis'),
#  ('ConoMass', 'Analysis'),
#  ('Crimap', 'Visualization'),
#  ('CrystalClear', 'DataCollection'),
#  ('CrystalClear', 'DataPreProcss'),
#  ('CubeX', 'Analysis'),
#  ('Cufflinks', 'Analysis'),
#  ('Curve Fitting Toolbox', 'Modelling'),
#  ('Cyberball', 'Stimulation'),
#  ('Cytobank', 'Analysis'),
#  ('Cytoscape', 'Analysis'),
#  ('Cytoscape', 'Visualization'),
#  ('DARTEL', 'DataCollection'),
#  ('DARTEL', 'DataPreProcss'),
#  ('DARTEL', 'Modelling'),
#  ('DESeq', 'Analysis'),
#  ('DESeq2', 'Analysis'),
#  ('DISSECT', 'Simulation'),
#  ('DISTRUCT', 'Visualization'),
#  ('DIVA-GIS', 'Visualization'),
#  ('DIYABC', 'Modelling'),
#  ('DNAsp', 'Analysis'),
#  ('DNAsp', 'DataPreProcss'),
#  ('DS ViewerPro', 'Visualization'),
#  ('DS modeling', 'Modelling'),
#  ('DTIFit', 'DataCollection'),
#  ('DTIFit', 'Modelling'),
#  ('DTV.II SR', 'Analysis'),
#  ('Database for Annotation, Visualization and Integrated Discovery',
#   'Analysis'),
#  ('Database for Annotation, Visualization and Integrated Discovery',
#   'DataCollection'),
#  ('Datacam', 'DataCollection'),
#  ('Datacam', 'Visualization'),
#  ('Datamonkey', 'Analysis'),
#  ('Datamonkey', 'DataCollection'),
#  ('Datamonkey', 'Programming'),
#  ('Dataquest', 'DataPreProcss'),
#  ('Debian', 'Analysis'),
#  ('Digilab', 'DataCollection'),
#  ('Digipro', 'DataCollection'),
#  ('Draeger EIT Data Analysis Tool', 'DataPreProcss'),
#  ('E-prime', 'Stimulation'),
#  ('EASY RA1 Easy Randomizer', 'Stimulation'),
#  ('EEGLAB', 'Analysis'),
#  ('EEGLAB', 'DataPreProcss'),
#  ('ENMtools', 'Analysis'),
#  ('ENMtools', 'DataPreProcss'),
#  ('ENVI', 'Analysis'),
#  ('EQ-5D calculator', 'Analysis'),
#  ('Endnote', 'DataCollection'),
#  ('Enketo', 'DataCollection'),
#  ('Ensembl', 'Analysis'),
#  ('Ensembl', 'DataCollection'),
#  ('Ensembl', 'DataPreProcss'),
#  ('Entrez Utilities Entrez Programming Utilities', 'DataCollection'),
#  ('Epi', 'Visualization'),
#  ('Epi Info', 'Analysis'),
#  ('Epi Info', 'DataCollection'),
#  ('EpiR', 'Analysis'),
#  ('EstimateS', 'Modelling'),
#  ('Ethovision', 'Analysis'),
#  ('Ethovision', 'DataCollection'),
#  ('EventIDE', 'Stimulation'),
#  ('Excel', 'Analysis'),
#  ('Excel', 'DataCollection'),
#  ('Excel', 'DataPreProcss'),
#  ('Excel', 'Modelling'),
#  ('Excel', 'Visualization'),
#  ('Experiment Center', 'DataCollection'),
#  ('Experimetrix', 'DataCollection'),
#  ('Expression Analysis Systematic Explorer', 'Analysis'),
#  ('EyeLink Data Viewer', 'DataCollection'),
#  ('EyeLink Data Viewer', 'DataPreProcss'),
#  ('EyeVision', 'DataCollection'),
#  ('EyeVision', 'DataPreProcss'),
#  ('Eyelink Toolbox', 'Stimulation'),
#  ('FACSuite', 'Analysis'),
#  ('FACSuite', 'DataCollection'),
#  ('FAP', 'DataPreProcss'),
#  ('FDT', 'Modelling'),
#  ('FGENESB', 'Analysis'),
#  ('FIMO', 'DataCollection'),
#  ('FLIRT', 'Analysis'),
#  ('FLIRT', 'DataCollection'),
#  ('FLIRT', 'DataPreProcss'),
#  ('FMRIB Software Library', 'Analysis'),
#  ('FMRIB Software Library', 'DataCollection'),
#  ('FMRIB Software Library', 'DataPreProcss'),
#  ('FMRIB Software Library', 'Modelling'),
#  ("FMRIB's Automated Segmentation Tool", 'DataPreProcss'),
#  ("FMRIB's ICA-based X-noiseifier", 'Analysis'),
#  ('FMRIBâ€™s Diffusion Toolbox', 'Analysis'),
#  ('FMRIBâ€™s Diffusion Toolbox', 'Modelling'),
#  ('FMRIBâ€™s Integrated Registration and Segmentation Tool', 'Analysis'),
#  ('FNIRT', 'DataPreProcss'),
#  ('FREENA', 'Modelling'),
#  ('FSL-VBM', 'Analysis'),
#  ('FSLView', 'Analysis'),
#  ('FSTAT', 'Analysis'),
#  ('FastQC', 'DataCollection'),
#  ('FastQC', 'Programming'),
#  ('Fieldmap', 'DataPreProcss'),
#  ('Fig Tree', 'Visualization'),
#  ('FigureJ', 'Visualization'),
#  ('Fiji', 'Analysis'),
#  ('Fiji', 'Visualization'),
#  ('Fire Weather Indices Calculator', 'Analysis'),
#  ('Firefox', 'DataCollection'),
#  ('Flash', 'Visualization'),
#  ('Flex Analysis', 'Visualization'),
#  ('FlexArray', 'Analysis'),
#  ('FlowJo', 'Analysis'),
#  ('Fortran', 'DataCollection'),
#  ('Fragstats', 'Analysis'),
#  ('FreeSurfer', 'Analysis'),
#  ('FreeSurfer', 'DataCollection'),
#  ('FreeSurfer', 'DataPreProcss'),
#  ('FreeSurfer', 'Modelling'),
#  ('FunRich', 'Analysis'),
#  ('Functional Annotation Tool', 'DataCollection'),
#  ('G*Power', 'Analysis'),
#  ('GARLI', 'Analysis'),
#  ('GARLI', 'Modelling'),
#  ('GARLI', 'Visualization'),
#  ('GATK', 'Analysis'),
#  ('GATK', 'DataPreProcss'),
#  ('GDAL', 'Modelling'),
#  ('GEMINI', 'Analysis'),
#  ('GENECOUNTING', 'Modelling'),
#  ('GENELAND', 'Analysis'),
#  ('GENEMAPPER', 'Analysis'),
#  ('GENEPOP', 'Analysis'),
#  ('GNU R', 'Analysis'),
#  ('GNU R', 'DataPreProcss'),
#  ('GNU R', 'Modelling'),
#  ('GNU R', 'Programming'),
#  ('GNU R', 'Simulation'),
#  ('GNU R', 'Visualization'),
#  ('GOseq', 'Analysis'),
#  ('GPS Sample', 'DataCollection'),
#  ('GREAT', 'Analysis'),
#  ('GREAT', 'DataPreProcss'),
#  ('GRIMP', 'Analysis'),
#  ('GSEA', 'Analysis'),
#  ('GTX', 'Analysis'),
#  ('GeNorm', 'Analysis'),
#  ('GenAlEx', 'Analysis'),
#  ('GenCall', 'Analysis'),
#  ('GeneOverlap', 'Analysis'),
#  ('GenePix', 'Analysis'),
#  ('Geneious', 'Analysis'),
#  ('Geneious', 'DataPreProcss'),
#  ('Geneious', 'Modelling'),
#  ('Genescan', 'Analysis'),
#  ('Genevestigator', 'Analysis'),
#  ('Genome Analysis Toolkit', 'Analysis'),
#  ('Genome Variation Server', 'Analysis'),
#  ('Genome browser', 'Analysis'),
#  ('GenomeStudio', 'DataPreProcss'),
#  ('Genomics Suite', 'Analysis'),
#  ('Genomics Suite', 'DataPreProcss'),
#  ('GitHub', 'DataCollection'),
#  ('GlobalWorks', 'Stimulation'),
#  ('Globalpark', 'DataCollection'),
#  ('Globalpark', 'DataPreProcss'),
#  ('Goldwave', 'DataPreProcss'),
#  ('Google Earth', 'DataCollection'),
#  ('Gower', 'Analysis'),
#  ('GraphPad', 'Analysis'),
#  ('GraphPad', 'Visualization'),
#  ('H2O R interface', 'Analysis'),
#  ('HGF', 'Modelling'),
#  ('HTSeq', 'Analysis'),
#  ('HVS Image', 'Analysis'),
#  ('Habit 2000', 'DataCollection'),
#  ('Haplotype Reference Consortium', 'DataPreProcss'),
#  ('Haploview', 'Analysis'),
#  ('Haploview', 'DataCollection'),
#  ("Hawth's analysis tools for ArcGis", 'Modelling'),
#  ('HyPhy', 'Analysis'),
#  ('I-TASSER', 'Modelling'),
#  ('IBDWS', 'Analysis'),
#  ('ICC toolbox', 'Analysis'),
#  ('IMPUTE', 'DataPreProcss'),
#  ('ISC-toolbox', 'Analysis'),
#  ('IVICT', 'Analysis'),
#  ('Igor pro', 'Analysis'),
#  ('Igor pro', 'DataPreProcss'),
#  ('Illustrator', 'Analysis'),
#  ('Illustrator', 'Visualization'),
#  ('Image J', 'Analysis'),
#  ('Image J', 'DataCollection'),
#  ('Image J', 'DataPreProcss'),
#  ('Image J', 'Programming'),
#  ('Image J', 'Simulation'),
#  ('Image Lab', 'Analysis'),
#  ('Image-Pro Plus', 'Analysis'),
#  ('Image-Pro Plus', 'DataCollection'),
#  ('Image-Pro Plus', 'DataPreProcss'),
#  ('ImageQuant TL', 'Analysis'),
#  ('Imagelab', 'DataCollection'),
#  ('Imaris', 'Analysis'),
#  ('Imaris', 'DataPreProcss'),
#  ('Imaris', 'Visualization'),
#  ('Immunoratio', 'Analysis'),
#  ('Immunoratio', 'DataCollection'),
#  ('Immunoratio', 'Visualization'),
#  ('ImpaxEE', 'Analysis'),
#  ('Ingenuity', 'Analysis'),
#  ('Inquisit', 'Modelling'),
#  ('Inquisit', 'Programming'),
#  ('InsightII', 'Analysis'),
#  ('InsightII', 'Modelling'),
#  ('Instat', 'Analysis'),
#  ('InterPro', 'Analysis'),
#  ('Iox', 'Analysis'),
#  ('Iox', 'DataCollection'),
#  ('J-Express', 'DataPreProcss'),
#  ('JASP', 'Analysis'),
#  ('JMP', 'Analysis'),
#  ('JWatcher', 'Analysis'),
#  ('KING', 'Analysis'),
#  ('KING', 'DataPreProcss'),
#  ('KOBAS', 'Analysis'),
#  ('Ki67 Vv', 'DataPreProcss'),
#  ('Kubios', 'Analysis'),
#  ('Kubios', 'DataPreProcss'),
#  ('LAGRANGE', 'Modelling'),
#  ('LAS AF', 'DataCollection'),
#  ('LAS X', 'DataCollection'),
#  ('LAS X', 'DataPreProcss'),
#  ('LI-toolbox', 'Analysis'),
#  ('LSM imaging', 'Visualization'),
#  ('LabVIEW', 'DataCollection'),
#  ('Land Cover Classification System', 'Modelling'),
#  ('Large Average Submatricies', 'Analysis'),
#  ('Large Average Submatricies', 'Modelling'),
#  ('Ledalab', 'Analysis'),
#  ('LiDAR Analyst', 'Analysis'),
#  ('Librosa', 'Analysis'),
#  ('Linux Red Hat', 'Analysis'),
#  ('LogCombiner', 'DataPreProcss'),
#  ('Luminex 100 â„¢ IS', 'Analysis'),
#  ('MACS', 'Analysis'),
#  ('MAGMA', 'Analysis'),
#  ('MAGMA', 'Visualization'),
#  ('MASCOT', 'Analysis'),
#  ('MASCOT', 'Visualization'),
#  ('MAXQDA', 'Analysis'),
#  ('MAXQDA', 'DataCollection'),
#  ('MCMCglmm', 'Modelling'),
#  ('MCODE', 'Analysis'),
#  ('MEGA', 'Analysis'),
#  ('MEGA', 'DataCollection'),
#  ('MEGA', 'DataPreProcss'),
#  ('MEGA', 'Modelling'),
#  ('MEGA', 'Visualization'),
#  ('MELODIC', 'Analysis'),
#  ('MELODIC', 'DataPreProcss'),
#  ('MERLIN', 'Analysis'),
#  ('METACARPA', 'Analysis'),
#  ('METAL', 'Analysis'),
#  ('MICRO-CHECKER', 'Analysis'),
#  ('MICRO-CHECKER', 'DataPreProcss'),
#  ('MLRELATE', 'Analysis'),
#  ('MLwiN', 'Analysis'),
#  ('MLwiN', 'Modelling'),
#  ('MODELTEST', 'Analysis'),
#  ('MODELTEST', 'DataPreProcss'),
#  ('MODELTEST', 'Modelling'),
#  ('MOE', 'DataCollection'),
#  ('MOE', 'Simulation'),
#  ('MOE', 'Visualization'),
#  ('MORGAN', 'Analysis'),
#  ('MRBAYES', 'Analysis'),
#  ('MRBAYES', 'Modelling'),
#  ('MRBAYES', 'Visualization'),
#  ('MSIsensor', 'Analysis'),
#  ('MSM-All', 'Analysis'),
#  ('MSM-All', 'DataPreProcss'),
#  ('MSM-All', 'Modelling'),
#  ('MSOffice', 'DataCollection'),
#  ('MSstats', 'DataPreProcss'),
#  ('MUSCLE', 'Analysis'),
#  ('MUSCLE', 'DataPreProcss'),
#  ('Mac', 'Analysis'),
#  ('Mac', 'Stimulation'),
#  ('MacVide', 'Analysis'),
#  ('Mach', 'DataPreProcss'),
#  ('Mach2QTL', 'Analysis'),
#  ('MapIcosahedron', 'Modelling'),
#  ('MapInfo Professional', 'Visualization'),
#  ('MapWin', 'Analysis'),
#  ('MapWin', 'DataCollection'),
#  ('MapWin', 'DataPreProcss'),
#  ('MarsBar', 'DataCollection'),
#  ('MarsBar', 'Modelling'),
#  ('Mass Profiler Professional', 'Analysis'),
#  ('MassARRAY Assay Design', 'DataCollection'),
#  ('MassARRAY Assay Design', 'Modelling'),
#  ('MassHunter Acquisition', 'DataCollection'),
#  ('MassHunter Qualitative Analysis', 'DataPreProcss'),
#  ('Matlab', 'Analysis'),
#  ('Matlab', 'DataCollection'),
#  ('Matlab', 'DataPreProcss'),
#  ('Matlab', 'Modelling'),
#  ('Matlab', 'Programming'),
#  ('Matlab', 'Simulation'),
#  ('Matlab', 'Stimulation'),
#  ('Matplotlib', 'Visualization'),
#  ('Maxent', 'Analysis'),
#  ('Maxent', 'Modelling'),
#  ('Maxent', 'Programming'),
#  ('Mechanical Turk', 'DataCollection'),
#  ('Med-PC', 'DataCollection'),
#  ('Med-PC', 'Stimulation'),
#  ('MetaMorph', 'DataCollection'),
#  ('MetaMorph', 'DataPreProcss'),
#  ('Mimics', 'DataCollection'),
#  ('Minitab', 'Analysis'),
#  ('Mirdeep2', 'Analysis'),
#  ('Mirdeep2', 'DataCollection'),
#  ('Mixer', 'Modelling'),
#  ('ModFit', 'Analysis'),
#  ('Mothur', 'Analysis'),
#  ('Mothur', 'DataPreProcss'),
#  ('Mothur', 'Visualization'),
#  ('Mplus', 'Analysis'),
#  ('Mplus', 'Modelling'),
#  ('Mricron', 'Analysis'),
#  ('MuPeXI', 'DataPreProcss'),
#  ('MuTect', 'Analysis'),
#  ('MultiPak', 'DataPreProcss'),
#  ('Mutation Surveyor', 'DataCollection'),
#  ('MutationAssessor', 'Analysis'),
#  ('MutationalPatterns', 'Analysis'),
#  ('MyIQ', 'Analysis'),
#  ('NCSS', 'Analysis'),
#  ('NET', 'Programming'),
#  ('NEURON', 'Simulation'),
#  ('NIS', 'Analysis'),
#  ('NIS', 'DataPreProcss'),
#  ('NLME', 'Analysis'),
#  ('NLME', 'Modelling'),
#  ('NLTK', 'DataPreProcss'),
#  ('NQuery Advisor', 'Analysis'),
#  ('NetLogo', 'Modelling'),
#  ('NetMHCpan', 'DataPreProcss'),
#  ('Network', 'Analysis'),
#  ('Network', 'Visualization'),
#  ('NeuroDebian', 'Analysis'),
#  ('NeuroExplorer', 'Analysis'),
#  ('NeuroSynth', 'Analysis'),
#  ('NeuroSynth', 'DataCollection'),
#  ('Newbler', 'Analysis'),
#  ('Newborn Size Application', 'Analysis'),
#  ('Nilearn', 'DataPreProcss'),
#  ('Novoalign', 'DataCollection'),
#  ('Novoalign', 'DataPreProcss'),
#  ('Nvivo', 'Analysis'),
#  ('Nvivo', 'DataPreProcss'),
#  ('OOIBase', 'DataCollection'),
#  ('ORTEP', 'Visualization'),
#  ('Objective-C', 'Programming'),
#  ('Oligo Calc', 'Modelling'),
#  ('OntoFox', 'Analysis'),
#  ('Open Meta-Analyst', 'Analysis'),
#  ('Open sorter', 'Analysis'),
#  ('OpenCL', 'Programming'),
#  ('OpenEpi', 'Analysis'),
#  ('Openlab', 'DataCollection'),
#  ('OptimalCutpoints', 'Analysis'),
#  ('OriginLab', 'Modelling'),
#  ('OsiriX', 'Programming'),
#  ('PASS', 'Analysis'),
#  ('PAST', 'Analysis'),
#  ('PASW', 'Analysis'),
#  ('PASW', 'DataCollection'),
#  ('PASW', 'DataPreProcss'),
#  ('PASW', 'Modelling'),
#  ('PASW', 'Visualization'),
#  ('PAUP', 'Analysis'),
#  ('PAUP', 'Visualization'),
#  ('PBAP', 'Analysis'),
#  ('PCORD', 'Analysis'),
#  ('PEDSTATS', 'Analysis'),
#  ('PGA', 'Analysis'),
#  ('PHASE', 'Programming'),
#  ('PIVOT', 'Analysis'),
#  ('PLATON', 'DataPreProcss'),
#  ('PLINK', 'Analysis'),
#  ('PLINK', 'DataPreProcss'),
#  ('PLINK/SEQ', 'Analysis'),
#  ('PPI Network', 'Analysis'),
#  ('PRIMER', 'Analysis'),
#  ('PRIMER', 'Modelling'),
#  ('PROCESS', 'Analysis'),
#  ('Pajek', 'Analysis'),
#  ('Patch Analyst', 'DataCollection'),
#  ('Patchmaster', 'Analysis'),
#  ('Peakscanner', 'Analysis'),
#  ('PennCNV', 'Analysis'),
#  ('Perl', 'DataPreProcss'),
#  ('Photofiltre', 'Visualization'),
#  ('Photoshop', 'Analysis'),
#  ('Photoshop', 'DataPreProcss'),
#  ('Photoshop', 'Visualization'),
#  ('PhyML', 'Analysis'),
#  ('PhyML', 'Visualization'),
#  ('PhylopythiaS', 'Analysis'),
#  ('Picard', 'Analysis'),
#  ('Picard', 'DataCollection'),
#  ('Picard', 'DataPreProcss'),
#  ('Pickatlas', 'Analysis'),
#  ('Pickatlas', 'DataPreProcss'),
#  ('Pickatlas', 'Modelling'),
#  ('Pixelmator', 'Analysis'),
#  ('PolyPhen', 'Analysis'),
#  ('Polysolver', 'Analysis'),
#  ('Pong', 'Stimulation'),
#  ('PowerPoint', 'Visualization'),
#  ('Praat', 'Analysis'),
#  ('Praat', 'DataPreProcss'),
#  ('Praat', 'Simulation'),
#  ('Presentation', 'DataCollection'),
#  ('Presentation', 'Stimulation'),
#  ('Presentation', 'Visualization'),
#  ('Primer-BLAST', 'Modelling'),
#  ('ProctorU', 'Simulation'),
#  ('Prokaryotic Genomes Automatic Annotation Pipeline', 'DataPreProcss'),
#  ('Promasys', 'DataCollection'),
#  ('ProteomeWeaver', 'Analysis'),
#  ('ProtÃ©gÃ©', 'Visualization'),
#  ('PsychoPy', 'Simulation'),
#  ('PsychoPy', 'Visualization'),
#  ('Psychophysics Toolbox', 'Modelling'),
#  ('Psychophysics Toolbox', 'Programming'),
#  ('Psychophysics Toolbox', 'Stimulation'),
#  ('PyMOL', 'Visualization'),
#  ('PyMVPA', 'Analysis'),
#  ('PyRadiomics', 'Analysis'),
#  ('PyroTagger', 'Analysis'),
#  ('Python', 'Analysis'),
#  ('Python', 'Programming'),
#  ('Python', 'Stimulation'),
#  ('Python', 'Visualization'),
#  ('Q-LAB', 'DataCollection'),
#  ('QGIS', 'Analysis'),
#  ('QGIS', 'Visualization'),
#  ('QTL Express', 'Analysis'),
#  ('QUEST', 'Modelling'),
#  ('Quantity One', 'Analysis'),
#  ('Quanto', 'Analysis'),
#  ('Quicktime', 'Visualization'),
#  ('R Studio', 'Analysis'),
#  ('R-Scan', 'DataCollection'),
#  ('R/Qtl', 'Analysis'),
#  ('RDP Classifier', 'DataPreProcss'),
#  ('READ', 'Analysis'),
#  ('READ', 'DataPreProcss'),
#  ('READ', 'Modelling'),
#  ('REDCap', 'DataCollection'),
#  ('REST', 'DataPreProcss'),
#  ('RIU', 'DataCollection'),
#  ('ROCR', 'Analysis'),
#  ('RSeQC', 'Analysis'),
#  ('RT2 Profiler PCR Array Data analysis', 'Visualization'),
#  ('RTA', 'Analysis'),
#  ('RTN', 'Analysis'),
#  ('RabiesEcon', 'Analysis'),
#  ('RabiesEcon', 'DataCollection'),
#  ('RabiesEcon', 'Modelling'),
#  ('Rapid Annotation using Subsystem Technology', 'DataPreProcss'),
#  ('Reactome', 'Analysis'),
#  ('Remote Proctor Now', 'Simulation'),
#  ('Review Manager', 'Analysis'),
#  ('Revman', 'Analysis'),
#  ('Revman', 'Visualization'),
#  ('Rotor-Gene Q', 'Analysis'),
#  ('Rstan', 'Modelling'),
#  ('Rtsne', 'Analysis'),
#  ('RuleBender', 'Analysis'),
#  ('SADABS', 'DataPreProcss'),
#  ('SAINT', 'DataPreProcss'),
#  ('SAMSCo', 'Analysis'),
#  ('SAMSCo', 'DataPreProcss'),
#  ('SAS', 'Analysis'),
#  ('SAS', 'DataCollection'),
#  ('SAS', 'DataPreProcss'),
#  ('SAS', 'Modelling'),
#  ('SDMtoolbox', 'Analysis'),
#  ('SDMtoolbox', 'DataPreProcss'),
#  ('SHAPEITv', 'DataPreProcss'),
#  ('SHARP2', 'Analysis'),
#  ('SHELXL', 'Analysis'),
#  ('SHELXL', 'DataPreProcss'),
#  ('SILVA SINA', 'DataPreProcss'),
#  ('SIMCA-P', 'Analysis'),
#  ('SLINK', 'Analysis'),
#  ('SMART', 'Modelling'),
#  ('SMARTPCA', 'Analysis'),
#  ('SMRT analysis', 'Analysis'),
#  ('SNAP', 'DataCollection'),
#  ('SNPTEST', 'Analysis'),
#  ('SOCPROG', 'Analysis'),
#  ('SOCPROG', 'Programming'),
#  ('SOCPROG', 'Visualization'),
#  ('SPAGeDI', 'Analysis'),
#  ('SPLITSTREE', 'Analysis'),
#  ('SPM', 'Analysis'),
#  ('SPM', 'DataPreProcss'),
#  ('SPM', 'Modelling'),
#  ('STAR', 'DataPreProcss'),
#  ('STATA', 'Analysis'),
#  ('STATA', 'DataPreProcss'),
#  ('STATA', 'Modelling'),
#  ('STATA', 'Visualization'),
#  ('STATISTICA', 'Analysis'),
#  ('STATISTICA', 'Modelling'),
#  ('STRAIGHT', 'Stimulation'),
#  ('SUDAAN', 'Analysis'),
#  ('SUMA', 'Modelling'),
#  ('SUNDIALS', 'Analysis'),
#  ('Sailfish', 'DataCollection'),
#  ('Salmon', 'Analysis'),
#  ('Santa Cruz genome browser', 'Analysis'),
#  ('Satistix', 'Analysis'),
#  ('Scan', 'DataCollection'),
#  ('Scan', 'DataPreProcss'),
#  ('SciPy', 'Analysis'),
#  ('Scikit-learn', 'Analysis'),
#  ('Scikit-learn', 'Visualization'),
#  ('Scion image', 'DataPreProcss'),
#  ('Scope-Pro', 'DataCollection'),
#  ('ScopeWin', 'Analysis'),
#  ('Seattle Seq', 'DataPreProcss'),
#  ('Sente', 'DataCollection'),
#  ('SeqScape', 'Analysis'),
#  ('Sequence Scanner', 'Analysis'),
#  ('Sift', 'Analysis'),
#  ('Sightlines DxCG Risk Solutions', 'Analysis'),
#  ('Sigma plot', 'Analysis'),
#  ('Sigma plot', 'Visualization'),
#  ('SigmaStat', 'Analysis'),
#  ('SignalP', 'Modelling'),
#  ('Skeeter Buster', 'Modelling'),
#  ('Skeeter Buster', 'Simulation'),
#  ('Skyline', 'Analysis'),
#  ('Skyline', 'Modelling'),
#  ('SnpEff', 'Analysis'),
#  ('SnpEff', 'DataPreProcss'),
#  ('SnpEff', 'Modelling'),
#  ('SomaticSignatures', 'Analysis'),
#  ('Soscisurvey', 'Analysis'),
#  ('Soscisurvey', 'DataCollection'),
#  ('Spatial Analyst', 'Modelling'),
#  ('Spatial Statistics', 'Analysis'),
#  ('Spectrum Mill', 'Analysis'),
#  ('Spectrum Mill', 'DataPreProcss'),
#  ('Sperm Class Analyzer', 'Analysis'),
#  ('Stan', 'Analysis'),
#  ('Stan', 'Modelling'),
#  ('Statistical Toolbox', 'Modelling'),
#  ('Statview', 'Analysis'),
#  ('Stella', 'Programming'),
#  ('Stereo investigator', 'DataCollection'),
#  ('Strand7', 'DataCollection'),
#  ('Strand7', 'Visualization'),
#  ('Structure', 'Analysis'),
#  ('Structure', 'Modelling'),
#  ('Subread', 'DataCollection'),
#  ('Surfer', 'Visualization'),
#  ('Survival', 'Analysis'),
#  ('T-LoCoH', 'Analysis'),
#  ('T-LoCoH', 'Simulation'),
#  ('TANRIC', 'Analysis'),
#  ('TAPAS', 'Modelling'),
#  ('TBSS', 'Analysis'),
#  ('TGAME', 'Stimulation'),
#  ('TRACER', 'Analysis'),
#  ('TRANS-TOOLS', 'DataCollection'),
#  ('Tailarach Daemon', 'DataPreProcss'),
#  ('TargetScan', 'Analysis'),
#  ('TargetScan', 'Modelling'),
#  ('TensorFlow', 'Analysis'),
#  ('TopSpin', 'Analysis'),
#  ('Tophat', 'DataPreProcss'),
#  ('ToppFun', 'Analysis'),
#  ('TouchStat', 'Analysis'),
#  ('ToupView', 'DataCollection'),
#  ('TrackVis', 'Modelling'),
#  ('TreeAnnotator', 'Visualization'),
#  ('Treeview', 'Analysis'),
#  ('Treeview', 'Visualization'),
#  ('Trim Galore', 'DataPreProcss'),
#  ('Trimmomatic', 'DataPreProcss'),
#  ('TurkPrime', 'DataCollection'),
#  ('Twitter', 'DataCollection'),
#  ('VA Computerized Patient Record System', 'DataCollection'),
#  ('VAX', 'DataPreProcss'),
#  ('VIP', 'Analysis'),
#  ('VPixx', 'Stimulation'),
#  ('VarScan', 'Analysis'),
#  ('Variant Effect Predictor', 'Modelling'),
#  ('Vegan', 'Analysis'),
#  ('Vegan', 'Visualization'),
#  ('Venny', 'Analysis'),
#  ('Venny', 'Visualization'),
#  ('Videomot', 'Analysis'),
#  ('Videotrack', 'Analysis'),
#  ('Videotrack', 'DataCollection'),
#  ('ViewPoint', 'DataCollection'),
#  ('Virtuoso', 'Analysis'),
#  ('Visilog', 'Analysis'),
#  ('Visilog', 'DataCollection'),
#  ('Visiopharm', 'Analysis'),
#  ('Visiopharm', 'DataPreProcss'),
#  ('Visual Basic', 'Programming'),
#  ('Visual C++', 'Programming'),
#  ('Visual Studio', 'Programming'),
#  ('Volume 1', 'Analysis'),
#  ('Waikato Environment for Knowledge Analysis', 'Modelling'),
#  ('Win', 'Analysis'),
#  ('Win', 'DataCollection'),
#  ('Win', 'Stimulation'),
#  ('Win', 'Visualization'),
#  ('WinEEG', 'DataCollection'),
#  ('WinEpiscope', 'Analysis'),
#  ('Windows Mobile', 'DataCollection'),
#  ('XHMM', 'Analysis'),
#  ('XHMM', 'DataPreProcss'),
#  ('Xcalibur', 'Stimulation'),
#  ('Xena', 'Analysis'),
#  ('Xena', 'DataCollection'),
#  ('Yahoo-BOSS', 'DataPreProcss'),
#  ('ZEN', 'DataPreProcss'),
#  ('ZSCORE06', 'Analysis'),
#  ('adjustedRandIndex', 'Analysis'),
#  ('articulatory synthesizer', 'Simulation'),
#  ('bam-readcount', 'Analysis'),
#  ('bcl2fastq2', 'DataPreProcss'),
#  ('bedtools', 'DataPreProcss'),
#  ('bipartite', 'Analysis'),
#  ('bnlearn', 'Modelling'),
#  ('boot', 'Modelling'),
#  ('car', 'Analysis'),
#  ('caret', 'Analysis'),
#  ('cellSens Dimension', 'DataCollection'),
#  ('clam', 'Modelling'),
#  ('clam', 'Visualization'),
#  ('clusterMaker', 'Visualization'),
#  ('cnvHap', 'Analysis'),
#  ('consensus MIBC', 'Modelling'),
#  ('convert', 'DataPreProcss'),
#  ('cutadapt', 'DataPreProcss'),
#  ('dcm4che', 'Programming'),
#  ('dcm4chee', 'Programming'),
#  ('dismo', 'Modelling'),
#  ('dplyr', 'Analysis'),
#  ('dual regression', 'Analysis'),
#  ('eRM', 'Analysis'),
#  ('edge', 'Modelling'),
#  ('edgeR', 'Analysis'),
#  ('epidata', 'DataCollection'),
#  ('fmsb', 'Visualization'),
#  ('geo-spatial modeling environment', 'Analysis'),
#  ('geographic information system', 'Analysis'),
#  ('ggplot2', 'Visualization'),
#  ('glmnet', 'Analysis'),
#  ('gplots', 'Analysis'),
#  ('gpu-lasso', 'Analysis'),
#  ('h2oEnsemble', 'Modelling'),
#  ('iDataFax', 'DataCollection'),
#  ('iGenomes', 'DataPreProcss'),
#  ('iQ5 Optical system', 'Analysis'),
#  ('iTeva', 'Analysis'),
#  ('iView X', 'DataCollection'),
#  ('image processing toolbox', 'Stimulation'),
#  ('immunoSEQ Analyzer', 'Analysis'),
#  ('irr', 'Analysis'),
#  ('lattice', 'Analysis'),
#  ('lme4', 'Analysis'),
#  ('lme4', 'Modelling'),
#  ('mRMRe', 'Analysis'),
#  ('map2stan', 'Modelling'),
#  ('mgcv', 'Analysis'),
#  ('mgcv', 'Programming'),
#  ('miRDB', 'Analysis'),
#  ('miRDB', 'Modelling'),
#  ('mice', 'Analysis'),
#  ('mice', 'DataPreProcss'),
#  ('microRNA', 'Modelling'),
#  ('migrate', 'Modelling'),
#  ('mitml', 'Analysis'),
#  ('mrsFAST', 'Modelling'),
#  ('mtPhyl', 'Analysis'),
#  ('netcarto', 'Analysis'),
#  ('openMEEG', 'Modelling'),
#  ('ordinal', 'Analysis'),
#  ('pClamp', 'Analysis'),
#  ('pClamp', 'DataCollection'),
#  ('pROC', 'Modelling'),
#  ('principal component analysis spike sorter', 'Analysis'),
#  ('psych', 'Analysis'),
#  ('qBase', 'Analysis'),
#  ('qBase', 'DataPreProcss'),
#  ('quantregForest', 'Analysis'),
#  ('qxpak', 'Analysis'),
#  ('raster', 'Programming'),
#  ('rgdal', 'Programming'),
#  ('rioja', 'Analysis'),
#  ('rms', 'Analysis'),
#  ('rpart', 'Analysis'),
#  ('runmlwin', 'Modelling'),
#  ('sLORETA', 'Analysis'),
#  ('sLORETA', 'DataCollection'),
#  ('samtools', 'Analysis'),
#  ('samtools', 'DataPreProcss'),
#  ('samtools', 'Modelling'),
#  ('sensitivity', 'Analysis'),
#  ('sickle', 'DataPreProcss'),
#  ('skewer', 'DataPreProcss'),
#  ('survC1', 'Analysis'),
#  ('survcomp', 'Analysis'),
#  ('survminer', 'Analysis'),
#  ('threshold-free cluster enhancement', 'DataPreProcss'),
#  ('tidyr', 'Analysis'),
#  ('tnet', 'Analysis'),
#  ('tximport', 'Analysis'),
#  ('vcftools', 'Analysis'),
#  ('waver', 'Analysis'),
#  ('xCell', 'Analysis')]

# %%
'''
create a dict that stores 

SoftwareName : list of purposes

'''

sw_name_purpose = {}


for sw_Name, sw_purposes in liT:
    
    sw_name_purpose.setdefault(sw_Name, []).append(sw_purposes)
    
#sw_name_purpose

# %%
'''
create a dict that stores 

SoftwareName : purpose count

'''

sw_pcount = {}

for sw in list(sw_name_purpose):
    sw_pcount[sw] = len(sw_name_purpose.get(sw))

# %%
pCount = pd.DataFrame(sw_pcount.items(), columns=['SwName', 'Purpose_Count'])
pCount
# Out:
#            SwName  Purpose_Count
# 0             2LD              1
# 1      3dBandpass              1
# 2      3dClustsim              1
# 3    3dDeconvolve              1
# 4       3dDespike              1
# ..            ...            ...
# 652          tnet              1
# 653      tximport              1
# 654      vcftools              1
# 655         waver              1
# 656         xCell              1
#
# [657 rows x 2 columns]

# %%
# aggregate by pcount

pCount_ag = pCount.groupby(['Purpose_Count']).size().reset_index(name='SoftwareCount')
pCount_ag = pCount_ag.set_index('Purpose_Count')
pCount_ag
# Out:
#                SoftwareCount
# Purpose_Count
# 1                        505
# 2                        107
# 3                         30
# 4                          9
# 5                          4
# 6                          1
# 7                          1

# %%
# rename index for clarity on the visualization

pCount_ag = pCount_ag.rename(index={1: '1 Purpose', 
                                2: '2 Purpose',
                                3: '3 Purpose',
                                4: '4 Purpose',
                                5: '5 Purpose',
                                6: '6 Purpose',
                                7: '7 Purpose',
                                8: '8 Purpose',})

pCount_ag
# Out:
#                SoftwareCount
# Purpose_Count
# 1 Purpose                505
# 2 Purpose                107
# 3 Purpose                 30
# 4 Purpose                  9
# 5 Purpose                  4
# 6 Purpose                  1
# 7 Purpose                  1

# %%
import matplotlib.pyplot as plt

# plot style
plt.style.use("seaborn-deep")

fig, ax = plt.subplots(figsize=(10, 5))



val_pc = pCount_ag['SoftwareCount'].values
ind_pc = pCount_ag['SoftwareCount'].index


ax.bar(ind_pc,val_pc, align='center')


# labels
ax.set_title("Software with purpose counts")
ax.set_ylabel("Counts of software")
ax.set_xlabel("Counts of Purposes")

ax.set_xticklabels(ind_pc, rotation=15)


#ax.invert_yaxis()
plt.grid(color='grey', linestyle='-.', linewidth=0.3)
plt.show()

fig.tight_layout()
fig.savefig("Ananlysis_output_pngs/7.counts of software purpose.png", dpi = 130)
# Out:
# C:\Users\Beck\AppData\Local\Temp\ipykernel_10056\4257582796.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ind_pc, rotation=15)

# %%
# visualize the shre of resources pie-chart

import matplotlib.pyplot as plt

# plot style
plt.style.use("seaborn-deep")
fig, ax = plt.subplots(figsize=(10, 5), subplot_kw=dict(aspect="equal"))

# Data to plot


label = pCount_ag['SoftwareCount'].index
x     = pCount_ag['SoftwareCount'].values

explode = (0.1, 0.1, 0.1,0.3, 0.5, 0.7, 0.9)  # explode 1st slice


plt.pie(x,explode=explode,autopct='%1.1f%%', shadow=True, startangle=55)

# annotate
plt.legend(label, loc="best")

ax.set_title("counts of software purpose")
plt.axis('equal')

fig.tight_layout()
fig.savefig("Ananlysis_output_pngs/8.counts of software purpose pie.png", dpi = 130)

plt.show()

# %% [markdown]
# ### Analysis #6: Software `Name Type`

# %%
SwNT = PubMedPLoS_swNTP.groupby(['Sw_Name','Type']).size().reset_index(name='Count')



SwNT_dsc = SwNT.sort_values(by=['Count','Type', 'Sw_Name'], ascending=False)

SwNT_dsc
# Out:
#         Sw_Name                    Type  Count
# 380        PASW             Application    129
# 211       GNU R  ProgrammingEnvironment     91
# 477       STATA             Application     76
# 326      Matlab  ProgrammingEnvironment     68
# 459         SAS             Application     52
# ..          ...                     ...    ...
# 14         AMIX             Application      1
# 13   AMBERTOOLS             Application      1
# 11     ADMIXMAP             Application      1
# 10        ADAPT             Application      1
# 0           2LD             Application      1
#
# [657 rows x 3 columns]

# %% [markdown]
# ### Analysis #7: Software `[Name, Type, Purpose]`

# %%
# Aggregate by multiple columns 


SwNTP_agg = PubMedPLoS_swNTP.groupby(['Sw_Name','Type', 'Purpose']).size().reset_index(name='Count')



SwNTP_agg_dsc = SwNTP_agg.sort_values(by=['Purpose','Type','Sw_Name'], ascending=True)

# top 10 Apps,PE, Os
SwNTP_agg_dsc.head(20)
# Out:
#                                              Sw_Name         Type   Purpose  \
# 0                                                2LD  Application  Analysis
# 14                                              AFNI  Application  Analysis
# 18                                        AMBERTOOLS  Application  Analysis
# 19                                              AMIX  Application  Analysis
# 20                                              AMOS  Application  Analysis
# 25                                          ATLAS.ti  Application  Analysis
# 31                                          Actiware  Application  Analysis
# 37                                           Analyst  Application  Analysis
# 40                                          Aninhado  Application  Analysis
# 41                                            ArcGis  Application  Analysis
# 48                                          Arlequin  Application  Analysis
# 52                                            AsReml  Application  Analysis
# 54                                     Autodock Vina  Application  Analysis
# 58                                       BD FACSDiva  Application  Analysis
# 59                                            BEAGLE  Application  Analysis
# 61                                          BOLT-LMM  Application  Analysis
# 62                                        BOTTLENECK  Application  Analysis
# 66                 Basic Local Alignment Search Tool  Application  Analysis
# 70  Bayesian Evolutionary Analysis by Sampling Trees  Application  Analysis
# 73                                        BeadStudio  Application  Analysis
#
#     Count
# 0       1
# 14      4
# 18      1
# 19      1
# 20      1
# 25      2
# 31      1
# 37      1
# 40      1
# 41      4
# 48     12
# 52      1
# 54      1
# 58      1
# 59      2
# 61      1
# 62      3
# 66     12
# 70      1
# 73      1

# %%
from articlenizer.formatting import brat_to_bio

# %%
with open("PMC3004789PP.ann", "r") as txt_f:

    ann_cont = txt_f.read()

    print(ann_cont)
    
with open("PMC3004789.txt", "r") as txt_f:
        
        txt_cont = txt_f.read()
        
        #print(txt_cont)
        

output = brat_to_bio(txt_cont, ann_cont)
# Out:
# T1	Application_Usage:Purpose_Analysis 4470 4473	JMP
# T2	Application_Usage:Purpose_Analysis 4475 4478	JMP
# R1	Specification_of Arg1:T2 Arg2:T1
# T3	Version 4479 4482	7.0
# R2	Version_of Arg1:T3 Arg2:T2
# T4	Developer 4484 4502	SAS Institute Inc.
# R3	Developer_of Arg1:T4 Arg2:T2
#
# Annotation does not match the token split, token: analysis, entities: {'T1': {'label': 'Application_Usage:Purpose_Analysis', 'beg': 16, 'end': 19, 'string': 'ysi', 'idx': 0}, 'T2': {'label': 'Application_Usage:Purpose_Analysis', 'beg': 21, 'end': 24, 'string': 'was', 'idx': 1}, 'T3': {'label': 'Version', 'beg': 25, 'end': 28, 'string': 'per', 'idx': 2}, 'T4': {'label': 'Developer', 'beg': 30, 'end': 48, 'string': 'rmed using JMP (JM', 'idx': 3}}
# Treating as B..
# Annotation does not match the token split, token: performed, entities: {'T1': {'label': 'Application_Usage:Purpose_Analysis', 'beg': 16, 'end': 19, 'string': 'ysi', 'idx': 0, 'new_beg': 12, 'new_end': 20}, 'T2': {'label': 'Application_Usage:Purpose_Analysis', 'beg': 21, 'end': 24, 'string': 'was', 'idx': 1, 'new_beg': 21, 'new_end': 24}, 'T3': {'label': 'Version', 'beg': 25, 'end': 28, 'string': 'per', 'idx': 2, 'new_beg': 25, 'new_end': 34}, 'T4': {'label': 'Developer', 'beg': 30, 'end': 48, 'string': 'rmed using JMP (JM', 'idx': 3}}
# Treating as B..
# Annotation does not match the token split, token: JMP, entities: {'T1': {'label': 'Application_Usage:Purpose_Analysis', 'beg': 16, 'end': 19, 'string': 'ysi', 'idx': 0, 'new_beg': 12, 'new_end': 20}, 'T2': {'label': 'Application_Usage:Purpose_Analysis', 'beg': 21, 'end': 24, 'string': 'was', 'idx': 1, 'new_beg': 21, 'new_end': 24}, 'T3': {'label': 'Version', 'beg': 25, 'end': 28, 'string': 'per', 'idx': 2, 'new_beg': 25, 'new_end': 34}, 'T4': {'label': 'Developer', 'beg': 30, 'end': 48, 'string': 'rmed using JMP (JM', 'idx': 3, 'new_beg': 25, 'new_end': 46}}
# Treating as B..

# %%
output
# Out:
# [{'string': 'The study protocol was approved by the Ethics Committee of the International Foundation for the Albert Schweitzer Hospital in LambarA™nA™.',
#   'tokens': ['The',
#    'study',
#    'protocol',
#    'was',
#    'approved',
#    'by',
#    'the',
#    'Ethics',
#    'Committee',
#    'of',
#    'the',
#    'International',
#    'Foundation',
#    'for',
#    'the',
#    'Albert',
#    'Schweitzer',
#    'Hospital',
#    'in',
#    'LambarA',
#    '™',
#    'nA',
#    '™',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Written informed consent was sought from the mother and the guardian accompanying the patient to the hospital.',
#   'tokens': ['Written',
#    'informed',
#    'consent',
#    'was',
#    'sought',
#    'from',
#    'the',
#    'mother',
#    'and',
#    'the',
#    'guardian',
#    'accompanying',
#    'the',
#    'patient',
#    'to',
#    'the',
#    'hospital',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Study design, study site, participants: From May 2005 to September 2006 a cross-sectional study in women delivering at the obstetric departments of local hospitals in the cities of Libreville (Centre Hospitalier de Libreville) and LambarA™nA™ (HApital RA™gional de LambarA™nA™ and Albert Schweitzer Hospital) was conducted in the Central African country Gabon.',
#   'tokens': ['Study',
#    'design',
#    ',',
#    'study',
#    'site',
#    ',',
#    'participants',
#    ':',
#    'From',
#    'May',
#    '2005',
#    'to',
#    'September',
#    '2006',
#    'a',
#    'cross',
#    '-',
#    'sectional',
#    'study',
#    'in',
#    'women',
#    'delivering',
#    'at',
#    'the',
#    'obstetric',
#    'departments',
#    'of',
#    'local',
#    'hospitals',
#    'in',
#    'the',
#    'cities',
#    'of',
#    'Libreville',
#    '(',
#    'Centre',
#    'Hospitalier',
#    'de',
#    'Libreville',
#    ')',
#    'and',
#    'LambarA',
#    '™',
#    'nA',
#    '™',
#    '(',
#    'HApital',
#    'RA',
#    '™',
#    'gional',
#    'de',
#    'LambarA',
#    '™',
#    'nA',
#    '™',
#    'and',
#    'Albert',
#    'Schweitzer',
#    'Hospital',
#    ')',
#    'was',
#    'conducted',
#    'in',
#    'the',
#    'Central',
#    'African',
#    'country',
#    'Gabon',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'The region is characterized by perennial high transmission of Plasmodium falciparum malaria [17], [18].',
#   'tokens': ['The',
#    'region',
#    'is',
#    'characterized',
#    'by',
#    'perennial',
#    'high',
#    'transmission',
#    'of',
#    'Plasmodium',
#    'falciparum',
#    'malaria',
#    '[17]',
#    ',',
#    '[18]',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Intermittent preventive treatment in pregnancy with sulfadoxine-pyrimethamine and the use of insecticide treated bednets have been adopted as national policy for the prevention of malaria in pregnancy since 2005.',
#   'tokens': ['Intermittent',
#    'preventive',
#    'treatment',
#    'in',
#    'pregnancy',
#    'with',
#    'sulfadoxine',
#    '-',
#    'pyrimethamine',
#    'and',
#    'the',
#    'use',
#    'of',
#    'insecticide',
#    'treated',
#    'bednets',
#    'have',
#    'been',
#    'adopted',
#    'as',
#    'national',
#    'policy',
#    'for',
#    'the',
#    'prevention',
#    'of',
#    'malaria',
#    'in',
#    'pregnancy',
#    'since',
#    '2005',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'HIV prevalence among pregnant women is estimated to be between 5% and 10%.',
#   'tokens': ['HIV',
#    'prevalence',
#    'among',
#    'pregnant',
#    'women',
#    'is',
#    'estimated',
#    'to',
#    'be',
#    'between',
#    '5',
#    '%',
#    'and',
#    '10',
#    '%',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Libreville a€“ the capital of Gabon a€“is a typical Central African city whereas LambarA™nA™ a€“ situated approximately 300 km inland a€“ is characterized by a semi-urban environment and is located in a predominantly rural province.',
#   'tokens': ['Libreville',
#    'a',
#    '€',
#    '“',
#    'the',
#    'capital',
#    'of',
#    'Gabon',
#    'a',
#    '€',
#    '“',
#    'is',
#    'a',
#    'typical',
#    'Central',
#    'African',
#    'city',
#    'whereas',
#    'LambarA',
#    '™',
#    'nA',
#    '™',
#    'a',
#    '€',
#    '“',
#    'situated',
#    'approximately',
#    '300',
#    'km',
#    'inland',
#    'a',
#    '€',
#    '“',
#    'is',
#    'characterized',
#    'by',
#    'a',
#    'semi',
#    '-',
#    'urban',
#    'environment',
#    'and',
#    'is',
#    'located',
#    'in',
#    'a',
#    'predominantly',
#    'rural',
#    'province',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Women in labour attending the hospital for delivery were eligible for participation in this survey.',
#   'tokens': ['Women',
#    'in',
#    'labour',
#    'attending',
#    'the',
#    'hospital',
#    'for',
#    'delivery',
#    'were',
#    'eligible',
#    'for',
#    'participation',
#    'in',
#    'this',
#    'survey',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Information on maternal age, last date of menstruation, parity, number of antenatal consultations, use of bednets during pregnancy and intake of sulfadoxine-pyrimethamine for intermittent preventive treatment of malaria were collected in structured interviews and from mother-child health booklets.',
#   'tokens': ['Information',
#    'on',
#    'maternal',
#    'age',
#    ',',
#    'last',
#    'date',
#    'of',
#    'menstruation',
#    ',',
#    'parity',
#    ',',
#    'number',
#    'of',
#    'antenatal',
#    'consultations',
#    ',',
#    'use',
#    'of',
#    'bednets',
#    'during',
#    'pregnancy',
#    'and',
#    'intake',
#    'of',
#    'sulfadoxine',
#    '-',
#    'pyrimethamine',
#    'for',
#    'intermittent',
#    'preventive',
#    'treatment',
#    'of',
#    'malaria',
#    'were',
#    'collected',
#    'in',
#    'structured',
#    'interviews',
#    'and',
#    'from',
#    'mother',
#    '-',
#    'child',
#    'health',
#    'booklets',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'A thick blood smear for the diagnosis of malaria was performed as well as maternal haemoglobin measurements (CellDyn 3000, Abbott Laboratories, Santa Clara, CA).',
#   'tokens': ['A',
#    'thick',
#    'blood',
#    'smear',
#    'for',
#    'the',
#    'diagnosis',
#    'of',
#    'malaria',
#    'was',
#    'performed',
#    'as',
#    'well',
#    'as',
#    'maternal',
#    'haemoglobin',
#    'measurements',
#    '(',
#    'CellDyn',
#    '3000',
#    ',',
#    'Abbott',
#    'Laboratories',
#    ',',
#    'Santa',
#    'Clara',
#    ',',
#    'CA',
#    ')',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'All newborns were weighed immediately after birth and birth outcome was evaluated by the midwife in charge of the delivering women.',
#   'tokens': ['All',
#    'newborns',
#    'were',
#    'weighed',
#    'immediately',
#    'after',
#    'birth',
#    'and',
#    'birth',
#    'outcome',
#    'was',
#    'evaluated',
#    'by',
#    'the',
#    'midwife',
#    'in',
#    'charge',
#    'of',
#    'the',
#    'delivering',
#    'women',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Only women giving birth to live singletons were considered for analysis.',
#   'tokens': ['Only',
#    'women',
#    'giving',
#    'birth',
#    'to',
#    'live',
#    'singletons',
#    'were',
#    'considered',
#    'for',
#    'analysis',
#    '.'],
#   'names': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'labels': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Data were captured on paper record forms and reviewed manually before analysis.',
#   'tokens': ['Data',
#    'were',
#    'captured',
#    'on',
#    'paper',
#    'record',
#    'forms',
#    'and',
#    'reviewed',
#    'manually',
#    'before',
#    'analysis',
#    '.'],
#   'names': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'labels': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Outcome variables, definitions and statistical analysis: The aim of the statistical analysis was to evaluate differences in pregnancy characteristics and birth outcomes of adolescent versus adult women.',
#   'tokens': ['Outcome',
#    'variables',
#    ',',
#    'definitions',
#    'and',
#    'statistical',
#    'analysis',
#    ':',
#    'The',
#    'aim',
#    'of',
#    'the',
#    'statistical',
#    'analysis',
#    'was',
#    'to',
#    'evaluate',
#    'differences',
#    'in',
#    'pregnancy',
#    'characteristics',
#    'and',
#    'birth',
#    'outcomes',
#    'of',
#    'adolescent',
#    'versus',
#    'adult',
#    'women',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Adolescent status was defined as an age of or below 16 years at delivery.',
#   'tokens': ['Adolescent',
#    'status',
#    'was',
#    'defined',
#    'as',
#    'an',
#    'age',
#    'of',
#    'or',
#    'below',
#    '16',
#    'years',
#    'at',
#    'delivery',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'The number of antenatal consultations, use of bednet during pregnancy, intake of sulfadoxine-pyrimethamine for intermittent preventive treatment of malaria, maternal haemoglobin at delivery, and peripheral parasitaemia at delivery were specified as main pregnancy characteristics.',
#   'tokens': ['The',
#    'number',
#    'of',
#    'antenatal',
#    'consultations',
#    ',',
#    'use',
#    'of',
#    'bednet',
#    'during',
#    'pregnancy',
#    ',',
#    'intake',
#    'of',
#    'sulfadoxine',
#    '-',
#    'pyrimethamine',
#    'for',
#    'intermittent',
#    'preventive',
#    'treatment',
#    'of',
#    'malaria',
#    ',',
#    'maternal',
#    'haemoglobin',
#    'at',
#    'delivery',
#    ',',
#    'and',
#    'peripheral',
#    'parasitaemia',
#    'at',
#    'delivery',
#    'were',
#    'specified',
#    'as',
#    'main',
#    'pregnancy',
#    'characteristics',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Continuous and categorical measures of birth weight and gestational age at delivery were defined as main birth outcome variables.',
#   'tokens': ['Continuous',
#    'and',
#    'categorical',
#    'measures',
#    'of',
#    'birth',
#    'weight',
#    'and',
#    'gestational',
#    'age',
#    'at',
#    'delivery',
#    'were',
#    'defined',
#    'as',
#    'main',
#    'birth',
#    'outcome',
#    'variables',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Gestational age was calculated based on the last date of menses as reported by the pregnant women.',
#   'tokens': ['Gestational',
#    'age',
#    'was',
#    'calculated',
#    'based',
#    'on',
#    'the',
#    'last',
#    'date',
#    'of',
#    'menses',
#    'as',
#    'reported',
#    'by',
#    'the',
#    'pregnant',
#    'women',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Birth weight below 2500g was defined as low birth weight and deliveries before 37 weeks of gestation were classified as preterm deliveries.',
#   'tokens': ['Birth',
#    'weight',
#    'below',
#    '2500g',
#    'was',
#    'defined',
#    'as',
#    'low',
#    'birth',
#    'weight',
#    'and',
#    'deliveries',
#    'before',
#    '37',
#    'weeks',
#    'of',
#    'gestation',
#    'were',
#    'classified',
#    'as',
#    'preterm',
#    'deliveries',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': "Univariable analysis of epidemiological data for the two groups (adolescent and adult pregnant women) was performed by Student's t-test at a two-sided significance level of formtok for continuous variables and odds ratios for categorical variables.",
#   'tokens': ['Univariable',
#    'analysis',
#    'of',
#    'epidemiological',
#    'data',
#    'for',
#    'the',
#    'two',
#    'groups',
#    '(',
#    'adolescent',
#    'and',
#    'adult',
#    'pregnant',
#    'women',
#    ')',
#    'was',
#    'performed',
#    'by',
#    'Student',
#    "'",
#    's',
#    't',
#    '-',
#    'test',
#    'at',
#    'a',
#    'two',
#    '-',
#    'sided',
#    'significance',
#    'level',
#    'of',
#    'formtok',
#    'for',
#    'continuous',
#    'variables',
#    'and',
#    'odds',
#    'ratios',
#    'for',
#    'categorical',
#    'variables',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Since parity is a known risk factor for low birth weight an analysis of nulliparous adolescent and adult mothers was performed to correct for differences in parity between the two groups.',
#   'tokens': ['Since',
#    'parity',
#    'is',
#    'a',
#    'known',
#    'risk',
#    'factor',
#    'for',
#    'low',
#    'birth',
#    'weight',
#    'an',
#    'analysis',
#    'of',
#    'nulliparous',
#    'adolescent',
#    'and',
#    'adult',
#    'mothers',
#    'was',
#    'performed',
#    'to',
#    'correct',
#    'for',
#    'differences',
#    'in',
#    'parity',
#    'between',
#    'the',
#    'two',
#    'groups',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'In addition a separate analysis of differences in birth weight was carried out in the subset of term-newborns in order to account for the strong influence of preterm delivery on the occurrence of low birth weight.',
#   'tokens': ['In',
#    'addition',
#    'a',
#    'separate',
#    'analysis',
#    'of',
#    'differences',
#    'in',
#    'birth',
#    'weight',
#    'was',
#    'carried',
#    'out',
#    'in',
#    'the',
#    'subset',
#    'of',
#    'term',
#    '-',
#    'newborns',
#    'in',
#    'order',
#    'to',
#    'account',
#    'for',
#    'the',
#    'strong',
#    'influence',
#    'of',
#    'preterm',
#    'delivery',
#    'on',
#    'the',
#    'occurrence',
#    'of',
#    'low',
#    'birth',
#    'weight',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Finally, a comparative graphical analysis of birth weight for each completed week of gestation was performed in the subset of term-newborns to appreciate potential differences of growth retardation in adolescent and adult mothers over time.',
#   'tokens': ['Finally',
#    ',',
#    'a',
#    'comparative',
#    'graphical',
#    'analysis',
#    'of',
#    'birth',
#    'weight',
#    'for',
#    'each',
#    'completed',
#    'week',
#    'of',
#    'gestation',
#    'was',
#    'performed',
#    'in',
#    'the',
#    'subset',
#    'of',
#    'term',
#    '-',
#    'newborns',
#    'to',
#    'appreciate',
#    'potential',
#    'differences',
#    'of',
#    'growth',
#    'retardation',
#    'in',
#    'adolescent',
#    'and',
#    'adult',
#    'mothers',
#    'over',
#    'time',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'To further analyse the impact of adolescent pregnancy on low birth weight multivariable logistic regression analysis was performed.',
#   'tokens': ['To',
#    'further',
#    'analyse',
#    'the',
#    'impact',
#    'of',
#    'adolescent',
#    'pregnancy',
#    'on',
#    'low',
#    'birth',
#    'weight',
#    'multivariable',
#    'logistic',
#    'regression',
#    'analysis',
#    'was',
#    'performed',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'For this purpose statistical significance of variables associated with low birth weight was computed.',
#   'tokens': ['For',
#    'this',
#    'purpose',
#    'statistical',
#    'significance',
#    'of',
#    'variables',
#    'associated',
#    'with',
#    'low',
#    'birth',
#    'weight',
#    'was',
#    'computed',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Known risk factors for low birth weight and variables showing a statistically significant association with low birth weight in our study population were included as dichotomized variables in the logistic regression analysis.',
#   'tokens': ['Known',
#    'risk',
#    'factors',
#    'for',
#    'low',
#    'birth',
#    'weight',
#    'and',
#    'variables',
#    'showing',
#    'a',
#    'statistically',
#    'significant',
#    'association',
#    'with',
#    'low',
#    'birth',
#    'weight',
#    'in',
#    'our',
#    'study',
#    'population',
#    'were',
#    'included',
#    'as',
#    'dichotomized',
#    'variables',
#    'in',
#    'the',
#    'logistic',
#    'regression',
#    'analysis',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Data are displayed as mean (A±standard deviation) or median (A±interquartile range).',
#   'tokens': ['Data',
#    'are',
#    'displayed',
#    'as',
#    'mean',
#    '(',
#    'A',
#    '±',
#    'standard',
#    'deviation',
#    ')',
#    'or',
#    'median',
#    '(',
#    'A',
#    '±',
#    'interquartile',
#    'range',
#    ')',
#    '.'],
#   'names': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {},
#   'relations': {}},
#  {'string': 'Statistical analysis was performed using JMP (JMP 7.0, SAS Institute Inc., NC, USA).',
#   'tokens': ['Statistical',
#    'analysis',
#    'was',
#    'performed',
#    'using',
#    'JMP',
#    '(',
#    'JMP',
#    '7.0',
#    ',',
#    'SAS',
#    'Institute',
#    'Inc',
#    '.',
#    ',',
#    'NC',
#    ',',
#    'USA',
#    ')',
#    '.'],
#   'names': ['O',
#    'T1',
#    'T2',
#    'T4',
#    'T4',
#    'T4',
#    'T4',
#    'T4',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'labels': ['O',
#    'B-Application_Usage:Purpose_Analysis',
#    'B-Application_Usage:Purpose_Analysis',
#    'B-Developer',
#    'I-Developer',
#    'I-Developer',
#    'I-Developer',
#    'B-Developer',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'entities': {'T1': {'label': 'Application_Usage:Purpose_Analysis',
#     'beg': 16,
#     'end': 19,
#     'string': 'ysi',
#     'idx': 0,
#     'new_beg': 12,
#     'new_end': 20},
#    'T2': {'label': 'Application_Usage:Purpose_Analysis',
#     'beg': 21,
#     'end': 24,
#     'string': 'was',
#     'idx': 1,
#     'new_beg': 21,
#     'new_end': 24},
#    'T3': {'label': 'Version',
#     'beg': 25,
#     'end': 28,
#     'string': 'per',
#     'idx': 2,
#     'new_beg': 25,
#     'new_end': 34},
#    'T4': {'label': 'Developer',
#     'beg': 30,
#     'end': 48,
#     'string': 'rmed using JMP (JM',
#     'idx': 3,
#     'new_beg': 47,
#     'new_end': 50}},
#   'relations': {'R1': {'label': 'Specification_of',
#     'arg1_old': 'T2',
#     'arg2_old': 'T1',
#     'arg1': 'was',
#     'arg2': 'ysi',
#     'pos1': 21,
#     'pos2': 12,
#     'ent1': 1,
#     'ent2': 0},
#    'R2': {'label': 'Version_of',
#     'arg1_old': 'T3',
#     'arg2_old': 'T2',
#     'arg1': 'per',
#     'arg2': 'was',
#     'pos1': 25,
#     'pos2': 21,
#     'ent1': 2,
#     'ent2': 1},
#    'R3': {'label': 'Developer_of',
#     'arg1_old': 'T4',
#     'arg2_old': 'T2',
#     'arg1': 'rmed using JMP (JM',
#     'arg2': 'was',
#     'pos1': 47,
#     'pos2': 21,
#     'ent1': 3,
#     'ent2': 1}}}]

# %%
from articlenizer.formatting import brat_to_bio

_bioPLos = {}

bio_lst = []

path = 'SoMeSci/PLoS_methodsClean/'

for fileName in PLOS_filesList[:]:
    
    # get file name without extension
    fName = fileName.split('.')[0]
    filePath = path+fName
    
    # open ann file 
    
    filePatha_nn = filePath+".ann"
    #print(filePatha_nn)
        
    with open(filePatha_nn, "r", encoding="utf8") as txt_f:
        ann_cont = txt_f.read()
        #print(fName)
           
    # open .txt file 
    
    filePatha_txt = filePath+".txt"
    #print(filePatha_txt)
       
    with open(filePatha_txt, "r", encoding="utf8") as txt_f:
        txt_cont = txt_f.read()
        #print(fName)
    
    output = brat_to_bio(txt_cont, ann_cont)
    
    _bioPLos[fName] = output
    
    bio_lst.append(output)

# %%
from articlenizer.formatting import brat_to_bio

_bioPub = {}


path = 'SoMeSci/Pubmed_fulltext_Clean/'

for fileName in Pubmed_filesList[:]:
    
    # get file name without extension
    fName = fileName.split('.')[0]
    filePath = path+fName
    
    # open ann file 
    
    filePatha_nn = filePath+".ann"
    #print(filePatha_nn)
        
    with open(filePatha_nn, "r", encoding="utf8") as txt_f:
        ann_cont = txt_f.read()
        #print(fName)
           
    # open .txt file 
    
    filePatha_txt = filePath+".txt"
    #print(filePatha_txt)
       
    with open(filePatha_txt, "r", encoding="utf8") as txt_f:
        txt_cont = txt_f.read()
        #print(fName)
    
    output = brat_to_bio(txt_cont, ann_cont)
    
    _bioPub[fName] = output
    bio_lst.append(output)

# %%
len(bio_lst)
# Out:
# 580

# %%
for file in bio_lst:
    #print(file)
    
    for snt_num in range(len(file)):
        print(snt_num, bio_lst[snt_num])
        break
    
    
    break

len(bio_lst[0])
# Out:
# 0 [{'string': 'We examined the cross-sectional relationship between mean population blood pressure, cholesterol, and body mass index (BMI) and three socioeconomic variables: national income, average share of household expenditure spent on food, and proportion of population in urban areas.', 'tokens': ['We', 'examined', 'the', 'cross', '-', 'sectional', 'relationship', 'between', 'mean', 'population', 'blood', 'pressure', ',', 'cholesterol', ',', 'and', 'body', 'mass', 'index', '(', 'BMI', ')', 'and', 'three', 'socioeconomic', 'variables', ':', 'national', 'income', ',', 'average', 'share', 'of', 'household', 'expenditure', 'spent', 'on', 'food', ',', 'and', 'proportion', 'of', 'population', 'in', 'urban', 'areas', '.'], 'names': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'labels': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'entities': {}, 'relations': {}}, {'string': 'Blood pressure, cholesterol, and BMI are well-established cardiovascular risk factors and provide aggregate indicators of more complex dietary patterns (e.g., caloric intake, and consumption of salt, fats of different composition, and fruits and vegetables) and physical activity.', 'tokens': ['Blood', 'pressure', ',', 'cholesterol', ',', 'and', 'BMI', 'are', 'well', '-', 'established', 'cardiovascular', 'risk', 'factors', 'and', 'provide', 'aggregate', 'indicators', 'of', 'more', 'complex', 'dietary', 'patterns', '(', 'e.g.', ',', 'caloric', 'intake', ',', 'and', 'consumption', 'of', 'salt', ',', 'fats', 'of', 'different', 'composition', ',', 'and', 'fruits', 'and', 'vegetables', ')', 'and', 'physical', 'activity', '.'], 'names': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'labels': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'entities': {}, 'relations': {}}, {'string': 'Further, there are more comparable data from population-based health and nutrition surveys on these physiological indicators than on dietary patterns and physical activity, because these indicators can be more easily defined in a consistent manner and measured using standard techniques.', 'tokens': ['Further', ',', 'there', 'are', 'more', 'comparable', 'data', 'from', 'population', '-', 'based', 'health', 'and', 'nutrition', 'surveys', 'on', 'these', 'physiological', 'indicators', 'than', 'on', 'dietary', 'patterns', 'and', 'physical', 'activity', ',', 'because', 'these', 'indicators', 'can', 'be', 'more', 'easily', 'defined', 'in', 'a', 'consistent', 'manner', 'and', 'measured', 'using', 'standard', 'techniques', '.'], 'names': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'labels': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'entities': {}, 'relations': {}}, {'string': "National income is the commonly used indicator for a society's material well-being.", 'tokens': ['National', 'income', 'is', 'the', 'commonly', 'used', 'indicator', 'for', 'a', 'society', "'", 's', 'mat ...
# 23

# %%
_bioPLos['PMC3055867'][36]
# Out:
# {'string': 'Both of the random choices were performed by a MATLAB program.',
#  'tokens': ['Both',
#   'of',
#   'the',
#   'random',
#   'choices',
#   'were',
#   'performed',
#   'by',
#   'a',
#   'MATLAB',
#   'program',
#   '.'],
#  'names': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'T1', 'O', 'O'],
#  'labels': ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ProgrammingEnvironment_Usage_Simulation',
#   'O',
#   'O'],
#  'entities': {'T1': {'label': 'ProgrammingEnvironment_Usage_Simulation',
#    'beg': 47,
#    'end': 53,
#    'string': 'MATLAB',
#    'idx': 0,
#    'new_beg': 47,
#    'new_end': 53}},
#  'relations': {}}

# %%
len(_bioPLos)
# Out:
# 480

# %%
len(_bioPub)
# Out:
# 100

# %%
with open("PMC3004789PP.ann", "r", encoding="utf8") as txt_f:

    ann_cont = txt_f.read()

    print(ann_cont)
    
with open("PMC3004789.txt", "r", encoding="utf8") as txt_f:
        
        txt_cont = txt_f.read()
        
        #print(txt_cont)
        

output = brat_to_bio(txt_cont, ann_cont)
# Out:
# T1	Application_Usage:Purpose_Analysis 4470 4473	JMP
# T2	Application_Usage:Purpose_Analysis 4475 4478	JMP
# R1	Specification_of Arg1:T2 Arg2:T1
# T3	Version 4479 4482	7.0
# R2	Version_of Arg1:T3 Arg2:T2
# T4	Developer 4484 4502	SAS Institute Inc.
# R3	Developer_of Arg1:T4 Arg2:T2
